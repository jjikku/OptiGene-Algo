# %% [markdown]
# <a href="https://colab.research.google.com/github/jjikku/OptiGene-Algo/blob/main/ICT_Group_2_ML_AI_Algo_Trading_data_aggregation_pre_processing_weekly_9_16_Sep_2021_test_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# Specify the exact path to the CSV file
file_path = "/content/drive/My Drive/NIfty_Dataset/09-16-SEP-2021-weekly-expiry_data__VEGE_NF_AND_BNF_Options.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Exclude rows where the ticker contains any of the following
excluded_tickers = [
    "BANKNIFTY", "FINNIFTY", "FUT", "NIFTYAUTO", "NIFTYENERGY",
    "NIFTYFINSERVICE", "NIFTYFMCG", "NIFTYINFRA", "NIFTYIT", "NIFTYMEDIA",
    "NIFTYMETAL", "NIFTYMIDCAP50", "NIFTYPHARMA", "NIFTYPSUBANK",
    "NIFTYREALTY", "USDINR-I"
]

# Create a regular expression pattern that matches any of the excluded tickers
pattern = '|'.join(excluded_tickers)

# Apply the mask to filter the DataFrame
mask = ~df['Ticker'].str.contains(pattern)
df_filtered = df[mask]

# Get unique values in the 'Ticker' column after filtering
unique_tickers = df_filtered['Ticker'].unique()

# Extract all rows that match the unique tickers
final_df = df[df['Ticker'].isin(unique_tickers)]

# Create a new CSV file with the extracted rows
output_file_path = "/content/drive/My Drive/NIfty_Dataset/weekly_filtered_tickers_data_9_16_Sep.csv"
final_df.to_csv(output_file_path, index=False)

print(f"Created new CSV file at: {output_file_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Created new CSV file at: /content/drive/My Drive/NIfty_Dataset/weekly_filtered_tickers_data_9_16_Sep.csv

# %%
# print(unique_tickers)

# %%
# final_df.count()

# %%
# final_df['Open Interest'].count()

# %%
# non_zero_count = final_df['Open Interest'].ne(0).sum()
# print(f"The count of non-zero 'Open Interest' values is: {non_zero_count}")

# %%
# Create a separate DataFrame for each unique ticker and store it in a dictionary
dfs = {ticker: df[df['Ticker'] == ticker] for ticker in unique_tickers}

# Now dfs is a dictionary with tickers as keys and the corresponding DataFrame as values

# Assuming df is your original DataFrame with all tickers
for ticker in unique_tickers:
    # Select the DataFrame for the current ticker
    ticker_df = df[df['Ticker'] == ticker].copy()  # Use copy to avoid SettingWithCopyWarning

    # Convert 'Date/Time' to datetime and set as index
    ticker_df['Date/Time'] = pd.to_datetime(ticker_df['Date/Time'], format='%d-%m-%Y %H:%M:%S')
    ticker_df.set_index('Date/Time', inplace=True)

    # Remove duplicate indices if any
    ticker_df = ticker_df[~ticker_df.index.duplicated(keep='first')]

    # Assign the processed DataFrame back to the dfs dictionary
    dfs[ticker] = ticker_df

# Now dfs is a dictionary where each value is a DataFrame with 'Date/Time' as a datetime index

# %%
# Iterate through the dfs dictionary
for ticker, dataframe in dfs.items():
    # Check if the ticker ends with 'PE' or 'CE'
    if ticker.endswith('PE') or ticker.endswith('CE'):
        # Forward fill any NaN values
        dataframe['Open Interest'] = dataframe['Open Interest'].fillna(method='ffill')

        # Replace zero values with the forward filled values
        dataframe['Open Interest'] = dataframe['Open Interest'].replace(to_replace=0, method='ffill')

        # Assign the processed DataFrame back to the dfs dictionary
        dfs[ticker] = dataframe

# %%
import numpy as np
# Get the DataFrame for NIFTY as the reference
reference_df = dfs['NIFTY'].copy()

# Get all timestamps from the NIFTY DataFrame
reference_timestamps = reference_df.index
print("REF",reference_timestamps)

# Function to insert missing timestamps into a DataFrame
def insert_missing_timestamps(df, reference_ts):
    # Ensure the DataFrame index is unique and sorted
    df = df[~df.index.duplicated(keep='first')].sort_index()

    # Find the missing timestamps
    missing_timestamps = reference_ts.difference(df.index)

    # Insert rows with NaNs for missing timestamps
    for ts in missing_timestamps:
        if ts not in df.index:
            df.loc[ts] = [np.nan] * len(df.columns)

    # Sort the DataFrame after inserting new rows
    df.sort_index(inplace=True)

    return df

# Iterate over each DataFrame in dfs
for ticker, dataframe in dfs.items():
    if ticker != 'NIFTY':  # Skip the NIFTY DataFrame as it is the reference
        # Insert missing timestamps without altering existing data
        print("TICKER",ticker)
        dfs[ticker] = insert_missing_timestamps(dataframe, reference_timestamps)
# Out:
# REF DatetimeIndex(['2021-09-03 09:15:00', '2021-09-03 09:16:00',
#                '2021-09-03 09:17:00', '2021-09-03 09:18:00',
#                '2021-09-03 09:19:00', '2021-09-03 09:20:00',
#                '2021-09-03 09:21:00', '2021-09-03 09:22:00',
#                '2021-09-03 09:23:00', '2021-09-03 09:24:00',
#                ...
#                '2021-09-16 15:21:00', '2021-09-16 15:22:00',
#                '2021-09-16 15:23:00', '2021-09-16 15:24:00',
#                '2021-09-16 15:25:00', '2021-09-16 15:26:00',
#                '2021-09-16 15:27:00', '2021-09-16 15:28:00',
#                '2021-09-16 15:29:00', '2021-09-16 15:30:00'],
#               dtype='datetime64[ns]', name='Date/Time', length=3384, freq=None)
# TICKER INDIAVIX
# TICKER NIFTYWK16000CE
# TICKER NIFTYWK16000PE
# TICKER NIFTYWK16050CE
# TICKER NIFTYWK16050PE
# TICKER NIFTYWK16100CE
# TICKER NIFTYWK16100PE
# TICKER NIFTYWK16150CE
# TICKER NIFTYWK16150PE
# TICKER NIFTYWK16200CE
# TICKER NIFTYWK16200PE
# TICKER NIFTYWK16250CE
# TICKER NIFTYWK16250PE
# TICKER NIFTYWK16300CE
# TICKER NIFTYWK16300PE
# TICKER NIFTYWK16350CE
# TICKER NIFTYWK16350PE
# TICKER NIFTYWK16400CE
# TICKER NIFTYWK16400PE
# TICKER NIFTYWK16450CE
# TICKER NIFTYWK16450PE
# TICKER NIFTYWK16500CE
# TICKER NIFTYWK16500PE
# TICKER NIFTYWK16550CE
# TICKER NIFTYWK16550PE
# TICKER NIFTYWK16600CE
# TICKER NIFTYWK16600PE
# TICKER NIFTYWK16650CE
# TICKER NIFTYWK16650PE
# TICKER NIFTYWK16700CE
# TICKER NIFTYWK16700PE
# TICKER NIFTYWK16750CE
# TICKER NIFTYWK16750PE
# TICKER NIFTYWK16800CE
# TICKER NIFTYWK16800PE
# TICKER NIFTYWK16850CE
# TICKER NIFTYWK16850PE
# TICKER NIFTYWK16900CE
# TICKER NIFTYWK16900PE
# TICKER NIFTYWK16950CE
# TICKER NIFTYWK16950PE
# TICKER NIFTYWK17000CE
# TICKER NIFTYWK17000PE
# TICKER NIFTYWK17050CE
# TICKER NIFTYWK17050PE
# TICKER NIFTYWK17100CE
# TICKER NIFTYWK17100PE
# TICKER NIFTYWK17150CE
# TICKER NIFTYWK17150PE
# TICKER NIFTYWK17200CE
# TICKER NIFTYWK17200PE
# TICKER NIFTYWK17250CE
# TICKER NIFTYWK17250PE
# TICKER NIFTYWK17300CE
# TICKER NIFTYWK17300PE
# TICKER NIFTYWK17350CE
# TICKER NIFTYWK17350PE
# TICKER NIFTYWK17400CE
# TICKER NIFTYWK17400PE
# TICKER NIFTYWK17450CE
# TICKER NIFTYWK17450PE
# TICKER NIFTYWK17500CE
# TICKER NIFTYWK17500PE
# TICKER NIFTYWK17550CE
# TICKER NIFTYWK17550PE
# TICKER NIFTYWK17600CE
# TICKER NIFTYWK17600PE
# TICKER NIFTYWK17650CE
# TICKER NIFTYWK17650PE
# TICKER NIFTYWK17700CE
# TICKER NIFTYWK17700PE
# TICKER NIFTYWK17750CE
# TICKER NIFTYWK17750PE
# TICKER NIFTYWK17800CE
# TICKER NIFTYWK17800PE
# TICKER NIFTYWK17850CE
# TICKER NIFTYWK17850PE
# TICKER NIFTYWK17900CE
# TICKER NIFTYWK17900PE
# TICKER NIFTYWK17950CE
# TICKER NIFTYWK17950PE
# TICKER NIFTYWK18000CE
# TICKER NIFTYWK18000PE

# %%
# # Define trading hours
# trading_hours = pd.date_range(start='09:15:00', end='15:30:00', freq='1min')

# # Get the DataFrame for NIFTY as the reference
# reference_df = dfs['NIFTY'].copy()

# # Generate a full range of timestamps for all trading days in the reference NIFTY DataFrame
# all_trading_days = reference_df.index.normalize().unique()
# all_possible_timestamps = pd.DatetimeIndex([pd.Timestamp(day) + pd.Timedelta(minutes=m.minute + m.hour * 60)
#                                             for day in all_trading_days for m in trading_hours])

# # Now update all DataFrames in dfs to have the same timestamps as the reference NIFTY DataFrame
# for ticker, dataframe in dfs.items():
#     # Reindex to the full range of possible timestamps, forward filling the missing data
#     dataframe = dataframe.reindex(all_possible_timestamps, method='ffill')

#     # Forward fill the Open Interest, if the ticker ends with 'PE' or 'CE'
#     if ticker.endswith(('PE', 'CE')):
#         dataframe['Open Interest'].fillna(method='ffill', inplace=True)
#         dataframe['Open Interest'].replace(to_replace=0, method='ffill', inplace=True)

#     # Update the dictionary with the modified DataFrame
#     dfs[ticker] = dataframe

# # After this loop, each DataFrame in dfs should have no missing timestamps and the 'Open Interest' column should be forward filled.

# %%
# Define the market open and close times
market_open_time = '09:15:00'
market_close_time = '15:30:00'

# Create a new dictionary to store the filled DataFrames
filled_dfs = {}

for ticker, dataframe in dfs.items():
    # Copy the DataFrame to avoid modifying the original
    df_filled = dataframe.copy()

    # Get unique trading days
    trading_days = df_filled.index.normalize().unique()

    # Forward fill for each day
    for day in trading_days:
        # Select the data for the current trading day
        day_data = df_filled[df_filled.index.date == day.date()]

        # Forward fill the data for the current day
        df_filled.loc[day_data.index] = day_data.fillna(method='ffill')

    # Now, backward fill the entire DataFrame to cover the start of the day
    df_filled = df_filled.fillna(method='bfill')

    # Assign the filled DataFrame to the new dictionary
    filled_dfs[ticker] = df_filled

# %%
# Assuming filled_dfs is your dictionary containing DataFrames with filled values
for ticker in unique_tickers:
    # Select the DataFrame for the current ticker
    ticker_df = filled_dfs[ticker].copy()  # Use copy to avoid SettingWithCopyWarning

    # Since filled_dfs already contains the DataFrames with 'Date/Time' as a datetime index,
    #  do not need to convert 'Date/Time' again, and  can use ticker_df directly if needed

    # Remove duplicate indices if any (if this step is still necessary)
    ticker_df = ticker_df[~ticker_df.index.duplicated(keep='first')]


    # Assign the processed DataFrame back to the dfs dictionary
    dfs[ticker] = ticker_df

# Now dfs is a dictionary where each value is a DataFrame with 'Date/Time' as a datetime index

# %%
print(dfs['NIFTY'])
# Out:
#                     Ticker     Open     High      Low    Close  Volume  \
# Date/Time
# 2021-09-03 09:15:00  NIFTY  17262.5  17296.8  17255.3  17293.3       0
# 2021-09-03 09:16:00  NIFTY  17292.3  17300.3  17289.0  17289.0       0
# 2021-09-03 09:17:00  NIFTY  17288.9  17298.2  17282.0  17297.3       0
# 2021-09-03 09:18:00  NIFTY  17298.8  17312.0  17296.5  17302.3       0
# 2021-09-03 09:19:00  NIFTY  17302.3  17306.7  17301.2  17306.1       0
# ...                    ...      ...      ...      ...      ...     ...
# 2021-09-16 15:26:00  NIFTY  17632.3  17635.4  17631.3  17633.0       0
# 2021-09-16 15:27:00  NIFTY  17635.3  17635.4  17630.3  17631.8       0
# 2021-09-16 15:28:00  NIFTY  17629.5  17630.7  17626.3  17630.2       0
# 2021-09-16 15:29:00  NIFTY  17630.6  17630.6  17624.5  17627.5       0
# 2021-09-16 15:30:00  NIFTY  17626.5  17626.5  17626.5  17626.5       0
#
#                      Open Interest
# Date/Time
# 2021-09-03 09:15:00              0
# 2021-09-03 09:16:00              0
# 2021-09-03 09:17:00              0
# 2021-09-03 09:18:00              0
# 2021-09-03 09:19:00              0
# ...                            ...
# 2021-09-16 15:26:00              0
# 2021-09-16 15:27:00              0
# 2021-09-16 15:28:00              0
# 2021-09-16 15:29:00              0
# 2021-09-16 15:30:00              0
#
# [3384 rows x 7 columns]

# %%
# Assuming dfs['NIFTY'] is the DataFrame you want to save
nifty_df = dfs['NIFTY']

# Specify the path in your Google Drive where you want to save the CSV
csv_file_path = '/content/drive/My Drive/NIfty_Dataset/NIFTY_9_16_Sep_2021.csv'

# Save the DataFrame to CSV
nifty_df.to_csv(csv_file_path, index=True)

print(f"DataFrame saved to {csv_file_path}")
# Out:
# DataFrame saved to /content/drive/My Drive/NIfty_Dataset/NIFTY_9_16_Sep_2021.csv

# %%
# Assuming dfs['NIFTY'] is the DataFrame you want to save
indiavix_df = dfs['INDIAVIX']

# Specify the path in your Google Drive where you want to save the CSV
csv_file_path = '/content/drive/My Drive/NIfty_Dataset/INDIAVIX_9_16_Sep_2021.csv'

# Save the DataFrame to CSV
indiavix_df.to_csv(csv_file_path, index=True)

print(f"DataFrame saved to {csv_file_path}")
# Out:
# DataFrame saved to /content/drive/My Drive/NIfty_Dataset/INDIAVIX_9_16_Sep_2021.csv

# %%
# !pip install mibian
# Out:
# Requirement already satisfied: mibian in /usr/local/lib/python3.10/dist-packages (0.1.3)

# %%
indiavix_df = pd.read_csv('/content/drive/My Drive/NIfty_Dataset/INDIAVIX_9_16_Sep_2021.csv')
# Print the columns to check the exact name of the 'Date/Time' column
print(indiavix_df.columns)
# Out:
# Index(['Date/Time', 'Ticker', 'Open', 'High', 'Low', 'Close', 'Volume',
#        'Open Interest'],
#       dtype='object')

# %%
print(indiavix_df.index)
# Out:
# RangeIndex(start=0, stop=3384, step=1)

# %%
# !pip install datetime
# Out:
# Requirement already satisfied: datetime in /usr/local/lib/python3.10/dist-packages (5.3)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.10/dist-packages (from datetime) (6.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from datetime) (2023.3.post1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from zope.interface->datetime) (67.7.2)

# %%
import pandas as pd
import numpy as np
import mibian
from datetime import time, datetime, timedelta


indiavix_df = pd.read_csv('/content/drive/My Drive/NIfty_Dataset/INDIAVIX_9_16_Sep_2021.csv', index_col='Date/Time', parse_dates=['Date/Time'])
indiavix_df.rename(columns={'Close': 'INDIAVIX'}, inplace=True)

# Load the NIFTY data
nifty_df = pd.read_csv('/content/drive/My Drive/NIfty_Dataset/NIFTY_9_16_Sep_2021.csv', index_col='Date/Time', parse_dates=['Date/Time'])

# Join INDIAVIX data with NIFTY data
nifty_df = nifty_df.join(indiavix_df['INDIAVIX'], how='left')
nifty_df['INDIAVIX'].fillna(method='ffill', inplace=True)  # Fill NaN values with the forward fill method


# Check if the 'INDIAVIX' column exists after the join operation
if 'INDIAVIX' not in nifty_df.columns:
    raise KeyError('The INDIAVIX column was not found after the join operation. Please check the column names and join operation.')

print("NIFTYDF",nifty_df)
print("columns",nifty_df.columns)

# Constants
interest_rate = 3.32  # 3-month Indian government bond yield as annual percentage
days_in_year = 365  # Days in a year for the Greeks' calculations
strike_step = 50  # Known step between strike prices
minutes_in_a_year = 365 * 24 * 60  # Total minutes in a year
market_close_time = time(15, 30)



def calculate_minutes_to_expiry(current_timestamp, expiry_date, market_close_time):
    # Ensure market_close_time is a datetime.time object
    if isinstance(market_close_time, pd.Timestamp):
        market_close_time = market_close_time.time()

    closing_time = datetime.combine(expiry_date, market_close_time)

    # If the current timestamp is on the expiry date
    if current_timestamp.date() == expiry_date.date():
        # Calculate the remaining time until market close
        return max(int((closing_time - current_timestamp).total_seconds() / 60), 0)
    else:
        # Calculate time from the current timestamp to the end of day
        end_of_day = datetime.combine(current_timestamp.date(), time(23, 59))  # Last minute of the current day
        minutes_today = int((end_of_day - current_timestamp).total_seconds() / 60) + 1  # Plus one for the last minute

        # Calculate full days until the expiry date
        full_days = (expiry_date.date() - current_timestamp.date()).days - 1  # Minus one because we already counted today

        # Calculate minutes from the start of the expiry day to the market close
        start_of_expiry_day = datetime.combine(expiry_date.date(), time(0, 0))  # Midnight of the expiry day
        minutes_expiry_day = int((closing_time - start_of_expiry_day).total_seconds() / 60)

        # Total minutes is the sum of all parts
        return minutes_today + (full_days * 24 * 60) + minutes_expiry_day


# Function to calculate the Greeks using the Black-Scholes model
def calculate_greeks(underlying_price, strike_price, minutes_to_expiry, volatility, interest_rate, option_type):
    # Convert minutes to expiry into years for the Black-Scholes model
    time_to_expiry_in_years = minutes_to_expiry / minutes_in_a_year

    # Ensure we do not have a division by zero or negative time to expiry
    if time_to_expiry_in_years <= 0:
        return {greek: 0 for greek in ['Delta', 'Gamma', 'Theta', 'Vega', 'Rho']}

    # Convert annual interest rate and volatility from percentages to decimals
    annual_interest_rate = interest_rate / 100
    annual_volatility = volatility / 100

    # Black-Scholes model calculations
    bs = mibian.BS([underlying_price, strike_price, annual_interest_rate * 100, time_to_expiry_in_years * 365], volatility=annual_volatility * 100)

    # Return a dictionary of Greeks
    return {
        'Delta': bs.callDelta if option_type == 'call' else bs.putDelta,
        'Gamma': bs.gamma,
        'Theta': bs.callTheta / 365 if option_type == 'call' else bs.putTheta / 365,
        'Vega': bs.vega / 100,  # per 1% change in IV
        'Rho': bs.callRho / 100 if option_type == 'call' else bs.putRho / 100  # per 1% change in interest rate
    }


# Function to populate the DataFrame with strikes and Greeks
def populate_greeks(nifty_df, indiavix_df, strike_step, dfs):

    expiry_date = nifty_df.index.max().normalize() + pd.Timedelta(hours=15, minutes=30)
    print("EXPIRY DAY", expiry_date)
    market_close_time = expiry_date #pd.to_datetime(expiry_date.strftime('%Y-%m-%d') + ' 15:30:00')  # Assuming 3:30 PM market close

    # Create columns for Greeks in the dataframe
    for strike_type in ['ATM', 'ITM1', 'OTM1', 'ITM2', 'OTM2', 'ITM3', 'OTM3', 'ITM4', 'OTM4', 'ITM5', 'OTM5']:
        for greek in ['Delta', 'Gamma', 'Theta', 'Vega', 'Rho']:
            nifty_df[f'{strike_type}_{greek}'] = np.nan
            nifty_df[f'{strike_type}_OI'] = np.nan
            nifty_df[f'{strike_type}_Call_Volume'] = np.nan
            nifty_df[f'{strike_type}_Put_Volume'] = np.nan

    nifty_df['PCR'] = np.nan

    # Iterate over the dataframe and calculate Greeks
    for timestamp, row in nifty_df.iterrows():
        total_call_oi = 0
        total_put_oi = 0
        nifty_close = row['Close']
        # Find ATM, ITM, and OTM strikes
        atm_strike = int(round(nifty_close / strike_step) * strike_step)  # Closest strike
        itm_strikes = [atm_strike - i * strike_step for i in range(1, 6)]
        otm_strikes = [atm_strike + i * strike_step for i in range(1, 6)]
        all_strikes = [atm_strike] + itm_strikes + otm_strikes

        print(f"Processing timestamp: {timestamp}")

        # Get VIX value for the timestamp
        vix_value = indiavix_df.loc[timestamp, 'INDIAVIX'] if timestamp in indiavix_df.index else np.nan
        if vix_value is None:
            print(f"VIX value is missing for timestamp: {timestamp}")
            continue  # Skip this iteration if VIX value is missing


        minutes_to_expiry = calculate_minutes_to_expiry(timestamp, expiry_date, market_close_time)
        print("Current time & days to expiry:", timestamp.date(), minutes_to_expiry / (60 * 24))

        print("Curr time & days to EXpiry", timestamp.date(),minutes_to_expiry/(60*24))
        # Calculate Greeks for all strikes
        for i, strike in enumerate(all_strikes, start=1):
            if i == 1:  # ATM
                strike_type = 'ATM'
            elif i <= 6:  # ITM strikes
                strike_type = f'ITM{i-1}'
            else:  # OTM strikes
                strike_type = f'OTM{i-6}'

            call_key = f'NIFTYWK{strike}CE'
            put_key = f'NIFTYWK{strike}PE'

            call_volume = dfs[call_key].loc[timestamp, 'Volume'] if timestamp in dfs[call_key].index else np.nan
            put_volume = dfs[put_key].loc[timestamp, 'Volume'] if timestamp in dfs[put_key].index else np.nan

            # Populate volume data
            nifty_df.at[timestamp, f'{strike_type}_Call_Volume'] = call_volume
            nifty_df.at[timestamp, f'{strike_type}_Put_Volume'] = put_volume

            # print(f"Retrieving data for strike {strike} ({call_key} and {put_key})")

             # Check if the keys are present in the dfs dictionary
            if call_key not in dfs or put_key not in dfs:
                print(f"Missing data for strike {strike}: {call_key} or {put_key} not in dfs")
                continue

            # Check if the timestamp exists in the dfs DataFrames
            if timestamp not in dfs[call_key].index:
                print(f"Timestamp {timestamp} not found in dfs for {call_key}")
                continue
            if timestamp not in dfs[put_key].index:
                print(f"Timestamp {timestamp} not found in dfs for {put_key}")
                continue

            call_close = dfs[call_key].loc[timestamp, 'Close'] if timestamp in dfs[call_key].index else np.nan
            put_close = dfs[put_key].loc[timestamp, 'Close'] if timestamp in dfs[put_key].index else np.nan
            call_oi = dfs[call_key].loc[timestamp, 'Open Interest'] if timestamp in dfs[call_key].index else np.nan
            put_oi = dfs[put_key].loc[timestamp, 'Open Interest'] if timestamp in dfs[put_key].index else np.nan
            # print(f"Call Close: {call_close}, Put Close: {put_close}, Call OI: {call_oi}, Put OI: {put_oi}")

            #print("STRIKE",nifty_close, strike)
            # Calculate Greeks using the close prices
            if not np.isnan(call_close):
                greeks = calculate_greeks(nifty_close, strike, minutes_to_expiry, call_close, interest_rate, option_type='call')
                # Populate Greeks for call
                for greek_name, greek_value in greeks.items():
                    nifty_df.at[timestamp, f'{strike_type}_{greek_name}'] = greek_value
                    nifty_df.at[timestamp, f'{strike_type}_OI'] = call_oi  # Populate OI for call

            if not np.isnan(put_close):
                greeks = calculate_greeks(nifty_close, strike, minutes_to_expiry, put_close, interest_rate, option_type='put')
                # Populate Greeks for put
                for greek_name, greek_value in greeks.items():
                    nifty_df.at[timestamp, f'{strike_type}_PE_{greek_name}'] = greek_value
                    nifty_df.at[timestamp, f'{strike_type}_PE_OI'] = put_oi  # Populate OI for put

    return nifty_df

# Populate the DataFrame with Greeks
nifty_with_greeks = populate_greeks(nifty_df, indiavix_df, strike_step, dfs)

def calculate_pcr(row):
    total_call_oi = sum(row.get(f'{strike}_OI', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    total_put_oi = sum(row.get(f'{strike}_PE_OI', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    print("OI", total_call_oi, total_put_oi)
    return total_put_oi / total_call_oi if total_call_oi != 0 else np.nan

# Function to calculate PCR for volume
def calculate_pcr_volume(row):
    total_call_volume = sum(row.get(f'{strike}_Call_Volume', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    total_put_volume = sum(row.get(f'{strike}_Put_Volume', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    return total_put_volume / total_call_volume if total_call_volume != 0 else np.nan

# Apply PCR calculation to each row
nifty_with_greeks['PCR'] = nifty_with_greeks.apply(calculate_pcr, axis=1)
print(nifty_with_greeks.head())
# Apply PCR calculation for volume to each row
nifty_with_greeks['PCR_Volume'] = nifty_with_greeks.apply(calculate_pcr_volume, axis=1)
# # Output the DataFrame to a CSV
nifty_with_greeks.to_csv('/content/drive/My Drive/NIfty_Dataset/NIFTY_with_Greeks_9_16_Sep_2021.csv')

print("Greeks and Open Interest data have been populated and the DataFrame has been saved to CSV.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Current time & days to expiry: 2021-09-15 1.1027777777777779
# Curr time & days to EXpiry 2021-09-15 1.1027777777777779
# Processing timestamp: 2021-09-15 13:03:00
# Current time & days to expiry: 2021-09-15 1.1020833333333333
# Curr time & days to EXpiry 2021-09-15 1.1020833333333333
# Processing timestamp: 2021-09-15 13:04:00
# Current time & days to expiry: 2021-09-15 1.101388888888889
# Curr time & days to EXpiry 2021-09-15 1.101388888888889
# Processing timestamp: 2021-09-15 13:05:00
# Current time & days to expiry: 2021-09-15 1.1006944444444444
# Curr time & days to EXpiry 2021-09-15 1.1006944444444444
# Processing timestamp: 2021-09-15 13:06:00
# Current time & days to expiry: 2021-09-15 1.1
# Curr time & days to EXpiry 2021-09-15 1.1
# Processing timestamp: 2021-09-15 13:07:00
# Current time & days to expiry: 2021-09-15 1.0993055555555555
# Curr time & days to EXpiry 2021-09-15 1.0993055555555555
# Processing timestamp: 2021-09-15 13:08:00
# Current time & days to expiry: 2021-09-15 1.0986111111111112
# Curr time & days to EXpiry 2021-09-15 1.0986111111111112
# Processing timestamp: 2021-09-15 13:09:00
# Current time & days to expiry: 2021-09-15 1.0979166666666667
# Curr time & days to EXpiry 2021-09-15 1.0979166666666667
# Processing timestamp: 2021-09-15 13:10:00
# Current time & days to expiry: 2021-09-15 1.0972222222222223
# Curr time & days to EXpiry 2021-09-15 1.0972222222222223
# Processing timestamp: 2021-09-15 13:11:00
# Current time & days to expiry: 2021-09-15 1.0965277777777778
# Curr time & days to EXpiry 2021-09-15 1.0965277777777778
# Processing timestamp: 2021-09-15 13:12:00
# Current time & days to expiry: 2021-09-15 1.0958333333333334
# Curr time & days to EXpiry 2021-09-15 1.0958333333333334
# Processing timestamp: 2021-09-15 13:13:00
# Current time & days to expiry: 2021-09-15 1.0951388888888889
# Curr time & days to EXpiry 2021-09-15 1.0951388888888889
# Processing timestamp: 2021-09-15 13:14:00
# Current time & days to expiry: 2021-09-15 1.0944444444444446
# Curr time & days to EXpiry 2021-09-15 1.0944444444444446
# Processing timestamp: 2021-09-15 13:15:00
# Current time & days to expiry: 2021-09-15 1.09375
# Curr time & days to EXpiry 2021-09-15 1.09375
# Processing timestamp: 2021-09-15 13:16:00
# Current time & days to expiry: 2021-09-15 1.0930555555555554
# Curr time & days to EXpiry 2021-09-15 1.0930555555555554
# Processing timestamp: 2021-09-15 13:17:00
# Current time & days to expiry: 2021-09-15 1.0923611111111111
# Curr time & days to EXpiry 2021-09-15 1.0923611111111111
# Processing timestamp: 2021-09-15 13:18:00
# Current time & days to expiry: 2021-09-15 1.0916666666666666
# Curr time & days to EXpiry 2021-09-15 1.0916666666666666
# Processing timestamp: 2021-09-15 13:19:00
# Current time & days to expiry: 2021-09-15 1.0909722222222222
# Curr time & days to EXpiry 2021-09-15 1.0909722222222222
# Processing timestamp: 2021-09-15 13:20:00
# Current time & days to expiry: 2021-09-15 1.0902777777777777
# Curr time & days to EXpiry 2021-09-15 1.0902777777777777
# Processing timestamp: 2021-09-15 13:21:00
# Current time & days to expiry: 2021-09-15 1.0895833333333333
# Curr time & days to EXpiry 2021-09-15 1.0895833333333333
# Processing timestamp: 2021-09-15 13:22:00
# Current time & days to expiry: 2021-09-15 1.0888888888888888
# Curr time & days to EXpiry 2021-09-15 1.0888888888888888
# Processing timestamp: 2021-09-15 13:23:00
# Current time & days to expiry: 2021-09-15 1.0881944444444445
# Curr time & days to EXpiry 2021-09-15 1.0881944444444445
# Processing timestamp: 2021-09-15 13:24:00
# Current time & days to expiry: 2021-09-15 1.0875
# Curr time & days to EXpiry 2021-09-15 1.0875
# Processing timestamp: 2021-09-15 13:25:00
# Current time & days to expiry: 2021-09-15 1.0868055555555556
# Curr time & days to EXpiry 2021-09-15 1.0868055555555556
# Processing timestamp: 2021-09-15 13:26:00
# Current time & days to expiry: 2021-09-15 1.086111111111111
# Curr time & days to EXpiry 2021-09-15 1.086111111111111
# Processing timestamp: 2021-09-15 13:27:00
# Current time & days to expiry: 2021-09-15 1.0854166666666667
# Curr time & days to EXpiry 2021-09-15 1.0854166666666667
# Processing timestamp: 2021-09-15 13:28:00
# Current time & days to expiry: 2021-09-15 1.0847222222222221
# Curr time & days to EXpiry 2021-09-15 1.0847222222222221
# Processing timestamp: 2021-09-15 13:29:00
# Current time & days to expiry: 2021-09-15 1.0840277777777778
# Curr time & days to EXpiry 2021-09-15 1.0840277777777778
# Processing timestamp: 2021-09-15 13:30:00
# Current time & days to expiry: 2021-09-15 1.0833333333333333
# Curr time & days to EXpiry 2021-09-15 1.0833333333333333
# Processing timestamp: 2021-09-15 13:31:00
# Current time & days to expiry: 2021-09-15 1.082638888888889
# Curr time & days to EXpiry 2021-09-15 1.082638888888889
# Processing timestamp: 2021-09-15 13:32:00
# Current time & days to expiry: 2021-09-15 1.0819444444444444
# Curr time & days to EXpiry 2021-09-15 1.0819444444444444
# Processing timestamp: 2021-09-15 13:33:00
# Current time & days to expiry: 2021-09-15 1.08125
# Curr time & days to EXpiry 2021-09-15 1.08125
# Processing timestamp: 2021-09-15 13:34:00
# Current time & days to expiry: 2021-09-15 1.0805555555555555
# Curr time & days to EXpiry 2021-09-15 1.0805555555555555
# Processing timestamp: 2021-09-15 13:35:00
# Current time & days to expiry: 2021-09-15 1.0798611111111112
# Curr time & days to EXpiry 2021-09-15 1.0798611111111112
# Processing timestamp: 2021-09-15 13:36:00
# Current time & days to expiry: 2021-09-15 1.0791666666666666
# Curr time & days to EXpiry 2021-09-15 1.0791666666666666
# Processing timestamp: 2021-09-15 13:37:00
# Current time & days to expiry: 2021-09-15 1.0784722222222223
# Curr time & days to EXpiry 2021-09-15 1.0784722222222223
# Processing timestamp: 2021-09-15 13:38:00
# Current time & days to expiry: 2021-09-15 1.0777777777777777
# Curr time & days to EXpiry 2021-09-15 1.0777777777777777
# Processing timestamp: 2021-09-15 13:39:00
# Current time & days to expiry: 2021-09-15 1.0770833333333334
# Curr time & days to EXpiry 2021-09-15 1.0770833333333334
# Processing timestamp: 2021-09-15 13:40:00
# Current time & days to expiry: 2021-09-15 1.0763888888888888
# Curr time & days to EXpiry 2021-09-15 1.0763888888888888
# Processing timestamp: 2021-09-15 13:41:00
# Current time & days to expiry: 2021-09-15 1.0756944444444445
# Curr time & days to EXpiry 2021-09-15 1.0756944444444445
# Processing timestamp: 2021-09-15 13:42:00
# Current time & days to expiry: 2021-09-15 1.075
# Curr time & days to EXpiry 2021-09-15 1.075
# Processing timestamp: 2021-09-15 13:43:00
# Current time & days to expiry: 2021-09-15 1.0743055555555556
# Curr time & days to EXpiry 2021-09-15 1.0743055555555556
# Processing timestamp: 2021-09-15 13:44:00
# Current time & days to expiry: 2021-09-15 1.073611111111111
# Curr time & days to EXpiry 2021-09-15 1.073611111111111
# Processing timestamp: 2021-09-15 13:45:00
# Current time & days to expiry: 2021-09-15 1.0729166666666667
# Curr time & days to EXpiry 2021-09-15 1.0729166666666667
# Processing timestamp: 2021-09-15 13:46:00
# Current time & days to expiry: 2021-09-15 1.0722222222222222
# Curr time & days to EXpiry 2021-09-15 1.0722222222222222
# Processing timestamp: 2021-09-15 13:47:00
# Current time & days to expiry: 2021-09-15 1.0715277777777779
# Curr time & days to EXpiry 2021-09-15 1.0715277777777779
# Processing timestamp: 2021-09-15 13:48:00
# Current time & days to expiry: 2021-09-15 1.0708333333333333
# Curr time & days to EXpiry 2021-09-15 1.0708333333333333
# Processing timestamp: 2021-09-15 13:49:00
# Current time & days to expiry: 2021-09-15 1.070138888888889
# Curr time & days to EXpiry 2021-09-15 1.070138888888889
# Processing timestamp: 2021-09-15 13:50:00
# Current time & days to expiry: 2021-09-15 1.0694444444444444
# Curr time & days to EXpiry 2021-09-15 1.0694444444444444
# Processing timestamp: 2021-09-15 13:51:00
# Current time & days to expiry: 2021-09-15 1.06875
# Curr time & days to EXpiry 2021-09-15 1.06875
# Processing timestamp: 2021-09-15 13:52:00
# Current time & days to expiry: 2021-09-15 1.0680555555555555
# Curr time & days to EXpiry 2021-09-15 1.0680555555555555
# Processing timestamp: 2021-09-15 13:53:00
# Current time & days to expiry: 2021-09-15 1.0673611111111112
# Curr time & days to EXpiry 2021-09-15 1.0673611111111112
# Processing timestamp: 2021-09-15 13:54:00
# Current time & days to expiry: 2021-09-15 1.0666666666666667
# Curr time & days to EXpiry 2021-09-15 1.0666666666666667
# Processing timestamp: 2021-09-15 13:55:00
# Current time & days to expiry: 2021-09-15 1.0659722222222223
# Curr time & days to EXpiry 2021-09-15 1.0659722222222223
# Processing timestamp: 2021-09-15 13:56:00
# Current time & days to expiry: 2021-09-15 1.0652777777777778
# Curr time & days to EXpiry 2021-09-15 1.0652777777777778
# Processing timestamp: 2021-09-15 13:57:00
# Current time & days to expiry: 2021-09-15 1.0645833333333334
# Curr time & days to EXpiry 2021-09-15 1.0645833333333334
# Processing timestamp: 2021-09-15 13:58:00
# Current time & days to expiry: 2021-09-15 1.0638888888888889
# Curr time & days to EXpiry 2021-09-15 1.0638888888888889
# Processing timestamp: 2021-09-15 13:59:00
# Current time & days to expiry: 2021-09-15 1.0631944444444446
# Curr time & days to EXpiry 2021-09-15 1.0631944444444446
# Processing timestamp: 2021-09-15 14:00:00
# Current time & days to expiry: 2021-09-15 1.0625
# Curr time & days to EXpiry 2021-09-15 1.0625
# Processing timestamp: 2021-09-15 14:01:00
# Current time & days to expiry: 2021-09-15 1.0618055555555554
# Curr time & days to EXpiry 2021-09-15 1.0618055555555554
# Processing timestamp: 2021-09-15 14:02:00
# Current time & days to expiry: 2021-09-15 1.0611111111111111
# Curr time & days to EXpiry 2021-09-15 1.0611111111111111
# Processing timestamp: 2021-09-15 14:03:00
# Current time & days to expiry: 2021-09-15 1.0604166666666666
# Curr time & days to EXpiry 2021-09-15 1.0604166666666666
# Processing timestamp: 2021-09-15 14:04:00
# Current time & days to expiry: 2021-09-15 1.0597222222222222
# Curr time & days to EXpiry 2021-09-15 1.0597222222222222
# Processing timestamp: 2021-09-15 14:05:00
# Current time & days to expiry: 2021-09-15 1.0590277777777777
# Curr time & days to EXpiry 2021-09-15 1.0590277777777777
# Processing timestamp: 2021-09-15 14:06:00
# Current time & days to expiry: 2021-09-15 1.0583333333333333
# Curr time & days to EXpiry 2021-09-15 1.0583333333333333
# Processing timestamp: 2021-09-15 14:07:00
# Current time & days to expiry: 2021-09-15 1.0576388888888888
# Curr time & days to EXpiry 2021-09-15 1.0576388888888888
# Processing timestamp: 2021-09-15 14:08:00
# Current time & days to expiry: 2021-09-15 1.0569444444444445
# Curr time & days to EXpiry 2021-09-15 1.0569444444444445
# Processing timestamp: 2021-09-15 14:09:00
# Current time & days to expiry: 2021-09-15 1.05625
# Curr time & days to EXpiry 2021-09-15 1.05625
# Processing timestamp: 2021-09-15 14:10:00
# Current time & days to expiry: 2021-09-15 1.0555555555555556
# Curr time & days to EXpiry 2021-09-15 1.0555555555555556
# Processing timestamp: 2021-09-15 14:11:00
# Current time & days to expiry: 2021-09-15 1.054861111111111
# Curr time & days to EXpiry 2021-09-15 1.054861111111111
# Processing timestamp: 2021-09-15 14:12:00
# Current time & days to expiry: 2021-09-15 1.0541666666666667
# Curr time & days to EXpiry 2021-09-15 1.0541666666666667
# Processing timestamp: 2021-09-15 14:13:00
# Current time & days to expiry: 2021-09-15 1.0534722222222221
# Curr time & days to EXpiry 2021-09-15 1.0534722222222221
# Processing timestamp: 2021-09-15 14:14:00
# Current time & days to expiry: 2021-09-15 1.0527777777777778
# Curr time & days to EXpiry 2021-09-15 1.0527777777777778
# Processing timestamp: 2021-09-15 14:15:00
# Current time & days to expiry: 2021-09-15 1.0520833333333333
# Curr time & days to EXpiry 2021-09-15 1.0520833333333333
# Processing timestamp: 2021-09-15 14:16:00
# Current time & days to expiry: 2021-09-15 1.051388888888889
# Curr time & days to EXpiry 2021-09-15 1.051388888888889
# Processing timestamp: 2021-09-15 14:17:00
# Current time & days to expiry: 2021-09-15 1.0506944444444444
# Curr time & days to EXpiry 2021-09-15 1.0506944444444444
# Processing timestamp: 2021-09-15 14:18:00
# Current time & days to expiry: 2021-09-15 1.05
# Curr time & days to EXpiry 2021-09-15 1.05
# Processing timestamp: 2021-09-15 14:19:00
# Current time & days to expiry: 2021-09-15 1.0493055555555555
# Curr time & days to EXpiry 2021-09-15 1.0493055555555555
# Processing timestamp: 2021-09-15 14:20:00
# Current time & days to expiry: 2021-09-15 1.0486111111111112
# Curr time & days to EXpiry 2021-09-15 1.0486111111111112
# Processing timestamp: 2021-09-15 14:21:00
# Current time & days to expiry: 2021-09-15 1.0479166666666666
# Curr time & days to EXpiry 2021-09-15 1.0479166666666666
# Processing timestamp: 2021-09-15 14:22:00
# Current time & days to expiry: 2021-09-15 1.0472222222222223
# Curr time & days to EXpiry 2021-09-15 1.0472222222222223
# Processing timestamp: 2021-09-15 14:23:00
# Current time & days to expiry: 2021-09-15 1.0465277777777777
# Curr time & days to EXpiry 2021-09-15 1.0465277777777777
# Processing timestamp: 2021-09-15 14:24:00
# Current time & days to expiry: 2021-09-15 1.0458333333333334
# Curr time & days to EXpiry 2021-09-15 1.0458333333333334
# Processing timestamp: 2021-09-15 14:25:00
# Current time & days to expiry: 2021-09-15 1.0451388888888888
# Curr time & days to EXpiry 2021-09-15 1.0451388888888888
# Processing timestamp: 2021-09-15 14:26:00
# Current time & days to expiry: 2021-09-15 1.0444444444444445
# Curr time & days to EXpiry 2021-09-15 1.0444444444444445
# Processing timestamp: 2021-09-15 14:27:00
# Current time & days to expiry: 2021-09-15 1.04375
# Curr time & days to EXpiry 2021-09-15 1.04375
# Processing timestamp: 2021-09-15 14:28:00
# Current time & days to expiry: 2021-09-15 1.0430555555555556
# Curr time & days to EXpiry 2021-09-15 1.0430555555555556
# Processing timestamp: 2021-09-15 14:29:00
# Current time & days to expiry: 2021-09-15 1.042361111111111
# Curr time & days to EXpiry 2021-09-15 1.042361111111111
# Processing timestamp: 2021-09-15 14:30:00
# Current time & days to expiry: 2021-09-15 1.0416666666666667
# Curr time & days to EXpiry 2021-09-15 1.0416666666666667
# Processing timestamp: 2021-09-15 14:31:00
# Current time & days to expiry: 2021-09-15 1.0409722222222222
# Curr time & days to EXpiry 2021-09-15 1.0409722222222222
# Processing timestamp: 2021-09-15 14:32:00
# Current time & days to expiry: 2021-09-15 1.0402777777777779
# Curr time & days to EXpiry 2021-09-15 1.0402777777777779
# Processing timestamp: 2021-09-15 14:33:00
# Current time & days to expiry: 2021-09-15 1.0395833333333333
# Curr time & days to EXpiry 2021-09-15 1.0395833333333333
# Processing timestamp: 2021-09-15 14:34:00
# Current time & days to expiry: 2021-09-15 1.038888888888889
# Curr time & days to EXpiry 2021-09-15 1.038888888888889
# Processing timestamp: 2021-09-15 14:35:00
# Current time & days to expiry: 2021-09-15 1.0381944444444444
# Curr time & days to EXpiry 2021-09-15 1.0381944444444444
# Processing timestamp: 2021-09-15 14:36:00
# Current time & days to expiry: 2021-09-15 1.0375
# Curr time & days to EXpiry 2021-09-15 1.0375
# Processing timestamp: 2021-09-15 14:37:00
# Current time & days to expiry: 2021-09-15 1.0368055555555555
# Curr time & days to EXpiry 2021-09-15 1.0368055555555555
# Processing timestamp: 2021-09-15 14:38:00
# Current time & days to expiry: 2021-09-15 1.0361111111111112
# Curr time & days to EXpiry 2021-09-15 1.0361111111111112
# Processing timestamp: 2021-09-15 14:39:00
# Current time & days to expiry: 2021-09-15 1.0354166666666667
# Curr time & days to EXpiry 2021-09-15 1.0354166666666667
# Processing timestamp: 2021-09-15 14:40:00
# Current time & days to expiry: 2021-09-15 1.0347222222222223
# Curr time & days to EXpiry 2021-09-15 1.0347222222222223
# Processing timestamp: 2021-09-15 14:41:00
# Current time & days to expiry: 2021-09-15 1.0340277777777778
# Curr time & days to EXpiry 2021-09-15 1.0340277777777778
# Processing timestamp: 2021-09-15 14:42:00
# Current time & days to expiry: 2021-09-15 1.0333333333333334
# Curr time & days to EXpiry 2021-09-15 1.0333333333333334
# Processing timestamp: 2021-09-15 14:43:00
# Current time & days to expiry: 2021-09-15 1.0326388888888889
# Curr time & days to EXpiry 2021-09-15 1.0326388888888889
# Processing timestamp: 2021-09-15 14:44:00
# Current time & days to expiry: 2021-09-15 1.0319444444444446
# Curr time & days to EXpiry 2021-09-15 1.0319444444444446
# Processing timestamp: 2021-09-15 14:45:00
# Current time & days to expiry: 2021-09-15 1.03125
# Curr time & days to EXpiry 2021-09-15 1.03125
# Processing timestamp: 2021-09-15 14:46:00
# Current time & days to expiry: 2021-09-15 1.0305555555555554
# Curr time & days to EXpiry 2021-09-15 1.0305555555555554
# Processing timestamp: 2021-09-15 14:47:00
# Current time & days to expiry: 2021-09-15 1.0298611111111111
# Curr time & days to EXpiry 2021-09-15 1.0298611111111111
# Processing timestamp: 2021-09-15 14:48:00
# Current time & days to expiry: 2021-09-15 1.0291666666666666
# Curr time & days to EXpiry 2021-09-15 1.0291666666666666
# Processing timestamp: 2021-09-15 14:49:00
# Current time & days to expiry: 2021-09-15 1.0284722222222222
# Curr time & days to EXpiry 2021-09-15 1.0284722222222222
# Processing timestamp: 2021-09-15 14:50:00
# Current time & days to expiry: 2021-09-15 1.0277777777777777
# Curr time & days to EXpiry 2021-09-15 1.0277777777777777
# Processing timestamp: 2021-09-15 14:51:00
# Current time & days to expiry: 2021-09-15 1.0270833333333333
# Curr time & days to EXpiry 2021-09-15 1.0270833333333333
# Processing timestamp: 2021-09-15 14:52:00
# Current time & days to expiry: 2021-09-15 1.0263888888888888
# Curr time & days to EXpiry 2021-09-15 1.0263888888888888
# Processing timestamp: 2021-09-15 14:53:00
# Current time & days to expiry: 2021-09-15 1.0256944444444445
# Curr time & days to EXpiry 2021-09-15 1.0256944444444445
# Processing timestamp: 2021-09-15 14:54:00
# Current time & days to expiry: 2021-09-15 1.025
# Curr time & days to EXpiry 2021-09-15 1.025
# Processing timestamp: 2021-09-15 14:55:00
# Current time & days to expiry: 2021-09-15 1.0243055555555556
# Curr time & days to EXpiry 2021-09-15 1.0243055555555556
# Processing timestamp: 2021-09-15 14:56:00
# Current time & days to expiry: 2021-09-15 1.023611111111111
# Curr time & days to EXpiry 2021-09-15 1.023611111111111
# Processing timestamp: 2021-09-15 14:57:00
# Current time & days to expiry: 2021-09-15 1.0229166666666667
# Curr time & days to EXpiry 2021-09-15 1.0229166666666667
# Processing timestamp: 2021-09-15 14:58:00
# Current time & days to expiry: 2021-09-15 1.0222222222222221
# Curr time & days to EXpiry 2021-09-15 1.0222222222222221
# Processing timestamp: 2021-09-15 14:59:00
# Current time & days to expiry: 2021-09-15 1.0215277777777778
# Curr time & days to EXpiry 2021-09-15 1.0215277777777778
# Processing timestamp: 2021-09-15 15:00:00
# Current time & days to expiry: 2021-09-15 1.0208333333333333
# Curr time & days to EXpiry 2021-09-15 1.0208333333333333
# Processing timestamp: 2021-09-15 15:01:00
# Current time & days to expiry: 2021-09-15 1.020138888888889
# Curr time & days to EXpiry 2021-09-15 1.020138888888889
# Processing timestamp: 2021-09-15 15:02:00
# Current time & days to expiry: 2021-09-15 1.0194444444444444
# Curr time & days to EXpiry 2021-09-15 1.0194444444444444
# Processing timestamp: 2021-09-15 15:03:00
# Current time & days to expiry: 2021-09-15 1.01875
# Curr time & days to EXpiry 2021-09-15 1.01875
# Processing timestamp: 2021-09-15 15:04:00
# Current time & days to expiry: 2021-09-15 1.0180555555555555
# Curr time & days to EXpiry 2021-09-15 1.0180555555555555
# Processing timestamp: 2021-09-15 15:05:00
# Current time & days to expiry: 2021-09-15 1.0173611111111112
# Curr time & days to EXpiry 2021-09-15 1.0173611111111112
# Processing timestamp: 2021-09-15 15:06:00
# Current time & days to expiry: 2021-09-15 1.0166666666666666
# Curr time & days to EXpiry 2021-09-15 1.0166666666666666
# Processing timestamp: 2021-09-15 15:07:00
# Current time & days to expiry: 2021-09-15 1.0159722222222223
# Curr time & days to EXpiry 2021-09-15 1.0159722222222223
# Processing timestamp: 2021-09-15 15:08:00
# Current time & days to expiry: 2021-09-15 1.0152777777777777
# Curr time & days to EXpiry 2021-09-15 1.0152777777777777
# Processing timestamp: 2021-09-15 15:09:00
# Current time & days to expiry: 2021-09-15 1.0145833333333334
# Curr time & days to EXpiry 2021-09-15 1.0145833333333334
# Processing timestamp: 2021-09-15 15:10:00
# Current time & days to expiry: 2021-09-15 1.0138888888888888
# Curr time & days to EXpiry 2021-09-15 1.0138888888888888
# Processing timestamp: 2021-09-15 15:11:00
# Current time & days to expiry: 2021-09-15 1.0131944444444445
# Curr time & days to EXpiry 2021-09-15 1.0131944444444445
# Processing timestamp: 2021-09-15 15:12:00
# Current time & days to expiry: 2021-09-15 1.0125
# Curr time & days to EXpiry 2021-09-15 1.0125
# Processing timestamp: 2021-09-15 15:13:00
# Current time & days to expiry: 2021-09-15 1.0118055555555556
# Curr time & days to EXpiry 2021-09-15 1.0118055555555556
# Processing timestamp: 2021-09-15 15:14:00
# Current time & days to expiry: 2021-09-15 1.011111111111111
# Curr time & days to EXpiry 2021-09-15 1.011111111111111
# Processing timestamp: 2021-09-15 15:15:00
# Current time & days to expiry: 2021-09-15 1.0104166666666667
# Curr time & days to EXpiry 2021-09-15 1.0104166666666667
# Processing timestamp: 2021-09-15 15:16:00
# Current time & days to expiry: 2021-09-15 1.0097222222222222
# Curr time & days to EXpiry 2021-09-15 1.0097222222222222
# Processing timestamp: 2021-09-15 15:17:00
# Current time & days to expiry: 2021-09-15 1.0090277777777779
# Curr time & days to EXpiry 2021-09-15 1.0090277777777779
# Processing timestamp: 2021-09-15 15:18:00
# Current time & days to expiry: 2021-09-15 1.0083333333333333
# Curr time & days to EXpiry 2021-09-15 1.0083333333333333
# Processing timestamp: 2021-09-15 15:19:00
# Current time & days to expiry: 2021-09-15 1.007638888888889
# Curr time & days to EXpiry 2021-09-15 1.007638888888889
# Processing timestamp: 2021-09-15 15:20:00
# Current time & days to expiry: 2021-09-15 1.0069444444444444
# Curr time & days to EXpiry 2021-09-15 1.0069444444444444
# Processing timestamp: 2021-09-15 15:21:00
# Current time & days to expiry: 2021-09-15 1.00625
# Curr time & days to EXpiry 2021-09-15 1.00625
# Processing timestamp: 2021-09-15 15:22:00
# Current time & days to expiry: 2021-09-15 1.0055555555555555
# Curr time & days to EXpiry 2021-09-15 1.0055555555555555
# Processing timestamp: 2021-09-15 15:23:00
# Current time & days to expiry: 2021-09-15 1.0048611111111112
# Curr time & days to EXpiry 2021-09-15 1.0048611111111112
# Processing timestamp: 2021-09-15 15:24:00
# Current time & days to expiry: 2021-09-15 1.0041666666666667
# Curr time & days to EXpiry 2021-09-15 1.0041666666666667
# Processing timestamp: 2021-09-15 15:25:00
# Current time & days to expiry: 2021-09-15 1.0034722222222223
# Curr time & days to EXpiry 2021-09-15 1.0034722222222223
# Processing timestamp: 2021-09-15 15:26:00
# Current time & days to expiry: 2021-09-15 1.0027777777777778
# Curr time & days to EXpiry 2021-09-15 1.0027777777777778
# Processing timestamp: 2021-09-15 15:27:00
# Current time & days to expiry: 2021-09-15 1.0020833333333334
# Curr time & days to EXpiry 2021-09-15 1.0020833333333334
# Processing timestamp: 2021-09-15 15:28:00
# Current time & days to expiry: 2021-09-15 1.0013888888888889
# Curr time & days to EXpiry 2021-09-15 1.0013888888888889
# Processing timestamp: 2021-09-15 15:29:00
# Current time & days to expiry: 2021-09-15 1.0006944444444446
# Curr time & days to EXpiry 2021-09-15 1.0006944444444446
# Processing timestamp: 2021-09-15 15:30:00
# Current time & days to expiry: 2021-09-15 1.0
# Curr time & days to EXpiry 2021-09-15 1.0
# Processing timestamp: 2021-09-16 09:15:00
# Current time & days to expiry: 2021-09-16 0.2604166666666667
# Curr time & days to EXpiry 2021-09-16 0.2604166666666667
# Processing timestamp: 2021-09-16 09:16:00
# Current time & days to expiry: 2021-09-16 0.25972222222222224
# Curr time & days to EXpiry 2021-09-16 0.25972222222222224
# Processing timestamp: 2021-09-16 09:17:00
# Current time & days to expiry: 2021-09-16 0.2590277777777778
# Curr time & days to EXpiry 2021-09-16 0.2590277777777778
# Processing timestamp: 2021-09-16 09:18:00
# Current time & days to expiry: 2021-09-16 0.25833333333333336
# Curr time & days to EXpiry 2021-09-16 0.25833333333333336
# Processing timestamp: 2021-09-16 09:19:00
# Current time & days to expiry: 2021-09-16 0.25763888888888886
# Curr time & days to EXpiry 2021-09-16 0.25763888888888886
# Processing timestamp: 2021-09-16 09:20:00
# Current time & days to expiry: 2021-09-16 0.2569444444444444
# Curr time & days to EXpiry 2021-09-16 0.2569444444444444
# Processing timestamp: 2021-09-16 09:21:00
# Current time & days to expiry: 2021-09-16 0.25625
# Curr time & days to EXpiry 2021-09-16 0.25625
# Processing timestamp: 2021-09-16 09:22:00
# Current time & days to expiry: 2021-09-16 0.25555555555555554
# Curr time & days to EXpiry 2021-09-16 0.25555555555555554
# Processing timestamp: 2021-09-16 09:23:00
# Current time & days to expiry: 2021-09-16 0.2548611111111111
# Curr time & days to EXpiry 2021-09-16 0.2548611111111111
# Processing timestamp: 2021-09-16 09:24:00
# Current time & days to expiry: 2021-09-16 0.25416666666666665
# Curr time & days to EXpiry 2021-09-16 0.25416666666666665
# Processing timestamp: 2021-09-16 09:25:00
# Current time & days to expiry: 2021-09-16 0.2534722222222222
# Curr time & days to EXpiry 2021-09-16 0.2534722222222222
# Processing timestamp: 2021-09-16 09:26:00
# Current time & days to expiry: 2021-09-16 0.25277777777777777
# Curr time & days to EXpiry 2021-09-16 0.25277777777777777
# Processing timestamp: 2021-09-16 09:27:00
# Current time & days to expiry: 2021-09-16 0.2520833333333333
# Curr time & days to EXpiry 2021-09-16 0.2520833333333333
# Processing timestamp: 2021-09-16 09:28:00
# Current time & days to expiry: 2021-09-16 0.2513888888888889
# Curr time & days to EXpiry 2021-09-16 0.2513888888888889
# Processing timestamp: 2021-09-16 09:29:00
# Current time & days to expiry: 2021-09-16 0.25069444444444444
# Curr time & days to EXpiry 2021-09-16 0.25069444444444444
# Processing timestamp: 2021-09-16 09:30:00
# Current time & days to expiry: 2021-09-16 0.25
# Curr time & days to EXpiry 2021-09-16 0.25
# Processing timestamp: 2021-09-16 09:31:00
# Current time & days to expiry: 2021-09-16 0.24930555555555556
# Curr time & days to EXpiry 2021-09-16 0.24930555555555556
# Processing timestamp: 2021-09-16 09:32:00
# Current time & days to expiry: 2021-09-16 0.24861111111111112
# Curr time & days to EXpiry 2021-09-16 0.24861111111111112
# Processing timestamp: 2021-09-16 09:33:00
# Current time & days to expiry: 2021-09-16 0.24791666666666667
# Curr time & days to EXpiry 2021-09-16 0.24791666666666667
# Processing timestamp: 2021-09-16 09:34:00
# Current time & days to expiry: 2021-09-16 0.24722222222222223
# Curr time & days to EXpiry 2021-09-16 0.24722222222222223
# Processing timestamp: 2021-09-16 09:35:00
# Current time & days to expiry: 2021-09-16 0.2465277777777778
# Curr time & days to EXpiry 2021-09-16 0.2465277777777778
# Processing timestamp: 2021-09-16 09:36:00
# Current time & days to expiry: 2021-09-16 0.24583333333333332
# Curr time & days to EXpiry 2021-09-16 0.24583333333333332
# Processing timestamp: 2021-09-16 09:37:00
# Current time & days to expiry: 2021-09-16 0.24513888888888888
# Curr time & days to EXpiry 2021-09-16 0.24513888888888888
# Processing timestamp: 2021-09-16 09:38:00
# Current time & days to expiry: 2021-09-16 0.24444444444444444
# Curr time & days to EXpiry 2021-09-16 0.24444444444444444
# Processing timestamp: 2021-09-16 09:39:00
# Current time & days to expiry: 2021-09-16 0.24375
# Curr time & days to EXpiry 2021-09-16 0.24375
# Processing timestamp: 2021-09-16 09:40:00
# Current time & days to expiry: 2021-09-16 0.24305555555555555
# Curr time & days to EXpiry 2021-09-16 0.24305555555555555
# Processing timestamp: 2021-09-16 09:41:00
# Current time & days to expiry: 2021-09-16 0.2423611111111111
# Curr time & days to EXpiry 2021-09-16 0.2423611111111111
# Processing timestamp: 2021-09-16 09:42:00
# Current time & days to expiry: 2021-09-16 0.24166666666666667
# Curr time & days to EXpiry 2021-09-16 0.24166666666666667
# Processing timestamp: 2021-09-16 09:43:00
# Current time & days to expiry: 2021-09-16 0.24097222222222223
# Curr time & days to EXpiry 2021-09-16 0.24097222222222223
# Processing timestamp: 2021-09-16 09:44:00
# Current time & days to expiry: 2021-09-16 0.24027777777777778
# Curr time & days to EXpiry 2021-09-16 0.24027777777777778
# Processing timestamp: 2021-09-16 09:45:00
# Current time & days to expiry: 2021-09-16 0.23958333333333334
# Curr time & days to EXpiry 2021-09-16 0.23958333333333334
# Processing timestamp: 2021-09-16 09:46:00
# Current time & days to expiry: 2021-09-16 0.2388888888888889
# Curr time & days to EXpiry 2021-09-16 0.2388888888888889
# Processing timestamp: 2021-09-16 09:47:00
# Current time & days to expiry: 2021-09-16 0.23819444444444443
# Curr time & days to EXpiry 2021-09-16 0.23819444444444443
# Processing timestamp: 2021-09-16 09:48:00
# Current time & days to expiry: 2021-09-16 0.2375
# Curr time & days to EXpiry 2021-09-16 0.2375
# Processing timestamp: 2021-09-16 09:49:00
# Current time & days to expiry: 2021-09-16 0.23680555555555555
# Curr time & days to EXpiry 2021-09-16 0.23680555555555555
# Processing timestamp: 2021-09-16 09:50:00
# Current time & days to expiry: 2021-09-16 0.2361111111111111
# Curr time & days to EXpiry 2021-09-16 0.2361111111111111
# Processing timestamp: 2021-09-16 09:51:00
# Current time & days to expiry: 2021-09-16 0.23541666666666666
# Curr time & days to EXpiry 2021-09-16 0.23541666666666666
# Processing timestamp: 2021-09-16 09:52:00
# Current time & days to expiry: 2021-09-16 0.23472222222222222
# Curr time & days to EXpiry 2021-09-16 0.23472222222222222
# Processing timestamp: 2021-09-16 09:53:00
# Current time & days to expiry: 2021-09-16 0.23402777777777778
# Curr time & days to EXpiry 2021-09-16 0.23402777777777778
# Processing timestamp: 2021-09-16 09:54:00
# Current time & days to expiry: 2021-09-16 0.23333333333333334
# Curr time & days to EXpiry 2021-09-16 0.23333333333333334
# Processing timestamp: 2021-09-16 09:55:00
# Current time & days to expiry: 2021-09-16 0.2326388888888889
# Curr time & days to EXpiry 2021-09-16 0.2326388888888889
# Processing timestamp: 2021-09-16 09:56:00
# Current time & days to expiry: 2021-09-16 0.23194444444444445
# Curr time & days to EXpiry 2021-09-16 0.23194444444444445
# Processing timestamp: 2021-09-16 09:57:00
# Current time & days to expiry: 2021-09-16 0.23125
# Curr time & days to EXpiry 2021-09-16 0.23125
# Processing timestamp: 2021-09-16 09:58:00
# Current time & days to expiry: 2021-09-16 0.23055555555555557
# Curr time & days to EXpiry 2021-09-16 0.23055555555555557
# Processing timestamp: 2021-09-16 09:59:00
# Current time & days to expiry: 2021-09-16 0.2298611111111111
# Curr time & days to EXpiry 2021-09-16 0.2298611111111111
# Processing timestamp: 2021-09-16 10:00:00
# Current time & days to expiry: 2021-09-16 0.22916666666666666
# Curr time & days to EXpiry 2021-09-16 0.22916666666666666
# Processing timestamp: 2021-09-16 10:01:00
# Current time & days to expiry: 2021-09-16 0.22847222222222222
# Curr time & days to EXpiry 2021-09-16 0.22847222222222222
# Processing timestamp: 2021-09-16 10:02:00
# Current time & days to expiry: 2021-09-16 0.22777777777777777
# Curr time & days to EXpiry 2021-09-16 0.22777777777777777
# Processing timestamp: 2021-09-16 10:03:00
# Current time & days to expiry: 2021-09-16 0.22708333333333333
# Curr time & days to EXpiry 2021-09-16 0.22708333333333333
# Processing timestamp: 2021-09-16 10:04:00
# Current time & days to expiry: 2021-09-16 0.2263888888888889
# Curr time & days to EXpiry 2021-09-16 0.2263888888888889
# Processing timestamp: 2021-09-16 10:05:00
# Current time & days to expiry: 2021-09-16 0.22569444444444445
# Curr time & days to EXpiry 2021-09-16 0.22569444444444445
# Processing timestamp: 2021-09-16 10:06:00
# Current time & days to expiry: 2021-09-16 0.225
# Curr time & days to EXpiry 2021-09-16 0.225
# Processing timestamp: 2021-09-16 10:07:00
# Current time & days to expiry: 2021-09-16 0.22430555555555556
# Curr time & days to EXpiry 2021-09-16 0.22430555555555556
# Processing timestamp: 2021-09-16 10:08:00
# Current time & days to expiry: 2021-09-16 0.22361111111111112
# Curr time & days to EXpiry 2021-09-16 0.22361111111111112
# Processing timestamp: 2021-09-16 10:09:00
# Current time & days to expiry: 2021-09-16 0.22291666666666668
# Curr time & days to EXpiry 2021-09-16 0.22291666666666668
# Processing timestamp: 2021-09-16 10:10:00
# Current time & days to expiry: 2021-09-16 0.2222222222222222
# Curr time & days to EXpiry 2021-09-16 0.2222222222222222
# Processing timestamp: 2021-09-16 10:11:00
# Current time & days to expiry: 2021-09-16 0.22152777777777777
# Curr time & days to EXpiry 2021-09-16 0.22152777777777777
# Processing timestamp: 2021-09-16 10:12:00
# Current time & days to expiry: 2021-09-16 0.22083333333333333
# Curr time & days to EXpiry 2021-09-16 0.22083333333333333
# Processing timestamp: 2021-09-16 10:13:00
# Current time & days to expiry: 2021-09-16 0.22013888888888888
# Curr time & days to EXpiry 2021-09-16 0.22013888888888888
# Processing timestamp: 2021-09-16 10:14:00
# Current time & days to expiry: 2021-09-16 0.21944444444444444
# Curr time & days to EXpiry 2021-09-16 0.21944444444444444
# Processing timestamp: 2021-09-16 10:15:00
# Current time & days to expiry: 2021-09-16 0.21875
# Curr time & days to EXpiry 2021-09-16 0.21875
# Processing timestamp: 2021-09-16 10:16:00
# Current time & days to expiry: 2021-09-16 0.21805555555555556
# Curr time & days to EXpiry 2021-09-16 0.21805555555555556
# Processing timestamp: 2021-09-16 10:17:00
# Current time & days to expiry: 2021-09-16 0.21736111111111112
# Curr time & days to EXpiry 2021-09-16 0.21736111111111112
# Processing timestamp: 2021-09-16 10:18:00
# Current time & days to expiry: 2021-09-16 0.21666666666666667
# Curr time & days to EXpiry 2021-09-16 0.21666666666666667
# Processing timestamp: 2021-09-16 10:19:00
# Current time & days to expiry: 2021-09-16 0.21597222222222223
# Curr time & days to EXpiry 2021-09-16 0.21597222222222223
# Processing timestamp: 2021-09-16 10:20:00
# Current time & days to expiry: 2021-09-16 0.2152777777777778
# Curr time & days to EXpiry 2021-09-16 0.2152777777777778
# Processing timestamp: 2021-09-16 10:21:00
# Current time & days to expiry: 2021-09-16 0.21458333333333332
# Curr time & days to EXpiry 2021-09-16 0.21458333333333332
# Processing timestamp: 2021-09-16 10:22:00
# Current time & days to expiry: 2021-09-16 0.21388888888888888
# Curr time & days to EXpiry 2021-09-16 0.21388888888888888
# Processing timestamp: 2021-09-16 10:23:00
# Current time & days to expiry: 2021-09-16 0.21319444444444444
# Curr time & days to EXpiry 2021-09-16 0.21319444444444444
# Processing timestamp: 2021-09-16 10:24:00
# Current time & days to expiry: 2021-09-16 0.2125
# Curr time & days to EXpiry 2021-09-16 0.2125
# Processing timestamp: 2021-09-16 10:25:00
# Current time & days to expiry: 2021-09-16 0.21180555555555555
# Curr time & days to EXpiry 2021-09-16 0.21180555555555555
# Processing timestamp: 2021-09-16 10:26:00
# Current time & days to expiry: 2021-09-16 0.2111111111111111
# Curr time & days to EXpiry 2021-09-16 0.2111111111111111
# Processing timestamp: 2021-09-16 10:27:00
# Current time & days to expiry: 2021-09-16 0.21041666666666667
# Curr time & days to EXpiry 2021-09-16 0.21041666666666667
# Processing timestamp: 2021-09-16 10:28:00
# Current time & days to expiry: 2021-09-16 0.20972222222222223
# Curr time & days to EXpiry 2021-09-16 0.20972222222222223
# Processing timestamp: 2021-09-16 10:29:00
# Current time & days to expiry: 2021-09-16 0.20902777777777778
# Curr time & days to EXpiry 2021-09-16 0.20902777777777778
# Processing timestamp: 2021-09-16 10:30:00
# Current time & days to expiry: 2021-09-16 0.20833333333333334
# Curr time & days to EXpiry 2021-09-16 0.20833333333333334
# Processing timestamp: 2021-09-16 10:31:00
# Current time & days to expiry: 2021-09-16 0.2076388888888889
# Curr time & days to EXpiry 2021-09-16 0.2076388888888889
# Processing timestamp: 2021-09-16 10:32:00
# Current time & days to expiry: 2021-09-16 0.20694444444444443
# Curr time & days to EXpiry 2021-09-16 0.20694444444444443
# Processing timestamp: 2021-09-16 10:33:00
# Current time & days to expiry: 2021-09-16 0.20625
# Curr time & days to EXpiry 2021-09-16 0.20625
# Processing timestamp: 2021-09-16 10:34:00
# Current time & days to expiry: 2021-09-16 0.20555555555555555
# Curr time & days to EXpiry 2021-09-16 0.20555555555555555
# Processing timestamp: 2021-09-16 10:35:00
# Current time & days to expiry: 2021-09-16 0.2048611111111111
# Curr time & days to EXpiry 2021-09-16 0.2048611111111111
# Processing timestamp: 2021-09-16 10:36:00
# Current time & days to expiry: 2021-09-16 0.20416666666666666
# Curr time & days to EXpiry 2021-09-16 0.20416666666666666
# Processing timestamp: 2021-09-16 10:37:00
# Current time & days to expiry: 2021-09-16 0.20347222222222222
# Curr time & days to EXpiry 2021-09-16 0.20347222222222222
# Processing timestamp: 2021-09-16 10:38:00
# Current time & days to expiry: 2021-09-16 0.20277777777777778
# Curr time & days to EXpiry 2021-09-16 0.20277777777777778
# Processing timestamp: 2021-09-16 10:39:00
# Current time & days to expiry: 2021-09-16 0.20208333333333334
# Curr time & days to EXpiry 2021-09-16 0.20208333333333334
# Processing timestamp: 2021-09-16 10:40:00
# Current time & days to expiry: 2021-09-16 0.2013888888888889
# Curr time & days to EXpiry 2021-09-16 0.2013888888888889
# Processing timestamp: 2021-09-16 10:41:00
# Current time & days to expiry: 2021-09-16 0.20069444444444445
# Curr time & days to EXpiry 2021-09-16 0.20069444444444445
# Processing timestamp: 2021-09-16 10:42:00
# Current time & days to expiry: 2021-09-16 0.2
# Curr time & days to EXpiry 2021-09-16 0.2
# Processing timestamp: 2021-09-16 10:43:00
# Current time & days to expiry: 2021-09-16 0.19930555555555557
# Curr time & days to EXpiry 2021-09-16 0.19930555555555557
# Processing timestamp: 2021-09-16 10:44:00
# Current time & days to expiry: 2021-09-16 0.1986111111111111
# Curr time & days to EXpiry 2021-09-16 0.1986111111111111
# Processing timestamp: 2021-09-16 10:45:00
# Current time & days to expiry: 2021-09-16 0.19791666666666666
# Curr time & days to EXpiry 2021-09-16 0.19791666666666666
# Processing timestamp: 2021-09-16 10:46:00
# Current time & days to expiry: 2021-09-16 0.19722222222222222
# Curr time & days to EXpiry 2021-09-16 0.19722222222222222
# Processing timestamp: 2021-09-16 10:47:00
# Current time & days to expiry: 2021-09-16 0.19652777777777777
# Curr time & days to EXpiry 2021-09-16 0.19652777777777777
# Processing timestamp: 2021-09-16 10:48:00
# Current time & days to expiry: 2021-09-16 0.19583333333333333
# Curr time & days to EXpiry 2021-09-16 0.19583333333333333
# Processing timestamp: 2021-09-16 10:49:00
# Current time & days to expiry: 2021-09-16 0.1951388888888889
# Curr time & days to EXpiry 2021-09-16 0.1951388888888889
# Processing timestamp: 2021-09-16 10:50:00
# Current time & days to expiry: 2021-09-16 0.19444444444444445
# Curr time & days to EXpiry 2021-09-16 0.19444444444444445
# Processing timestamp: 2021-09-16 10:51:00
# Current time & days to expiry: 2021-09-16 0.19375
# Curr time & days to EXpiry 2021-09-16 0.19375
# Processing timestamp: 2021-09-16 10:52:00
# Current time & days to expiry: 2021-09-16 0.19305555555555556
# Curr time & days to EXpiry 2021-09-16 0.19305555555555556
# Processing timestamp: 2021-09-16 10:53:00
# Current time & days to expiry: 2021-09-16 0.19236111111111112
# Curr time & days to EXpiry 2021-09-16 0.19236111111111112
# Processing timestamp: 2021-09-16 10:54:00
# Current time & days to expiry: 2021-09-16 0.19166666666666668
# Curr time & days to EXpiry 2021-09-16 0.19166666666666668
# Processing timestamp: 2021-09-16 10:55:00
# Current time & days to expiry: 2021-09-16 0.1909722222222222
# Curr time & days to EXpiry 2021-09-16 0.1909722222222222
# Processing timestamp: 2021-09-16 10:56:00
# Current time & days to expiry: 2021-09-16 0.19027777777777777
# Curr time & days to EXpiry 2021-09-16 0.19027777777777777
# Processing timestamp: 2021-09-16 10:57:00
# Current time & days to expiry: 2021-09-16 0.18958333333333333
# Curr time & days to EXpiry 2021-09-16 0.18958333333333333
# Processing timestamp: 2021-09-16 10:58:00
# Current time & days to expiry: 2021-09-16 0.18888888888888888
# Curr time & days to EXpiry 2021-09-16 0.18888888888888888
# Processing timestamp: 2021-09-16 10:59:00
# Current time & days to expiry: 2021-09-16 0.18819444444444444
# Curr time & days to EXpiry 2021-09-16 0.18819444444444444
# Processing timestamp: 2021-09-16 11:00:00
# Current time & days to expiry: 2021-09-16 0.1875
# Curr time & days to EXpiry 2021-09-16 0.1875
# Processing timestamp: 2021-09-16 11:01:00
# Current time & days to expiry: 2021-09-16 0.18680555555555556
# Curr time & days to EXpiry 2021-09-16 0.18680555555555556
# Processing timestamp: 2021-09-16 11:02:00
# Current time & days to expiry: 2021-09-16 0.18611111111111112
# Curr time & days to EXpiry 2021-09-16 0.18611111111111112
# Processing timestamp: 2021-09-16 11:03:00
# Current time & days to expiry: 2021-09-16 0.18541666666666667
# Curr time & days to EXpiry 2021-09-16 0.18541666666666667
# Processing timestamp: 2021-09-16 11:04:00
# Current time & days to expiry: 2021-09-16 0.18472222222222223
# Curr time & days to EXpiry 2021-09-16 0.18472222222222223
# Processing timestamp: 2021-09-16 11:05:00
# Current time & days to expiry: 2021-09-16 0.1840277777777778
# Curr time & days to EXpiry 2021-09-16 0.1840277777777778
# Processing timestamp: 2021-09-16 11:06:00
# Current time & days to expiry: 2021-09-16 0.18333333333333332
# Curr time & days to EXpiry 2021-09-16 0.18333333333333332
# Processing timestamp: 2021-09-16 11:07:00
# Current time & days to expiry: 2021-09-16 0.18263888888888888
# Curr time & days to EXpiry 2021-09-16 0.18263888888888888
# Processing timestamp: 2021-09-16 11:08:00
# Current time & days to expiry: 2021-09-16 0.18194444444444444
# Curr time & days to EXpiry 2021-09-16 0.18194444444444444
# Processing timestamp: 2021-09-16 11:09:00
# Current time & days to expiry: 2021-09-16 0.18125
# Curr time & days to EXpiry 2021-09-16 0.18125
# Processing timestamp: 2021-09-16 11:10:00
# Current time & days to expiry: 2021-09-16 0.18055555555555555
# Curr time & days to EXpiry 2021-09-16 0.18055555555555555
# Processing timestamp: 2021-09-16 11:11:00
# Current time & days to expiry: 2021-09-16 0.1798611111111111
# Curr time & days to EXpiry 2021-09-16 0.1798611111111111
# Processing timestamp: 2021-09-16 11:12:00
# Current time & days to expiry: 2021-09-16 0.17916666666666667
# Curr time & days to EXpiry 2021-09-16 0.17916666666666667
# Processing timestamp: 2021-09-16 11:13:00
# Current time & days to expiry: 2021-09-16 0.17847222222222223
# Curr time & days to EXpiry 2021-09-16 0.17847222222222223
# Processing timestamp: 2021-09-16 11:14:00
# Current time & days to expiry: 2021-09-16 0.17777777777777778
# Curr time & days to EXpiry 2021-09-16 0.17777777777777778
# Processing timestamp: 2021-09-16 11:15:00
# Current time & days to expiry: 2021-09-16 0.17708333333333334
# Curr time & days to EXpiry 2021-09-16 0.17708333333333334
# Processing timestamp: 2021-09-16 11:16:00
# Current time & days to expiry: 2021-09-16 0.1763888888888889
# Curr time & days to EXpiry 2021-09-16 0.1763888888888889
# Processing timestamp: 2021-09-16 11:17:00
# Current time & days to expiry: 2021-09-16 0.17569444444444443
# Curr time & days to EXpiry 2021-09-16 0.17569444444444443
# Processing timestamp: 2021-09-16 11:18:00
# Current time & days to expiry: 2021-09-16 0.175
# Curr time & days to EXpiry 2021-09-16 0.175
# Processing timestamp: 2021-09-16 11:19:00
# Current time & days to expiry: 2021-09-16 0.17430555555555555
# Curr time & days to EXpiry 2021-09-16 0.17430555555555555
# Processing timestamp: 2021-09-16 11:20:00
# Current time & days to expiry: 2021-09-16 0.1736111111111111
# Curr time & days to EXpiry 2021-09-16 0.1736111111111111
# Processing timestamp: 2021-09-16 11:21:00
# Current time & days to expiry: 2021-09-16 0.17291666666666666
# Curr time & days to EXpiry 2021-09-16 0.17291666666666666
# Processing timestamp: 2021-09-16 11:22:00
# Current time & days to expiry: 2021-09-16 0.17222222222222222
# Curr time & days to EXpiry 2021-09-16 0.17222222222222222
# Processing timestamp: 2021-09-16 11:23:00
# Current time & days to expiry: 2021-09-16 0.17152777777777778
# Curr time & days to EXpiry 2021-09-16 0.17152777777777778
# Processing timestamp: 2021-09-16 11:24:00
# Current time & days to expiry: 2021-09-16 0.17083333333333334
# Curr time & days to EXpiry 2021-09-16 0.17083333333333334
# Processing timestamp: 2021-09-16 11:25:00
# Current time & days to expiry: 2021-09-16 0.1701388888888889
# Curr time & days to EXpiry 2021-09-16 0.1701388888888889
# Processing timestamp: 2021-09-16 11:26:00
# Current time & days to expiry: 2021-09-16 0.16944444444444445
# Curr time & days to EXpiry 2021-09-16 0.16944444444444445
# Processing timestamp: 2021-09-16 11:27:00
# Current time & days to expiry: 2021-09-16 0.16875
# Curr time & days to EXpiry 2021-09-16 0.16875
# Processing timestamp: 2021-09-16 11:28:00
# Current time & days to expiry: 2021-09-16 0.16805555555555557
# Curr time & days to EXpiry 2021-09-16 0.16805555555555557
# Processing timestamp: 2021-09-16 11:29:00
# Current time & days to expiry: 2021-09-16 0.1673611111111111
# Curr time & days to EXpiry 2021-09-16 0.1673611111111111
# Processing timestamp: 2021-09-16 11:30:00
# Current time & days to expiry: 2021-09-16 0.16666666666666666
# Curr time & days to EXpiry 2021-09-16 0.16666666666666666
# Processing timestamp: 2021-09-16 11:31:00
# Current time & days to expiry: 2021-09-16 0.16597222222222222
# Curr time & days to EXpiry 2021-09-16 0.16597222222222222
# Processing timestamp: 2021-09-16 11:32:00
# Current time & days to expiry: 2021-09-16 0.16527777777777777
# Curr time & days to EXpiry 2021-09-16 0.16527777777777777
# Processing timestamp: 2021-09-16 11:33:00
# Current time & days to expiry: 2021-09-16 0.16458333333333333
# Curr time & days to EXpiry 2021-09-16 0.16458333333333333
# Processing timestamp: 2021-09-16 11:34:00
# Current time & days to expiry: 2021-09-16 0.1638888888888889
# Curr time & days to EXpiry 2021-09-16 0.1638888888888889
# Processing timestamp: 2021-09-16 11:35:00
# Current time & days to expiry: 2021-09-16 0.16319444444444445
# Curr time & days to EXpiry 2021-09-16 0.16319444444444445
# Processing timestamp: 2021-09-16 11:36:00
# Current time & days to expiry: 2021-09-16 0.1625
# Curr time & days to EXpiry 2021-09-16 0.1625
# Processing timestamp: 2021-09-16 11:37:00
# Current time & days to expiry: 2021-09-16 0.16180555555555556
# Curr time & days to EXpiry 2021-09-16 0.16180555555555556
# Processing timestamp: 2021-09-16 11:38:00
# Current time & days to expiry: 2021-09-16 0.16111111111111112
# Curr time & days to EXpiry 2021-09-16 0.16111111111111112
# Processing timestamp: 2021-09-16 11:39:00
# Current time & days to expiry: 2021-09-16 0.16041666666666668
# Curr time & days to EXpiry 2021-09-16 0.16041666666666668
# Processing timestamp: 2021-09-16 11:40:00
# Current time & days to expiry: 2021-09-16 0.1597222222222222
# Curr time & days to EXpiry 2021-09-16 0.1597222222222222
# Processing timestamp: 2021-09-16 11:41:00
# Current time & days to expiry: 2021-09-16 0.15902777777777777
# Curr time & days to EXpiry 2021-09-16 0.15902777777777777
# Processing timestamp: 2021-09-16 11:42:00
# Current time & days to expiry: 2021-09-16 0.15833333333333333
# Curr time & days to EXpiry 2021-09-16 0.15833333333333333
# Processing timestamp: 2021-09-16 11:43:00
# Current time & days to expiry: 2021-09-16 0.15763888888888888
# Curr time & days to EXpiry 2021-09-16 0.15763888888888888
# Processing timestamp: 2021-09-16 11:44:00
# Current time & days to expiry: 2021-09-16 0.15694444444444444
# Curr time & days to EXpiry 2021-09-16 0.15694444444444444
# Processing timestamp: 2021-09-16 11:45:00
# Current time & days to expiry: 2021-09-16 0.15625
# Curr time & days to EXpiry 2021-09-16 0.15625
# Processing timestamp: 2021-09-16 11:46:00
# Current time & days to expiry: 2021-09-16 0.15555555555555556
# Curr time & days to EXpiry 2021-09-16 0.15555555555555556
# Processing timestamp: 2021-09-16 11:47:00
# Current time & days to expiry: 2021-09-16 0.15486111111111112
# Curr time & days to EXpiry 2021-09-16 0.15486111111111112
# Processing timestamp: 2021-09-16 11:48:00
# Current time & days to expiry: 2021-09-16 0.15416666666666667
# Curr time & days to EXpiry 2021-09-16 0.15416666666666667
# Processing timestamp: 2021-09-16 11:49:00
# Current time & days to expiry: 2021-09-16 0.15347222222222223
# ...
# OI 31744700.0 34724400.0
# OI 32101600.0 31069050.0
# OI 32213050.0 31091100.0
# OI 32213050.0 31091100.0
# OI 32213050.0 31091100.0
# OI 32075000.0 31215750.0
# OI 32075000.0 31215750.0
# OI 32075000.0 31215750.0
# OI 31732550.0 31317300.0
# OI 31732550.0 31318050.0
# OI 31732550.0 31318050.0
# OI 31699650.0 31504550.0
# OI 31699650.0 31504550.0
# OI 31699650.0 31504550.0
# OI 31627650.0 31519300.0
# OI 31627650.0 31519250.0
# OI 31627650.0 31519250.0
# OI 30435050.0 31840350.0
# OI 30435050.0 31840350.0
# OI 30435050.0 31840350.0
# OI 30285450.0 32079600.0
# OI 30285450.0 32079600.0
# OI 30285450.0 32079600.0
# OI 30448050.0 32235750.0
# OI 30448050.0 32235750.0
# OI 30448050.0 32235750.0
# OI 30604400.0 32412050.0
# OI 30604400.0 32412050.0
# OI 30604400.0 32412000.0
# OI 30700700.0 32406150.0
# OI 30700700.0 32406050.0
# OI 30700700.0 32406050.0
# OI 30773600.0 32361950.0
# OI 30773600.0 32361950.0
# OI 30773600.0 32361900.0
# OI 30736900.0 32244150.0
# OI 30736900.0 32244400.0
# OI 30736900.0 32244400.0
# OI 30640400.0 31864800.0
# OI 30640400.0 31864800.0
# OI 30640400.0 31864800.0
# OI 30256650.0 31504850.0
# OI 30256650.0 31504850.0
# OI 30256650.0 31504850.0
# OI 30051700.0 31673050.0
# OI 30051700.0 31672900.0
# OI 30051700.0 31672900.0
# OI 29933400.0 31856250.0
# OI 29933400.0 31856250.0
# OI 29933400.0 31856250.0
# OI 29751300.0 31825950.0
# OI 29751300.0 31826200.0
# OI 29751300.0 31826200.0
# OI 29594500.0 31791450.0
# OI 29594500.0 31791450.0
# OI 29594500.0 31791450.0
# OI 29140500.0 31678250.0
# OI 29140500.0 31678200.0
# OI 29140500.0 31678200.0
# OI 29123900.0 31343350.0
# OI 29123900.0 31343250.0
# OI 29123900.0 31343250.0
# OI 28715150.0 30580650.0
# OI 28717200.0 30580650.0
# OI 28717200.0 30580650.0
# OI 28746300.0 30480150.0
# OI 28746200.0 30480150.0
# OI 28746200.0 30480200.0
# OI 28819950.0 30423650.0
# OI 28819950.0 30423650.0
# OI 28819950.0 30423650.0
# OI 28448250.0 30430700.0
# OI 28448250.0 30430700.0
# OI 28448250.0 30430700.0
# OI 27767700.0 30594850.0
# OI 27767700.0 30594850.0
# OI 27767700.0 30594850.0
# OI 27691350.0 30737800.0
# OI 27689850.0 30737800.0
# OI 27689850.0 30737800.0
# OI 27609900.0 30640900.0
# OI 27608650.0 30640900.0
# OI 27608650.0 30640900.0
# OI 27482700.0 30718600.0
# OI 30371150.0 28298950.0
# OI 27482700.0 30718600.0
# OI 27107650.0 30655150.0
# OI 29992750.0 28279650.0
# OI 27107650.0 30655200.0
# OI 26844100.0 30524450.0
# OI 26844100.0 30524450.0
# OI 26844100.0 30524450.0
# OI 26794150.0 30378250.0
# OI 26794150.0 30378250.0
# OI 26794150.0 30378250.0
# OI 26764400.0 30433700.0
# OI 26764400.0 30433500.0
# OI 26764400.0 30433500.0
# OI 29653850.0 28366650.0
# OI 26667800.0 30485850.0
# OI 26667800.0 30485850.0
# OI 26524700.0 30369150.0
# OI 26524700.0 30369150.0
# OI 26524700.0 30369150.0
# OI 26690850.0 30441900.0
# OI 26690850.0 30443100.0
# OI 26690850.0 30443100.0
# OI 26717650.0 30335300.0
# OI 26717800.0 30335300.0
# OI 26717800.0 30334400.0
# OI 26766400.0 30322300.0
# OI 26766700.0 30322300.0
# OI 26766700.0 30322300.0
# OI 26727900.0 30293700.0
# OI 29898350.0 28150900.0
# OI 29898350.0 28150800.0
# OI 29960950.0 27980450.0
# OI 29960950.0 27980150.0
# OI 29960950.0 27980150.0
# OI 29672950.0 27760250.0
# OI 29672950.0 27760250.0
# OI 29672950.0 27760250.0
# OI 29565750.0 27702150.0
# OI 29565750.0 27702050.0
# OI 29565750.0 27702050.0
# OI 26194650.0 29370750.0
# OI 29539400.0 27419500.0
# OI 26194300.0 29370800.0
# OI 25963900.0 28910850.0
# OI 25963900.0 28910850.0
# OI 25963900.0 28910850.0
# OI 25707300.0 28631950.0
# OI 25707300.0 28631950.0
# OI 25707300.0 28632000.0
# OI 25762500.0 28587150.0
# OI 25763800.0 28587150.0
# OI 25763800.0 28587150.0
# OI 25945700.0 28261200.0
# OI 25946100.0 28261200.0
# OI 25946100.0 28261250.0
# OI 25872650.0 27907900.0
# OI 25864300.0 27876050.0
# OI 25864300.0 27876100.0
# OI 25738650.0 27833850.0
# OI 25666900.0 27787700.0
# OI 25666900.0 27787700.0
# OI 29120200.0 26002900.0
# OI 29107750.0 26038000.0
# OI 29107750.0 26038000.0
# OI 26023650.0 27666050.0
# OI 25941700.0 27492100.0
# OI 25941700.0 27492100.0
# OI 25959700.0 27283750.0
# OI 25924500.0 26868900.0
# OI 25924500.0 26868900.0
# OI 25931750.0 26783650.0
# OI 25643600.0 26113650.0
# OI 25643600.0 26113650.0
# OI 25643600.0 26113650.0
# OI 28644450.0 24237350.0
# OI 28644450.0 24237350.0
# OI 29973800.0 21368400.0
# OI 30233200.0 25438450.0
# OI 30233200.0 25438450.0
# OI 31749350.0 27052050.0
# OI 31749350.0 27052050.0
# OI 31749350.0 27052050.0
# OI 32962150.0 27845450.0
# OI 32962150.0 27845450.0
# OI 32962150.0 27845450.0
# OI 33745100.0 28572650.0
# OI 33745100.0 28572650.0
# OI 33745100.0 28572650.0
# OI 34668750.0 29476950.0
# OI 34668750.0 29476950.0
# OI 34668750.0 29476950.0
# OI 35130950.0 30094850.0
# OI 35130950.0 30094850.0
# OI 35130950.0 30094850.0
# OI 35517700.0 30805650.0
# OI 35517700.0 30805650.0
# OI 35517700.0 30805650.0
# OI 36028650.0 31151600.0
# OI 36028650.0 31151600.0
# OI 36028650.0 31151600.0
# OI 36495000.0 31163350.0
# OI 36495000.0 31163350.0
# OI 36495000.0 31163350.0
# OI 37021250.0 31264850.0
# OI 37021250.0 31267300.0
# OI 37021250.0 31267300.0
# OI 37383100.0 31271950.0
# OI 37383100.0 31271950.0
# OI 37383100.0 31271950.0
# OI 37807150.0 31563850.0
# OI 37807150.0 31563850.0
# OI 37807150.0 31563850.0
# OI 38227600.0 31687650.0
# OI 38227600.0 31687650.0
# OI 38227600.0 31687650.0
# OI 38625550.0 30598650.0
# OI 33462750.0 32025800.0
# OI 33462750.0 32025800.0
# OI 34001250.0 31099250.0
# OI 34001450.0 31099250.0
# OI 34001450.0 31099250.0
# OI 39772600.0 29635950.0
# OI 39772600.0 29635950.0
# OI 39772600.0 29635950.0
# OI 40526800.0 29802750.0
# OI 40526800.0 29802750.0
# OI 40526800.0 29802750.0
# OI 40671300.0 30426600.0
# OI 40671300.0 30426600.0
# OI 40671300.0 30426600.0
# OI 40796450.0 30792400.0
# OI 40796450.0 30792400.0
# OI 40796450.0 30792400.0
# OI 40519900.0 31285950.0
# OI 40519900.0 31285950.0
# OI 40519900.0 31285950.0
# OI 40376900.0 31584950.0
# OI 40376900.0 31584950.0
# OI 40376900.0 31584950.0
# OI 40132150.0 31751600.0
# OI 40132150.0 31750000.0
# OI 40132150.0 31750000.0
# OI 40278950.0 31809100.0
# OI 40280900.0 31809100.0
# OI 40280900.0 31809100.0
# OI 40298250.0 32006450.0
# OI 40294000.0 32006550.0
# OI 40294000.0 32006550.0
# OI 40372200.0 32304250.0
# OI 40372200.0 32304250.0
# OI 40372200.0 32304250.0
# OI 40383300.0 32367250.0
# OI 40383300.0 32367950.0
# OI 40383300.0 32367950.0
# OI 40531100.0 32302250.0
# OI 40531100.0 32302250.0
# OI 40531100.0 32302250.0
# OI 40581350.0 32350700.0
# OI 40581350.0 32351850.0
# OI 40581350.0 32351850.0
# OI 40882450.0 32447350.0
# OI 40881600.0 32463050.0
# OI 40881600.0 32463050.0
# OI 41142150.0 32242400.0
# OI 41141100.0 32242400.0
# OI 41141100.0 32242850.0
# OI 41237400.0 32164250.0
# OI 41237400.0 32164450.0
# OI 41237400.0 32164450.0
# OI 41540450.0 32019700.0
# OI 41540450.0 32019100.0
# OI 41540450.0 32019100.0
# OI 41599550.0 32091050.0
# OI 41597650.0 32091400.0
# OI 41597650.0 32091400.0
# OI 41756600.0 32138450.0
# OI 41756600.0 32138100.0
# OI 41756600.0 32138100.0
# OI 41708750.0 32163500.0
# OI 41708750.0 32162250.0
# OI 41708750.0 32162250.0
# OI 41698700.0 32028500.0
# OI 41698700.0 32031200.0
# OI 41698700.0 32031200.0
# OI 41839450.0 31706100.0
# OI 41839450.0 31706100.0
# OI 41839450.0 31706100.0
# OI 41708700.0 31259950.0
# OI 41708100.0 31282800.0
# OI 41708100.0 31282800.0
# OI 41899650.0 31277600.0
# OI 41898700.0 31277150.0
# OI 41898700.0 31277150.0
# OI 42126600.0 31211700.0
# OI 42074700.0 31211700.0
# OI 42074700.0 31211700.0
# OI 42008450.0 31229900.0
# OI 42001500.0 31245500.0
# OI 42001500.0 31245500.0
# OI 42277750.0 31099900.0
# OI 42275050.0 31099700.0
# OI 42275050.0 31099700.0
# OI 42385000.0 31109200.0
# OI 42384900.0 31079100.0
# OI 42384900.0 31079100.0
# OI 42403100.0 31147500.0
# OI 42390200.0 31166950.0
# OI 42390200.0 31166950.0
# OI 42441150.0 31239850.0
# OI 42436200.0 31213300.0
# OI 42436200.0 31213300.0
# OI 42451200.0 31213400.0
# OI 42265550.0 31222700.0
# OI 42265550.0 31224100.0
# OI 42278400.0 31239750.0
# OI 42176200.0 31363550.0
# OI 42176200.0 31363550.0
# OI 42127000.0 31387400.0
# OI 42115550.0 31574400.0
# OI 42115550.0 31574400.0
# OI 42080600.0 31652900.0
# OI 42083600.0 31675000.0
# OI 42083600.0 31675000.0
# OI 42084450.0 31681200.0
# OI 41958400.0 31650050.0
# OI 41958400.0 31650050.0
# OI 41945450.0 31648800.0
# OI 42189650.0 31561050.0
# OI 42189650.0 31561050.0
# OI 42194150.0 31559250.0
# OI 42018400.0 31709400.0
# OI 42018400.0 31709400.0
# OI 41997650.0 31709400.0
# OI 41526400.0 32179350.0
# OI 41526400.0 32179350.0
# OI 41526400.0 32179350.0
# OI 41190750.0 32559750.0
# OI 41190750.0 32559750.0
# OI 41190750.0 32569350.0
# OI 41154300.0 32861050.0
# OI 41154300.0 32861050.0
# OI 41154300.0 32861050.0
# OI 41206950.0 32851850.0
# OI 41206950.0 32851850.0
# OI 41206950.0 32851000.0
# OI 41081200.0 32894400.0
# OI 41081200.0 32894400.0
# OI 41145950.0 29100650.0
# OI 40267550.0 29509550.0
# OI 40202900.0 33244450.0
# OI 40202900.0 33244450.0
# OI 39891150.0 29743750.0
# OI 39891150.0 29743750.0
# OI 39891150.0 29743750.0
# OI 39483450.0 30031950.0
# OI 39483450.0 30031950.0
# OI 39483450.0 30031950.0
# OI 38229700.0 30073000.0
# OI 38229700.0 30073000.0
# OI 38229700.0 30073000.0
# OI 38229300.0 30213400.0
# OI 38229300.0 30213400.0
# OI 38229300.0 30213400.0
# OI 38302750.0 30393800.0
# OI 38302750.0 30393800.0
# OI 38302750.0 30393800.0
# OI 38354400.0 30138000.0
# OI 38354400.0 30138000.0
# OI 38354400.0 30138000.0
# OI 38410100.0 30152900.0
# OI 38410100.0 30152850.0
# OI 38410100.0 30152850.0
# OI 38496100.0 29771550.0
# OI 38496100.0 29771550.0
# OI 38496100.0 29771550.0
# OI 38512050.0 29641050.0
# OI 38512050.0 29641100.0
# OI 38512050.0 29641100.0
# OI 38471250.0 29569600.0
# OI 38471250.0 29569600.0
# OI 38471250.0 29569600.0
# OI 37873900.0 29326150.0
# OI 37873900.0 29326150.0
# OI 37873900.0 29326150.0
# OI 37608300.0 29544650.0
# OI 37608300.0 29544750.0
# OI 37608300.0 29544750.0
# OI 37829150.0 29426400.0
# OI 37829150.0 29426400.0
# OI 37829150.0 29426400.0
# OI 37980650.0 29580350.0
# OI 37980650.0 29580350.0
# OI 37980650.0 29580350.0
# OI 37936500.0 29586100.0
# OI 37936500.0 29586100.0
# OI 37936500.0 29586100.0
# OI 38144800.0 32898150.0
# OI 38209350.0 29517950.0
# OI 38209350.0 29517950.0
# OI 38420950.0 29494700.0
# OI 38420950.0 29494700.0
# OI 38420950.0 29494700.0
# OI 38514950.0 29559150.0
# OI 38455500.0 32938800.0
# OI 38514950.0 29559150.0
# OI 38490350.0 29376250.0
# OI 38429100.0 32754250.0
# OI 38429100.0 32754250.0
# OI 38788750.0 29311700.0
# OI 38788750.0 29311050.0
# OI 38788750.0 29311050.0
# OI 38741350.0 29263750.0
# OI 38741350.0 29263750.0
# OI 38741350.0 29263700.0
# OI 38842300.0 29041100.0
# OI 38842300.0 29040300.0
# OI 38842300.0 29040300.0
# OI 38717800.0 32120950.0
# OI 38717750.0 32120750.0
# OI 38717750.0 32120750.0
# OI 38517500.0 31776050.0
# OI 38577050.0 28529650.0
# OI 38577050.0 28529650.0
# OI 38409050.0 28499950.0
# OI 38409050.0 28500100.0
# OI 38409050.0 28500100.0
# OI 38250800.0 28439650.0
# OI 38250800.0 28439500.0
# OI 38250800.0 28439500.0
# OI 37710500.0 28418150.0
# OI 37710500.0 28418150.0
# OI 37710500.0 28418150.0
# OI 37781850.0 28324350.0
# OI 37781850.0 28324350.0
# OI 37781850.0 28324350.0
# OI 37688850.0 28334300.0
# OI 37688850.0 28334300.0
# OI 37688850.0 28334650.0
# OI 37613000.0 28618600.0
# OI 37613000.0 28618600.0
# OI 37613000.0 28618600.0
# OI 37144200.0 28751400.0
# OI 37144200.0 28751400.0
# OI 37144200.0 28751400.0
# OI 36988600.0 28641050.0
# OI 36988600.0 28641050.0
# OI 36988600.0 28641050.0
# OI 36739950.0 28743450.0
# OI 36739950.0 28743450.0
# OI 36739950.0 28743450.0
# OI 36902000.0 28714600.0
# OI 36902000.0 28714050.0
# OI 36902000.0 28714050.0
# OI 36707450.0 28811500.0
# OI 36707450.0 28811550.0
# OI 36707450.0 28811550.0
# OI 35909650.0 28328650.0
# OI 35909650.0 28328650.0
# OI 35909650.0 28328650.0
# OI 35625400.0 28351550.0
# OI 35625400.0 28351550.0
# OI 35625400.0 28351550.0
# OI 35529050.0 28432300.0
# OI 35529050.0 28432300.0
# OI 35529050.0 28432150.0
# OI 35085950.0 28375500.0
# OI 35085950.0 28375500.0
# OI 35085950.0 28375500.0
# OI 35319050.0 28357650.0
# OI 35320350.0 28357650.0
# OI 35320350.0 28357550.0
# OI 34692300.0 28171450.0
# OI 34697200.0 28171450.0
# OI 34697200.0 28171500.0
# OI 33322150.0 28264200.0
# OI 33322150.0 28265200.0
# OI 33322150.0 28265200.0
# OI 32429250.0 28056350.0
# OI 32429250.0 28056350.0
# OI 32429250.0 28056350.0
# OI 32600300.0 27882700.0
# OI 32600300.0 27882700.0
# OI 32600300.0 27882700.0
# OI 32738900.0 27533450.0
# OI 32739000.0 27533450.0
# OI 32739000.0 27533450.0
# OI 32706650.0 27629600.0
# OI 32705350.0 27629550.0
# OI 32705350.0 27629550.0
# OI 32131700.0 27782000.0
# OI 32128600.0 27781850.0
# OI 33577000.0 25877900.0
# OI 32475050.0 25893200.0
# OI 32475050.0 25893200.0
# OI 32475050.0 25893200.0
# OI 31117050.0 25824500.0
# OI 31117050.0 25824300.0
# OI 31117050.0 25825100.0
# OI 31012750.0 25825650.0
# OI 31012750.0 25825700.0
# OI 31012750.0 25825700.0
# OI 30938100.0 25301900.0
# OI 30936000.0 25301950.0
# OI 30936000.0 25301950.0
# OI 30857100.0 25006550.0
# OI 30855900.0 25006350.0
# OI 30855900.0 25006350.0
# OI 31452650.0 25252800.0
# OI 31437200.0 25252400.0
# OI 31437200.0 25252400.0
# OI 31670900.0 25187150.0
# OI 31670900.0 25187450.0
# OI 31670900.0 25187450.0
# OI 32181950.0 25370250.0
# OI 32181950.0 25370150.0
# OI 32181950.0 25370150.0
# OI 32570850.0 25366400.0
# OI 32541250.0 25368600.0
# OI 32541250.0 25368850.0
# OI 32018000.0 25158100.0
# OI 32018000.0 25160750.0
# OI 32018000.0 25160750.0
# OI 31499850.0 23858400.0
# OI 31499850.0 23860650.0
# OI 31499850.0 23860650.0
# OI 30609100.0 22996050.0
# OI 30574200.0 22997100.0
# OI 30574200.0 22998050.0
# OI 29753650.0 22608350.0
# OI 29742800.0 22588500.0
# OI 29742800.0 22588700.0
# OI 28269000.0 21815300.0
# OI 28209750.0 21782400.0
# OI 28209750.0 21782400.0
# OI 24383700.0 22719350.0
# OI 24350050.0 22651600.0
# OI 24350050.0 22651600.0
# OI 22518550.0 22381200.0
# OI 22449850.0 22268450.0
# OI 23549900.0 20741800.0
# OI 21809650.0 21721650.0
# OI 21519000.0 21645750.0
# OI 21519000.0 21645750.0
# OI 21825200.0 19515200.0
# OI 21661050.0 19372200.0
# OI 21656650.0 19372200.0
# OI 21503650.0 19142250.0
# OI 20774350.0 17859400.0
# OI 20774350.0 17859400.0
# OI 20774350.0 17859400.0
#                     Ticker     Open     High      Low    Close  Volume  \
# Date/Time
# 2021-09-03 09:15:00  NIFTY  17262.5  17296.8  17255.3  17293.3       0
# 2021-09-03 09:16:00  NIFTY  17292.3  17300.3  17289.0  17289.0       0
# 2021-09-03 09:17:00  NIFTY  17288.9  17298.2  17282.0  17297.3       0
# 2021-09-03 09:18:00  NIFTY  17298.8  17312.0  17296.5  17302.3       0
# 2021-09-03 09:19:00  NIFTY  17302.3  17306.7  17301.2  17306.1       0
#
#                      Open Interest  INDIAVIX  ATM_Delta     ATM_OI  ...  \
# Date/Time                                                           ...
# 2021-09-03 09:15:00              0     14.19   0.542985  1666100.0  ...
# 2021-09-03 09:16:00              0     14.21   0.541113  1666100.0  ...
# 2021-09-03 09:17:00              0     14.17   0.543083  2063500.0  ...
# 2021-09-03 09:18:00              0     14.14   0.544595  2063500.0  ...
# 2021-09-03 09:19:00              0     13.78   0.545744  2063500.0  ...
#
#                      OTM4_PE_Gamma  OTM4_PE_Theta  OTM4_PE_Vega  OTM4_PE_Rho  \
# Date/Time
# 2021-09-03 09:15:00       0.000046      -0.335532      0.128321    -0.038388
# 2021-09-03 09:16:00       0.000046      -0.336990      0.128265    -0.038423
# 2021-09-03 09:17:00       0.000047      -0.331726      0.128422    -0.038306
# 2021-09-03 09:18:00       0.000047      -0.329288      0.128497    -0.038246
# 2021-09-03 09:19:00       0.000048      -0.325014      0.128609    -0.038160
#
#                      OTM5_PE_Delta  OTM5_PE_OI  OTM5_PE_Gamma  OTM5_PE_Theta  \
# Date/Time
# 2021-09-03 09:15:00      -0.396585      9250.0       0.000039      -0.390981
# 2021-09-03 09:16:00      -0.398732      9250.0       0.000040      -0.384963
# 2021-09-03 09:17:00      -0.399044      9400.0       0.000040      -0.383140
# 2021-09-03 09:18:00      -0.400844      9400.0       0.000041      -0.377140
# 2021-09-03 09:19:00      -0.401112      9400.0       0.000041      -0.375918
#
#                      OTM5_PE_Vega  OTM5_PE_Rho
# Date/Time
# 2021-09-03 09:15:00      0.127055    -0.039581
# 2021-09-03 09:16:00      0.127204    -0.039485
# 2021-09-03 09:17:00      0.127288    -0.039428
# 2021-09-03 09:18:00      0.127472    -0.039307
# 2021-09-03 09:19:00      0.127519    -0.039273
#
# [5 rows x 163 columns]
# Greeks and Open Interest data have been populated and the DataFrame has been saved to CSV.

# %%
print(nifty_with_greeks.head())
# Out:
#                     Ticker     Open     High      Low    Close  Volume  \
# Date/Time
# 2021-09-03 09:15:00  NIFTY  17262.5  17296.8  17255.3  17293.3       0
# 2021-09-03 09:16:00  NIFTY  17292.3  17300.3  17289.0  17289.0       0
# 2021-09-03 09:17:00  NIFTY  17288.9  17298.2  17282.0  17297.3       0
# 2021-09-03 09:18:00  NIFTY  17298.8  17312.0  17296.5  17302.3       0
# 2021-09-03 09:19:00  NIFTY  17302.3  17306.7  17301.2  17306.1       0
#
#                      Open Interest  INDIAVIX  ATM_Delta     ATM_OI  ...  \
# Date/Time                                                           ...
# 2021-09-03 09:15:00              0     14.19   0.542985  1666100.0  ...
# 2021-09-03 09:16:00              0     14.21   0.541113  1666100.0  ...
# 2021-09-03 09:17:00              0     14.17   0.543083  2063500.0  ...
# 2021-09-03 09:18:00              0     14.14   0.544595  2063500.0  ...
# 2021-09-03 09:19:00              0     13.78   0.545744  2063500.0  ...
#
#                      OTM4_PE_Theta  OTM4_PE_Vega  OTM4_PE_Rho  OTM5_PE_Delta  \
# Date/Time
# 2021-09-03 09:15:00      -0.335532      0.128321    -0.038388      -0.396585
# 2021-09-03 09:16:00      -0.336990      0.128265    -0.038423      -0.398732
# 2021-09-03 09:17:00      -0.331726      0.128422    -0.038306      -0.399044
# 2021-09-03 09:18:00      -0.329288      0.128497    -0.038246      -0.400844
# 2021-09-03 09:19:00      -0.325014      0.128609    -0.038160      -0.401112
#
#                      OTM5_PE_OI  OTM5_PE_Gamma  OTM5_PE_Theta  OTM5_PE_Vega  \
# Date/Time
# 2021-09-03 09:15:00      9250.0       0.000039      -0.390981      0.127055
# 2021-09-03 09:16:00      9250.0       0.000040      -0.384963      0.127204
# 2021-09-03 09:17:00      9400.0       0.000040      -0.383140      0.127288
# 2021-09-03 09:18:00      9400.0       0.000041      -0.377140      0.127472
# 2021-09-03 09:19:00      9400.0       0.000041      -0.375918      0.127519
#
#                      OTM5_PE_Rho  PCR_Volume
# Date/Time
# 2021-09-03 09:15:00    -0.039581    0.400507
# 2021-09-03 09:16:00    -0.039485    0.475421
# 2021-09-03 09:17:00    -0.039428    0.644477
# 2021-09-03 09:18:00    -0.039307    0.492156
# 2021-09-03 09:19:00    -0.039273    0.564910
#
# [5 rows x 164 columns]

# %%
print("PCR_Volume" in nifty_with_greeks.columns)
# Out:
# True

# %%
pd.set_option('display.max_columns', None)
print(nifty_with_greeks.columns.tolist())
# Out:
# ['Ticker', 'Open', 'High', 'Low', 'Close', 'Volume', 'Open Interest', 'INDIAVIX', 'ATM_Delta', 'ATM_OI', 'ATM_Call_Volume', 'ATM_Put_Volume', 'ATM_Gamma', 'ATM_Theta', 'ATM_Vega', 'ATM_Rho', 'ITM1_Delta', 'ITM1_OI', 'ITM1_Call_Volume', 'ITM1_Put_Volume', 'ITM1_Gamma', 'ITM1_Theta', 'ITM1_Vega', 'ITM1_Rho', 'OTM1_Delta', 'OTM1_OI', 'OTM1_Call_Volume', 'OTM1_Put_Volume', 'OTM1_Gamma', 'OTM1_Theta', 'OTM1_Vega', 'OTM1_Rho', 'ITM2_Delta', 'ITM2_OI', 'ITM2_Call_Volume', 'ITM2_Put_Volume', 'ITM2_Gamma', 'ITM2_Theta', 'ITM2_Vega', 'ITM2_Rho', 'OTM2_Delta', 'OTM2_OI', 'OTM2_Call_Volume', 'OTM2_Put_Volume', 'OTM2_Gamma', 'OTM2_Theta', 'OTM2_Vega', 'OTM2_Rho', 'ITM3_Delta', 'ITM3_OI', 'ITM3_Call_Volume', 'ITM3_Put_Volume', 'ITM3_Gamma', 'ITM3_Theta', 'ITM3_Vega', 'ITM3_Rho', 'OTM3_Delta', 'OTM3_OI', 'OTM3_Call_Volume', 'OTM3_Put_Volume', 'OTM3_Gamma', 'OTM3_Theta', 'OTM3_Vega', 'OTM3_Rho', 'ITM4_Delta', 'ITM4_OI', 'ITM4_Call_Volume', 'ITM4_Put_Volume', 'ITM4_Gamma', 'ITM4_Theta', 'ITM4_Vega', 'ITM4_Rho', 'OTM4_Delta', 'OTM4_OI', 'OTM4_Call_Volume', 'OTM4_Put_Volume', 'OTM4_Gamma', 'OTM4_Theta', 'OTM4_Vega', 'OTM4_Rho', 'ITM5_Delta', 'ITM5_OI', 'ITM5_Call_Volume', 'ITM5_Put_Volume', 'ITM5_Gamma', 'ITM5_Theta', 'ITM5_Vega', 'ITM5_Rho', 'OTM5_Delta', 'OTM5_OI', 'OTM5_Call_Volume', 'OTM5_Put_Volume', 'OTM5_Gamma', 'OTM5_Theta', 'OTM5_Vega', 'OTM5_Rho', 'PCR', 'ATM_PE_Delta', 'ATM_PE_OI', 'ATM_PE_Gamma', 'ATM_PE_Theta', 'ATM_PE_Vega', 'ATM_PE_Rho', 'ITM1_PE_Delta', 'ITM1_PE_OI', 'ITM1_PE_Gamma', 'ITM1_PE_Theta', 'ITM1_PE_Vega', 'ITM1_PE_Rho', 'ITM2_PE_Delta', 'ITM2_PE_OI', 'ITM2_PE_Gamma', 'ITM2_PE_Theta', 'ITM2_PE_Vega', 'ITM2_PE_Rho', 'ITM3_PE_Delta', 'ITM3_PE_OI', 'ITM3_PE_Gamma', 'ITM3_PE_Theta', 'ITM3_PE_Vega', 'ITM3_PE_Rho', 'ITM4_PE_Delta', 'ITM4_PE_OI', 'ITM4_PE_Gamma', 'ITM4_PE_Theta', 'ITM4_PE_Vega', 'ITM4_PE_Rho', 'ITM5_PE_Delta', 'ITM5_PE_OI', 'ITM5_PE_Gamma', 'ITM5_PE_Theta', 'ITM5_PE_Vega', 'ITM5_PE_Rho', 'OTM1_PE_Delta', 'OTM1_PE_OI', 'OTM1_PE_Gamma', 'OTM1_PE_Theta', 'OTM1_PE_Vega', 'OTM1_PE_Rho', 'OTM2_PE_Delta', 'OTM2_PE_OI', 'OTM2_PE_Gamma', 'OTM2_PE_Theta', 'OTM2_PE_Vega', 'OTM2_PE_Rho', 'OTM3_PE_Delta', 'OTM3_PE_OI', 'OTM3_PE_Gamma', 'OTM3_PE_Theta', 'OTM3_PE_Vega', 'OTM3_PE_Rho', 'OTM4_PE_Delta', 'OTM4_PE_OI', 'OTM4_PE_Gamma', 'OTM4_PE_Theta', 'OTM4_PE_Vega', 'OTM4_PE_Rho', 'OTM5_PE_Delta', 'OTM5_PE_OI', 'OTM5_PE_Gamma', 'OTM5_PE_Theta', 'OTM5_PE_Vega', 'OTM5_PE_Rho', 'PCR_Volume']

# %%
print(nifty_with_greeks['PCR_Volume'])
# Out:
# Date/Time
# 2021-09-03 09:15:00    0.400507
# 2021-09-03 09:16:00    0.475421
# 2021-09-03 09:17:00    0.644477
# 2021-09-03 09:18:00    0.492156
# 2021-09-03 09:19:00    0.564910
#                          ...
# 2021-09-16 15:26:00    2.357391
# 2021-09-16 15:27:00    1.685187
# 2021-09-16 15:28:00    1.463176
# 2021-09-16 15:29:00    1.982279
# 2021-09-16 15:30:00    1.982279
# Name: PCR_Volume, Length: 3384, dtype: float64
