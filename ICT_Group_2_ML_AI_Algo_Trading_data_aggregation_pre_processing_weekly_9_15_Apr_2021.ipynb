# %% [markdown]
# <a href="https://colab.research.google.com/github/jjikku/OptiGene-Algo/blob/main/ICT_Group_2_ML_AI_Algo_Trading_data_aggregation_pre_processing_weekly_9_15_Apr_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# Specify the exact path to the CSV file
file_path = "/content/drive/My Drive/NIfty_Dataset/09_15_APR_2021_weekly_Expirydata_VEGE_NF_AND_BNF_Options_shortweek.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Exclude rows where the ticker contains any of the following
excluded_tickers = [
    "BANKNIFTY", "FINNIFTY", "FUT", "NIFTYAUTO", "NIFTYENERGY",
    "NIFTYFINSERVICE", "NIFTYFMCG", "NIFTYINFRA", "NIFTYIT", "NIFTYMEDIA",
    "NIFTYMETAL", "NIFTYMIDCAP50", "NIFTYPHARMA", "NIFTYPSUBANK",
    "NIFTYREALTY", "USDINR-I"
]

# Create a regular expression pattern that matches any of the excluded tickers
pattern = '|'.join(excluded_tickers)

# Apply the mask to filter the DataFrame
mask = ~df['Ticker'].str.contains(pattern)
df_filtered = df[mask]

# Get unique values in the 'Ticker' column after filtering
unique_tickers = df_filtered['Ticker'].unique()

# Extract all rows that match the unique tickers
final_df = df[df['Ticker'].isin(unique_tickers)]

# Create a new CSV file with the extracted rows
output_file_path = "/content/drive/My Drive/NIfty_Dataset/weekly_filtered_tickers_data_09_15_APR.csv"
final_df.to_csv(output_file_path, index=False)

print(f"Created new CSV file at: {output_file_path}")
# Out:
# Mounted at /content/drive
# Created new CSV file at: /content/drive/My Drive/NIfty_Dataset/weekly_filtered_tickers_data_09_15_APR.csv

# %%
# print(unique_tickers)

# %%
# final_df.count()

# %%
# final_df['Open Interest'].count()

# %%
# non_zero_count = final_df['Open Interest'].ne(0).sum()
# print(f"The count of non-zero 'Open Interest' values is: {non_zero_count}")

# %%
# Create a separate DataFrame for each unique ticker and store it in a dictionary
dfs = {ticker: df[df['Ticker'] == ticker] for ticker in unique_tickers}

# Now dfs is a dictionary with tickers as keys and the corresponding DataFrame as values

# Assuming df is your original DataFrame with all tickers
for ticker in unique_tickers:
    # Select the DataFrame for the current ticker
    ticker_df = df[df['Ticker'] == ticker].copy()  # Use copy to avoid SettingWithCopyWarning

    # Convert 'Date/Time' to datetime and set as index
    ticker_df['Date/Time'] = pd.to_datetime(ticker_df['Date/Time'], format='%d-%m-%Y %H:%M:%S')
    ticker_df.set_index('Date/Time', inplace=True)

    # Remove duplicate indices if any
    ticker_df = ticker_df[~ticker_df.index.duplicated(keep='first')]

    # Assign the processed DataFrame back to the dfs dictionary
    dfs[ticker] = ticker_df

# Now dfs is a dictionary where each value is a DataFrame with 'Date/Time' as a datetime index

# %%
# Iterate through the dfs dictionary
for ticker, dataframe in dfs.items():
    # Check if the ticker ends with 'PE' or 'CE'
    if ticker.endswith('PE') or ticker.endswith('CE'):
        # Forward fill any NaN values
        dataframe['Open Interest'] = dataframe['Open Interest'].fillna(method='ffill')

        # Replace zero values with the forward filled values
        dataframe['Open Interest'] = dataframe['Open Interest'].replace(to_replace=0, method='ffill')

        # Assign the processed DataFrame back to the dfs dictionary
        dfs[ticker] = dataframe

# %%
import numpy as np
# Get the DataFrame for NIFTY as the reference
reference_df = dfs['NIFTY'].copy()

# Get all timestamps from the NIFTY DataFrame
reference_timestamps = reference_df.index
print("REF",reference_timestamps)

# Function to insert missing timestamps into a DataFrame
def insert_missing_timestamps(df, reference_ts):
    # Ensure the DataFrame index is unique and sorted
    df = df[~df.index.duplicated(keep='first')].sort_index()

    # Find the missing timestamps
    missing_timestamps = reference_ts.difference(df.index)

    # Insert rows with NaNs for missing timestamps
    for ts in missing_timestamps:
        if ts not in df.index:
            df.loc[ts] = [np.nan] * len(df.columns)

    # Sort the DataFrame after inserting new rows
    df.sort_index(inplace=True)

    return df

# Iterate over each DataFrame in dfs
for ticker, dataframe in dfs.items():
    if ticker != 'NIFTY':  # Skip the NIFTY DataFrame as it is the reference
        # Insert missing timestamps without altering existing data
        print("TICKER",ticker)
        dfs[ticker] = insert_missing_timestamps(dataframe, reference_timestamps)
# Out:
# REF DatetimeIndex(['2021-04-09 09:15:00', '2021-04-09 09:16:00',
#                '2021-04-09 09:17:00', '2021-04-09 09:18:00',
#                '2021-04-09 09:19:00', '2021-04-09 09:20:00',
#                '2021-04-09 09:21:00', '2021-04-09 09:22:00',
#                '2021-04-09 09:23:00', '2021-04-09 09:24:00',
#                ...
#                '2021-04-15 15:21:00', '2021-04-15 15:22:00',
#                '2021-04-15 15:23:00', '2021-04-15 15:24:00',
#                '2021-04-15 15:25:00', '2021-04-15 15:26:00',
#                '2021-04-15 15:27:00', '2021-04-15 15:28:00',
#                '2021-04-15 15:29:00', '2021-04-15 15:30:00'],
#               dtype='datetime64[ns]', name='Date/Time', length=1504, freq=None)
# TICKER INDIAVIX
# TICKER NIFTYWK13000CE
# TICKER NIFTYWK13000PE
# TICKER NIFTYWK13050CE
# TICKER NIFTYWK13050PE
# TICKER NIFTYWK13100CE
# TICKER NIFTYWK13100PE
# TICKER NIFTYWK13150CE
# TICKER NIFTYWK13150PE
# TICKER NIFTYWK13200CE
# TICKER NIFTYWK13200PE
# TICKER NIFTYWK13250CE
# TICKER NIFTYWK13250PE
# TICKER NIFTYWK13300CE
# TICKER NIFTYWK13300PE
# TICKER NIFTYWK13350CE
# TICKER NIFTYWK13350PE
# TICKER NIFTYWK13400CE
# TICKER NIFTYWK13400PE
# TICKER NIFTYWK13450CE
# TICKER NIFTYWK13450PE
# TICKER NIFTYWK13500CE
# TICKER NIFTYWK13500PE
# TICKER NIFTYWK13550CE
# TICKER NIFTYWK13600CE
# TICKER NIFTYWK13600PE
# TICKER NIFTYWK13650CE
# TICKER NIFTYWK13650PE
# TICKER NIFTYWK13700CE
# TICKER NIFTYWK13700PE
# TICKER NIFTYWK13750CE
# TICKER NIFTYWK13750PE
# TICKER NIFTYWK13800CE
# TICKER NIFTYWK13800PE
# TICKER NIFTYWK13850CE
# TICKER NIFTYWK13850PE
# TICKER NIFTYWK13900CE
# TICKER NIFTYWK13900PE
# TICKER NIFTYWK13950CE
# TICKER NIFTYWK13950PE
# TICKER NIFTYWK14000CE
# TICKER NIFTYWK14000PE
# TICKER NIFTYWK14050CE
# TICKER NIFTYWK14050PE
# TICKER NIFTYWK14100CE
# TICKER NIFTYWK14100PE
# TICKER NIFTYWK14150CE
# TICKER NIFTYWK14150PE
# TICKER NIFTYWK14200CE
# TICKER NIFTYWK14200PE
# TICKER NIFTYWK14250CE
# TICKER NIFTYWK14250PE
# TICKER NIFTYWK14300CE
# TICKER NIFTYWK14300PE
# TICKER NIFTYWK14350CE
# TICKER NIFTYWK14350PE
# TICKER NIFTYWK14400CE
# TICKER NIFTYWK14400PE
# TICKER NIFTYWK14450CE
# TICKER NIFTYWK14450PE
# TICKER NIFTYWK14500CE
# TICKER NIFTYWK14500PE
# TICKER NIFTYWK14550CE
# TICKER NIFTYWK14550PE
# TICKER NIFTYWK14600CE
# TICKER NIFTYWK14600PE
# TICKER NIFTYWK14650CE
# TICKER NIFTYWK14650PE
# TICKER NIFTYWK14700CE
# TICKER NIFTYWK14700PE
# TICKER NIFTYWK14750CE
# TICKER NIFTYWK14750PE
# TICKER NIFTYWK14800CE
# TICKER NIFTYWK14800PE
# TICKER NIFTYWK14850CE
# TICKER NIFTYWK14850PE
# TICKER NIFTYWK14900CE
# TICKER NIFTYWK14900PE
# TICKER NIFTYWK14950CE
# TICKER NIFTYWK14950PE
# TICKER NIFTYWK15000CE
# TICKER NIFTYWK15000PE
# TICKER NIFTYWK15050CE
# TICKER NIFTYWK15050PE
# TICKER NIFTYWK15100CE
# TICKER NIFTYWK15100PE
# TICKER NIFTYWK15150CE
# TICKER NIFTYWK15150PE
# TICKER NIFTYWK15200CE
# TICKER NIFTYWK15200PE
# TICKER NIFTYWK15250CE
# TICKER NIFTYWK15250PE
# TICKER NIFTYWK15300CE
# TICKER NIFTYWK15300PE
# TICKER NIFTYWK15350CE
# TICKER NIFTYWK15350PE
# TICKER NIFTYWK15400CE
# TICKER NIFTYWK15400PE
# TICKER NIFTYWK15450CE
# TICKER NIFTYWK15450PE
# TICKER NIFTYWK15500CE
# TICKER NIFTYWK15500PE
# TICKER NIFTYWK15550CE
# TICKER NIFTYWK15550PE
# TICKER NIFTYWK15600CE
# TICKER NIFTYWK15600PE
# TICKER NIFTYWK15650CE
# TICKER NIFTYWK15650PE
# TICKER NIFTYWK15700CE
# TICKER NIFTYWK15700PE
# TICKER NIFTYWK15750CE
# TICKER NIFTYWK15750PE
# TICKER NIFTYWK15800CE
# TICKER NIFTYWK15800PE
# TICKER NIFTYWK15850CE
# TICKER NIFTYWK15850PE
# TICKER NIFTYWK15900CE
# TICKER NIFTYWK15900PE
# TICKER NIFTYWK15950CE
# TICKER NIFTYWK15950PE
# TICKER NIFTYWK16000CE
# TICKER NIFTYWK16000PE

# %%
# # Define trading hours
# trading_hours = pd.date_range(start='09:15:00', end='15:30:00', freq='1min')

# # Get the DataFrame for NIFTY as the reference
# reference_df = dfs['NIFTY'].copy()

# # Generate a full range of timestamps for all trading days in the reference NIFTY DataFrame
# all_trading_days = reference_df.index.normalize().unique()
# all_possible_timestamps = pd.DatetimeIndex([pd.Timestamp(day) + pd.Timedelta(minutes=m.minute + m.hour * 60)
#                                             for day in all_trading_days for m in trading_hours])

# # Now update all DataFrames in dfs to have the same timestamps as the reference NIFTY DataFrame
# for ticker, dataframe in dfs.items():
#     # Reindex to the full range of possible timestamps, forward filling the missing data
#     dataframe = dataframe.reindex(all_possible_timestamps, method='ffill')

#     # Forward fill the Open Interest, if the ticker ends with 'PE' or 'CE'
#     if ticker.endswith(('PE', 'CE')):
#         dataframe['Open Interest'].fillna(method='ffill', inplace=True)
#         dataframe['Open Interest'].replace(to_replace=0, method='ffill', inplace=True)

#     # Update the dictionary with the modified DataFrame
#     dfs[ticker] = dataframe

# # After this loop, each DataFrame in dfs should have no missing timestamps and the 'Open Interest' column should be forward filled.

# %%
# Define the market open and close times
market_open_time = '09:15:00'
market_close_time = '15:30:00'

# Create a new dictionary to store the filled DataFrames
filled_dfs = {}

for ticker, dataframe in dfs.items():
    # Copy the DataFrame to avoid modifying the original
    df_filled = dataframe.copy()

    # Get unique trading days
    trading_days = df_filled.index.normalize().unique()

    # Forward fill for each day
    for day in trading_days:
        # Select the data for the current trading day
        day_data = df_filled[df_filled.index.date == day.date()]

        # Forward fill the data for the current day
        df_filled.loc[day_data.index] = day_data.fillna(method='ffill')

    # Now, backward fill the entire DataFrame to cover the start of the day
    df_filled = df_filled.fillna(method='bfill')

    # Assign the filled DataFrame to the new dictionary
    filled_dfs[ticker] = df_filled

# %%
# Assuming filled_dfs is your dictionary containing DataFrames with filled values
for ticker in unique_tickers:
    # Select the DataFrame for the current ticker
    ticker_df = filled_dfs[ticker].copy()  # Use copy to avoid SettingWithCopyWarning

    # Since filled_dfs already contains the DataFrames with 'Date/Time' as a datetime index,
    #  do not need to convert 'Date/Time' again, and  can use ticker_df directly if needed

    # Remove duplicate indices if any (if this step is still necessary)
    ticker_df = ticker_df[~ticker_df.index.duplicated(keep='first')]


    # Assign the processed DataFrame back to the dfs dictionary
    dfs[ticker] = ticker_df

# Now dfs is a dictionary where each value is a DataFrame with 'Date/Time' as a datetime index

# %%
print(dfs['NIFTY'])
# Out:
#                     Ticker     Open     High      Low    Close  Volume  \
# Date/Time
# 2021-04-09 09:15:00  NIFTY  14882.6  14882.6  14822.9  14837.6       1
# 2021-04-09 09:16:00  NIFTY  14839.2  14846.4  14817.1  14846.4       1
# 2021-04-09 09:17:00  NIFTY  14848.1  14877.2  14848.1  14861.6       1
# 2021-04-09 09:18:00  NIFTY  14862.9  14862.9  14845.5  14847.1       1
# 2021-04-09 09:19:00  NIFTY  14841.0  14844.5  14833.1  14837.0       1
# ...                    ...      ...      ...      ...      ...     ...
# 2021-04-15 15:26:00  NIFTY  14593.5  14595.2  14592.4  14593.1       0
# 2021-04-15 15:27:00  NIFTY  14593.9  14596.0  14592.0  14592.4       0
# 2021-04-15 15:28:00  NIFTY  14593.0  14597.5  14587.0  14587.0       0
# 2021-04-15 15:29:00  NIFTY  14586.9  14590.7  14581.7  14589.4       0
# 2021-04-15 15:30:00  NIFTY  14587.4  14587.4  14587.4  14587.4       0
#
#                      Open Interest
# Date/Time
# 2021-04-09 09:15:00              0
# 2021-04-09 09:16:00              0
# 2021-04-09 09:17:00              0
# 2021-04-09 09:18:00              0
# 2021-04-09 09:19:00              0
# ...                            ...
# 2021-04-15 15:26:00              0
# 2021-04-15 15:27:00              0
# 2021-04-15 15:28:00              0
# 2021-04-15 15:29:00              0
# 2021-04-15 15:30:00              0
#
# [1504 rows x 7 columns]

# %%
# Assuming dfs['NIFTY'] is the DataFrame you want to save
nifty_df = dfs['NIFTY']

# Specify the path in your Google Drive where you want to save the CSV
csv_file_path = '/content/drive/My Drive/NIfty_Dataset/NIFTY_09_15_APR_2021.csv'

# Save the DataFrame to CSV
nifty_df.to_csv(csv_file_path, index=True)

print(f"DataFrame saved to {csv_file_path}")
# Out:
# DataFrame saved to /content/drive/My Drive/NIfty_Dataset/NIFTY_09_15_APR_2021.csv

# %%
# Assuming dfs['NIFTY'] is the DataFrame you want to save
indiavix_df = dfs['INDIAVIX']

# Specify the path in your Google Drive where you want to save the CSV
csv_file_path = '/content/drive/My Drive/NIfty_Dataset/INDIAVIX_09_15_APR_2021.csv'

# Save the DataFrame to CSV
indiavix_df.to_csv(csv_file_path, index=True)

print(f"DataFrame saved to {csv_file_path}")
# Out:
# DataFrame saved to /content/drive/My Drive/NIfty_Dataset/INDIAVIX_09_15_APR_2021.csv

# %%
# !pip install mibian
# Out:
# Collecting mibian
#   Downloading mibian-0.1.3.zip (4.3 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mibian
#   Building wheel for mibian (setup.py) ... done
#   Created wheel for mibian: filename=mibian-0.1.3-py3-none-any.whl size=4024 sha256=a97627fdfee2762909cb8af58a74eacdca8d085fa9c259c4ba0e5317db9982d2
#   Stored in directory: /root/.cache/pip/wheels/2c/4f/a7/be034e17cc306b0850f5f1a5b4541281b49475c58620a7ff40
# Successfully built mibian
# Installing collected packages: mibian
# Successfully installed mibian-0.1.3

# %%
indiavix_df = pd.read_csv('/content/drive/My Drive/NIfty_Dataset/INDIAVIX_09_15_APR_2021.csv')
# Print the columns to check the exact name of the 'Date/Time' column
print(indiavix_df.columns)
# Out:
# Index(['Date/Time', 'Ticker', 'Open', 'High', 'Low', 'Close', 'Volume',
#        'Open Interest'],
#       dtype='object')

# %%
print(indiavix_df.index)
# Out:
# RangeIndex(start=0, stop=1504, step=1)

# %%
# !pip install datetime
# Out:
# Collecting datetime
#   Downloading DateTime-5.3-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 2.1 MB/s eta 0:00:00
# Collecting zope.interface (from datetime)
#   Downloading zope.interface-6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from datetime) (2023.3.post1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from zope.interface->datetime) (67.7.2)
# Installing collected packages: zope.interface, datetime
# Successfully installed datetime-5.3 zope.interface-6.1

# %%
import pandas as pd
import numpy as np
import mibian
from datetime import time, datetime, timedelta


indiavix_df = pd.read_csv('/content/drive/My Drive/NIfty_Dataset/INDIAVIX_09_15_APR_2021.csv', index_col='Date/Time', parse_dates=['Date/Time'])
indiavix_df.rename(columns={'Close': 'INDIAVIX'}, inplace=True)

# Load the NIFTY data
nifty_df = pd.read_csv('/content/drive/My Drive/NIfty_Dataset/NIFTY_09_15_APR_2021.csv', index_col='Date/Time', parse_dates=['Date/Time'])

# Join INDIAVIX data with NIFTY data
nifty_df = nifty_df.join(indiavix_df['INDIAVIX'], how='left')
nifty_df['INDIAVIX'].fillna(method='ffill', inplace=True)  # Fill NaN values with the forward fill method


# Check if the 'INDIAVIX' column exists after the join operation
if 'INDIAVIX' not in nifty_df.columns:
    raise KeyError('The INDIAVIX column was not found after the join operation. Please check the column names and join operation.')

print("NIFTYDF",nifty_df)
print("columns",nifty_df.columns)

# Constants
interest_rate = 3.32  # 3-month Indian government bond yield as annual percentage
days_in_year = 365  # Days in a year for the Greeks' calculations
strike_step = 50  # Known step between strike prices
minutes_in_a_year = 365 * 24 * 60  # Total minutes in a year
market_close_time = time(15, 30)



def calculate_minutes_to_expiry(current_timestamp, expiry_date, market_close_time):
    # Ensure market_close_time is a datetime.time object
    if isinstance(market_close_time, pd.Timestamp):
        market_close_time = market_close_time.time()

    closing_time = datetime.combine(expiry_date, market_close_time)

    # If the current timestamp is on the expiry date
    if current_timestamp.date() == expiry_date.date():
        # Calculate the remaining time until market close
        return max(int((closing_time - current_timestamp).total_seconds() / 60), 0)
    else:
        # Calculate time from the current timestamp to the end of day
        end_of_day = datetime.combine(current_timestamp.date(), time(23, 59))  # Last minute of the current day
        minutes_today = int((end_of_day - current_timestamp).total_seconds() / 60) + 1  # Plus one for the last minute

        # Calculate full days until the expiry date
        full_days = (expiry_date.date() - current_timestamp.date()).days - 1  # Minus one because we already counted today

        # Calculate minutes from the start of the expiry day to the market close
        start_of_expiry_day = datetime.combine(expiry_date.date(), time(0, 0))  # Midnight of the expiry day
        minutes_expiry_day = int((closing_time - start_of_expiry_day).total_seconds() / 60)

        # Total minutes is the sum of all parts
        return minutes_today + (full_days * 24 * 60) + minutes_expiry_day


# Function to calculate the Greeks using the Black-Scholes model
def calculate_greeks(underlying_price, strike_price, minutes_to_expiry, volatility, interest_rate, option_type):
    # Convert minutes to expiry into years for the Black-Scholes model
    time_to_expiry_in_years = minutes_to_expiry / minutes_in_a_year

    # Ensure we do not have a division by zero or negative time to expiry
    if time_to_expiry_in_years <= 0:
        return {greek: 0 for greek in ['Delta', 'Gamma', 'Theta', 'Vega', 'Rho']}

    # Convert annual interest rate and volatility from percentages to decimals
    annual_interest_rate = interest_rate / 100
    annual_volatility = volatility / 100

    # Black-Scholes model calculations
    bs = mibian.BS([underlying_price, strike_price, annual_interest_rate * 100, time_to_expiry_in_years * 365], volatility=annual_volatility * 100)

    # Return a dictionary of Greeks
    return {
        'Delta': bs.callDelta if option_type == 'call' else bs.putDelta,
        'Gamma': bs.gamma,
        'Theta': bs.callTheta / 365 if option_type == 'call' else bs.putTheta / 365,
        'Vega': bs.vega / 100,  # per 1% change in IV
        'Rho': bs.callRho / 100 if option_type == 'call' else bs.putRho / 100  # per 1% change in interest rate
    }


# Function to populate the DataFrame with strikes and Greeks
def populate_greeks(nifty_df, indiavix_df, strike_step, dfs):

    expiry_date = nifty_df.index.max().normalize() + pd.Timedelta(hours=15, minutes=30)
    print("EXPIRY DAY", expiry_date)
    market_close_time = expiry_date #pd.to_datetime(expiry_date.strftime('%Y-%m-%d') + ' 15:30:00')  # Assuming 3:30 PM market close

    # Create columns for Greeks in the dataframe
    for strike_type in ['ATM', 'ITM1', 'OTM1', 'ITM2', 'OTM2', 'ITM3', 'OTM3', 'ITM4', 'OTM4', 'ITM5', 'OTM5']:
        for greek in ['Delta', 'Gamma', 'Theta', 'Vega', 'Rho']:
            nifty_df[f'{strike_type}_{greek}'] = np.nan
            nifty_df[f'{strike_type}_OI'] = np.nan
            nifty_df[f'{strike_type}_Call_Volume'] = np.nan
            nifty_df[f'{strike_type}_Put_Volume'] = np.nan

    nifty_df['PCR'] = np.nan

    # Iterate over the dataframe and calculate Greeks
    for timestamp, row in nifty_df.iterrows():
        total_call_oi = 0
        total_put_oi = 0
        nifty_close = row['Close']
        # Find ATM, ITM, and OTM strikes
        atm_strike = int(round(nifty_close / strike_step) * strike_step)  # Closest strike
        itm_strikes = [atm_strike - i * strike_step for i in range(1, 6)]
        otm_strikes = [atm_strike + i * strike_step for i in range(1, 6)]
        all_strikes = [atm_strike] + itm_strikes + otm_strikes

        print(f"Processing timestamp: {timestamp}")

        # Get VIX value for the timestamp
        vix_value = indiavix_df.loc[timestamp, 'INDIAVIX'] if timestamp in indiavix_df.index else np.nan
        if vix_value is None:
            print(f"VIX value is missing for timestamp: {timestamp}")
            continue  # Skip this iteration if VIX value is missing


        minutes_to_expiry = calculate_minutes_to_expiry(timestamp, expiry_date, market_close_time)
        print("Current time & days to expiry:", timestamp.date(), minutes_to_expiry / (60 * 24))

        print("Curr time & days to EXpiry", timestamp.date(),minutes_to_expiry/(60*24))
        # Calculate Greeks for all strikes
        for i, strike in enumerate(all_strikes, start=1):
            if i == 1:  # ATM
                strike_type = 'ATM'
            elif i <= 6:  # ITM strikes
                strike_type = f'ITM{i-1}'
            else:  # OTM strikes
                strike_type = f'OTM{i-6}'

            call_key = f'NIFTYWK{strike}CE'
            put_key = f'NIFTYWK{strike}PE'

            call_volume = dfs[call_key].loc[timestamp, 'Volume'] if timestamp in dfs[call_key].index else np.nan
            put_volume = dfs[put_key].loc[timestamp, 'Volume'] if timestamp in dfs[put_key].index else np.nan

            # Populate volume data
            nifty_df.at[timestamp, f'{strike_type}_Call_Volume'] = call_volume
            nifty_df.at[timestamp, f'{strike_type}_Put_Volume'] = put_volume

            # print(f"Retrieving data for strike {strike} ({call_key} and {put_key})")

             # Check if the keys are present in the dfs dictionary
            if call_key not in dfs or put_key not in dfs:
                print(f"Missing data for strike {strike}: {call_key} or {put_key} not in dfs")
                continue

            # Check if the timestamp exists in the dfs DataFrames
            if timestamp not in dfs[call_key].index:
                print(f"Timestamp {timestamp} not found in dfs for {call_key}")
                continue
            if timestamp not in dfs[put_key].index:
                print(f"Timestamp {timestamp} not found in dfs for {put_key}")
                continue

            call_close = dfs[call_key].loc[timestamp, 'Close'] if timestamp in dfs[call_key].index else np.nan
            put_close = dfs[put_key].loc[timestamp, 'Close'] if timestamp in dfs[put_key].index else np.nan
            call_oi = dfs[call_key].loc[timestamp, 'Open Interest'] if timestamp in dfs[call_key].index else np.nan
            put_oi = dfs[put_key].loc[timestamp, 'Open Interest'] if timestamp in dfs[put_key].index else np.nan
            # print(f"Call Close: {call_close}, Put Close: {put_close}, Call OI: {call_oi}, Put OI: {put_oi}")

            #print("STRIKE",nifty_close, strike)
            # Calculate Greeks using the close prices
            if not np.isnan(call_close):
                greeks = calculate_greeks(nifty_close, strike, minutes_to_expiry, call_close, interest_rate, option_type='call')
                # Populate Greeks for call
                for greek_name, greek_value in greeks.items():
                    nifty_df.at[timestamp, f'{strike_type}_{greek_name}'] = greek_value
                    nifty_df.at[timestamp, f'{strike_type}_OI'] = call_oi  # Populate OI for call

            if not np.isnan(put_close):
                greeks = calculate_greeks(nifty_close, strike, minutes_to_expiry, put_close, interest_rate, option_type='put')
                # Populate Greeks for put
                for greek_name, greek_value in greeks.items():
                    nifty_df.at[timestamp, f'{strike_type}_PE_{greek_name}'] = greek_value
                    nifty_df.at[timestamp, f'{strike_type}_PE_OI'] = put_oi  # Populate OI for put

    return nifty_df

# Populate the DataFrame with Greeks
nifty_with_greeks = populate_greeks(nifty_df, indiavix_df, strike_step, dfs)

def calculate_pcr(row):
    total_call_oi = sum(row.get(f'{strike}_OI', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    total_put_oi = sum(row.get(f'{strike}_PE_OI', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    print("OI", total_call_oi, total_put_oi)
    return total_put_oi / total_call_oi if total_call_oi != 0 else np.nan

# Function to calculate PCR for volume
def calculate_pcr_volume(row):
    total_call_volume = sum(row.get(f'{strike}_Call_Volume', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    total_put_volume = sum(row.get(f'{strike}_Put_Volume', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    return total_put_volume / total_call_volume if total_call_volume != 0 else np.nan

# Apply PCR calculation to each row
nifty_with_greeks['PCR'] = nifty_with_greeks.apply(calculate_pcr, axis=1)
print(nifty_with_greeks.head())
# Apply PCR calculation for volume to each row
nifty_with_greeks['PCR_Volume'] = nifty_with_greeks.apply(calculate_pcr_volume, axis=1)
# # Output the DataFrame to a CSV
nifty_with_greeks.to_csv('/content/drive/My Drive/NIfty_Dataset/NIFTY_with_Greeks_09_15_APR_2021.csv')

print("Greeks and Open Interest data have been populated and the DataFrame has been saved to CSV.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Curr time & days to EXpiry 2021-04-09 6.0159722222222225
# Processing timestamp: 2021-04-09 15:08:00
# Current time & days to expiry: 2021-04-09 6.0152777777777775
# Curr time & days to EXpiry 2021-04-09 6.0152777777777775
# Processing timestamp: 2021-04-09 15:09:00
# Current time & days to expiry: 2021-04-09 6.014583333333333
# Curr time & days to EXpiry 2021-04-09 6.014583333333333
# Processing timestamp: 2021-04-09 15:10:00
# Current time & days to expiry: 2021-04-09 6.013888888888889
# Curr time & days to EXpiry 2021-04-09 6.013888888888889
# Processing timestamp: 2021-04-09 15:11:00
# Current time & days to expiry: 2021-04-09 6.013194444444444
# Curr time & days to EXpiry 2021-04-09 6.013194444444444
# Processing timestamp: 2021-04-09 15:12:00
# Current time & days to expiry: 2021-04-09 6.0125
# Curr time & days to EXpiry 2021-04-09 6.0125
# Processing timestamp: 2021-04-09 15:13:00
# Current time & days to expiry: 2021-04-09 6.011805555555555
# Curr time & days to EXpiry 2021-04-09 6.011805555555555
# Processing timestamp: 2021-04-09 15:14:00
# Current time & days to expiry: 2021-04-09 6.011111111111111
# Curr time & days to EXpiry 2021-04-09 6.011111111111111
# Processing timestamp: 2021-04-09 15:15:00
# Current time & days to expiry: 2021-04-09 6.010416666666667
# Curr time & days to EXpiry 2021-04-09 6.010416666666667
# Processing timestamp: 2021-04-09 15:16:00
# Current time & days to expiry: 2021-04-09 6.009722222222222
# Curr time & days to EXpiry 2021-04-09 6.009722222222222
# Processing timestamp: 2021-04-09 15:17:00
# Current time & days to expiry: 2021-04-09 6.009027777777778
# Curr time & days to EXpiry 2021-04-09 6.009027777777778
# Processing timestamp: 2021-04-09 15:18:00
# Current time & days to expiry: 2021-04-09 6.008333333333334
# Curr time & days to EXpiry 2021-04-09 6.008333333333334
# Processing timestamp: 2021-04-09 15:19:00
# Current time & days to expiry: 2021-04-09 6.007638888888889
# Curr time & days to EXpiry 2021-04-09 6.007638888888889
# Processing timestamp: 2021-04-09 15:20:00
# Current time & days to expiry: 2021-04-09 6.006944444444445
# Curr time & days to EXpiry 2021-04-09 6.006944444444445
# Processing timestamp: 2021-04-09 15:21:00
# Current time & days to expiry: 2021-04-09 6.00625
# Curr time & days to EXpiry 2021-04-09 6.00625
# Processing timestamp: 2021-04-09 15:22:00
# Current time & days to expiry: 2021-04-09 6.0055555555555555
# Curr time & days to EXpiry 2021-04-09 6.0055555555555555
# Processing timestamp: 2021-04-09 15:23:00
# Current time & days to expiry: 2021-04-09 6.004861111111111
# Curr time & days to EXpiry 2021-04-09 6.004861111111111
# Processing timestamp: 2021-04-09 15:24:00
# Current time & days to expiry: 2021-04-09 6.004166666666666
# Curr time & days to EXpiry 2021-04-09 6.004166666666666
# Processing timestamp: 2021-04-09 15:25:00
# Current time & days to expiry: 2021-04-09 6.003472222222222
# Curr time & days to EXpiry 2021-04-09 6.003472222222222
# Processing timestamp: 2021-04-09 15:26:00
# Current time & days to expiry: 2021-04-09 6.002777777777778
# Curr time & days to EXpiry 2021-04-09 6.002777777777778
# Processing timestamp: 2021-04-09 15:27:00
# Current time & days to expiry: 2021-04-09 6.002083333333333
# Curr time & days to EXpiry 2021-04-09 6.002083333333333
# Processing timestamp: 2021-04-09 15:28:00
# Current time & days to expiry: 2021-04-09 6.001388888888889
# Curr time & days to EXpiry 2021-04-09 6.001388888888889
# Processing timestamp: 2021-04-09 15:29:00
# Current time & days to expiry: 2021-04-09 6.000694444444444
# Curr time & days to EXpiry 2021-04-09 6.000694444444444
# Processing timestamp: 2021-04-09 15:30:00
# Current time & days to expiry: 2021-04-09 6.0
# Curr time & days to EXpiry 2021-04-09 6.0
# Processing timestamp: 2021-04-12 09:15:00
# Current time & days to expiry: 2021-04-12 3.2604166666666665
# Curr time & days to EXpiry 2021-04-12 3.2604166666666665
# Processing timestamp: 2021-04-12 09:16:00
# Current time & days to expiry: 2021-04-12 3.2597222222222224
# Curr time & days to EXpiry 2021-04-12 3.2597222222222224
# Processing timestamp: 2021-04-12 09:17:00
# Current time & days to expiry: 2021-04-12 3.259027777777778
# Curr time & days to EXpiry 2021-04-12 3.259027777777778
# Processing timestamp: 2021-04-12 09:18:00
# Current time & days to expiry: 2021-04-12 3.2583333333333333
# Curr time & days to EXpiry 2021-04-12 3.2583333333333333
# Processing timestamp: 2021-04-12 09:19:00
# Current time & days to expiry: 2021-04-12 3.2576388888888888
# Curr time & days to EXpiry 2021-04-12 3.2576388888888888
# Processing timestamp: 2021-04-12 09:20:00
# Current time & days to expiry: 2021-04-12 3.2569444444444446
# Curr time & days to EXpiry 2021-04-12 3.2569444444444446
# Processing timestamp: 2021-04-12 09:21:00
# Current time & days to expiry: 2021-04-12 3.25625
# Curr time & days to EXpiry 2021-04-12 3.25625
# Processing timestamp: 2021-04-12 09:22:00
# Current time & days to expiry: 2021-04-12 3.2555555555555555
# Curr time & days to EXpiry 2021-04-12 3.2555555555555555
# Processing timestamp: 2021-04-12 09:23:00
# Current time & days to expiry: 2021-04-12 3.254861111111111
# Curr time & days to EXpiry 2021-04-12 3.254861111111111
# Processing timestamp: 2021-04-12 09:24:00
# Current time & days to expiry: 2021-04-12 3.254166666666667
# Curr time & days to EXpiry 2021-04-12 3.254166666666667
# Processing timestamp: 2021-04-12 09:25:00
# Current time & days to expiry: 2021-04-12 3.2534722222222223
# Curr time & days to EXpiry 2021-04-12 3.2534722222222223
# Processing timestamp: 2021-04-12 09:26:00
# Current time & days to expiry: 2021-04-12 3.2527777777777778
# Curr time & days to EXpiry 2021-04-12 3.2527777777777778
# Processing timestamp: 2021-04-12 09:27:00
# Current time & days to expiry: 2021-04-12 3.252083333333333
# Curr time & days to EXpiry 2021-04-12 3.252083333333333
# Processing timestamp: 2021-04-12 09:28:00
# Current time & days to expiry: 2021-04-12 3.251388888888889
# Curr time & days to EXpiry 2021-04-12 3.251388888888889
# Processing timestamp: 2021-04-12 09:29:00
# Current time & days to expiry: 2021-04-12 3.2506944444444446
# Curr time & days to EXpiry 2021-04-12 3.2506944444444446
# Processing timestamp: 2021-04-12 09:30:00
# Current time & days to expiry: 2021-04-12 3.25
# Curr time & days to EXpiry 2021-04-12 3.25
# Processing timestamp: 2021-04-12 09:31:00
# Current time & days to expiry: 2021-04-12 3.2493055555555554
# Curr time & days to EXpiry 2021-04-12 3.2493055555555554
# Processing timestamp: 2021-04-12 09:32:00
# Current time & days to expiry: 2021-04-12 3.248611111111111
# Curr time & days to EXpiry 2021-04-12 3.248611111111111
# Processing timestamp: 2021-04-12 09:33:00
# Current time & days to expiry: 2021-04-12 3.247916666666667
# Curr time & days to EXpiry 2021-04-12 3.247916666666667
# Processing timestamp: 2021-04-12 09:34:00
# Current time & days to expiry: 2021-04-12 3.2472222222222222
# Curr time & days to EXpiry 2021-04-12 3.2472222222222222
# Processing timestamp: 2021-04-12 09:35:00
# Current time & days to expiry: 2021-04-12 3.2465277777777777
# Curr time & days to EXpiry 2021-04-12 3.2465277777777777
# Processing timestamp: 2021-04-12 09:36:00
# Current time & days to expiry: 2021-04-12 3.245833333333333
# Curr time & days to EXpiry 2021-04-12 3.245833333333333
# Processing timestamp: 2021-04-12 09:37:00
# Current time & days to expiry: 2021-04-12 3.245138888888889
# Curr time & days to EXpiry 2021-04-12 3.245138888888889
# Processing timestamp: 2021-04-12 09:38:00
# Current time & days to expiry: 2021-04-12 3.2444444444444445
# Curr time & days to EXpiry 2021-04-12 3.2444444444444445
# Processing timestamp: 2021-04-12 09:39:00
# Current time & days to expiry: 2021-04-12 3.24375
# Curr time & days to EXpiry 2021-04-12 3.24375
# Processing timestamp: 2021-04-12 09:40:00
# Current time & days to expiry: 2021-04-12 3.2430555555555554
# Curr time & days to EXpiry 2021-04-12 3.2430555555555554
# Processing timestamp: 2021-04-12 09:41:00
# Current time & days to expiry: 2021-04-12 3.2423611111111112
# Curr time & days to EXpiry 2021-04-12 3.2423611111111112
# Processing timestamp: 2021-04-12 09:42:00
# Current time & days to expiry: 2021-04-12 3.2416666666666667
# Curr time & days to EXpiry 2021-04-12 3.2416666666666667
# Processing timestamp: 2021-04-12 09:43:00
# Current time & days to expiry: 2021-04-12 3.240972222222222
# Curr time & days to EXpiry 2021-04-12 3.240972222222222
# Processing timestamp: 2021-04-12 09:44:00
# Current time & days to expiry: 2021-04-12 3.2402777777777776
# Curr time & days to EXpiry 2021-04-12 3.2402777777777776
# Processing timestamp: 2021-04-12 09:45:00
# Current time & days to expiry: 2021-04-12 3.2395833333333335
# Curr time & days to EXpiry 2021-04-12 3.2395833333333335
# Processing timestamp: 2021-04-12 09:46:00
# Current time & days to expiry: 2021-04-12 3.238888888888889
# Curr time & days to EXpiry 2021-04-12 3.238888888888889
# Processing timestamp: 2021-04-12 09:47:00
# Current time & days to expiry: 2021-04-12 3.2381944444444444
# Curr time & days to EXpiry 2021-04-12 3.2381944444444444
# Processing timestamp: 2021-04-12 09:48:00
# Current time & days to expiry: 2021-04-12 3.2375
# Curr time & days to EXpiry 2021-04-12 3.2375
# Processing timestamp: 2021-04-12 09:49:00
# Current time & days to expiry: 2021-04-12 3.2368055555555557
# Curr time & days to EXpiry 2021-04-12 3.2368055555555557
# Processing timestamp: 2021-04-12 09:50:00
# Current time & days to expiry: 2021-04-12 3.236111111111111
# Curr time & days to EXpiry 2021-04-12 3.236111111111111
# Processing timestamp: 2021-04-12 09:51:00
# Current time & days to expiry: 2021-04-12 3.2354166666666666
# Curr time & days to EXpiry 2021-04-12 3.2354166666666666
# Processing timestamp: 2021-04-12 09:52:00
# Current time & days to expiry: 2021-04-12 3.234722222222222
# Curr time & days to EXpiry 2021-04-12 3.234722222222222
# Processing timestamp: 2021-04-12 09:53:00
# Current time & days to expiry: 2021-04-12 3.234027777777778
# Curr time & days to EXpiry 2021-04-12 3.234027777777778
# Processing timestamp: 2021-04-12 09:54:00
# Current time & days to expiry: 2021-04-12 3.2333333333333334
# Curr time & days to EXpiry 2021-04-12 3.2333333333333334
# Processing timestamp: 2021-04-12 09:55:00
# Current time & days to expiry: 2021-04-12 3.232638888888889
# Curr time & days to EXpiry 2021-04-12 3.232638888888889
# Processing timestamp: 2021-04-12 09:56:00
# Current time & days to expiry: 2021-04-12 3.2319444444444443
# Curr time & days to EXpiry 2021-04-12 3.2319444444444443
# Processing timestamp: 2021-04-12 09:57:00
# Current time & days to expiry: 2021-04-12 3.23125
# Curr time & days to EXpiry 2021-04-12 3.23125
# Processing timestamp: 2021-04-12 09:58:00
# Current time & days to expiry: 2021-04-12 3.2305555555555556
# Curr time & days to EXpiry 2021-04-12 3.2305555555555556
# Processing timestamp: 2021-04-12 09:59:00
# Current time & days to expiry: 2021-04-12 3.229861111111111
# Curr time & days to EXpiry 2021-04-12 3.229861111111111
# Processing timestamp: 2021-04-12 10:00:00
# Current time & days to expiry: 2021-04-12 3.2291666666666665
# Curr time & days to EXpiry 2021-04-12 3.2291666666666665
# Processing timestamp: 2021-04-12 10:01:00
# Current time & days to expiry: 2021-04-12 3.2284722222222224
# Curr time & days to EXpiry 2021-04-12 3.2284722222222224
# Processing timestamp: 2021-04-12 10:02:00
# Current time & days to expiry: 2021-04-12 3.227777777777778
# Curr time & days to EXpiry 2021-04-12 3.227777777777778
# Processing timestamp: 2021-04-12 10:03:00
# Current time & days to expiry: 2021-04-12 3.2270833333333333
# Curr time & days to EXpiry 2021-04-12 3.2270833333333333
# Processing timestamp: 2021-04-12 10:04:00
# Current time & days to expiry: 2021-04-12 3.2263888888888888
# Curr time & days to EXpiry 2021-04-12 3.2263888888888888
# Processing timestamp: 2021-04-12 10:05:00
# Current time & days to expiry: 2021-04-12 3.2256944444444446
# Curr time & days to EXpiry 2021-04-12 3.2256944444444446
# Processing timestamp: 2021-04-12 10:06:00
# Current time & days to expiry: 2021-04-12 3.225
# Curr time & days to EXpiry 2021-04-12 3.225
# Processing timestamp: 2021-04-12 10:07:00
# Current time & days to expiry: 2021-04-12 3.2243055555555555
# Curr time & days to EXpiry 2021-04-12 3.2243055555555555
# Processing timestamp: 2021-04-12 10:08:00
# Current time & days to expiry: 2021-04-12 3.223611111111111
# Curr time & days to EXpiry 2021-04-12 3.223611111111111
# Processing timestamp: 2021-04-12 10:09:00
# Current time & days to expiry: 2021-04-12 3.222916666666667
# Curr time & days to EXpiry 2021-04-12 3.222916666666667
# Processing timestamp: 2021-04-12 10:10:00
# Current time & days to expiry: 2021-04-12 3.2222222222222223
# Curr time & days to EXpiry 2021-04-12 3.2222222222222223
# Processing timestamp: 2021-04-12 10:11:00
# Current time & days to expiry: 2021-04-12 3.2215277777777778
# Curr time & days to EXpiry 2021-04-12 3.2215277777777778
# Processing timestamp: 2021-04-12 10:12:00
# Current time & days to expiry: 2021-04-12 3.220833333333333
# Curr time & days to EXpiry 2021-04-12 3.220833333333333
# Processing timestamp: 2021-04-12 10:13:00
# Current time & days to expiry: 2021-04-12 3.220138888888889
# Curr time & days to EXpiry 2021-04-12 3.220138888888889
# Processing timestamp: 2021-04-12 10:14:00
# Current time & days to expiry: 2021-04-12 3.2194444444444446
# Curr time & days to EXpiry 2021-04-12 3.2194444444444446
# Processing timestamp: 2021-04-12 10:15:00
# Current time & days to expiry: 2021-04-12 3.21875
# Curr time & days to EXpiry 2021-04-12 3.21875
# Processing timestamp: 2021-04-12 10:16:00
# Current time & days to expiry: 2021-04-12 3.2180555555555554
# Curr time & days to EXpiry 2021-04-12 3.2180555555555554
# Processing timestamp: 2021-04-12 10:17:00
# Current time & days to expiry: 2021-04-12 3.217361111111111
# Curr time & days to EXpiry 2021-04-12 3.217361111111111
# Processing timestamp: 2021-04-12 10:18:00
# Current time & days to expiry: 2021-04-12 3.216666666666667
# Curr time & days to EXpiry 2021-04-12 3.216666666666667
# Processing timestamp: 2021-04-12 10:19:00
# Current time & days to expiry: 2021-04-12 3.2159722222222222
# Curr time & days to EXpiry 2021-04-12 3.2159722222222222
# Processing timestamp: 2021-04-12 10:20:00
# Current time & days to expiry: 2021-04-12 3.2152777777777777
# Curr time & days to EXpiry 2021-04-12 3.2152777777777777
# Processing timestamp: 2021-04-12 10:21:00
# Current time & days to expiry: 2021-04-12 3.214583333333333
# Curr time & days to EXpiry 2021-04-12 3.214583333333333
# Processing timestamp: 2021-04-12 10:22:00
# Current time & days to expiry: 2021-04-12 3.213888888888889
# Curr time & days to EXpiry 2021-04-12 3.213888888888889
# Processing timestamp: 2021-04-12 10:23:00
# Current time & days to expiry: 2021-04-12 3.2131944444444445
# Curr time & days to EXpiry 2021-04-12 3.2131944444444445
# Processing timestamp: 2021-04-12 10:24:00
# Current time & days to expiry: 2021-04-12 3.2125
# Curr time & days to EXpiry 2021-04-12 3.2125
# Processing timestamp: 2021-04-12 10:25:00
# Current time & days to expiry: 2021-04-12 3.2118055555555554
# Curr time & days to EXpiry 2021-04-12 3.2118055555555554
# Processing timestamp: 2021-04-12 10:26:00
# Current time & days to expiry: 2021-04-12 3.2111111111111112
# Curr time & days to EXpiry 2021-04-12 3.2111111111111112
# Processing timestamp: 2021-04-12 10:27:00
# Current time & days to expiry: 2021-04-12 3.2104166666666667
# Curr time & days to EXpiry 2021-04-12 3.2104166666666667
# Processing timestamp: 2021-04-12 10:28:00
# Current time & days to expiry: 2021-04-12 3.209722222222222
# Curr time & days to EXpiry 2021-04-12 3.209722222222222
# Processing timestamp: 2021-04-12 10:29:00
# Current time & days to expiry: 2021-04-12 3.2090277777777776
# Curr time & days to EXpiry 2021-04-12 3.2090277777777776
# Processing timestamp: 2021-04-12 10:30:00
# Current time & days to expiry: 2021-04-12 3.2083333333333335
# Curr time & days to EXpiry 2021-04-12 3.2083333333333335
# Processing timestamp: 2021-04-12 10:31:00
# Current time & days to expiry: 2021-04-12 3.207638888888889
# Curr time & days to EXpiry 2021-04-12 3.207638888888889
# Processing timestamp: 2021-04-12 10:32:00
# Current time & days to expiry: 2021-04-12 3.2069444444444444
# Curr time & days to EXpiry 2021-04-12 3.2069444444444444
# Processing timestamp: 2021-04-12 10:33:00
# Current time & days to expiry: 2021-04-12 3.20625
# Curr time & days to EXpiry 2021-04-12 3.20625
# Processing timestamp: 2021-04-12 10:34:00
# Current time & days to expiry: 2021-04-12 3.2055555555555557
# Curr time & days to EXpiry 2021-04-12 3.2055555555555557
# Processing timestamp: 2021-04-12 10:35:00
# Current time & days to expiry: 2021-04-12 3.204861111111111
# Curr time & days to EXpiry 2021-04-12 3.204861111111111
# Processing timestamp: 2021-04-12 10:36:00
# Current time & days to expiry: 2021-04-12 3.2041666666666666
# Curr time & days to EXpiry 2021-04-12 3.2041666666666666
# Processing timestamp: 2021-04-12 10:37:00
# Current time & days to expiry: 2021-04-12 3.203472222222222
# Curr time & days to EXpiry 2021-04-12 3.203472222222222
# Processing timestamp: 2021-04-12 10:38:00
# Current time & days to expiry: 2021-04-12 3.202777777777778
# Curr time & days to EXpiry 2021-04-12 3.202777777777778
# Processing timestamp: 2021-04-12 10:39:00
# Current time & days to expiry: 2021-04-12 3.2020833333333334
# Curr time & days to EXpiry 2021-04-12 3.2020833333333334
# Processing timestamp: 2021-04-12 10:40:00
# Current time & days to expiry: 2021-04-12 3.201388888888889
# Curr time & days to EXpiry 2021-04-12 3.201388888888889
# Processing timestamp: 2021-04-12 10:41:00
# Current time & days to expiry: 2021-04-12 3.2006944444444443
# Curr time & days to EXpiry 2021-04-12 3.2006944444444443
# Processing timestamp: 2021-04-12 10:42:00
# Current time & days to expiry: 2021-04-12 3.2
# Curr time & days to EXpiry 2021-04-12 3.2
# Processing timestamp: 2021-04-12 10:43:00
# Current time & days to expiry: 2021-04-12 3.1993055555555556
# Curr time & days to EXpiry 2021-04-12 3.1993055555555556
# Processing timestamp: 2021-04-12 10:44:00
# Current time & days to expiry: 2021-04-12 3.198611111111111
# Curr time & days to EXpiry 2021-04-12 3.198611111111111
# Processing timestamp: 2021-04-12 10:45:00
# Current time & days to expiry: 2021-04-12 3.1979166666666665
# Curr time & days to EXpiry 2021-04-12 3.1979166666666665
# Processing timestamp: 2021-04-12 10:46:00
# Current time & days to expiry: 2021-04-12 3.1972222222222224
# Curr time & days to EXpiry 2021-04-12 3.1972222222222224
# Processing timestamp: 2021-04-12 10:47:00
# Current time & days to expiry: 2021-04-12 3.196527777777778
# Curr time & days to EXpiry 2021-04-12 3.196527777777778
# Processing timestamp: 2021-04-12 10:48:00
# Current time & days to expiry: 2021-04-12 3.1958333333333333
# Curr time & days to EXpiry 2021-04-12 3.1958333333333333
# Processing timestamp: 2021-04-12 10:49:00
# Current time & days to expiry: 2021-04-12 3.1951388888888888
# Curr time & days to EXpiry 2021-04-12 3.1951388888888888
# Processing timestamp: 2021-04-12 10:50:00
# Current time & days to expiry: 2021-04-12 3.1944444444444446
# Curr time & days to EXpiry 2021-04-12 3.1944444444444446
# Processing timestamp: 2021-04-12 10:51:00
# Current time & days to expiry: 2021-04-12 3.19375
# Curr time & days to EXpiry 2021-04-12 3.19375
# Processing timestamp: 2021-04-12 10:52:00
# Current time & days to expiry: 2021-04-12 3.1930555555555555
# Curr time & days to EXpiry 2021-04-12 3.1930555555555555
# Processing timestamp: 2021-04-12 10:53:00
# Current time & days to expiry: 2021-04-12 3.192361111111111
# Curr time & days to EXpiry 2021-04-12 3.192361111111111
# Processing timestamp: 2021-04-12 10:54:00
# Current time & days to expiry: 2021-04-12 3.191666666666667
# Curr time & days to EXpiry 2021-04-12 3.191666666666667
# Processing timestamp: 2021-04-12 10:55:00
# Current time & days to expiry: 2021-04-12 3.1909722222222223
# Curr time & days to EXpiry 2021-04-12 3.1909722222222223
# Processing timestamp: 2021-04-12 10:56:00
# Current time & days to expiry: 2021-04-12 3.1902777777777778
# Curr time & days to EXpiry 2021-04-12 3.1902777777777778
# Processing timestamp: 2021-04-12 10:57:00
# Current time & days to expiry: 2021-04-12 3.189583333333333
# Curr time & days to EXpiry 2021-04-12 3.189583333333333
# Processing timestamp: 2021-04-12 10:58:00
# Current time & days to expiry: 2021-04-12 3.188888888888889
# Curr time & days to EXpiry 2021-04-12 3.188888888888889
# Processing timestamp: 2021-04-12 10:59:00
# Current time & days to expiry: 2021-04-12 3.1881944444444446
# Curr time & days to EXpiry 2021-04-12 3.1881944444444446
# Processing timestamp: 2021-04-12 11:00:00
# Current time & days to expiry: 2021-04-12 3.1875
# Curr time & days to EXpiry 2021-04-12 3.1875
# Processing timestamp: 2021-04-12 11:01:00
# Current time & days to expiry: 2021-04-12 3.1868055555555554
# Curr time & days to EXpiry 2021-04-12 3.1868055555555554
# Processing timestamp: 2021-04-12 11:02:00
# Current time & days to expiry: 2021-04-12 3.186111111111111
# Curr time & days to EXpiry 2021-04-12 3.186111111111111
# Processing timestamp: 2021-04-12 11:03:00
# Current time & days to expiry: 2021-04-12 3.185416666666667
# Curr time & days to EXpiry 2021-04-12 3.185416666666667
# Processing timestamp: 2021-04-12 11:04:00
# Current time & days to expiry: 2021-04-12 3.1847222222222222
# Curr time & days to EXpiry 2021-04-12 3.1847222222222222
# Processing timestamp: 2021-04-12 11:05:00
# Current time & days to expiry: 2021-04-12 3.1840277777777777
# Curr time & days to EXpiry 2021-04-12 3.1840277777777777
# Processing timestamp: 2021-04-12 11:06:00
# Current time & days to expiry: 2021-04-12 3.183333333333333
# Curr time & days to EXpiry 2021-04-12 3.183333333333333
# Processing timestamp: 2021-04-12 11:07:00
# Current time & days to expiry: 2021-04-12 3.182638888888889
# Curr time & days to EXpiry 2021-04-12 3.182638888888889
# Processing timestamp: 2021-04-12 11:08:00
# Current time & days to expiry: 2021-04-12 3.1819444444444445
# Curr time & days to EXpiry 2021-04-12 3.1819444444444445
# Processing timestamp: 2021-04-12 11:09:00
# Current time & days to expiry: 2021-04-12 3.18125
# Curr time & days to EXpiry 2021-04-12 3.18125
# Processing timestamp: 2021-04-12 11:10:00
# Current time & days to expiry: 2021-04-12 3.1805555555555554
# Curr time & days to EXpiry 2021-04-12 3.1805555555555554
# Processing timestamp: 2021-04-12 11:11:00
# Current time & days to expiry: 2021-04-12 3.1798611111111112
# Curr time & days to EXpiry 2021-04-12 3.1798611111111112
# Processing timestamp: 2021-04-12 11:12:00
# Current time & days to expiry: 2021-04-12 3.1791666666666667
# Curr time & days to EXpiry 2021-04-12 3.1791666666666667
# Processing timestamp: 2021-04-12 11:13:00
# Current time & days to expiry: 2021-04-12 3.178472222222222
# Curr time & days to EXpiry 2021-04-12 3.178472222222222
# Processing timestamp: 2021-04-12 11:14:00
# Current time & days to expiry: 2021-04-12 3.1777777777777776
# Curr time & days to EXpiry 2021-04-12 3.1777777777777776
# Processing timestamp: 2021-04-12 11:15:00
# Current time & days to expiry: 2021-04-12 3.1770833333333335
# Curr time & days to EXpiry 2021-04-12 3.1770833333333335
# Processing timestamp: 2021-04-12 11:16:00
# Current time & days to expiry: 2021-04-12 3.176388888888889
# Curr time & days to EXpiry 2021-04-12 3.176388888888889
# Processing timestamp: 2021-04-12 11:17:00
# Current time & days to expiry: 2021-04-12 3.1756944444444444
# Curr time & days to EXpiry 2021-04-12 3.1756944444444444
# Processing timestamp: 2021-04-12 11:18:00
# Current time & days to expiry: 2021-04-12 3.175
# Curr time & days to EXpiry 2021-04-12 3.175
# Processing timestamp: 2021-04-12 11:19:00
# Current time & days to expiry: 2021-04-12 3.1743055555555557
# Curr time & days to EXpiry 2021-04-12 3.1743055555555557
# Processing timestamp: 2021-04-12 11:20:00
# Current time & days to expiry: 2021-04-12 3.173611111111111
# Curr time & days to EXpiry 2021-04-12 3.173611111111111
# Processing timestamp: 2021-04-12 11:21:00
# Current time & days to expiry: 2021-04-12 3.1729166666666666
# Curr time & days to EXpiry 2021-04-12 3.1729166666666666
# Processing timestamp: 2021-04-12 11:22:00
# Current time & days to expiry: 2021-04-12 3.172222222222222
# Curr time & days to EXpiry 2021-04-12 3.172222222222222
# Processing timestamp: 2021-04-12 11:23:00
# Current time & days to expiry: 2021-04-12 3.171527777777778
# Curr time & days to EXpiry 2021-04-12 3.171527777777778
# Processing timestamp: 2021-04-12 11:24:00
# Current time & days to expiry: 2021-04-12 3.1708333333333334
# Curr time & days to EXpiry 2021-04-12 3.1708333333333334
# Processing timestamp: 2021-04-12 11:25:00
# Current time & days to expiry: 2021-04-12 3.170138888888889
# Curr time & days to EXpiry 2021-04-12 3.170138888888889
# Processing timestamp: 2021-04-12 11:26:00
# Current time & days to expiry: 2021-04-12 3.1694444444444443
# Curr time & days to EXpiry 2021-04-12 3.1694444444444443
# Processing timestamp: 2021-04-12 11:27:00
# Current time & days to expiry: 2021-04-12 3.16875
# Curr time & days to EXpiry 2021-04-12 3.16875
# Processing timestamp: 2021-04-12 11:28:00
# Current time & days to expiry: 2021-04-12 3.1680555555555556
# Curr time & days to EXpiry 2021-04-12 3.1680555555555556
# Processing timestamp: 2021-04-12 11:29:00
# Current time & days to expiry: 2021-04-12 3.167361111111111
# Curr time & days to EXpiry 2021-04-12 3.167361111111111
# Processing timestamp: 2021-04-12 11:30:00
# Current time & days to expiry: 2021-04-12 3.1666666666666665
# Curr time & days to EXpiry 2021-04-12 3.1666666666666665
# Processing timestamp: 2021-04-12 11:31:00
# Current time & days to expiry: 2021-04-12 3.1659722222222224
# Curr time & days to EXpiry 2021-04-12 3.1659722222222224
# Processing timestamp: 2021-04-12 11:32:00
# Current time & days to expiry: 2021-04-12 3.165277777777778
# Curr time & days to EXpiry 2021-04-12 3.165277777777778
# Processing timestamp: 2021-04-12 11:33:00
# Current time & days to expiry: 2021-04-12 3.1645833333333333
# Curr time & days to EXpiry 2021-04-12 3.1645833333333333
# Processing timestamp: 2021-04-12 11:34:00
# Current time & days to expiry: 2021-04-12 3.1638888888888888
# Curr time & days to EXpiry 2021-04-12 3.1638888888888888
# Processing timestamp: 2021-04-12 11:35:00
# Current time & days to expiry: 2021-04-12 3.1631944444444446
# Curr time & days to EXpiry 2021-04-12 3.1631944444444446
# Processing timestamp: 2021-04-12 11:36:00
# Current time & days to expiry: 2021-04-12 3.1625
# Curr time & days to EXpiry 2021-04-12 3.1625
# Processing timestamp: 2021-04-12 11:37:00
# Current time & days to expiry: 2021-04-12 3.1618055555555555
# Curr time & days to EXpiry 2021-04-12 3.1618055555555555
# Processing timestamp: 2021-04-12 11:38:00
# Current time & days to expiry: 2021-04-12 3.161111111111111
# Curr time & days to EXpiry 2021-04-12 3.161111111111111
# Processing timestamp: 2021-04-12 11:39:00
# Current time & days to expiry: 2021-04-12 3.160416666666667
# Curr time & days to EXpiry 2021-04-12 3.160416666666667
# Processing timestamp: 2021-04-12 11:40:00
# Current time & days to expiry: 2021-04-12 3.1597222222222223
# Curr time & days to EXpiry 2021-04-12 3.1597222222222223
# Processing timestamp: 2021-04-12 11:41:00
# Current time & days to expiry: 2021-04-12 3.1590277777777778
# Curr time & days to EXpiry 2021-04-12 3.1590277777777778
# Processing timestamp: 2021-04-12 11:42:00
# Current time & days to expiry: 2021-04-12 3.158333333333333
# Curr time & days to EXpiry 2021-04-12 3.158333333333333
# Processing timestamp: 2021-04-12 11:43:00
# Current time & days to expiry: 2021-04-12 3.157638888888889
# Curr time & days to EXpiry 2021-04-12 3.157638888888889
# Processing timestamp: 2021-04-12 11:44:00
# Current time & days to expiry: 2021-04-12 3.1569444444444446
# Curr time & days to EXpiry 2021-04-12 3.1569444444444446
# Processing timestamp: 2021-04-12 11:45:00
# Current time & days to expiry: 2021-04-12 3.15625
# Curr time & days to EXpiry 2021-04-12 3.15625
# Processing timestamp: 2021-04-12 11:46:00
# Current time & days to expiry: 2021-04-12 3.1555555555555554
# Curr time & days to EXpiry 2021-04-12 3.1555555555555554
# Processing timestamp: 2021-04-12 11:47:00
# Current time & days to expiry: 2021-04-12 3.154861111111111
# Curr time & days to EXpiry 2021-04-12 3.154861111111111
# Processing timestamp: 2021-04-12 11:48:00
# Current time & days to expiry: 2021-04-12 3.154166666666667
# Curr time & days to EXpiry 2021-04-12 3.154166666666667
# Processing timestamp: 2021-04-12 11:49:00
# Current time & days to expiry: 2021-04-12 3.1534722222222222
# Curr time & days to EXpiry 2021-04-12 3.1534722222222222
# Processing timestamp: 2021-04-12 11:50:00
# Current time & days to expiry: 2021-04-12 3.1527777777777777
# Curr time & days to EXpiry 2021-04-12 3.1527777777777777
# Processing timestamp: 2021-04-12 11:51:00
# Current time & days to expiry: 2021-04-12 3.152083333333333
# Curr time & days to EXpiry 2021-04-12 3.152083333333333
# Processing timestamp: 2021-04-12 11:52:00
# Current time & days to expiry: 2021-04-12 3.151388888888889
# Curr time & days to EXpiry 2021-04-12 3.151388888888889
# Processing timestamp: 2021-04-12 11:53:00
# Current time & days to expiry: 2021-04-12 3.1506944444444445
# Curr time & days to EXpiry 2021-04-12 3.1506944444444445
# Processing timestamp: 2021-04-12 11:54:00
# Current time & days to expiry: 2021-04-12 3.15
# Curr time & days to EXpiry 2021-04-12 3.15
# Processing timestamp: 2021-04-12 11:55:00
# Current time & days to expiry: 2021-04-12 3.1493055555555554
# Curr time & days to EXpiry 2021-04-12 3.1493055555555554
# Processing timestamp: 2021-04-12 11:56:00
# Current time & days to expiry: 2021-04-12 3.1486111111111112
# Curr time & days to EXpiry 2021-04-12 3.1486111111111112
# Processing timestamp: 2021-04-12 11:57:00
# Current time & days to expiry: 2021-04-12 3.1479166666666667
# Curr time & days to EXpiry 2021-04-12 3.1479166666666667
# Processing timestamp: 2021-04-12 11:58:00
# Current time & days to expiry: 2021-04-12 3.147222222222222
# Curr time & days to EXpiry 2021-04-12 3.147222222222222
# Processing timestamp: 2021-04-12 11:59:00
# Current time & days to expiry: 2021-04-12 3.1465277777777776
# Curr time & days to EXpiry 2021-04-12 3.1465277777777776
# Processing timestamp: 2021-04-12 12:00:00
# Current time & days to expiry: 2021-04-12 3.1458333333333335
# Curr time & days to EXpiry 2021-04-12 3.1458333333333335
# Processing timestamp: 2021-04-12 12:01:00
# Current time & days to expiry: 2021-04-12 3.145138888888889
# Curr time & days to EXpiry 2021-04-12 3.145138888888889
# Processing timestamp: 2021-04-12 12:02:00
# Current time & days to expiry: 2021-04-12 3.1444444444444444
# Curr time & days to EXpiry 2021-04-12 3.1444444444444444
# Processing timestamp: 2021-04-12 12:03:00
# Current time & days to expiry: 2021-04-12 3.14375
# Curr time & days to EXpiry 2021-04-12 3.14375
# Processing timestamp: 2021-04-12 12:04:00
# Current time & days to expiry: 2021-04-12 3.1430555555555557
# Curr time & days to EXpiry 2021-04-12 3.1430555555555557
# Processing timestamp: 2021-04-12 12:05:00
# Current time & days to expiry: 2021-04-12 3.142361111111111
# Curr time & days to EXpiry 2021-04-12 3.142361111111111
# Processing timestamp: 2021-04-12 12:06:00
# Current time & days to expiry: 2021-04-12 3.1416666666666666
# Curr time & days to EXpiry 2021-04-12 3.1416666666666666
# Processing timestamp: 2021-04-12 12:07:00
# Current time & days to expiry: 2021-04-12 3.140972222222222
# Curr time & days to EXpiry 2021-04-12 3.140972222222222
# Processing timestamp: 2021-04-12 12:08:00
# Current time & days to expiry: 2021-04-12 3.140277777777778
# Curr time & days to EXpiry 2021-04-12 3.140277777777778
# Processing timestamp: 2021-04-12 12:09:00
# Current time & days to expiry: 2021-04-12 3.1395833333333334
# Curr time & days to EXpiry 2021-04-12 3.1395833333333334
# Processing timestamp: 2021-04-12 12:10:00
# Current time & days to expiry: 2021-04-12 3.138888888888889
# Curr time & days to EXpiry 2021-04-12 3.138888888888889
# Processing timestamp: 2021-04-12 12:11:00
# Current time & days to expiry: 2021-04-12 3.1381944444444443
# Curr time & days to EXpiry 2021-04-12 3.1381944444444443
# Processing timestamp: 2021-04-12 12:12:00
# Current time & days to expiry: 2021-04-12 3.1375
# Curr time & days to EXpiry 2021-04-12 3.1375
# Processing timestamp: 2021-04-12 12:13:00
# Current time & days to expiry: 2021-04-12 3.1368055555555556
# Curr time & days to EXpiry 2021-04-12 3.1368055555555556
# Processing timestamp: 2021-04-12 12:14:00
# Current time & days to expiry: 2021-04-12 3.136111111111111
# Curr time & days to EXpiry 2021-04-12 3.136111111111111
# Processing timestamp: 2021-04-12 12:15:00
# Current time & days to expiry: 2021-04-12 3.1354166666666665
# Curr time & days to EXpiry 2021-04-12 3.1354166666666665
# Processing timestamp: 2021-04-12 12:16:00
# Current time & days to expiry: 2021-04-12 3.1347222222222224
# Curr time & days to EXpiry 2021-04-12 3.1347222222222224
# Processing timestamp: 2021-04-12 12:17:00
# Current time & days to expiry: 2021-04-12 3.134027777777778
# Curr time & days to EXpiry 2021-04-12 3.134027777777778
# Processing timestamp: 2021-04-12 12:18:00
# Current time & days to expiry: 2021-04-12 3.1333333333333333
# Curr time & days to EXpiry 2021-04-12 3.1333333333333333
# Processing timestamp: 2021-04-12 12:19:00
# Current time & days to expiry: 2021-04-12 3.1326388888888888
# Curr time & days to EXpiry 2021-04-12 3.1326388888888888
# Processing timestamp: 2021-04-12 12:20:00
# Current time & days to expiry: 2021-04-12 3.1319444444444446
# Curr time & days to EXpiry 2021-04-12 3.1319444444444446
# Processing timestamp: 2021-04-12 12:21:00
# Current time & days to expiry: 2021-04-12 3.13125
# Curr time & days to EXpiry 2021-04-12 3.13125
# Processing timestamp: 2021-04-12 12:22:00
# Current time & days to expiry: 2021-04-12 3.1305555555555555
# Curr time & days to EXpiry 2021-04-12 3.1305555555555555
# Processing timestamp: 2021-04-12 12:23:00
# Current time & days to expiry: 2021-04-12 3.129861111111111
# Curr time & days to EXpiry 2021-04-12 3.129861111111111
# Processing timestamp: 2021-04-12 12:24:00
# Current time & days to expiry: 2021-04-12 3.129166666666667
# Curr time & days to EXpiry 2021-04-12 3.129166666666667
# Processing timestamp: 2021-04-12 12:25:00
# Current time & days to expiry: 2021-04-12 3.1284722222222223
# Curr time & days to EXpiry 2021-04-12 3.1284722222222223
# Processing timestamp: 2021-04-12 12:26:00
# Current time & days to expiry: 2021-04-12 3.1277777777777778
# Curr time & days to EXpiry 2021-04-12 3.1277777777777778
# Processing timestamp: 2021-04-12 12:27:00
# Current time & days to expiry: 2021-04-12 3.127083333333333
# Curr time & days to EXpiry 2021-04-12 3.127083333333333
# Processing timestamp: 2021-04-12 12:28:00
# Current time & days to expiry: 2021-04-12 3.126388888888889
# Curr time & days to EXpiry 2021-04-12 3.126388888888889
# Processing timestamp: 2021-04-12 12:29:00
# Current time & days to expiry: 2021-04-12 3.1256944444444446
# Curr time & days to EXpiry 2021-04-12 3.1256944444444446
# Processing timestamp: 2021-04-12 12:30:00
# Current time & days to expiry: 2021-04-12 3.125
# Curr time & days to EXpiry 2021-04-12 3.125
# Processing timestamp: 2021-04-12 12:31:00
# Current time & days to expiry: 2021-04-12 3.1243055555555554
# Curr time & days to EXpiry 2021-04-12 3.1243055555555554
# Processing timestamp: 2021-04-12 12:32:00
# Current time & days to expiry: 2021-04-12 3.123611111111111
# Curr time & days to EXpiry 2021-04-12 3.123611111111111
# Processing timestamp: 2021-04-12 12:33:00
# Current time & days to expiry: 2021-04-12 3.122916666666667
# Curr time & days to EXpiry 2021-04-12 3.122916666666667
# Processing timestamp: 2021-04-12 12:34:00
# Current time & days to expiry: 2021-04-12 3.1222222222222222
# Curr time & days to EXpiry 2021-04-12 3.1222222222222222
# Processing timestamp: 2021-04-12 12:35:00
# Current time & days to expiry: 2021-04-12 3.1215277777777777
# Curr time & days to EXpiry 2021-04-12 3.1215277777777777
# Processing timestamp: 2021-04-12 12:36:00
# Current time & days to expiry: 2021-04-12 3.120833333333333
# Curr time & days to EXpiry 2021-04-12 3.120833333333333
# Processing timestamp: 2021-04-12 12:37:00
# Current time & days to expiry: 2021-04-12 3.120138888888889
# Curr time & days to EXpiry 2021-04-12 3.120138888888889
# Processing timestamp: 2021-04-12 12:38:00
# Current time & days to expiry: 2021-04-12 3.1194444444444445
# Curr time & days to EXpiry 2021-04-12 3.1194444444444445
# Processing timestamp: 2021-04-12 12:39:00
# Current time & days to expiry: 2021-04-12 3.11875
# Curr time & days to EXpiry 2021-04-12 3.11875
# Processing timestamp: 2021-04-12 12:40:00
# Current time & days to expiry: 2021-04-12 3.1180555555555554
# Curr time & days to EXpiry 2021-04-12 3.1180555555555554
# Processing timestamp: 2021-04-12 12:41:00
# Current time & days to expiry: 2021-04-12 3.1173611111111112
# Curr time & days to EXpiry 2021-04-12 3.1173611111111112
# Processing timestamp: 2021-04-12 12:42:00
# Current time & days to expiry: 2021-04-12 3.1166666666666667
# Curr time & days to EXpiry 2021-04-12 3.1166666666666667
# Processing timestamp: 2021-04-12 12:43:00
# Current time & days to expiry: 2021-04-12 3.115972222222222
# Curr time & days to EXpiry 2021-04-12 3.115972222222222
# Processing timestamp: 2021-04-12 12:44:00
# Current time & days to expiry: 2021-04-12 3.1152777777777776
# Curr time & days to EXpiry 2021-04-12 3.1152777777777776
# Processing timestamp: 2021-04-12 12:45:00
# Current time & days to expiry: 2021-04-12 3.1145833333333335
# Curr time & days to EXpiry 2021-04-12 3.1145833333333335
# Processing timestamp: 2021-04-12 12:46:00
# Current time & days to expiry: 2021-04-12 3.113888888888889
# Curr time & days to EXpiry 2021-04-12 3.113888888888889
# Processing timestamp: 2021-04-12 12:47:00
# Current time & days to expiry: 2021-04-12 3.1131944444444444
# Curr time & days to EXpiry 2021-04-12 3.1131944444444444
# Processing timestamp: 2021-04-12 12:48:00
# Current time & days to expiry: 2021-04-12 3.1125
# Curr time & days to EXpiry 2021-04-12 3.1125
# Processing timestamp: 2021-04-12 12:49:00
# Current time & days to expiry: 2021-04-12 3.1118055555555557
# Curr time & days to EXpiry 2021-04-12 3.1118055555555557
# Processing timestamp: 2021-04-12 12:50:00
# Current time & days to expiry: 2021-04-12 3.111111111111111
# Curr time & days to EXpiry 2021-04-12 3.111111111111111
# Processing timestamp: 2021-04-12 12:51:00
# Current time & days to expiry: 2021-04-12 3.1104166666666666
# Curr time & days to EXpiry 2021-04-12 3.1104166666666666
# Processing timestamp: 2021-04-12 12:52:00
# Current time & days to expiry: 2021-04-12 3.109722222222222
# Curr time & days to EXpiry 2021-04-12 3.109722222222222
# Processing timestamp: 2021-04-12 12:53:00
# Current time & days to expiry: 2021-04-12 3.109027777777778
# Curr time & days to EXpiry 2021-04-12 3.109027777777778
# Processing timestamp: 2021-04-12 12:54:00
# Current time & days to expiry: 2021-04-12 3.1083333333333334
# Curr time & days to EXpiry 2021-04-12 3.1083333333333334
# Processing timestamp: 2021-04-12 12:55:00
# Current time & days to expiry: 2021-04-12 3.107638888888889
# Curr time & days to EXpiry 2021-04-12 3.107638888888889
# Processing timestamp: 2021-04-12 12:56:00
# Current time & days to expiry: 2021-04-12 3.1069444444444443
# Curr time & days to EXpiry 2021-04-12 3.1069444444444443
# Processing timestamp: 2021-04-12 12:57:00
# Current time & days to expiry: 2021-04-12 3.10625
# Curr time & days to EXpiry 2021-04-12 3.10625
# Processing timestamp: 2021-04-12 12:58:00
# Current time & days to expiry: 2021-04-12 3.1055555555555556
# Curr time & days to EXpiry 2021-04-12 3.1055555555555556
# Processing timestamp: 2021-04-12 12:59:00
# Current time & days to expiry: 2021-04-12 3.104861111111111
# Curr time & days to EXpiry 2021-04-12 3.104861111111111
# Processing timestamp: 2021-04-12 13:00:00
# Current time & days to expiry: 2021-04-12 3.1041666666666665
# Curr time & days to EXpiry 2021-04-12 3.1041666666666665
# Processing timestamp: 2021-04-12 13:01:00
# Current time & days to expiry: 2021-04-12 3.1034722222222224
# Curr time & days to EXpiry 2021-04-12 3.1034722222222224
# Processing timestamp: 2021-04-12 13:02:00
# Current time & days to expiry: 2021-04-12 3.102777777777778
# Curr time & days to EXpiry 2021-04-12 3.102777777777778
# Processing timestamp: 2021-04-12 13:03:00
# Current time & days to expiry: 2021-04-12 3.1020833333333333
# Curr time & days to EXpiry 2021-04-12 3.1020833333333333
# Processing timestamp: 2021-04-12 13:04:00
# Current time & days to expiry: 2021-04-12 3.1013888888888888
# Curr time & days to EXpiry 2021-04-12 3.1013888888888888
# Processing timestamp: 2021-04-12 13:05:00
# Current time & days to expiry: 2021-04-12 3.1006944444444446
# Curr time & days to EXpiry 2021-04-12 3.1006944444444446
# Processing timestamp: 2021-04-12 13:06:00
# Current time & days to expiry: 2021-04-12 3.1
# Curr time & days to EXpiry 2021-04-12 3.1
# Processing timestamp: 2021-04-12 13:07:00
# Current time & days to expiry: 2021-04-12 3.0993055555555555
# Curr time & days to EXpiry 2021-04-12 3.0993055555555555
# Processing timestamp: 2021-04-12 13:08:00
# Current time & days to expiry: 2021-04-12 3.098611111111111
# Curr time & days to EXpiry 2021-04-12 3.098611111111111
# Processing timestamp: 2021-04-12 13:09:00
# Current time & days to expiry: 2021-04-12 3.097916666666667
# Curr time & days to EXpiry 2021-04-12 3.097916666666667
# Processing timestamp: 2021-04-12 13:10:00
# Current time & days to expiry: 2021-04-12 3.0972222222222223
# Curr time & days to EXpiry 2021-04-12 3.0972222222222223
# Processing timestamp: 2021-04-12 13:11:00
# Current time & days to expiry: 2021-04-12 3.0965277777777778
# Curr time & days to EXpiry 2021-04-12 3.0965277777777778
# Processing timestamp: 2021-04-12 13:12:00
# Current time & days to expiry: 2021-04-12 3.095833333333333
# Curr time & days to EXpiry 2021-04-12 3.095833333333333
# Processing timestamp: 2021-04-12 13:13:00
# Current time & days to expiry: 2021-04-12 3.095138888888889
# Curr time & days to EXpiry 2021-04-12 3.095138888888889
# Processing timestamp: 2021-04-12 13:14:00
# Current time & days to expiry: 2021-04-12 3.0944444444444446
# Curr time & days to EXpiry 2021-04-12 3.0944444444444446
# Processing timestamp: 2021-04-12 13:15:00
# Current time & days to expiry: 2021-04-12 3.09375
# Curr time & days to EXpiry 2021-04-12 3.09375
# Processing timestamp: 2021-04-12 13:16:00
# Current time & days to expiry: 2021-04-12 3.0930555555555554
# Curr time & days to EXpiry 2021-04-12 3.0930555555555554
# Processing timestamp: 2021-04-12 13:17:00
# Current time & days to expiry: 2021-04-12 3.092361111111111
# Curr time & days to EXpiry 2021-04-12 3.092361111111111
# Processing timestamp: 2021-04-12 13:18:00
# Current time & days to expiry: 2021-04-12 3.091666666666667
# Curr time & days to EXpiry 2021-04-12 3.091666666666667
# Processing timestamp: 2021-04-12 13:19:00
# Current time & days to expiry: 2021-04-12 3.0909722222222222
# Curr time & days to EXpiry 2021-04-12 3.0909722222222222
# Processing timestamp: 2021-04-12 13:20:00
# Current time & days to expiry: 2021-04-12 3.0902777777777777
# Curr time & days to EXpiry 2021-04-12 3.0902777777777777
# Processing timestamp: 2021-04-12 13:21:00
# Current time & days to expiry: 2021-04-12 3.089583333333333
# Curr time & days to EXpiry 2021-04-12 3.089583333333333
# Processing timestamp: 2021-04-12 13:22:00
# Current time & days to expiry: 2021-04-12 3.088888888888889
# Curr time & days to EXpiry 2021-04-12 3.088888888888889
# Processing timestamp: 2021-04-12 13:23:00
# Current time & days to expiry: 2021-04-12 3.0881944444444445
# Curr time & days to EXpiry 2021-04-12 3.0881944444444445
# Processing timestamp: 2021-04-12 13:24:00
# Current time & days to expiry: 2021-04-12 3.0875
# Curr time & days to EXpiry 2021-04-12 3.0875
# Processing timestamp: 2021-04-12 13:25:00
# Current time & days to expiry: 2021-04-12 3.0868055555555554
# Curr time & days to EXpiry 2021-04-12 3.0868055555555554
# Processing timestamp: 2021-04-12 13:26:00
# Current time & days to expiry: 2021-04-12 3.0861111111111112
# Curr time & days to EXpiry 2021-04-12 3.0861111111111112
# Processing timestamp: 2021-04-12 13:27:00
# Current time & days to expiry: 2021-04-12 3.0854166666666667
# Curr time & days to EXpiry 2021-04-12 3.0854166666666667
# Processing timestamp: 2021-04-12 13:28:00
# Current time & days to expiry: 2021-04-12 3.084722222222222
# Curr time & days to EXpiry 2021-04-12 3.084722222222222
# Processing timestamp: 2021-04-12 13:29:00
# Current time & days to expiry: 2021-04-12 3.0840277777777776
# Curr time & days to EXpiry 2021-04-12 3.0840277777777776
# Processing timestamp: 2021-04-12 13:30:00
# Current time & days to expiry: 2021-04-12 3.0833333333333335
# Curr time & days to EXpiry 2021-04-12 3.0833333333333335
# Processing timestamp: 2021-04-12 13:31:00
# Current time & days to expiry: 2021-04-12 3.082638888888889
# Curr time & days to EXpiry 2021-04-12 3.082638888888889
# Processing timestamp: 2021-04-12 13:32:00
# Current time & days to expiry: 2021-04-12 3.0819444444444444
# Curr time & days to EXpiry 2021-04-12 3.0819444444444444
# Processing timestamp: 2021-04-12 13:33:00
# Current time & days to expiry: 2021-04-12 3.08125
# Curr time & days to EXpiry 2021-04-12 3.08125
# Processing timestamp: 2021-04-12 13:34:00
# Current time & days to expiry: 2021-04-12 3.0805555555555557
# Curr time & days to EXpiry 2021-04-12 3.0805555555555557
# Processing timestamp: 2021-04-12 13:35:00
# Current time & days to expiry: 2021-04-12 3.079861111111111
# Curr time & days to EXpiry 2021-04-12 3.079861111111111
# Processing timestamp: 2021-04-12 13:36:00
# Current time & days to expiry: 2021-04-12 3.0791666666666666
# Curr time & days to EXpiry 2021-04-12 3.0791666666666666
# Processing timestamp: 2021-04-12 13:37:00
# Current time & days to expiry: 2021-04-12 3.078472222222222
# Curr time & days to EXpiry 2021-04-12 3.078472222222222
# Processing timestamp: 2021-04-12 13:38:00
# Current time & days to expiry: 2021-04-12 3.077777777777778
# Curr time & days to EXpiry 2021-04-12 3.077777777777778
# Processing timestamp: 2021-04-12 13:39:00
# Current time & days to expiry: 2021-04-12 3.0770833333333334
# Curr time & days to EXpiry 2021-04-12 3.0770833333333334
# Processing timestamp: 2021-04-12 13:40:00
# Current time & days to expiry: 2021-04-12 3.076388888888889
# Curr time & days to EXpiry 2021-04-12 3.076388888888889
# Processing timestamp: 2021-04-12 13:41:00
# Current time & days to expiry: 2021-04-12 3.0756944444444443
# Curr time & days to EXpiry 2021-04-12 3.0756944444444443
# Processing timestamp: 2021-04-12 13:42:00
# Current time & days to expiry: 2021-04-12 3.075
# Curr time & days to EXpiry 2021-04-12 3.075
# Processing timestamp: 2021-04-12 13:43:00
# Current time & days to expiry: 2021-04-12 3.0743055555555556
# Curr time & days to EXpiry 2021-04-12 3.0743055555555556
# Processing timestamp: 2021-04-12 13:44:00
# Current time & days to expiry: 2021-04-12 3.073611111111111
# Curr time & days to EXpiry 2021-04-12 3.073611111111111
# Processing timestamp: 2021-04-12 13:45:00
# Current time & days to expiry: 2021-04-12 3.0729166666666665
# Curr time & days to EXpiry 2021-04-12 3.0729166666666665
# Processing timestamp: 2021-04-12 13:46:00
# Current time & days to expiry: 2021-04-12 3.0722222222222224
# Curr time & days to EXpiry 2021-04-12 3.0722222222222224
# Processing timestamp: 2021-04-12 13:47:00
# Current time & days to expiry: 2021-04-12 3.071527777777778
# Curr time & days to EXpiry 2021-04-12 3.071527777777778
# Processing timestamp: 2021-04-12 13:48:00
# Current time & days to expiry: 2021-04-12 3.0708333333333333
# Curr time & days to EXpiry 2021-04-12 3.0708333333333333
# Processing timestamp: 2021-04-12 13:49:00
# Current time & days to expiry: 2021-04-12 3.0701388888888888
# Curr time & days to EXpiry 2021-04-12 3.0701388888888888
# Processing timestamp: 2021-04-12 13:50:00
# Current time & days to expiry: 2021-04-12 3.0694444444444446
# Curr time & days to EXpiry 2021-04-12 3.0694444444444446
# Processing timestamp: 2021-04-12 13:51:00
# Current time & days to expiry: 2021-04-12 3.06875
# Curr time & days to EXpiry 2021-04-12 3.06875
# Processing timestamp: 2021-04-12 13:52:00
# Current time & days to expiry: 2021-04-12 3.0680555555555555
# Curr time & days to EXpiry 2021-04-12 3.0680555555555555
# Processing timestamp: 2021-04-12 13:53:00
# Current time & days to expiry: 2021-04-12 3.067361111111111
# Curr time & days to EXpiry 2021-04-12 3.067361111111111
# Processing timestamp: 2021-04-12 13:54:00
# Current time & days to expiry: 2021-04-12 3.066666666666667
# Curr time & days to EXpiry 2021-04-12 3.066666666666667
# Processing timestamp: 2021-04-12 13:55:00
# Current time & days to expiry: 2021-04-12 3.0659722222222223
# Curr time & days to EXpiry 2021-04-12 3.0659722222222223
# Processing timestamp: 2021-04-12 13:56:00
# Current time & days to expiry: 2021-04-12 3.0652777777777778
# Curr time & days to EXpiry 2021-04-12 3.0652777777777778
# Processing timestamp: 2021-04-12 13:57:00
# Current time & days to expiry: 2021-04-12 3.064583333333333
# ...
# OI 16317450.0 12221100.0
# OI 16317450.0 12221100.0
# OI 16256925.0 12314850.0
# OI 16256925.0 12317400.0
# OI 15234600.0 13741275.0
# OI 15208725.0 13675725.0
# OI 16221675.0 12249525.0
# OI 16221675.0 12249525.0
# OI 16188375.0 12220500.0
# OI 15195375.0 13657725.0
# OI 15195375.0 13657725.0
# OI 15219825.0 13640925.0
# OI 15219825.0 13640925.0
# OI 15219825.0 13640925.0
# OI 15235125.0 13550250.0
# OI 15235125.0 13550250.0
# OI 15235125.0 13550250.0
# OI 15428925.0 13394325.0
# OI 15428925.0 13394325.0
# OI 15428925.0 13394325.0
# OI 15577575.0 13161150.0
# OI 15577575.0 13161150.0
# OI 15577575.0 13161150.0
# OI 15681825.0 13058400.0
# OI 15681825.0 13058400.0
# OI 15681825.0 13058400.0
# OI 15776775.0 12878400.0
# OI 15776250.0 12878400.0
# OI 15776250.0 12878400.0
# OI 15886500.0 12928200.0
# OI 15885225.0 12928200.0
# OI 15885225.0 12928200.0
# OI 15925950.0 12943050.0
# OI 15924525.0 12943050.0
# OI 15924525.0 12943050.0
# OI 15876375.0 12977325.0
# OI 15876375.0 12977325.0
# OI 12603825.0 12942900.0
# OI 16000800.0 12882525.0
# OI 16000800.0 12882525.0
# OI 16000800.0 12882525.0
# OI 16053600.0 13010625.0
# OI 16053600.0 13010625.0
# OI 16053600.0 13010625.0
# OI 15481650.0 12988275.0
# OI 15481650.0 12988275.0
# OI 16567950.0 11553750.0
# OI 15332850.0 13102425.0
# OI 15332850.0 13102425.0
# OI 15332850.0 13102425.0
# OI 16458375.0 11867325.0
# OI 15390675.0 13305450.0
# OI 15390675.0 13305450.0
# OI 15292425.0 13329075.0
# OI 15292425.0 13329075.0
# OI 16367625.0 11907000.0
# OI 16487625.0 12064425.0
# OI 16487625.0 12064425.0
# OI 16487625.0 12064425.0
# OI 15940800.0 12226950.0
# OI 15940800.0 12226650.0
# OI 15940800.0 12226650.0
# OI 16033350.0 12406050.0
# OI 16033350.0 12406050.0
# OI 16033350.0 12406050.0
# OI 15005925.0 12438300.0
# OI 15005925.0 12438300.0
# OI 18146925.0 12179100.0
# OI 17686050.0 12598275.0
# OI 14593500.0 12847800.0
# OI 14593500.0 12847800.0
# OI 14623950.0 13146150.0
# OI 14624025.0 13146150.0
# OI 14624025.0 13146150.0
# OI 14767050.0 13342275.0
# OI 17859600.0 13107750.0
# OI 17859600.0 13107750.0
# OI 17544000.0 13154550.0
# OI 17544000.0 13154550.0
# OI 17544000.0 13154550.0
# OI 16311825.0 13113825.0
# OI 16311825.0 13113825.0
# OI 16311825.0 13113825.0
# OI 17252025.0 10731450.0
# OI 16233900.0 13383825.0
# OI 16233900.0 13383825.0
# OI 15999075.0 13555650.0
# OI 15999075.0 13555650.0
# OI 15999075.0 13555650.0
# OI 15934125.0 13693800.0
# OI 15934125.0 13693800.0
# OI 15934125.0 13693800.0
# OI 15914175.0 13783650.0
# OI 15914175.0 13783650.0
# OI 15914175.0 13783650.0
# OI 15875250.0 13782750.0
# OI 15875250.0 13783125.0
# OI 15875250.0 13783125.0
# OI 16846950.0 11233725.0
# OI 16846950.0 11233725.0
# OI 15684750.0 13816050.0
# OI 15602025.0 13779000.0
# OI 15602025.0 13779000.0
# OI 15602025.0 13779000.0
# OI 15598275.0 13926675.0
# OI 15598275.0 13926825.0
# OI 16793700.0 11386125.0
# OI 16049700.0 11398350.0
# OI 16049700.0 11398350.0
# OI 16049700.0 11398350.0
# OI 15359700.0 11410275.0
# OI 15359700.0 11412525.0
# OI 15359700.0 11412525.0
# OI 15065550.0 11403975.0
# OI 15065550.0 11403975.0
# OI 15065550.0 11403975.0
# OI 15155850.0 11461575.0
# OI 15155850.0 11461500.0
# OI 15155850.0 11461500.0
# OI 15331950.0 11378100.0
# OI 15331950.0 11378100.0
# OI 14284575.0 13858650.0
# OI 14306250.0 13921725.0
# OI 15377400.0 11408700.0
# OI 15377400.0 11408700.0
# OI 15504150.0 11411700.0
# OI 15504150.0 11410275.0
# OI 15504150.0 11410275.0
# OI 15678900.0 11389950.0
# OI 15678900.0 11389875.0
# OI 15678900.0 11389875.0
# OI 14526450.0 13779000.0
# OI 14526450.0 13779000.0
# OI 14526450.0 13779000.0
# OI 15474975.0 11102850.0
# OI 15474975.0 11102850.0
# OI 15474975.0 11102850.0
# OI 15040950.0 10921275.0
# OI 15040950.0 10921275.0
# OI 15040950.0 10921275.0
# OI 14888625.0 10779525.0
# OI 14884725.0 10779525.0
# OI 14884725.0 10779525.0
# OI 14782350.0 10670100.0
# OI 14780100.0 10670100.0
# OI 14780100.0 10670100.0
# OI 14773725.0 10549050.0
# OI 14774100.0 10543425.0
# OI 14774100.0 10543425.0
# OI 14466150.0 10359600.0
# OI 14465175.0 10361400.0
# OI 14465175.0 10361400.0
# OI 16873650.0 9742125.0
# OI 14020875.0 10246125.0
# OI 16873650.0 9743025.0
# OI 13477050.0 9891150.0
# OI 13477050.0 9891900.0
# OI 13477050.0 9891900.0
# OI 16277700.0 9401925.0
# OI 12974775.0 9479550.0
# OI 15780975.0 9023400.0
# OI 17198025.0 9688725.0
# OI 17198025.0 9688725.0
# OI 17198025.0 9688725.0
# OI 18143850.0 11114550.0
# OI 18143850.0 11114550.0
# OI 18143850.0 11114550.0
# OI 19650750.0 12948375.0
# OI 19650750.0 12948375.0
# OI 19650750.0 12948375.0
# OI 20499450.0 14326725.0
# OI 20499450.0 14326725.0
# OI 20499450.0 14326725.0
# OI 21223275.0 15160875.0
# OI 21223275.0 15160875.0
# OI 21223275.0 15160875.0
# OI 22287900.0 16122150.0
# OI 22287900.0 16122150.0
# OI 18631875.0 17202000.0
# OI 19157550.0 17812800.0
# OI 19157550.0 17812800.0
# OI 17685750.0 20621475.0
# OI 17916150.0 19263900.0
# OI 17916150.0 19263900.0
# OI 17916150.0 19263900.0
# OI 18587625.0 18929550.0
# OI 18587625.0 18929550.0
# OI 18587625.0 18929550.0
# OI 19368450.0 18808725.0
# OI 19368450.0 18808725.0
# OI 19368450.0 18808725.0
# OI 19842075.0 19007175.0
# OI 19842075.0 19007175.0
# OI 19842075.0 19007175.0
# OI 20482275.0 19149525.0
# OI 20482275.0 19149525.0
# OI 20482275.0 19149525.0
# OI 21156900.0 19112400.0
# OI 21156900.0 19112400.0
# OI 21156900.0 19112400.0
# OI 21849225.0 18895950.0
# OI 21849225.0 18895950.0
# OI 21849225.0 18895950.0
# OI 22086150.0 18704175.0
# OI 23643600.0 15800025.0
# OI 23643600.0 15800025.0
# OI 24096975.0 16254300.0
# OI 24096975.0 16254300.0
# OI 24096975.0 16254300.0
# OI 23678400.0 16517175.0
# OI 22063725.0 19475100.0
# OI 22063725.0 19475100.0
# OI 23929200.0 16688475.0
# OI 22301925.0 19676925.0
# OI 22301925.0 19676925.0
# OI 22515000.0 19686450.0
# OI 22515000.0 19686450.0
# OI 22515000.0 19686450.0
# OI 23128875.0 19426275.0
# OI 23128875.0 19426275.0
# OI 23128875.0 19426275.0
# OI 23737800.0 19419975.0
# OI 23737800.0 19419975.0
# OI 18764850.0 19736400.0
# OI 19445850.0 19489200.0
# OI 19445850.0 19489200.0
# OI 19445850.0 19489200.0
# OI 19653000.0 19228200.0
# OI 19653000.0 19228200.0
# OI 19653000.0 19228200.0
# OI 20007000.0 19303050.0
# OI 20007000.0 19303050.0
# OI 20007000.0 19303050.0
# OI 20321250.0 18925275.0
# OI 20322450.0 18925275.0
# OI 20322450.0 18925275.0
# OI 20840775.0 18289200.0
# OI 20840250.0 18289200.0
# OI 20840250.0 18289200.0
# OI 21158625.0 18069600.0
# OI 21158625.0 18069600.0
# OI 21158625.0 18069600.0
# OI 21519675.0 18144075.0
# OI 21519675.0 18144075.0
# OI 21519675.0 18144075.0
# OI 21690225.0 18277800.0
# OI 21690225.0 18277800.0
# OI 21690225.0 18277800.0
# OI 21768450.0 18462525.0
# OI 21768675.0 18462525.0
# OI 21768675.0 18462525.0
# OI 26910675.0 18233175.0
# OI 26910675.0 18233175.0
# OI 21801975.0 18705675.0
# OI 21854850.0 18741075.0
# OI 21854850.0 18741075.0
# OI 21854850.0 18741075.0
# OI 22106850.0 18936825.0
# OI 22106850.0 18936825.0
# OI 22106850.0 18936825.0
# OI 22318200.0 19054575.0
# OI 22318800.0 19054575.0
# OI 22318800.0 19054575.0
# OI 22466775.0 19272900.0
# OI 22466625.0 19272900.0
# OI 22466625.0 19272900.0
# OI 22565025.0 19116825.0
# OI 22564950.0 19116825.0
# OI 22564950.0 19116825.0
# OI 22828650.0 18738150.0
# OI 22828950.0 18738150.0
# OI 22828950.0 18738150.0
# OI 23262075.0 18895350.0
# OI 21136800.0 20629650.0
# OI 23262150.0 18895350.0
# OI 21432225.0 20221050.0
# OI 21432675.0 20221050.0
# OI 21432675.0 20221050.0
# OI 21746700.0 19845825.0
# OI 21754275.0 19845825.0
# OI 23786325.0 18056850.0
# OI 23985600.0 18154650.0
# OI 21988725.0 19953300.0
# OI 23986425.0 18152250.0
# OI 24198675.0 18242775.0
# OI 24198900.0 18241275.0
# OI 22123200.0 20044800.0
# OI 22314450.0 19991100.0
# OI 22318650.0 19991100.0
# OI 22318875.0 19991100.0
# OI 22606125.0 19953975.0
# OI 22607925.0 19953975.0
# OI 22607925.0 19953975.0
# OI 22758075.0 20045250.0
# OI 22756725.0 20043000.0
# OI 22756725.0 20043000.0
# OI 24973575.0 18160125.0
# OI 24973575.0 18160125.0
# OI 24973575.0 18160125.0
# OI 23074800.0 19801350.0
# OI 23072850.0 19801350.0
# OI 25134375.0 18048975.0
# OI 25323000.0 18299325.0
# OI 25323375.0 18295425.0
# OI 25323375.0 18295425.0
# OI 25267275.0 18333150.0
# OI 25265025.0 18590100.0
# OI 25265025.0 18590100.0
# OI 25263600.0 18611925.0
# OI 24767550.0 18906000.0
# OI 24767550.0 18906000.0
# OI 29859450.0 18287775.0
# OI 29233650.0 18608325.0
# OI 29233650.0 18608325.0
# OI 29233650.0 18608325.0
# OI 28806750.0 19159875.0
# OI 28806750.0 19159875.0
# OI 28806750.0 19159875.0
# OI 28420650.0 19229100.0
# OI 28420650.0 19229100.0
# OI 28420650.0 19229100.0
# OI 28655475.0 19732575.0
# OI 28655475.0 19732575.0
# OI 23568750.0 20371725.0
# OI 23630700.0 20433825.0
# OI 23630700.0 20433825.0
# OI 23630700.0 20433825.0
# OI 23690700.0 20510475.0
# OI 23690700.0 20510475.0
# OI 28813875.0 19868175.0
# OI 23910600.0 20758200.0
# OI 29025675.0 20093400.0
# OI 29025675.0 20093400.0
# OI 28908900.0 20115075.0
# OI 28908900.0 20115075.0
# OI 28908900.0 20115075.0
# OI 28874475.0 20330700.0
# OI 28874475.0 20330700.0
# OI 28874475.0 20330700.0
# OI 29028525.0 20194500.0
# OI 29028525.0 20194500.0
# OI 29028525.0 20194500.0
# OI 24108900.0 20794200.0
# OI 24108900.0 20794200.0
# OI 24108900.0 20794200.0
# OI 24140850.0 20738325.0
# OI 24140850.0 20738325.0
# OI 24140850.0 20738325.0
# OI 24302475.0 20843175.0
# OI 24302475.0 20843175.0
# OI 29433525.0 20210325.0
# OI 29867400.0 20224500.0
# OI 24696600.0 20921175.0
# OI 24696600.0 20921175.0
# OI 24900975.0 21007125.0
# OI 24900975.0 21007125.0
# OI 24900975.0 21007125.0
# OI 24970725.0 21070200.0
# OI 30177150.0 20378475.0
# OI 30177150.0 20378475.0
# OI 30255150.0 20560425.0
# OI 30255150.0 20560425.0
# OI 30255150.0 20560425.0
# OI 30263100.0 20715825.0
# OI 30263100.0 20715825.0
# OI 30263100.0 20715825.0
# OI 30286500.0 20779125.0
# OI 30286500.0 20779125.0
# OI 30286500.0 20779125.0
# OI 30272025.0 20991375.0
# OI 30272025.0 20991375.0
# OI 30272025.0 20991375.0
# OI 29840475.0 21127875.0
# OI 29840475.0 21127875.0
# OI 29840475.0 21127875.0
# OI 30022500.0 21131025.0
# OI 30022500.0 21131025.0
# OI 30022500.0 21131025.0
# OI 30264825.0 21181200.0
# OI 30264825.0 21181200.0
# OI 30264825.0 21181200.0
# OI 30073275.0 21422625.0
# OI 30073275.0 21422625.0
# OI 30073275.0 21422625.0
# OI 30219600.0 21416925.0
# OI 30219600.0 21416925.0
# OI 30219600.0 21416925.0
# OI 29697000.0 21620175.0
# OI 29697000.0 21620175.0
# OI 24656475.0 22260525.0
# OI 24928050.0 22093200.0
# OI 24928050.0 22093200.0
# OI 29981400.0 21443925.0
# OI 25347825.0 22208475.0
# OI 25347825.0 22208475.0
# OI 30336825.0 21563550.0
# OI 25428525.0 22275375.0
# OI 30447450.0 21636075.0
# OI 30447450.0 21636075.0
# OI 30604125.0 21764325.0
# OI 30604125.0 21764325.0
# OI 30604125.0 21764325.0
# OI 30442650.0 21846525.0
# OI 30442650.0 21846525.0
# OI 30442650.0 21846525.0
# OI 30466650.0 21894075.0
# OI 30466650.0 21894075.0
# OI 25550925.0 22564500.0
# OI 25591050.0 22449975.0
# OI 30509175.0 21759300.0
# OI 30509175.0 21759300.0
# OI 30514950.0 21848475.0
# OI 30514950.0 21848475.0
# OI 30514950.0 21848475.0
# OI 30599400.0 21839475.0
# OI 30599400.0 21839475.0
# OI 30599400.0 21839475.0
# OI 30642825.0 22042275.0
# OI 30642825.0 22042275.0
# OI 30642825.0 22042275.0
# OI 30479775.0 22206600.0
# OI 30479775.0 22206600.0
# OI 30479775.0 22206600.0
# OI 30137100.0 22435425.0
# OI 30137100.0 22435425.0
# OI 30137100.0 22435425.0
# OI 30714075.0 19375200.0
# OI 30714075.0 19375200.0
# OI 29207850.0 22580250.0
# OI 30677175.0 19616250.0
# OI 29122200.0 22733700.0
# OI 29122200.0 22733700.0
# OI 29117700.0 22826850.0
# OI 29117700.0 22826850.0
# OI 30641475.0 19728900.0
# OI 29246025.0 23099325.0
# OI 30765525.0 19964175.0
# OI 29246025.0 23099325.0
# OI 30728550.0 20182875.0
# OI 30728550.0 20182875.0
# OI 30728550.0 20182875.0
# OI 30055575.0 20270325.0
# OI 28549800.0 23285700.0
# OI 28549800.0 23285700.0
# OI 30123825.0 20188950.0
# OI 30123825.0 20188950.0
# OI 30123825.0 20188950.0
# OI 29985600.0 20262450.0
# OI 29985600.0 20262450.0
# OI 29985600.0 20262450.0
# OI 28453800.0 20249025.0
# OI 28453800.0 20249025.0
# OI 28453800.0 20249025.0
# OI 27476325.0 20549700.0
# OI 27476325.0 20549700.0
# OI 27476325.0 20549700.0
# OI 27648600.0 20614950.0
# OI 27648600.0 20614950.0
# OI 27648600.0 20614950.0
# OI 27668475.0 20983800.0
# OI 27668475.0 20983800.0
# OI 27668475.0 20983800.0
# OI 27598650.0 20964600.0
# OI 31729200.0 19683600.0
# OI 31729200.0 19683600.0
# OI 27449400.0 21285600.0
# OI 27449400.0 21285075.0
# OI 27449400.0 21285075.0
# OI 27535125.0 20667075.0
# OI 27535125.0 20667075.0
# OI 27535125.0 20667075.0
# OI 28014150.0 20071875.0
# OI 28014150.0 20071875.0
# OI 28014150.0 20071875.0
# OI 28118475.0 20107800.0
# OI 28118475.0 20107800.0
# OI 28118475.0 20107800.0
# OI 28022625.0 20202150.0
# OI 28022625.0 20202150.0
# OI 28022625.0 20202150.0
# OI 28266150.0 20332650.0
# OI 28266150.0 20332650.0
# OI 28266150.0 20332650.0
# OI 27891525.0 19531650.0
# OI 27891975.0 19531650.0
# OI 27891975.0 19531650.0
# OI 27683850.0 19733250.0
# OI 27683850.0 19733250.0
# OI 27683850.0 19733250.0
# OI 27195825.0 19895775.0
# OI 27195825.0 19895775.0
# OI 27195825.0 19895775.0
# OI 27386925.0 19946625.0
# OI 27386925.0 19945800.0
# OI 27386925.0 19945800.0
# OI 27281850.0 19876125.0
# OI 27281850.0 19876125.0
# OI 27281850.0 19876125.0
# OI 26997975.0 19595025.0
# OI 26997975.0 19595025.0
# OI 26997975.0 19595025.0
# OI 26239500.0 19775400.0
# OI 26239500.0 19775400.0
# OI 30031950.0 18815625.0
# OI 28488600.0 19340175.0
# OI 28488600.0 19339800.0
# OI 28488600.0 19339800.0
# OI 27431775.0 19552950.0
# OI 27431775.0 19552950.0
# OI 27431775.0 19552950.0
# OI 27243000.0 19652475.0
# OI 27509400.0 16713525.0
# OI 27243000.0 19652475.0
# OI 26180850.0 16638450.0
# OI 26180850.0 16638450.0
# OI 26180850.0 16638450.0
# OI 25579725.0 16216275.0
# OI 25579725.0 16213500.0
# OI 25579725.0 16213500.0
# OI 25473525.0 15968850.0
# OI 25473150.0 15969975.0
# OI 25473150.0 15969975.0
# OI 25507500.0 14839950.0
# OI 25507500.0 14839950.0
# OI 25507500.0 14839950.0
# OI 24391125.0 13727250.0
# OI 24391125.0 13727250.0
# OI 24391125.0 13727250.0
# OI 22620750.0 12906750.0
# OI 22618350.0 12906750.0
# OI 22618350.0 12906750.0
# OI 20936700.0 11765100.0
# OI 20936700.0 11755500.0
# OI 20936700.0 11755500.0
# OI 20936700.0 11755500.0
#                     Ticker     Open     High      Low    Close  Volume  \
# Date/Time
# 2021-04-09 09:15:00  NIFTY  14882.6  14882.6  14822.9  14837.6       1
# 2021-04-09 09:16:00  NIFTY  14839.2  14846.4  14817.1  14846.4       1
# 2021-04-09 09:17:00  NIFTY  14848.1  14877.2  14848.1  14861.6       1
# 2021-04-09 09:18:00  NIFTY  14862.9  14862.9  14845.5  14847.1       1
# 2021-04-09 09:19:00  NIFTY  14841.0  14844.5  14833.1  14837.0       1
#
#                      Open Interest  INDIAVIX  ATM_Delta    ATM_OI  ...  \
# Date/Time                                                          ...
# 2021-04-09 09:15:00              0     20.81   0.539942  151125.0  ...
# 2021-04-09 09:16:00              0     20.78   0.542172  151125.0  ...
# 2021-04-09 09:17:00              0     20.67   0.546374  189525.0  ...
# 2021-04-09 09:18:00              0     20.97   0.541223  189525.0  ...
# 2021-04-09 09:19:00              0     20.92   0.538521  189525.0  ...
#
#                      OTM4_PE_Gamma  OTM4_PE_Theta  OTM4_PE_Vega  OTM4_PE_Rho  \
# Date/Time
# 2021-04-09 09:15:00       0.000070      -0.483921      0.076609    -0.015204
# 2021-04-09 09:16:00       0.000076      -0.448955      0.076823    -0.015072
# 2021-04-09 09:17:00       0.000079      -0.432263      0.076953    -0.014986
# 2021-04-09 09:18:00       0.000074      -0.459446      0.076762    -0.015101
# 2021-04-09 09:19:00       0.000071      -0.479246      0.076618    -0.015182
#
#                      OTM5_PE_Delta  OTM5_PE_OI  OTM5_PE_Gamma  OTM5_PE_Theta  \
# Date/Time
# 2021-04-09 09:15:00      -0.431047    107625.0       0.000062      -0.542374
# 2021-04-09 09:16:00      -0.437875    107625.0       0.000067      -0.504151
# 2021-04-09 09:17:00      -0.439185    112725.0       0.000069      -0.492372
# 2021-04-09 09:18:00      -0.435618    112725.0       0.000066      -0.515744
# 2021-04-09 09:19:00      -0.434177    112725.0       0.000064      -0.526482
#
#                      OTM5_PE_Vega  OTM5_PE_Rho
# Date/Time
# 2021-04-09 09:15:00      0.076362    -0.015529
# 2021-04-09 09:16:00      0.076622    -0.015387
# 2021-04-09 09:17:00      0.076736    -0.015319
# 2021-04-09 09:18:00      0.076547    -0.015419
# 2021-04-09 09:19:00      0.076445    -0.015470
#
# [5 rows x 163 columns]
# Greeks and Open Interest data have been populated and the DataFrame has been saved to CSV.

# %%
print(nifty_with_greeks.head())
# Out:
#                     Ticker     Open     High      Low    Close  Volume  \
# Date/Time
# 2021-04-09 09:15:00  NIFTY  14882.6  14882.6  14822.9  14837.6       1
# 2021-04-09 09:16:00  NIFTY  14839.2  14846.4  14817.1  14846.4       1
# 2021-04-09 09:17:00  NIFTY  14848.1  14877.2  14848.1  14861.6       1
# 2021-04-09 09:18:00  NIFTY  14862.9  14862.9  14845.5  14847.1       1
# 2021-04-09 09:19:00  NIFTY  14841.0  14844.5  14833.1  14837.0       1
#
#                      Open Interest  INDIAVIX  ATM_Delta    ATM_OI  ...  \
# Date/Time                                                          ...
# 2021-04-09 09:15:00              0     20.81   0.539942  151125.0  ...
# 2021-04-09 09:16:00              0     20.78   0.542172  151125.0  ...
# 2021-04-09 09:17:00              0     20.67   0.546374  189525.0  ...
# 2021-04-09 09:18:00              0     20.97   0.541223  189525.0  ...
# 2021-04-09 09:19:00              0     20.92   0.538521  189525.0  ...
#
#                      OTM4_PE_Theta  OTM4_PE_Vega  OTM4_PE_Rho  OTM5_PE_Delta  \
# Date/Time
# 2021-04-09 09:15:00      -0.483921      0.076609    -0.015204      -0.431047
# 2021-04-09 09:16:00      -0.448955      0.076823    -0.015072      -0.437875
# 2021-04-09 09:17:00      -0.432263      0.076953    -0.014986      -0.439185
# 2021-04-09 09:18:00      -0.459446      0.076762    -0.015101      -0.435618
# 2021-04-09 09:19:00      -0.479246      0.076618    -0.015182      -0.434177
#
#                      OTM5_PE_OI  OTM5_PE_Gamma  OTM5_PE_Theta  OTM5_PE_Vega  \
# Date/Time
# 2021-04-09 09:15:00    107625.0       0.000062      -0.542374      0.076362
# 2021-04-09 09:16:00    107625.0       0.000067      -0.504151      0.076622
# 2021-04-09 09:17:00    112725.0       0.000069      -0.492372      0.076736
# 2021-04-09 09:18:00    112725.0       0.000066      -0.515744      0.076547
# 2021-04-09 09:19:00    112725.0       0.000064      -0.526482      0.076445
#
#                      OTM5_PE_Rho  PCR_Volume
# Date/Time
# 2021-04-09 09:15:00    -0.015529    1.479039
# 2021-04-09 09:16:00    -0.015387    1.418962
# 2021-04-09 09:17:00    -0.015319    0.972888
# 2021-04-09 09:18:00    -0.015419    1.225572
# 2021-04-09 09:19:00    -0.015470    1.170069
#
# [5 rows x 164 columns]

# %%
print("PCR_Volume" in nifty_with_greeks.columns)
# Out:
# True

# %%
pd.set_option('display.max_columns', None)
print(nifty_with_greeks.columns.tolist())
# Out:
# ['Ticker', 'Open', 'High', 'Low', 'Close', 'Volume', 'Open Interest', 'INDIAVIX', 'ATM_Delta', 'ATM_OI', 'ATM_Call_Volume', 'ATM_Put_Volume', 'ATM_Gamma', 'ATM_Theta', 'ATM_Vega', 'ATM_Rho', 'ITM1_Delta', 'ITM1_OI', 'ITM1_Call_Volume', 'ITM1_Put_Volume', 'ITM1_Gamma', 'ITM1_Theta', 'ITM1_Vega', 'ITM1_Rho', 'OTM1_Delta', 'OTM1_OI', 'OTM1_Call_Volume', 'OTM1_Put_Volume', 'OTM1_Gamma', 'OTM1_Theta', 'OTM1_Vega', 'OTM1_Rho', 'ITM2_Delta', 'ITM2_OI', 'ITM2_Call_Volume', 'ITM2_Put_Volume', 'ITM2_Gamma', 'ITM2_Theta', 'ITM2_Vega', 'ITM2_Rho', 'OTM2_Delta', 'OTM2_OI', 'OTM2_Call_Volume', 'OTM2_Put_Volume', 'OTM2_Gamma', 'OTM2_Theta', 'OTM2_Vega', 'OTM2_Rho', 'ITM3_Delta', 'ITM3_OI', 'ITM3_Call_Volume', 'ITM3_Put_Volume', 'ITM3_Gamma', 'ITM3_Theta', 'ITM3_Vega', 'ITM3_Rho', 'OTM3_Delta', 'OTM3_OI', 'OTM3_Call_Volume', 'OTM3_Put_Volume', 'OTM3_Gamma', 'OTM3_Theta', 'OTM3_Vega', 'OTM3_Rho', 'ITM4_Delta', 'ITM4_OI', 'ITM4_Call_Volume', 'ITM4_Put_Volume', 'ITM4_Gamma', 'ITM4_Theta', 'ITM4_Vega', 'ITM4_Rho', 'OTM4_Delta', 'OTM4_OI', 'OTM4_Call_Volume', 'OTM4_Put_Volume', 'OTM4_Gamma', 'OTM4_Theta', 'OTM4_Vega', 'OTM4_Rho', 'ITM5_Delta', 'ITM5_OI', 'ITM5_Call_Volume', 'ITM5_Put_Volume', 'ITM5_Gamma', 'ITM5_Theta', 'ITM5_Vega', 'ITM5_Rho', 'OTM5_Delta', 'OTM5_OI', 'OTM5_Call_Volume', 'OTM5_Put_Volume', 'OTM5_Gamma', 'OTM5_Theta', 'OTM5_Vega', 'OTM5_Rho', 'PCR', 'ATM_PE_Delta', 'ATM_PE_OI', 'ATM_PE_Gamma', 'ATM_PE_Theta', 'ATM_PE_Vega', 'ATM_PE_Rho', 'ITM1_PE_Delta', 'ITM1_PE_OI', 'ITM1_PE_Gamma', 'ITM1_PE_Theta', 'ITM1_PE_Vega', 'ITM1_PE_Rho', 'ITM2_PE_Delta', 'ITM2_PE_OI', 'ITM2_PE_Gamma', 'ITM2_PE_Theta', 'ITM2_PE_Vega', 'ITM2_PE_Rho', 'ITM3_PE_Delta', 'ITM3_PE_OI', 'ITM3_PE_Gamma', 'ITM3_PE_Theta', 'ITM3_PE_Vega', 'ITM3_PE_Rho', 'ITM4_PE_Delta', 'ITM4_PE_OI', 'ITM4_PE_Gamma', 'ITM4_PE_Theta', 'ITM4_PE_Vega', 'ITM4_PE_Rho', 'ITM5_PE_Delta', 'ITM5_PE_OI', 'ITM5_PE_Gamma', 'ITM5_PE_Theta', 'ITM5_PE_Vega', 'ITM5_PE_Rho', 'OTM1_PE_Delta', 'OTM1_PE_OI', 'OTM1_PE_Gamma', 'OTM1_PE_Theta', 'OTM1_PE_Vega', 'OTM1_PE_Rho', 'OTM2_PE_Delta', 'OTM2_PE_OI', 'OTM2_PE_Gamma', 'OTM2_PE_Theta', 'OTM2_PE_Vega', 'OTM2_PE_Rho', 'OTM3_PE_Delta', 'OTM3_PE_OI', 'OTM3_PE_Gamma', 'OTM3_PE_Theta', 'OTM3_PE_Vega', 'OTM3_PE_Rho', 'OTM4_PE_Delta', 'OTM4_PE_OI', 'OTM4_PE_Gamma', 'OTM4_PE_Theta', 'OTM4_PE_Vega', 'OTM4_PE_Rho', 'OTM5_PE_Delta', 'OTM5_PE_OI', 'OTM5_PE_Gamma', 'OTM5_PE_Theta', 'OTM5_PE_Vega', 'OTM5_PE_Rho', 'PCR_Volume']

# %%
print(nifty_with_greeks['PCR_Volume'])
# Out:
# Date/Time
# 2021-04-09 09:15:00    1.479039
# 2021-04-09 09:16:00    1.418962
# 2021-04-09 09:17:00    0.972888
# 2021-04-09 09:18:00    1.225572
# 2021-04-09 09:19:00    1.170069
#                          ...
# 2021-04-15 15:26:00    1.146124
# 2021-04-15 15:27:00    0.577092
# 2021-04-15 15:28:00    0.414506
# 2021-04-15 15:29:00    0.219107
# 2021-04-15 15:30:00    0.219107
# Name: PCR_Volume, Length: 1504, dtype: float64
