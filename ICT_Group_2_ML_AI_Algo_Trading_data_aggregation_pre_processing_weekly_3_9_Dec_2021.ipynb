# %% [markdown]
# <a href="https://colab.research.google.com/github/jjikku/OptiGene-Algo/blob/main/ICT_Group_2_ML_AI_Algo_Trading_data_aggregation_pre_processing_weekly_3_9_Dec_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# Specify the exact path to the CSV file
file_path = "/content/drive/My Drive/NIfty_Dataset/03-09-DEC- -W-ExpiryWEEKdata_2021_NF_BNF_options_vege.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Exclude rows where the ticker contains any of the following
excluded_tickers = [
    "BANKNIFTY", "FINNIFTY", "FUT", "NIFTYAUTO", "NIFTYENERGY",
    "NIFTYFINSERVICE", "NIFTYFMCG", "NIFTYINFRA", "NIFTYIT", "NIFTYMEDIA",
    "NIFTYMETAL", "NIFTYMIDCAP50", "NIFTYPHARMA", "NIFTYPSUBANK",
    "NIFTYREALTY", "USDINR-I"
]

# Create a regular expression pattern that matches any of the excluded tickers
pattern = '|'.join(excluded_tickers)

# Apply the mask to filter the DataFrame
mask = ~df['Ticker'].str.contains(pattern)
df_filtered = df[mask]

# Get unique values in the 'Ticker' column after filtering
unique_tickers = df_filtered['Ticker'].unique()

# Extract all rows that match the unique tickers
final_df = df[df['Ticker'].isin(unique_tickers)]

# Create a new CSV file with the extracted rows
output_file_path = "/content/drive/My Drive/NIfty_Dataset/weekly_filtered_tickers_data_03-09-DEC.csv"
final_df.to_csv(output_file_path, index=False)

print(f"Created new CSV file at: {output_file_path}")
# Out:
# Mounted at /content/drive
# Created new CSV file at: /content/drive/My Drive/NIfty_Dataset/weekly_filtered_tickers_data_03-09-DEC.csv

# %%
# print(unique_tickers)

# %%
# final_df.count()

# %%
# final_df['Open Interest'].count()

# %%
# non_zero_count = final_df['Open Interest'].ne(0).sum()
# print(f"The count of non-zero 'Open Interest' values is: {non_zero_count}")

# %%
# Create a separate DataFrame for each unique ticker and store it in a dictionary
dfs = {ticker: df[df['Ticker'] == ticker] for ticker in unique_tickers}

# Now dfs is a dictionary with tickers as keys and the corresponding DataFrame as values

# Assuming df is your original DataFrame with all tickers
for ticker in unique_tickers:
    # Select the DataFrame for the current ticker
    ticker_df = df[df['Ticker'] == ticker].copy()  # Use copy to avoid SettingWithCopyWarning

    # Convert 'Date/Time' to datetime and set as index
    ticker_df['Date/Time'] = pd.to_datetime(ticker_df['Date/Time'], format='%d-%m-%Y %H:%M:%S')
    ticker_df.set_index('Date/Time', inplace=True)

    # Remove duplicate indices if any
    ticker_df = ticker_df[~ticker_df.index.duplicated(keep='first')]

    # Assign the processed DataFrame back to the dfs dictionary
    dfs[ticker] = ticker_df

# Now dfs is a dictionary where each value is a DataFrame with 'Date/Time' as a datetime index

# %%
# Iterate through the dfs dictionary
for ticker, dataframe in dfs.items():
    # Check if the ticker ends with 'PE' or 'CE'
    if ticker.endswith('PE') or ticker.endswith('CE'):
        # Forward fill any NaN values
        dataframe['Open Interest'] = dataframe['Open Interest'].fillna(method='ffill')

        # Replace zero values with the forward filled values
        dataframe['Open Interest'] = dataframe['Open Interest'].replace(to_replace=0, method='ffill')

        # Assign the processed DataFrame back to the dfs dictionary
        dfs[ticker] = dataframe

# %%
import numpy as np
# Get the DataFrame for NIFTY as the reference
reference_df = dfs['NIFTY'].copy()

# Get all timestamps from the NIFTY DataFrame
reference_timestamps = reference_df.index
print("REF",reference_timestamps)

# Function to insert missing timestamps into a DataFrame
def insert_missing_timestamps(df, reference_ts):
    # Ensure the DataFrame index is unique and sorted
    df = df[~df.index.duplicated(keep='first')].sort_index()

    # Find the missing timestamps
    missing_timestamps = reference_ts.difference(df.index)

    # Insert rows with NaNs for missing timestamps
    for ts in missing_timestamps:
        if ts not in df.index:
            df.loc[ts] = [np.nan] * len(df.columns)

    # Sort the DataFrame after inserting new rows
    df.sort_index(inplace=True)

    return df

# Iterate over each DataFrame in dfs
for ticker, dataframe in dfs.items():
    if ticker != 'NIFTY':  # Skip the NIFTY DataFrame as it is the reference
        # Insert missing timestamps without altering existing data
        print("TICKER",ticker)
        dfs[ticker] = insert_missing_timestamps(dataframe, reference_timestamps)
# Out:
# REF DatetimeIndex(['2021-12-03 09:15:00', '2021-12-03 09:16:00',
#                '2021-12-03 09:17:00', '2021-12-03 09:18:00',
#                '2021-12-03 09:19:00', '2021-12-03 09:20:00',
#                '2021-12-03 09:21:00', '2021-12-03 09:22:00',
#                '2021-12-03 09:23:00', '2021-12-03 09:24:00',
#                ...
#                '2021-12-09 15:21:00', '2021-12-09 15:22:00',
#                '2021-12-09 15:23:00', '2021-12-09 15:24:00',
#                '2021-12-09 15:25:00', '2021-12-09 15:26:00',
#                '2021-12-09 15:27:00', '2021-12-09 15:28:00',
#                '2021-12-09 15:29:00', '2021-12-09 15:30:00'],
#               dtype='datetime64[ns]', name='Date/Time', length=1880, freq=None)
# TICKER INDIAVIX
# TICKER NIFTYWK15400CE
# TICKER NIFTYWK15400PE
# TICKER NIFTYWK15450CE
# TICKER NIFTYWK15450PE
# TICKER NIFTYWK15500CE
# TICKER NIFTYWK15500PE
# TICKER NIFTYWK15550CE
# TICKER NIFTYWK15550PE
# TICKER NIFTYWK15600CE
# TICKER NIFTYWK15600PE
# TICKER NIFTYWK15650CE
# TICKER NIFTYWK15650PE
# TICKER NIFTYWK15700CE
# TICKER NIFTYWK15700PE
# TICKER NIFTYWK15750PE
# TICKER NIFTYWK15800CE
# TICKER NIFTYWK15800PE
# TICKER NIFTYWK15850CE
# TICKER NIFTYWK15850PE
# TICKER NIFTYWK15900PE
# TICKER NIFTYWK15950PE
# TICKER NIFTYWK16000CE
# TICKER NIFTYWK16000PE
# TICKER NIFTYWK16050CE
# TICKER NIFTYWK16050PE
# TICKER NIFTYWK16100CE
# TICKER NIFTYWK16100PE
# TICKER NIFTYWK16150PE
# TICKER NIFTYWK16200CE
# TICKER NIFTYWK16200PE
# TICKER NIFTYWK16250CE
# TICKER NIFTYWK16250PE
# TICKER NIFTYWK16300CE
# TICKER NIFTYWK16300PE
# TICKER NIFTYWK16350CE
# TICKER NIFTYWK16350PE
# TICKER NIFTYWK16400CE
# TICKER NIFTYWK16400PE
# TICKER NIFTYWK16450CE
# TICKER NIFTYWK16450PE
# TICKER NIFTYWK16500CE
# TICKER NIFTYWK16500PE
# TICKER NIFTYWK16550CE
# TICKER NIFTYWK16550PE
# TICKER NIFTYWK16600CE
# TICKER NIFTYWK16600PE
# TICKER NIFTYWK16650CE
# TICKER NIFTYWK16650PE
# TICKER NIFTYWK16700CE
# TICKER NIFTYWK16700PE
# TICKER NIFTYWK16750CE
# TICKER NIFTYWK16750PE
# TICKER NIFTYWK16800CE
# TICKER NIFTYWK16800PE
# TICKER NIFTYWK16850CE
# TICKER NIFTYWK16850PE
# TICKER NIFTYWK16900CE
# TICKER NIFTYWK16900PE
# TICKER NIFTYWK16950CE
# TICKER NIFTYWK16950PE
# TICKER NIFTYWK17000CE
# TICKER NIFTYWK17000PE
# TICKER NIFTYWK17050CE
# TICKER NIFTYWK17050PE
# TICKER NIFTYWK17100CE
# TICKER NIFTYWK17100PE
# TICKER NIFTYWK17150CE
# TICKER NIFTYWK17150PE
# TICKER NIFTYWK17200CE
# TICKER NIFTYWK17200PE
# TICKER NIFTYWK17250CE
# TICKER NIFTYWK17250PE
# TICKER NIFTYWK17300CE
# TICKER NIFTYWK17300PE
# TICKER NIFTYWK17350CE
# TICKER NIFTYWK17350PE
# TICKER NIFTYWK17400CE
# TICKER NIFTYWK17400PE
# TICKER NIFTYWK17450CE
# TICKER NIFTYWK17450PE
# TICKER NIFTYWK17500CE
# TICKER NIFTYWK17500PE
# TICKER NIFTYWK17550CE
# TICKER NIFTYWK17550PE
# TICKER NIFTYWK17600CE
# TICKER NIFTYWK17600PE
# TICKER NIFTYWK17650CE
# TICKER NIFTYWK17650PE
# TICKER NIFTYWK17700CE
# TICKER NIFTYWK17700PE
# TICKER NIFTYWK17750CE
# TICKER NIFTYWK17750PE
# TICKER NIFTYWK17800CE
# TICKER NIFTYWK17800PE
# TICKER NIFTYWK17850CE
# TICKER NIFTYWK17850PE
# TICKER NIFTYWK17900CE
# TICKER NIFTYWK17900PE
# TICKER NIFTYWK17950CE
# TICKER NIFTYWK17950PE
# TICKER NIFTYWK18000CE
# TICKER NIFTYWK18000PE
# TICKER NIFTYWK18050CE
# TICKER NIFTYWK18050PE
# TICKER NIFTYWK18100CE
# TICKER NIFTYWK18100PE
# TICKER NIFTYWK18150CE
# TICKER NIFTYWK18150PE
# TICKER NIFTYWK18200CE
# TICKER NIFTYWK18200PE
# TICKER NIFTYWK18250CE
# TICKER NIFTYWK18250PE
# TICKER NIFTYWK18300CE
# TICKER NIFTYWK18300PE
# TICKER NIFTYWK18350CE
# TICKER NIFTYWK18350PE
# TICKER NIFTYWK18400CE
# TICKER NIFTYWK18400PE
# TICKER NIFTYWK18450CE
# TICKER NIFTYWK18450PE
# TICKER NIFTYWK18500CE
# TICKER NIFTYWK18500PE
# TICKER NIFTYWK18550CE
# TICKER NIFTYWK18550PE
# TICKER NIFTYWK18600CE
# TICKER NIFTYWK18600PE
# TICKER NIFTYWK18650CE
# TICKER NIFTYWK18650PE
# TICKER NIFTYWK18700CE
# TICKER NIFTYWK18700PE
# TICKER NIFTYWK18750CE
# TICKER NIFTYWK18750PE
# TICKER NIFTYWK18800CE
# TICKER NIFTYWK18800PE
# TICKER NIFTYWK18850CE
# TICKER NIFTYWK18850PE
# TICKER NIFTYWK18900CE
# TICKER NIFTYWK18900PE
# TICKER NIFTYWK18950CE
# TICKER NIFTYWK18950PE
# TICKER NIFTYWK19000CE
# TICKER NIFTYWK19000PE

# %%
# # Define trading hours
# trading_hours = pd.date_range(start='09:15:00', end='15:30:00', freq='1min')

# # Get the DataFrame for NIFTY as the reference
# reference_df = dfs['NIFTY'].copy()

# # Generate a full range of timestamps for all trading days in the reference NIFTY DataFrame
# all_trading_days = reference_df.index.normalize().unique()
# all_possible_timestamps = pd.DatetimeIndex([pd.Timestamp(day) + pd.Timedelta(minutes=m.minute + m.hour * 60)
#                                             for day in all_trading_days for m in trading_hours])

# # Now update all DataFrames in dfs to have the same timestamps as the reference NIFTY DataFrame
# for ticker, dataframe in dfs.items():
#     # Reindex to the full range of possible timestamps, forward filling the missing data
#     dataframe = dataframe.reindex(all_possible_timestamps, method='ffill')

#     # Forward fill the Open Interest, if the ticker ends with 'PE' or 'CE'
#     if ticker.endswith(('PE', 'CE')):
#         dataframe['Open Interest'].fillna(method='ffill', inplace=True)
#         dataframe['Open Interest'].replace(to_replace=0, method='ffill', inplace=True)

#     # Update the dictionary with the modified DataFrame
#     dfs[ticker] = dataframe

# # After this loop, each DataFrame in dfs should have no missing timestamps and the 'Open Interest' column should be forward filled.

# %%
# Define the market open and close times
market_open_time = '09:15:00'
market_close_time = '15:30:00'

# Create a new dictionary to store the filled DataFrames
filled_dfs = {}

for ticker, dataframe in dfs.items():
    # Copy the DataFrame to avoid modifying the original
    df_filled = dataframe.copy()

    # Get unique trading days
    trading_days = df_filled.index.normalize().unique()

    # Forward fill for each day
    for day in trading_days:
        # Select the data for the current trading day
        day_data = df_filled[df_filled.index.date == day.date()]

        # Forward fill the data for the current day
        df_filled.loc[day_data.index] = day_data.fillna(method='ffill')

    # Now, backward fill the entire DataFrame to cover the start of the day
    df_filled = df_filled.fillna(method='bfill')

    # Assign the filled DataFrame to the new dictionary
    filled_dfs[ticker] = df_filled

# %%
# Assuming filled_dfs is your dictionary containing DataFrames with filled values
for ticker in unique_tickers:
    # Select the DataFrame for the current ticker
    ticker_df = filled_dfs[ticker].copy()  # Use copy to avoid SettingWithCopyWarning

    # Since filled_dfs already contains the DataFrames with 'Date/Time' as a datetime index,
    #  do not need to convert 'Date/Time' again, and  can use ticker_df directly if needed

    # Remove duplicate indices if any (if this step is still necessary)
    ticker_df = ticker_df[~ticker_df.index.duplicated(keep='first')]


    # Assign the processed DataFrame back to the dfs dictionary
    dfs[ticker] = ticker_df

# Now dfs is a dictionary where each value is a DataFrame with 'Date/Time' as a datetime index

# %%
print(dfs['NIFTY'])
# Out:
#                     Ticker     Open     High      Low    Close  Volume  \
# Date/Time
# 2021-12-03 09:15:00  NIFTY  17424.9  17455.9  17415.9  17455.9       0
# 2021-12-03 09:16:00  NIFTY  17458.0  17479.5  17458.0  17476.3       0
# 2021-12-03 09:17:00  NIFTY  17476.4  17476.4  17452.7  17452.7       0
# 2021-12-03 09:18:00  NIFTY  17452.4  17467.0  17442.0  17466.3       0
# 2021-12-03 09:19:00  NIFTY  17467.6  17478.0  17467.0  17477.3       0
# ...                    ...      ...      ...      ...      ...     ...
# 2021-12-09 15:26:00  NIFTY  17514.5  17516.2  17513.9  17514.9       0
# 2021-12-09 15:27:00  NIFTY  17515.2  17515.6  17511.5  17511.5       1
# 2021-12-09 15:28:00  NIFTY  17512.0  17513.2  17504.0  17505.3       1
# 2021-12-09 15:29:00  NIFTY  17506.4  17509.5  17500.9  17502.7       1
# 2021-12-09 15:30:00  NIFTY  17505.7  17505.7  17505.7  17505.7       1
#
#                      Open Interest
# Date/Time
# 2021-12-03 09:15:00              0
# 2021-12-03 09:16:00              0
# 2021-12-03 09:17:00              0
# 2021-12-03 09:18:00              0
# 2021-12-03 09:19:00              0
# ...                            ...
# 2021-12-09 15:26:00              0
# 2021-12-09 15:27:00              0
# 2021-12-09 15:28:00              0
# 2021-12-09 15:29:00              0
# 2021-12-09 15:30:00              0
#
# [1880 rows x 7 columns]

# %%
# Assuming dfs['NIFTY'] is the DataFrame you want to save
nifty_df = dfs['NIFTY']

# Specify the path in your Google Drive where you want to save the CSV
csv_file_path = '/content/drive/My Drive/NIfty_Dataset/NIFTY_03-09-DEC_2021.csv'

# Save the DataFrame to CSV
nifty_df.to_csv(csv_file_path, index=True)

print(f"DataFrame saved to {csv_file_path}")
# Out:
# DataFrame saved to /content/drive/My Drive/NIfty_Dataset/NIFTY_03-09-DEC_2021.csv

# %%
# Assuming dfs['NIFTY'] is the DataFrame you want to save
indiavix_df = dfs['INDIAVIX']

# Specify the path in your Google Drive where you want to save the CSV
csv_file_path = '/content/drive/My Drive/NIfty_Dataset/INDIAVIX_03-09-DEC_2021.csv'

# Save the DataFrame to CSV
indiavix_df.to_csv(csv_file_path, index=True)

print(f"DataFrame saved to {csv_file_path}")
# Out:
# DataFrame saved to /content/drive/My Drive/NIfty_Dataset/INDIAVIX_03-09-DEC_2021.csv

# %%
# !pip install mibian
# Out:
# Collecting mibian
#   Downloading mibian-0.1.3.zip (4.3 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mibian
#   Building wheel for mibian (setup.py) ... done
#   Created wheel for mibian: filename=mibian-0.1.3-py3-none-any.whl size=4024 sha256=7d09c3bafe3bfc5337d5377ae64c199b8f45743e6142e5e24a9a4706eeb6f7af
#   Stored in directory: /root/.cache/pip/wheels/2c/4f/a7/be034e17cc306b0850f5f1a5b4541281b49475c58620a7ff40
# Successfully built mibian
# Installing collected packages: mibian
# Successfully installed mibian-0.1.3

# %%
indiavix_df = pd.read_csv('/content/drive/My Drive/NIfty_Dataset/INDIAVIX_03-09-DEC_2021.csv')
# Print the columns to check the exact name of the 'Date/Time' column
print(indiavix_df.columns)
# Out:
# Index(['Date/Time', 'Ticker', 'Open', 'High', 'Low', 'Close', 'Volume',
#        'Open Interest'],
#       dtype='object')

# %%
print(indiavix_df.index)
# Out:
# RangeIndex(start=0, stop=1880, step=1)

# %%
# !pip install datetime
# Out:
# Collecting datetime
#   Downloading DateTime-5.3-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 1.6 MB/s eta 0:00:00
# Collecting zope.interface (from datetime)
#   Downloading zope.interface-6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from datetime) (2023.3.post1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from zope.interface->datetime) (67.7.2)
# Installing collected packages: zope.interface, datetime
# Successfully installed datetime-5.3 zope.interface-6.1

# %%
import pandas as pd
import numpy as np
import mibian
from datetime import time, datetime, timedelta


indiavix_df = pd.read_csv('/content/drive/My Drive/NIfty_Dataset/INDIAVIX_03-09-DEC_2021.csv', index_col='Date/Time', parse_dates=['Date/Time'])
indiavix_df.rename(columns={'Close': 'INDIAVIX'}, inplace=True)

# Load the NIFTY data
nifty_df = pd.read_csv('/content/drive/My Drive/NIfty_Dataset/NIFTY_03-09-DEC_2021.csv', index_col='Date/Time', parse_dates=['Date/Time'])

# Join INDIAVIX data with NIFTY data
nifty_df = nifty_df.join(indiavix_df['INDIAVIX'], how='left')
nifty_df['INDIAVIX'].fillna(method='ffill', inplace=True)  # Fill NaN values with the forward fill method


# Check if the 'INDIAVIX' column exists after the join operation
if 'INDIAVIX' not in nifty_df.columns:
    raise KeyError('The INDIAVIX column was not found after the join operation. Please check the column names and join operation.')

print("NIFTYDF",nifty_df)
print("columns",nifty_df.columns)

# Constants
interest_rate = 3.32  # 3-month Indian government bond yield as annual percentage
days_in_year = 365  # Days in a year for the Greeks' calculations
strike_step = 50  # Known step between strike prices
minutes_in_a_year = 365 * 24 * 60  # Total minutes in a year
market_close_time = time(15, 30)



def calculate_minutes_to_expiry(current_timestamp, expiry_date, market_close_time):
    # Ensure market_close_time is a datetime.time object
    if isinstance(market_close_time, pd.Timestamp):
        market_close_time = market_close_time.time()

    closing_time = datetime.combine(expiry_date, market_close_time)

    # If the current timestamp is on the expiry date
    if current_timestamp.date() == expiry_date.date():
        # Calculate the remaining time until market close
        return max(int((closing_time - current_timestamp).total_seconds() / 60), 0)
    else:
        # Calculate time from the current timestamp to the end of day
        end_of_day = datetime.combine(current_timestamp.date(), time(23, 59))  # Last minute of the current day
        minutes_today = int((end_of_day - current_timestamp).total_seconds() / 60) + 1  # Plus one for the last minute

        # Calculate full days until the expiry date
        full_days = (expiry_date.date() - current_timestamp.date()).days - 1  # Minus one because we already counted today

        # Calculate minutes from the start of the expiry day to the market close
        start_of_expiry_day = datetime.combine(expiry_date.date(), time(0, 0))  # Midnight of the expiry day
        minutes_expiry_day = int((closing_time - start_of_expiry_day).total_seconds() / 60)

        # Total minutes is the sum of all parts
        return minutes_today + (full_days * 24 * 60) + minutes_expiry_day


# Function to calculate the Greeks using the Black-Scholes model
def calculate_greeks(underlying_price, strike_price, minutes_to_expiry, volatility, interest_rate, option_type):
    # Convert minutes to expiry into years for the Black-Scholes model
    time_to_expiry_in_years = minutes_to_expiry / minutes_in_a_year

    # Ensure we do not have a division by zero or negative time to expiry
    if time_to_expiry_in_years <= 0:
        return {greek: 0 for greek in ['Delta', 'Gamma', 'Theta', 'Vega', 'Rho']}

    # Convert annual interest rate and volatility from percentages to decimals
    annual_interest_rate = interest_rate / 100
    annual_volatility = volatility / 100

    # Black-Scholes model calculations
    bs = mibian.BS([underlying_price, strike_price, annual_interest_rate * 100, time_to_expiry_in_years * 365], volatility=annual_volatility * 100)

    # Return a dictionary of Greeks
    return {
        'Delta': bs.callDelta if option_type == 'call' else bs.putDelta,
        'Gamma': bs.gamma,
        'Theta': bs.callTheta / 365 if option_type == 'call' else bs.putTheta / 365,
        'Vega': bs.vega / 100,  # per 1% change in IV
        'Rho': bs.callRho / 100 if option_type == 'call' else bs.putRho / 100  # per 1% change in interest rate
    }


# Function to populate the DataFrame with strikes and Greeks
def populate_greeks(nifty_df, indiavix_df, strike_step, dfs):

    expiry_date = nifty_df.index.max().normalize() + pd.Timedelta(hours=15, minutes=30)
    print("EXPIRY DAY", expiry_date)
    market_close_time = expiry_date #pd.to_datetime(expiry_date.strftime('%Y-%m-%d') + ' 15:30:00')  # Assuming 3:30 PM market close

    # Create columns for Greeks in the dataframe
    for strike_type in ['ATM', 'ITM1', 'OTM1', 'ITM2', 'OTM2', 'ITM3', 'OTM3', 'ITM4', 'OTM4', 'ITM5', 'OTM5']:
        for greek in ['Delta', 'Gamma', 'Theta', 'Vega', 'Rho']:
            nifty_df[f'{strike_type}_{greek}'] = np.nan
            nifty_df[f'{strike_type}_OI'] = np.nan
            nifty_df[f'{strike_type}_Call_Volume'] = np.nan
            nifty_df[f'{strike_type}_Put_Volume'] = np.nan

    nifty_df['PCR'] = np.nan

    # Iterate over the dataframe and calculate Greeks
    for timestamp, row in nifty_df.iterrows():
        total_call_oi = 0
        total_put_oi = 0
        nifty_close = row['Close']
        # Find ATM, ITM, and OTM strikes
        atm_strike = int(round(nifty_close / strike_step) * strike_step)  # Closest strike
        itm_strikes = [atm_strike - i * strike_step for i in range(1, 6)]
        otm_strikes = [atm_strike + i * strike_step for i in range(1, 6)]
        all_strikes = [atm_strike] + itm_strikes + otm_strikes

        print(f"Processing timestamp: {timestamp}")

        # Get VIX value for the timestamp
        vix_value = indiavix_df.loc[timestamp, 'INDIAVIX'] if timestamp in indiavix_df.index else np.nan
        if vix_value is None:
            print(f"VIX value is missing for timestamp: {timestamp}")
            continue  # Skip this iteration if VIX value is missing


        minutes_to_expiry = calculate_minutes_to_expiry(timestamp, expiry_date, market_close_time)
        print("Current time & days to expiry:", timestamp.date(), minutes_to_expiry / (60 * 24))

        print("Curr time & days to EXpiry", timestamp.date(),minutes_to_expiry/(60*24))
        # Calculate Greeks for all strikes
        for i, strike in enumerate(all_strikes, start=1):
            if i == 1:  # ATM
                strike_type = 'ATM'
            elif i <= 6:  # ITM strikes
                strike_type = f'ITM{i-1}'
            else:  # OTM strikes
                strike_type = f'OTM{i-6}'

            call_key = f'NIFTYWK{strike}CE'
            put_key = f'NIFTYWK{strike}PE'

            call_volume = dfs[call_key].loc[timestamp, 'Volume'] if timestamp in dfs[call_key].index else np.nan
            put_volume = dfs[put_key].loc[timestamp, 'Volume'] if timestamp in dfs[put_key].index else np.nan

            # Populate volume data
            nifty_df.at[timestamp, f'{strike_type}_Call_Volume'] = call_volume
            nifty_df.at[timestamp, f'{strike_type}_Put_Volume'] = put_volume

            # print(f"Retrieving data for strike {strike} ({call_key} and {put_key})")

             # Check if the keys are present in the dfs dictionary
            if call_key not in dfs or put_key not in dfs:
                print(f"Missing data for strike {strike}: {call_key} or {put_key} not in dfs")
                continue

            # Check if the timestamp exists in the dfs DataFrames
            if timestamp not in dfs[call_key].index:
                print(f"Timestamp {timestamp} not found in dfs for {call_key}")
                continue
            if timestamp not in dfs[put_key].index:
                print(f"Timestamp {timestamp} not found in dfs for {put_key}")
                continue

            call_close = dfs[call_key].loc[timestamp, 'Close'] if timestamp in dfs[call_key].index else np.nan
            put_close = dfs[put_key].loc[timestamp, 'Close'] if timestamp in dfs[put_key].index else np.nan
            call_oi = dfs[call_key].loc[timestamp, 'Open Interest'] if timestamp in dfs[call_key].index else np.nan
            put_oi = dfs[put_key].loc[timestamp, 'Open Interest'] if timestamp in dfs[put_key].index else np.nan
            # print(f"Call Close: {call_close}, Put Close: {put_close}, Call OI: {call_oi}, Put OI: {put_oi}")

            #print("STRIKE",nifty_close, strike)
            # Calculate Greeks using the close prices
            if not np.isnan(call_close):
                greeks = calculate_greeks(nifty_close, strike, minutes_to_expiry, call_close, interest_rate, option_type='call')
                # Populate Greeks for call
                for greek_name, greek_value in greeks.items():
                    nifty_df.at[timestamp, f'{strike_type}_{greek_name}'] = greek_value
                    nifty_df.at[timestamp, f'{strike_type}_OI'] = call_oi  # Populate OI for call

            if not np.isnan(put_close):
                greeks = calculate_greeks(nifty_close, strike, minutes_to_expiry, put_close, interest_rate, option_type='put')
                # Populate Greeks for put
                for greek_name, greek_value in greeks.items():
                    nifty_df.at[timestamp, f'{strike_type}_PE_{greek_name}'] = greek_value
                    nifty_df.at[timestamp, f'{strike_type}_PE_OI'] = put_oi  # Populate OI for put

    return nifty_df

# Populate the DataFrame with Greeks
nifty_with_greeks = populate_greeks(nifty_df, indiavix_df, strike_step, dfs)

def calculate_pcr(row):
    total_call_oi = sum(row.get(f'{strike}_OI', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    total_put_oi = sum(row.get(f'{strike}_PE_OI', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    print("OI", total_call_oi, total_put_oi)
    return total_put_oi / total_call_oi if total_call_oi != 0 else np.nan

# Function to calculate PCR for volume
def calculate_pcr_volume(row):
    total_call_volume = sum(row.get(f'{strike}_Call_Volume', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    total_put_volume = sum(row.get(f'{strike}_Put_Volume', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    return total_put_volume / total_call_volume if total_call_volume != 0 else np.nan

# Apply PCR calculation to each row
nifty_with_greeks['PCR'] = nifty_with_greeks.apply(calculate_pcr, axis=1)
print(nifty_with_greeks.head())
# Apply PCR calculation for volume to each row
nifty_with_greeks['PCR_Volume'] = nifty_with_greeks.apply(calculate_pcr_volume, axis=1)
# # Output the DataFrame to a CSV
nifty_with_greeks.to_csv('/content/drive/My Drive/NIfty_Dataset/NIFTY_with_Greeks_03-09-DEC_2021.csv')

print("Greeks and Open Interest data have been populated and the DataFrame has been saved to CSV.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing timestamp: 2021-12-07 10:57:00
# Current time & days to expiry: 2021-12-07 2.189583333333333
# Curr time & days to EXpiry 2021-12-07 2.189583333333333
# Processing timestamp: 2021-12-07 10:58:00
# Current time & days to expiry: 2021-12-07 2.188888888888889
# Curr time & days to EXpiry 2021-12-07 2.188888888888889
# Processing timestamp: 2021-12-07 10:59:00
# Current time & days to expiry: 2021-12-07 2.1881944444444446
# Curr time & days to EXpiry 2021-12-07 2.1881944444444446
# Processing timestamp: 2021-12-07 11:00:00
# Current time & days to expiry: 2021-12-07 2.1875
# Curr time & days to EXpiry 2021-12-07 2.1875
# Processing timestamp: 2021-12-07 11:01:00
# Current time & days to expiry: 2021-12-07 2.1868055555555554
# Curr time & days to EXpiry 2021-12-07 2.1868055555555554
# Processing timestamp: 2021-12-07 11:02:00
# Current time & days to expiry: 2021-12-07 2.186111111111111
# Curr time & days to EXpiry 2021-12-07 2.186111111111111
# Processing timestamp: 2021-12-07 11:03:00
# Current time & days to expiry: 2021-12-07 2.185416666666667
# Curr time & days to EXpiry 2021-12-07 2.185416666666667
# Processing timestamp: 2021-12-07 11:04:00
# Current time & days to expiry: 2021-12-07 2.1847222222222222
# Curr time & days to EXpiry 2021-12-07 2.1847222222222222
# Processing timestamp: 2021-12-07 11:05:00
# Current time & days to expiry: 2021-12-07 2.1840277777777777
# Curr time & days to EXpiry 2021-12-07 2.1840277777777777
# Processing timestamp: 2021-12-07 11:06:00
# Current time & days to expiry: 2021-12-07 2.183333333333333
# Curr time & days to EXpiry 2021-12-07 2.183333333333333
# Processing timestamp: 2021-12-07 11:07:00
# Current time & days to expiry: 2021-12-07 2.182638888888889
# Curr time & days to EXpiry 2021-12-07 2.182638888888889
# Processing timestamp: 2021-12-07 11:08:00
# Current time & days to expiry: 2021-12-07 2.1819444444444445
# Curr time & days to EXpiry 2021-12-07 2.1819444444444445
# Processing timestamp: 2021-12-07 11:09:00
# Current time & days to expiry: 2021-12-07 2.18125
# Curr time & days to EXpiry 2021-12-07 2.18125
# Processing timestamp: 2021-12-07 11:10:00
# Current time & days to expiry: 2021-12-07 2.1805555555555554
# Curr time & days to EXpiry 2021-12-07 2.1805555555555554
# Processing timestamp: 2021-12-07 11:11:00
# Current time & days to expiry: 2021-12-07 2.1798611111111112
# Curr time & days to EXpiry 2021-12-07 2.1798611111111112
# Processing timestamp: 2021-12-07 11:12:00
# Current time & days to expiry: 2021-12-07 2.1791666666666667
# Curr time & days to EXpiry 2021-12-07 2.1791666666666667
# Processing timestamp: 2021-12-07 11:13:00
# Current time & days to expiry: 2021-12-07 2.178472222222222
# Curr time & days to EXpiry 2021-12-07 2.178472222222222
# Processing timestamp: 2021-12-07 11:14:00
# Current time & days to expiry: 2021-12-07 2.1777777777777776
# Curr time & days to EXpiry 2021-12-07 2.1777777777777776
# Processing timestamp: 2021-12-07 11:15:00
# Current time & days to expiry: 2021-12-07 2.1770833333333335
# Curr time & days to EXpiry 2021-12-07 2.1770833333333335
# Processing timestamp: 2021-12-07 11:16:00
# Current time & days to expiry: 2021-12-07 2.176388888888889
# Curr time & days to EXpiry 2021-12-07 2.176388888888889
# Processing timestamp: 2021-12-07 11:17:00
# Current time & days to expiry: 2021-12-07 2.1756944444444444
# Curr time & days to EXpiry 2021-12-07 2.1756944444444444
# Processing timestamp: 2021-12-07 11:18:00
# Current time & days to expiry: 2021-12-07 2.175
# Curr time & days to EXpiry 2021-12-07 2.175
# Processing timestamp: 2021-12-07 11:19:00
# Current time & days to expiry: 2021-12-07 2.1743055555555557
# Curr time & days to EXpiry 2021-12-07 2.1743055555555557
# Processing timestamp: 2021-12-07 11:20:00
# Current time & days to expiry: 2021-12-07 2.173611111111111
# Curr time & days to EXpiry 2021-12-07 2.173611111111111
# Processing timestamp: 2021-12-07 11:21:00
# Current time & days to expiry: 2021-12-07 2.1729166666666666
# Curr time & days to EXpiry 2021-12-07 2.1729166666666666
# Processing timestamp: 2021-12-07 11:22:00
# Current time & days to expiry: 2021-12-07 2.172222222222222
# Curr time & days to EXpiry 2021-12-07 2.172222222222222
# Processing timestamp: 2021-12-07 11:23:00
# Current time & days to expiry: 2021-12-07 2.171527777777778
# Curr time & days to EXpiry 2021-12-07 2.171527777777778
# Processing timestamp: 2021-12-07 11:24:00
# Current time & days to expiry: 2021-12-07 2.1708333333333334
# Curr time & days to EXpiry 2021-12-07 2.1708333333333334
# Processing timestamp: 2021-12-07 11:25:00
# Current time & days to expiry: 2021-12-07 2.170138888888889
# Curr time & days to EXpiry 2021-12-07 2.170138888888889
# Processing timestamp: 2021-12-07 11:26:00
# Current time & days to expiry: 2021-12-07 2.1694444444444443
# Curr time & days to EXpiry 2021-12-07 2.1694444444444443
# Processing timestamp: 2021-12-07 11:27:00
# Current time & days to expiry: 2021-12-07 2.16875
# Curr time & days to EXpiry 2021-12-07 2.16875
# Processing timestamp: 2021-12-07 11:28:00
# Current time & days to expiry: 2021-12-07 2.1680555555555556
# Curr time & days to EXpiry 2021-12-07 2.1680555555555556
# Processing timestamp: 2021-12-07 11:29:00
# Current time & days to expiry: 2021-12-07 2.167361111111111
# Curr time & days to EXpiry 2021-12-07 2.167361111111111
# Processing timestamp: 2021-12-07 11:30:00
# Current time & days to expiry: 2021-12-07 2.1666666666666665
# Curr time & days to EXpiry 2021-12-07 2.1666666666666665
# Processing timestamp: 2021-12-07 11:31:00
# Current time & days to expiry: 2021-12-07 2.1659722222222224
# Curr time & days to EXpiry 2021-12-07 2.1659722222222224
# Processing timestamp: 2021-12-07 11:32:00
# Current time & days to expiry: 2021-12-07 2.165277777777778
# Curr time & days to EXpiry 2021-12-07 2.165277777777778
# Processing timestamp: 2021-12-07 11:33:00
# Current time & days to expiry: 2021-12-07 2.1645833333333333
# Curr time & days to EXpiry 2021-12-07 2.1645833333333333
# Processing timestamp: 2021-12-07 11:34:00
# Current time & days to expiry: 2021-12-07 2.1638888888888888
# Curr time & days to EXpiry 2021-12-07 2.1638888888888888
# Processing timestamp: 2021-12-07 11:35:00
# Current time & days to expiry: 2021-12-07 2.1631944444444446
# Curr time & days to EXpiry 2021-12-07 2.1631944444444446
# Processing timestamp: 2021-12-07 11:36:00
# Current time & days to expiry: 2021-12-07 2.1625
# Curr time & days to EXpiry 2021-12-07 2.1625
# Processing timestamp: 2021-12-07 11:37:00
# Current time & days to expiry: 2021-12-07 2.1618055555555555
# Curr time & days to EXpiry 2021-12-07 2.1618055555555555
# Processing timestamp: 2021-12-07 11:38:00
# Current time & days to expiry: 2021-12-07 2.161111111111111
# Curr time & days to EXpiry 2021-12-07 2.161111111111111
# Processing timestamp: 2021-12-07 11:39:00
# Current time & days to expiry: 2021-12-07 2.160416666666667
# Curr time & days to EXpiry 2021-12-07 2.160416666666667
# Processing timestamp: 2021-12-07 11:40:00
# Current time & days to expiry: 2021-12-07 2.1597222222222223
# Curr time & days to EXpiry 2021-12-07 2.1597222222222223
# Processing timestamp: 2021-12-07 11:41:00
# Current time & days to expiry: 2021-12-07 2.1590277777777778
# Curr time & days to EXpiry 2021-12-07 2.1590277777777778
# Processing timestamp: 2021-12-07 11:42:00
# Current time & days to expiry: 2021-12-07 2.158333333333333
# Curr time & days to EXpiry 2021-12-07 2.158333333333333
# Processing timestamp: 2021-12-07 11:43:00
# Current time & days to expiry: 2021-12-07 2.157638888888889
# Curr time & days to EXpiry 2021-12-07 2.157638888888889
# Processing timestamp: 2021-12-07 11:44:00
# Current time & days to expiry: 2021-12-07 2.1569444444444446
# Curr time & days to EXpiry 2021-12-07 2.1569444444444446
# Processing timestamp: 2021-12-07 11:45:00
# Current time & days to expiry: 2021-12-07 2.15625
# Curr time & days to EXpiry 2021-12-07 2.15625
# Processing timestamp: 2021-12-07 11:46:00
# Current time & days to expiry: 2021-12-07 2.1555555555555554
# Curr time & days to EXpiry 2021-12-07 2.1555555555555554
# Processing timestamp: 2021-12-07 11:47:00
# Current time & days to expiry: 2021-12-07 2.154861111111111
# Curr time & days to EXpiry 2021-12-07 2.154861111111111
# Processing timestamp: 2021-12-07 11:48:00
# Current time & days to expiry: 2021-12-07 2.154166666666667
# Curr time & days to EXpiry 2021-12-07 2.154166666666667
# Processing timestamp: 2021-12-07 11:49:00
# Current time & days to expiry: 2021-12-07 2.1534722222222222
# Curr time & days to EXpiry 2021-12-07 2.1534722222222222
# Processing timestamp: 2021-12-07 11:50:00
# Current time & days to expiry: 2021-12-07 2.1527777777777777
# Curr time & days to EXpiry 2021-12-07 2.1527777777777777
# Processing timestamp: 2021-12-07 11:51:00
# Current time & days to expiry: 2021-12-07 2.152083333333333
# Curr time & days to EXpiry 2021-12-07 2.152083333333333
# Processing timestamp: 2021-12-07 11:52:00
# Current time & days to expiry: 2021-12-07 2.151388888888889
# Curr time & days to EXpiry 2021-12-07 2.151388888888889
# Processing timestamp: 2021-12-07 11:53:00
# Current time & days to expiry: 2021-12-07 2.1506944444444445
# Curr time & days to EXpiry 2021-12-07 2.1506944444444445
# Processing timestamp: 2021-12-07 11:54:00
# Current time & days to expiry: 2021-12-07 2.15
# Curr time & days to EXpiry 2021-12-07 2.15
# Processing timestamp: 2021-12-07 11:55:00
# Current time & days to expiry: 2021-12-07 2.1493055555555554
# Curr time & days to EXpiry 2021-12-07 2.1493055555555554
# Processing timestamp: 2021-12-07 11:56:00
# Current time & days to expiry: 2021-12-07 2.1486111111111112
# Curr time & days to EXpiry 2021-12-07 2.1486111111111112
# Processing timestamp: 2021-12-07 11:57:00
# Current time & days to expiry: 2021-12-07 2.1479166666666667
# Curr time & days to EXpiry 2021-12-07 2.1479166666666667
# Processing timestamp: 2021-12-07 11:58:00
# Current time & days to expiry: 2021-12-07 2.147222222222222
# Curr time & days to EXpiry 2021-12-07 2.147222222222222
# Processing timestamp: 2021-12-07 11:59:00
# Current time & days to expiry: 2021-12-07 2.1465277777777776
# Curr time & days to EXpiry 2021-12-07 2.1465277777777776
# Processing timestamp: 2021-12-07 12:00:00
# Current time & days to expiry: 2021-12-07 2.1458333333333335
# Curr time & days to EXpiry 2021-12-07 2.1458333333333335
# Processing timestamp: 2021-12-07 12:01:00
# Current time & days to expiry: 2021-12-07 2.145138888888889
# Curr time & days to EXpiry 2021-12-07 2.145138888888889
# Processing timestamp: 2021-12-07 12:02:00
# Current time & days to expiry: 2021-12-07 2.1444444444444444
# Curr time & days to EXpiry 2021-12-07 2.1444444444444444
# Processing timestamp: 2021-12-07 12:03:00
# Current time & days to expiry: 2021-12-07 2.14375
# Curr time & days to EXpiry 2021-12-07 2.14375
# Processing timestamp: 2021-12-07 12:04:00
# Current time & days to expiry: 2021-12-07 2.1430555555555557
# Curr time & days to EXpiry 2021-12-07 2.1430555555555557
# Processing timestamp: 2021-12-07 12:05:00
# Current time & days to expiry: 2021-12-07 2.142361111111111
# Curr time & days to EXpiry 2021-12-07 2.142361111111111
# Processing timestamp: 2021-12-07 12:06:00
# Current time & days to expiry: 2021-12-07 2.1416666666666666
# Curr time & days to EXpiry 2021-12-07 2.1416666666666666
# Processing timestamp: 2021-12-07 12:07:00
# Current time & days to expiry: 2021-12-07 2.140972222222222
# Curr time & days to EXpiry 2021-12-07 2.140972222222222
# Processing timestamp: 2021-12-07 12:08:00
# Current time & days to expiry: 2021-12-07 2.140277777777778
# Curr time & days to EXpiry 2021-12-07 2.140277777777778
# Processing timestamp: 2021-12-07 12:09:00
# Current time & days to expiry: 2021-12-07 2.1395833333333334
# Curr time & days to EXpiry 2021-12-07 2.1395833333333334
# Processing timestamp: 2021-12-07 12:10:00
# Current time & days to expiry: 2021-12-07 2.138888888888889
# Curr time & days to EXpiry 2021-12-07 2.138888888888889
# Processing timestamp: 2021-12-07 12:11:00
# Current time & days to expiry: 2021-12-07 2.1381944444444443
# Curr time & days to EXpiry 2021-12-07 2.1381944444444443
# Processing timestamp: 2021-12-07 12:12:00
# Current time & days to expiry: 2021-12-07 2.1375
# Curr time & days to EXpiry 2021-12-07 2.1375
# Processing timestamp: 2021-12-07 12:13:00
# Current time & days to expiry: 2021-12-07 2.1368055555555556
# Curr time & days to EXpiry 2021-12-07 2.1368055555555556
# Processing timestamp: 2021-12-07 12:14:00
# Current time & days to expiry: 2021-12-07 2.136111111111111
# Curr time & days to EXpiry 2021-12-07 2.136111111111111
# Processing timestamp: 2021-12-07 12:15:00
# Current time & days to expiry: 2021-12-07 2.1354166666666665
# Curr time & days to EXpiry 2021-12-07 2.1354166666666665
# Processing timestamp: 2021-12-07 12:16:00
# Current time & days to expiry: 2021-12-07 2.1347222222222224
# Curr time & days to EXpiry 2021-12-07 2.1347222222222224
# Processing timestamp: 2021-12-07 12:17:00
# Current time & days to expiry: 2021-12-07 2.134027777777778
# Curr time & days to EXpiry 2021-12-07 2.134027777777778
# Processing timestamp: 2021-12-07 12:18:00
# Current time & days to expiry: 2021-12-07 2.1333333333333333
# Curr time & days to EXpiry 2021-12-07 2.1333333333333333
# Processing timestamp: 2021-12-07 12:19:00
# Current time & days to expiry: 2021-12-07 2.1326388888888888
# Curr time & days to EXpiry 2021-12-07 2.1326388888888888
# Processing timestamp: 2021-12-07 12:20:00
# Current time & days to expiry: 2021-12-07 2.1319444444444446
# Curr time & days to EXpiry 2021-12-07 2.1319444444444446
# Processing timestamp: 2021-12-07 12:21:00
# Current time & days to expiry: 2021-12-07 2.13125
# Curr time & days to EXpiry 2021-12-07 2.13125
# Processing timestamp: 2021-12-07 12:22:00
# Current time & days to expiry: 2021-12-07 2.1305555555555555
# Curr time & days to EXpiry 2021-12-07 2.1305555555555555
# Processing timestamp: 2021-12-07 12:23:00
# Current time & days to expiry: 2021-12-07 2.129861111111111
# Curr time & days to EXpiry 2021-12-07 2.129861111111111
# Processing timestamp: 2021-12-07 12:24:00
# Current time & days to expiry: 2021-12-07 2.129166666666667
# Curr time & days to EXpiry 2021-12-07 2.129166666666667
# Processing timestamp: 2021-12-07 12:25:00
# Current time & days to expiry: 2021-12-07 2.1284722222222223
# Curr time & days to EXpiry 2021-12-07 2.1284722222222223
# Processing timestamp: 2021-12-07 12:26:00
# Current time & days to expiry: 2021-12-07 2.1277777777777778
# Curr time & days to EXpiry 2021-12-07 2.1277777777777778
# Processing timestamp: 2021-12-07 12:27:00
# Current time & days to expiry: 2021-12-07 2.127083333333333
# Curr time & days to EXpiry 2021-12-07 2.127083333333333
# Processing timestamp: 2021-12-07 12:28:00
# Current time & days to expiry: 2021-12-07 2.126388888888889
# Curr time & days to EXpiry 2021-12-07 2.126388888888889
# Processing timestamp: 2021-12-07 12:29:00
# Current time & days to expiry: 2021-12-07 2.1256944444444446
# Curr time & days to EXpiry 2021-12-07 2.1256944444444446
# Processing timestamp: 2021-12-07 12:30:00
# Current time & days to expiry: 2021-12-07 2.125
# Curr time & days to EXpiry 2021-12-07 2.125
# Processing timestamp: 2021-12-07 12:31:00
# Current time & days to expiry: 2021-12-07 2.1243055555555554
# Curr time & days to EXpiry 2021-12-07 2.1243055555555554
# Processing timestamp: 2021-12-07 12:32:00
# Current time & days to expiry: 2021-12-07 2.123611111111111
# Curr time & days to EXpiry 2021-12-07 2.123611111111111
# Processing timestamp: 2021-12-07 12:33:00
# Current time & days to expiry: 2021-12-07 2.122916666666667
# Curr time & days to EXpiry 2021-12-07 2.122916666666667
# Processing timestamp: 2021-12-07 12:34:00
# Current time & days to expiry: 2021-12-07 2.1222222222222222
# Curr time & days to EXpiry 2021-12-07 2.1222222222222222
# Processing timestamp: 2021-12-07 12:35:00
# Current time & days to expiry: 2021-12-07 2.1215277777777777
# Curr time & days to EXpiry 2021-12-07 2.1215277777777777
# Processing timestamp: 2021-12-07 12:36:00
# Current time & days to expiry: 2021-12-07 2.120833333333333
# Curr time & days to EXpiry 2021-12-07 2.120833333333333
# Processing timestamp: 2021-12-07 12:37:00
# Current time & days to expiry: 2021-12-07 2.120138888888889
# Curr time & days to EXpiry 2021-12-07 2.120138888888889
# Processing timestamp: 2021-12-07 12:38:00
# Current time & days to expiry: 2021-12-07 2.1194444444444445
# Curr time & days to EXpiry 2021-12-07 2.1194444444444445
# Processing timestamp: 2021-12-07 12:39:00
# Current time & days to expiry: 2021-12-07 2.11875
# Curr time & days to EXpiry 2021-12-07 2.11875
# Processing timestamp: 2021-12-07 12:40:00
# Current time & days to expiry: 2021-12-07 2.1180555555555554
# Curr time & days to EXpiry 2021-12-07 2.1180555555555554
# Processing timestamp: 2021-12-07 12:41:00
# Current time & days to expiry: 2021-12-07 2.1173611111111112
# Curr time & days to EXpiry 2021-12-07 2.1173611111111112
# Processing timestamp: 2021-12-07 12:42:00
# Current time & days to expiry: 2021-12-07 2.1166666666666667
# Curr time & days to EXpiry 2021-12-07 2.1166666666666667
# Processing timestamp: 2021-12-07 12:43:00
# Current time & days to expiry: 2021-12-07 2.115972222222222
# Curr time & days to EXpiry 2021-12-07 2.115972222222222
# Processing timestamp: 2021-12-07 12:44:00
# Current time & days to expiry: 2021-12-07 2.1152777777777776
# Curr time & days to EXpiry 2021-12-07 2.1152777777777776
# Processing timestamp: 2021-12-07 12:45:00
# Current time & days to expiry: 2021-12-07 2.1145833333333335
# Curr time & days to EXpiry 2021-12-07 2.1145833333333335
# Processing timestamp: 2021-12-07 12:46:00
# Current time & days to expiry: 2021-12-07 2.113888888888889
# Curr time & days to EXpiry 2021-12-07 2.113888888888889
# Processing timestamp: 2021-12-07 12:47:00
# Current time & days to expiry: 2021-12-07 2.1131944444444444
# Curr time & days to EXpiry 2021-12-07 2.1131944444444444
# Processing timestamp: 2021-12-07 12:48:00
# Current time & days to expiry: 2021-12-07 2.1125
# Curr time & days to EXpiry 2021-12-07 2.1125
# Processing timestamp: 2021-12-07 12:49:00
# Current time & days to expiry: 2021-12-07 2.1118055555555557
# Curr time & days to EXpiry 2021-12-07 2.1118055555555557
# Processing timestamp: 2021-12-07 12:50:00
# Current time & days to expiry: 2021-12-07 2.111111111111111
# Curr time & days to EXpiry 2021-12-07 2.111111111111111
# Processing timestamp: 2021-12-07 12:51:00
# Current time & days to expiry: 2021-12-07 2.1104166666666666
# Curr time & days to EXpiry 2021-12-07 2.1104166666666666
# Processing timestamp: 2021-12-07 12:52:00
# Current time & days to expiry: 2021-12-07 2.109722222222222
# Curr time & days to EXpiry 2021-12-07 2.109722222222222
# Processing timestamp: 2021-12-07 12:53:00
# Current time & days to expiry: 2021-12-07 2.109027777777778
# Curr time & days to EXpiry 2021-12-07 2.109027777777778
# Processing timestamp: 2021-12-07 12:54:00
# Current time & days to expiry: 2021-12-07 2.1083333333333334
# Curr time & days to EXpiry 2021-12-07 2.1083333333333334
# Processing timestamp: 2021-12-07 12:55:00
# Current time & days to expiry: 2021-12-07 2.107638888888889
# Curr time & days to EXpiry 2021-12-07 2.107638888888889
# Processing timestamp: 2021-12-07 12:56:00
# Current time & days to expiry: 2021-12-07 2.1069444444444443
# Curr time & days to EXpiry 2021-12-07 2.1069444444444443
# Processing timestamp: 2021-12-07 12:57:00
# Current time & days to expiry: 2021-12-07 2.10625
# Curr time & days to EXpiry 2021-12-07 2.10625
# Processing timestamp: 2021-12-07 12:58:00
# Current time & days to expiry: 2021-12-07 2.1055555555555556
# Curr time & days to EXpiry 2021-12-07 2.1055555555555556
# Processing timestamp: 2021-12-07 12:59:00
# Current time & days to expiry: 2021-12-07 2.104861111111111
# Curr time & days to EXpiry 2021-12-07 2.104861111111111
# Processing timestamp: 2021-12-07 13:00:00
# Current time & days to expiry: 2021-12-07 2.1041666666666665
# Curr time & days to EXpiry 2021-12-07 2.1041666666666665
# Processing timestamp: 2021-12-07 13:01:00
# Current time & days to expiry: 2021-12-07 2.1034722222222224
# Curr time & days to EXpiry 2021-12-07 2.1034722222222224
# Processing timestamp: 2021-12-07 13:02:00
# Current time & days to expiry: 2021-12-07 2.102777777777778
# Curr time & days to EXpiry 2021-12-07 2.102777777777778
# Processing timestamp: 2021-12-07 13:03:00
# Current time & days to expiry: 2021-12-07 2.1020833333333333
# Curr time & days to EXpiry 2021-12-07 2.1020833333333333
# Processing timestamp: 2021-12-07 13:04:00
# Current time & days to expiry: 2021-12-07 2.1013888888888888
# Curr time & days to EXpiry 2021-12-07 2.1013888888888888
# Processing timestamp: 2021-12-07 13:05:00
# Current time & days to expiry: 2021-12-07 2.1006944444444446
# Curr time & days to EXpiry 2021-12-07 2.1006944444444446
# Processing timestamp: 2021-12-07 13:06:00
# Current time & days to expiry: 2021-12-07 2.1
# Curr time & days to EXpiry 2021-12-07 2.1
# Processing timestamp: 2021-12-07 13:07:00
# Current time & days to expiry: 2021-12-07 2.0993055555555555
# Curr time & days to EXpiry 2021-12-07 2.0993055555555555
# Processing timestamp: 2021-12-07 13:08:00
# Current time & days to expiry: 2021-12-07 2.098611111111111
# Curr time & days to EXpiry 2021-12-07 2.098611111111111
# Processing timestamp: 2021-12-07 13:09:00
# Current time & days to expiry: 2021-12-07 2.097916666666667
# Curr time & days to EXpiry 2021-12-07 2.097916666666667
# Processing timestamp: 2021-12-07 13:10:00
# Current time & days to expiry: 2021-12-07 2.0972222222222223
# Curr time & days to EXpiry 2021-12-07 2.0972222222222223
# Processing timestamp: 2021-12-07 13:11:00
# Current time & days to expiry: 2021-12-07 2.0965277777777778
# Curr time & days to EXpiry 2021-12-07 2.0965277777777778
# Processing timestamp: 2021-12-07 13:12:00
# Current time & days to expiry: 2021-12-07 2.095833333333333
# Curr time & days to EXpiry 2021-12-07 2.095833333333333
# Processing timestamp: 2021-12-07 13:13:00
# Current time & days to expiry: 2021-12-07 2.095138888888889
# Curr time & days to EXpiry 2021-12-07 2.095138888888889
# Processing timestamp: 2021-12-07 13:14:00
# Current time & days to expiry: 2021-12-07 2.0944444444444446
# Curr time & days to EXpiry 2021-12-07 2.0944444444444446
# Processing timestamp: 2021-12-07 13:15:00
# Current time & days to expiry: 2021-12-07 2.09375
# Curr time & days to EXpiry 2021-12-07 2.09375
# Processing timestamp: 2021-12-07 13:16:00
# Current time & days to expiry: 2021-12-07 2.0930555555555554
# Curr time & days to EXpiry 2021-12-07 2.0930555555555554
# Processing timestamp: 2021-12-07 13:17:00
# Current time & days to expiry: 2021-12-07 2.092361111111111
# Curr time & days to EXpiry 2021-12-07 2.092361111111111
# Processing timestamp: 2021-12-07 13:18:00
# Current time & days to expiry: 2021-12-07 2.091666666666667
# Curr time & days to EXpiry 2021-12-07 2.091666666666667
# Processing timestamp: 2021-12-07 13:19:00
# Current time & days to expiry: 2021-12-07 2.0909722222222222
# Curr time & days to EXpiry 2021-12-07 2.0909722222222222
# Processing timestamp: 2021-12-07 13:20:00
# Current time & days to expiry: 2021-12-07 2.0902777777777777
# Curr time & days to EXpiry 2021-12-07 2.0902777777777777
# Processing timestamp: 2021-12-07 13:21:00
# Current time & days to expiry: 2021-12-07 2.089583333333333
# Curr time & days to EXpiry 2021-12-07 2.089583333333333
# Processing timestamp: 2021-12-07 13:22:00
# Current time & days to expiry: 2021-12-07 2.088888888888889
# Curr time & days to EXpiry 2021-12-07 2.088888888888889
# Processing timestamp: 2021-12-07 13:23:00
# Current time & days to expiry: 2021-12-07 2.0881944444444445
# Curr time & days to EXpiry 2021-12-07 2.0881944444444445
# Processing timestamp: 2021-12-07 13:24:00
# Current time & days to expiry: 2021-12-07 2.0875
# Curr time & days to EXpiry 2021-12-07 2.0875
# Processing timestamp: 2021-12-07 13:25:00
# Current time & days to expiry: 2021-12-07 2.0868055555555554
# Curr time & days to EXpiry 2021-12-07 2.0868055555555554
# Processing timestamp: 2021-12-07 13:26:00
# Current time & days to expiry: 2021-12-07 2.0861111111111112
# Curr time & days to EXpiry 2021-12-07 2.0861111111111112
# Processing timestamp: 2021-12-07 13:27:00
# Current time & days to expiry: 2021-12-07 2.0854166666666667
# Curr time & days to EXpiry 2021-12-07 2.0854166666666667
# Processing timestamp: 2021-12-07 13:28:00
# Current time & days to expiry: 2021-12-07 2.084722222222222
# Curr time & days to EXpiry 2021-12-07 2.084722222222222
# Processing timestamp: 2021-12-07 13:29:00
# Current time & days to expiry: 2021-12-07 2.0840277777777776
# Curr time & days to EXpiry 2021-12-07 2.0840277777777776
# Processing timestamp: 2021-12-07 13:30:00
# Current time & days to expiry: 2021-12-07 2.0833333333333335
# Curr time & days to EXpiry 2021-12-07 2.0833333333333335
# Processing timestamp: 2021-12-07 13:31:00
# Current time & days to expiry: 2021-12-07 2.082638888888889
# Curr time & days to EXpiry 2021-12-07 2.082638888888889
# Processing timestamp: 2021-12-07 13:32:00
# Current time & days to expiry: 2021-12-07 2.0819444444444444
# Curr time & days to EXpiry 2021-12-07 2.0819444444444444
# Processing timestamp: 2021-12-07 13:33:00
# Current time & days to expiry: 2021-12-07 2.08125
# Curr time & days to EXpiry 2021-12-07 2.08125
# Processing timestamp: 2021-12-07 13:34:00
# Current time & days to expiry: 2021-12-07 2.0805555555555557
# Curr time & days to EXpiry 2021-12-07 2.0805555555555557
# Processing timestamp: 2021-12-07 13:35:00
# Current time & days to expiry: 2021-12-07 2.079861111111111
# Curr time & days to EXpiry 2021-12-07 2.079861111111111
# Processing timestamp: 2021-12-07 13:36:00
# Current time & days to expiry: 2021-12-07 2.0791666666666666
# Curr time & days to EXpiry 2021-12-07 2.0791666666666666
# Processing timestamp: 2021-12-07 13:37:00
# Current time & days to expiry: 2021-12-07 2.078472222222222
# Curr time & days to EXpiry 2021-12-07 2.078472222222222
# Processing timestamp: 2021-12-07 13:38:00
# Current time & days to expiry: 2021-12-07 2.077777777777778
# Curr time & days to EXpiry 2021-12-07 2.077777777777778
# Processing timestamp: 2021-12-07 13:39:00
# Current time & days to expiry: 2021-12-07 2.0770833333333334
# Curr time & days to EXpiry 2021-12-07 2.0770833333333334
# Processing timestamp: 2021-12-07 13:40:00
# Current time & days to expiry: 2021-12-07 2.076388888888889
# Curr time & days to EXpiry 2021-12-07 2.076388888888889
# Processing timestamp: 2021-12-07 13:41:00
# Current time & days to expiry: 2021-12-07 2.0756944444444443
# Curr time & days to EXpiry 2021-12-07 2.0756944444444443
# Processing timestamp: 2021-12-07 13:42:00
# Current time & days to expiry: 2021-12-07 2.075
# Curr time & days to EXpiry 2021-12-07 2.075
# Processing timestamp: 2021-12-07 13:43:00
# Current time & days to expiry: 2021-12-07 2.0743055555555556
# Curr time & days to EXpiry 2021-12-07 2.0743055555555556
# Processing timestamp: 2021-12-07 13:44:00
# Current time & days to expiry: 2021-12-07 2.073611111111111
# Curr time & days to EXpiry 2021-12-07 2.073611111111111
# Processing timestamp: 2021-12-07 13:45:00
# Current time & days to expiry: 2021-12-07 2.0729166666666665
# Curr time & days to EXpiry 2021-12-07 2.0729166666666665
# Processing timestamp: 2021-12-07 13:46:00
# Current time & days to expiry: 2021-12-07 2.0722222222222224
# Curr time & days to EXpiry 2021-12-07 2.0722222222222224
# Processing timestamp: 2021-12-07 13:47:00
# Current time & days to expiry: 2021-12-07 2.071527777777778
# Curr time & days to EXpiry 2021-12-07 2.071527777777778
# Processing timestamp: 2021-12-07 13:48:00
# Current time & days to expiry: 2021-12-07 2.0708333333333333
# Curr time & days to EXpiry 2021-12-07 2.0708333333333333
# Processing timestamp: 2021-12-07 13:49:00
# Current time & days to expiry: 2021-12-07 2.0701388888888888
# Curr time & days to EXpiry 2021-12-07 2.0701388888888888
# Processing timestamp: 2021-12-07 13:50:00
# Current time & days to expiry: 2021-12-07 2.0694444444444446
# Curr time & days to EXpiry 2021-12-07 2.0694444444444446
# Processing timestamp: 2021-12-07 13:51:00
# Current time & days to expiry: 2021-12-07 2.06875
# Curr time & days to EXpiry 2021-12-07 2.06875
# Processing timestamp: 2021-12-07 13:52:00
# Current time & days to expiry: 2021-12-07 2.0680555555555555
# Curr time & days to EXpiry 2021-12-07 2.0680555555555555
# Processing timestamp: 2021-12-07 13:53:00
# Current time & days to expiry: 2021-12-07 2.067361111111111
# Curr time & days to EXpiry 2021-12-07 2.067361111111111
# Processing timestamp: 2021-12-07 13:54:00
# Current time & days to expiry: 2021-12-07 2.066666666666667
# Curr time & days to EXpiry 2021-12-07 2.066666666666667
# Processing timestamp: 2021-12-07 13:55:00
# Current time & days to expiry: 2021-12-07 2.0659722222222223
# Curr time & days to EXpiry 2021-12-07 2.0659722222222223
# Processing timestamp: 2021-12-07 13:56:00
# Current time & days to expiry: 2021-12-07 2.0652777777777778
# Curr time & days to EXpiry 2021-12-07 2.0652777777777778
# Processing timestamp: 2021-12-07 13:57:00
# Current time & days to expiry: 2021-12-07 2.064583333333333
# Curr time & days to EXpiry 2021-12-07 2.064583333333333
# Processing timestamp: 2021-12-07 13:58:00
# Current time & days to expiry: 2021-12-07 2.063888888888889
# Curr time & days to EXpiry 2021-12-07 2.063888888888889
# Processing timestamp: 2021-12-07 13:59:00
# Current time & days to expiry: 2021-12-07 2.0631944444444446
# Curr time & days to EXpiry 2021-12-07 2.0631944444444446
# Processing timestamp: 2021-12-07 14:00:00
# Current time & days to expiry: 2021-12-07 2.0625
# Curr time & days to EXpiry 2021-12-07 2.0625
# Processing timestamp: 2021-12-07 14:01:00
# Current time & days to expiry: 2021-12-07 2.0618055555555554
# Curr time & days to EXpiry 2021-12-07 2.0618055555555554
# Processing timestamp: 2021-12-07 14:02:00
# Current time & days to expiry: 2021-12-07 2.061111111111111
# Curr time & days to EXpiry 2021-12-07 2.061111111111111
# Processing timestamp: 2021-12-07 14:03:00
# Current time & days to expiry: 2021-12-07 2.060416666666667
# Curr time & days to EXpiry 2021-12-07 2.060416666666667
# Processing timestamp: 2021-12-07 14:04:00
# Current time & days to expiry: 2021-12-07 2.0597222222222222
# Curr time & days to EXpiry 2021-12-07 2.0597222222222222
# Processing timestamp: 2021-12-07 14:05:00
# Current time & days to expiry: 2021-12-07 2.0590277777777777
# Curr time & days to EXpiry 2021-12-07 2.0590277777777777
# Processing timestamp: 2021-12-07 14:06:00
# Current time & days to expiry: 2021-12-07 2.058333333333333
# Curr time & days to EXpiry 2021-12-07 2.058333333333333
# Processing timestamp: 2021-12-07 14:07:00
# Current time & days to expiry: 2021-12-07 2.057638888888889
# Curr time & days to EXpiry 2021-12-07 2.057638888888889
# Processing timestamp: 2021-12-07 14:08:00
# Current time & days to expiry: 2021-12-07 2.0569444444444445
# Curr time & days to EXpiry 2021-12-07 2.0569444444444445
# Processing timestamp: 2021-12-07 14:09:00
# Current time & days to expiry: 2021-12-07 2.05625
# Curr time & days to EXpiry 2021-12-07 2.05625
# Processing timestamp: 2021-12-07 14:10:00
# Current time & days to expiry: 2021-12-07 2.0555555555555554
# Curr time & days to EXpiry 2021-12-07 2.0555555555555554
# Processing timestamp: 2021-12-07 14:11:00
# Current time & days to expiry: 2021-12-07 2.0548611111111112
# Curr time & days to EXpiry 2021-12-07 2.0548611111111112
# Processing timestamp: 2021-12-07 14:12:00
# Current time & days to expiry: 2021-12-07 2.0541666666666667
# Curr time & days to EXpiry 2021-12-07 2.0541666666666667
# Processing timestamp: 2021-12-07 14:13:00
# Current time & days to expiry: 2021-12-07 2.053472222222222
# Curr time & days to EXpiry 2021-12-07 2.053472222222222
# Processing timestamp: 2021-12-07 14:14:00
# Current time & days to expiry: 2021-12-07 2.0527777777777776
# Curr time & days to EXpiry 2021-12-07 2.0527777777777776
# Processing timestamp: 2021-12-07 14:15:00
# Current time & days to expiry: 2021-12-07 2.0520833333333335
# Curr time & days to EXpiry 2021-12-07 2.0520833333333335
# Processing timestamp: 2021-12-07 14:16:00
# Current time & days to expiry: 2021-12-07 2.051388888888889
# Curr time & days to EXpiry 2021-12-07 2.051388888888889
# Processing timestamp: 2021-12-07 14:17:00
# Current time & days to expiry: 2021-12-07 2.0506944444444444
# Curr time & days to EXpiry 2021-12-07 2.0506944444444444
# Processing timestamp: 2021-12-07 14:18:00
# Current time & days to expiry: 2021-12-07 2.05
# Curr time & days to EXpiry 2021-12-07 2.05
# Processing timestamp: 2021-12-07 14:19:00
# Current time & days to expiry: 2021-12-07 2.0493055555555557
# Curr time & days to EXpiry 2021-12-07 2.0493055555555557
# Processing timestamp: 2021-12-07 14:20:00
# Current time & days to expiry: 2021-12-07 2.048611111111111
# Curr time & days to EXpiry 2021-12-07 2.048611111111111
# Processing timestamp: 2021-12-07 14:21:00
# Current time & days to expiry: 2021-12-07 2.0479166666666666
# Curr time & days to EXpiry 2021-12-07 2.0479166666666666
# Processing timestamp: 2021-12-07 14:22:00
# Current time & days to expiry: 2021-12-07 2.047222222222222
# Curr time & days to EXpiry 2021-12-07 2.047222222222222
# Processing timestamp: 2021-12-07 14:23:00
# Current time & days to expiry: 2021-12-07 2.046527777777778
# Curr time & days to EXpiry 2021-12-07 2.046527777777778
# Processing timestamp: 2021-12-07 14:24:00
# Current time & days to expiry: 2021-12-07 2.0458333333333334
# Curr time & days to EXpiry 2021-12-07 2.0458333333333334
# Processing timestamp: 2021-12-07 14:25:00
# Current time & days to expiry: 2021-12-07 2.045138888888889
# Curr time & days to EXpiry 2021-12-07 2.045138888888889
# Processing timestamp: 2021-12-07 14:26:00
# Current time & days to expiry: 2021-12-07 2.0444444444444443
# Curr time & days to EXpiry 2021-12-07 2.0444444444444443
# Processing timestamp: 2021-12-07 14:27:00
# Current time & days to expiry: 2021-12-07 2.04375
# Curr time & days to EXpiry 2021-12-07 2.04375
# Processing timestamp: 2021-12-07 14:28:00
# Current time & days to expiry: 2021-12-07 2.0430555555555556
# Curr time & days to EXpiry 2021-12-07 2.0430555555555556
# Processing timestamp: 2021-12-07 14:29:00
# Current time & days to expiry: 2021-12-07 2.042361111111111
# Curr time & days to EXpiry 2021-12-07 2.042361111111111
# Processing timestamp: 2021-12-07 14:30:00
# Current time & days to expiry: 2021-12-07 2.0416666666666665
# Curr time & days to EXpiry 2021-12-07 2.0416666666666665
# Processing timestamp: 2021-12-07 14:31:00
# Current time & days to expiry: 2021-12-07 2.0409722222222224
# Curr time & days to EXpiry 2021-12-07 2.0409722222222224
# Processing timestamp: 2021-12-07 14:32:00
# Current time & days to expiry: 2021-12-07 2.040277777777778
# Curr time & days to EXpiry 2021-12-07 2.040277777777778
# Processing timestamp: 2021-12-07 14:33:00
# Current time & days to expiry: 2021-12-07 2.0395833333333333
# Curr time & days to EXpiry 2021-12-07 2.0395833333333333
# Processing timestamp: 2021-12-07 14:34:00
# Current time & days to expiry: 2021-12-07 2.0388888888888888
# Curr time & days to EXpiry 2021-12-07 2.0388888888888888
# Processing timestamp: 2021-12-07 14:35:00
# Current time & days to expiry: 2021-12-07 2.0381944444444446
# Curr time & days to EXpiry 2021-12-07 2.0381944444444446
# Processing timestamp: 2021-12-07 14:36:00
# Current time & days to expiry: 2021-12-07 2.0375
# Curr time & days to EXpiry 2021-12-07 2.0375
# Processing timestamp: 2021-12-07 14:37:00
# Current time & days to expiry: 2021-12-07 2.0368055555555555
# Curr time & days to EXpiry 2021-12-07 2.0368055555555555
# Processing timestamp: 2021-12-07 14:38:00
# Current time & days to expiry: 2021-12-07 2.036111111111111
# Curr time & days to EXpiry 2021-12-07 2.036111111111111
# Processing timestamp: 2021-12-07 14:39:00
# Current time & days to expiry: 2021-12-07 2.035416666666667
# Curr time & days to EXpiry 2021-12-07 2.035416666666667
# Processing timestamp: 2021-12-07 14:40:00
# Current time & days to expiry: 2021-12-07 2.0347222222222223
# Curr time & days to EXpiry 2021-12-07 2.0347222222222223
# Processing timestamp: 2021-12-07 14:41:00
# Current time & days to expiry: 2021-12-07 2.0340277777777778
# Curr time & days to EXpiry 2021-12-07 2.0340277777777778
# Processing timestamp: 2021-12-07 14:42:00
# Current time & days to expiry: 2021-12-07 2.033333333333333
# Curr time & days to EXpiry 2021-12-07 2.033333333333333
# Processing timestamp: 2021-12-07 14:43:00
# Current time & days to expiry: 2021-12-07 2.032638888888889
# Curr time & days to EXpiry 2021-12-07 2.032638888888889
# Processing timestamp: 2021-12-07 14:44:00
# Current time & days to expiry: 2021-12-07 2.0319444444444446
# Curr time & days to EXpiry 2021-12-07 2.0319444444444446
# Processing timestamp: 2021-12-07 14:45:00
# Current time & days to expiry: 2021-12-07 2.03125
# Curr time & days to EXpiry 2021-12-07 2.03125
# Processing timestamp: 2021-12-07 14:46:00
# Current time & days to expiry: 2021-12-07 2.0305555555555554
# Curr time & days to EXpiry 2021-12-07 2.0305555555555554
# Processing timestamp: 2021-12-07 14:47:00
# Current time & days to expiry: 2021-12-07 2.029861111111111
# Curr time & days to EXpiry 2021-12-07 2.029861111111111
# Processing timestamp: 2021-12-07 14:48:00
# Current time & days to expiry: 2021-12-07 2.029166666666667
# Curr time & days to EXpiry 2021-12-07 2.029166666666667
# Processing timestamp: 2021-12-07 14:49:00
# Current time & days to expiry: 2021-12-07 2.0284722222222222
# Curr time & days to EXpiry 2021-12-07 2.0284722222222222
# Processing timestamp: 2021-12-07 14:50:00
# Current time & days to expiry: 2021-12-07 2.0277777777777777
# Curr time & days to EXpiry 2021-12-07 2.0277777777777777
# Processing timestamp: 2021-12-07 14:51:00
# Current time & days to expiry: 2021-12-07 2.027083333333333
# Curr time & days to EXpiry 2021-12-07 2.027083333333333
# Processing timestamp: 2021-12-07 14:52:00
# Current time & days to expiry: 2021-12-07 2.026388888888889
# Curr time & days to EXpiry 2021-12-07 2.026388888888889
# Processing timestamp: 2021-12-07 14:53:00
# Current time & days to expiry: 2021-12-07 2.0256944444444445
# Curr time & days to EXpiry 2021-12-07 2.0256944444444445
# Processing timestamp: 2021-12-07 14:54:00
# Current time & days to expiry: 2021-12-07 2.025
# Curr time & days to EXpiry 2021-12-07 2.025
# Processing timestamp: 2021-12-07 14:55:00
# Current time & days to expiry: 2021-12-07 2.0243055555555554
# Curr time & days to EXpiry 2021-12-07 2.0243055555555554
# Processing timestamp: 2021-12-07 14:56:00
# Current time & days to expiry: 2021-12-07 2.0236111111111112
# Curr time & days to EXpiry 2021-12-07 2.0236111111111112
# Processing timestamp: 2021-12-07 14:57:00
# Current time & days to expiry: 2021-12-07 2.0229166666666667
# Curr time & days to EXpiry 2021-12-07 2.0229166666666667
# Processing timestamp: 2021-12-07 14:58:00
# Current time & days to expiry: 2021-12-07 2.022222222222222
# Curr time & days to EXpiry 2021-12-07 2.022222222222222
# Processing timestamp: 2021-12-07 14:59:00
# Current time & days to expiry: 2021-12-07 2.0215277777777776
# Curr time & days to EXpiry 2021-12-07 2.0215277777777776
# Processing timestamp: 2021-12-07 15:00:00
# Current time & days to expiry: 2021-12-07 2.0208333333333335
# Curr time & days to EXpiry 2021-12-07 2.0208333333333335
# Processing timestamp: 2021-12-07 15:01:00
# Current time & days to expiry: 2021-12-07 2.020138888888889
# Curr time & days to EXpiry 2021-12-07 2.020138888888889
# Processing timestamp: 2021-12-07 15:02:00
# Current time & days to expiry: 2021-12-07 2.0194444444444444
# Curr time & days to EXpiry 2021-12-07 2.0194444444444444
# Processing timestamp: 2021-12-07 15:03:00
# Current time & days to expiry: 2021-12-07 2.01875
# Curr time & days to EXpiry 2021-12-07 2.01875
# Processing timestamp: 2021-12-07 15:04:00
# Current time & days to expiry: 2021-12-07 2.0180555555555557
# Curr time & days to EXpiry 2021-12-07 2.0180555555555557
# Processing timestamp: 2021-12-07 15:05:00
# Current time & days to expiry: 2021-12-07 2.017361111111111
# Curr time & days to EXpiry 2021-12-07 2.017361111111111
# Processing timestamp: 2021-12-07 15:06:00
# Current time & days to expiry: 2021-12-07 2.0166666666666666
# Curr time & days to EXpiry 2021-12-07 2.0166666666666666
# Processing timestamp: 2021-12-07 15:07:00
# Current time & days to expiry: 2021-12-07 2.015972222222222
# Curr time & days to EXpiry 2021-12-07 2.015972222222222
# Processing timestamp: 2021-12-07 15:08:00
# Current time & days to expiry: 2021-12-07 2.015277777777778
# Curr time & days to EXpiry 2021-12-07 2.015277777777778
# Processing timestamp: 2021-12-07 15:09:00
# Current time & days to expiry: 2021-12-07 2.0145833333333334
# Curr time & days to EXpiry 2021-12-07 2.0145833333333334
# Processing timestamp: 2021-12-07 15:10:00
# Current time & days to expiry: 2021-12-07 2.013888888888889
# Curr time & days to EXpiry 2021-12-07 2.013888888888889
# Processing timestamp: 2021-12-07 15:11:00
# Current time & days to expiry: 2021-12-07 2.0131944444444443
# Curr time & days to EXpiry 2021-12-07 2.0131944444444443
# Processing timestamp: 2021-12-07 15:12:00
# Current time & days to expiry: 2021-12-07 2.0125
# Curr time & days to EXpiry 2021-12-07 2.0125
# Processing timestamp: 2021-12-07 15:13:00
# Current time & days to expiry: 2021-12-07 2.0118055555555556
# Curr time & days to EXpiry 2021-12-07 2.0118055555555556
# Processing timestamp: 2021-12-07 15:14:00
# Current time & days to expiry: 2021-12-07 2.011111111111111
# Curr time & days to EXpiry 2021-12-07 2.011111111111111
# Processing timestamp: 2021-12-07 15:15:00
# Current time & days to expiry: 2021-12-07 2.0104166666666665
# Curr time & days to EXpiry 2021-12-07 2.0104166666666665
# Processing timestamp: 2021-12-07 15:16:00
# Current time & days to expiry: 2021-12-07 2.0097222222222224
# Curr time & days to EXpiry 2021-12-07 2.0097222222222224
# Processing timestamp: 2021-12-07 15:17:00
# Current time & days to expiry: 2021-12-07 2.009027777777778
# Curr time & days to EXpiry 2021-12-07 2.009027777777778
# Processing timestamp: 2021-12-07 15:18:00
# Current time & days to expiry: 2021-12-07 2.0083333333333333
# Curr time & days to EXpiry 2021-12-07 2.0083333333333333
# Processing timestamp: 2021-12-07 15:19:00
# Current time & days to expiry: 2021-12-07 2.0076388888888888
# Curr time & days to EXpiry 2021-12-07 2.0076388888888888
# Processing timestamp: 2021-12-07 15:20:00
# Current time & days to expiry: 2021-12-07 2.0069444444444446
# Curr time & days to EXpiry 2021-12-07 2.0069444444444446
# Processing timestamp: 2021-12-07 15:21:00
# Current time & days to expiry: 2021-12-07 2.00625
# Curr time & days to EXpiry 2021-12-07 2.00625
# Processing timestamp: 2021-12-07 15:22:00
# Current time & days to expiry: 2021-12-07 2.0055555555555555
# Curr time & days to EXpiry 2021-12-07 2.0055555555555555
# Processing timestamp: 2021-12-07 15:23:00
# Current time & days to expiry: 2021-12-07 2.004861111111111
# Curr time & days to EXpiry 2021-12-07 2.004861111111111
# Processing timestamp: 2021-12-07 15:24:00
# Current time & days to expiry: 2021-12-07 2.004166666666667
# Curr time & days to EXpiry 2021-12-07 2.004166666666667
# Processing timestamp: 2021-12-07 15:25:00
# Current time & days to expiry: 2021-12-07 2.0034722222222223
# Curr time & days to EXpiry 2021-12-07 2.0034722222222223
# Processing timestamp: 2021-12-07 15:26:00
# Current time & days to expiry: 2021-12-07 2.0027777777777778
# Curr time & days to EXpiry 2021-12-07 2.0027777777777778
# Processing timestamp: 2021-12-07 15:27:00
# Current time & days to expiry: 2021-12-07 2.002083333333333
# Curr time & days to EXpiry 2021-12-07 2.002083333333333
# Processing timestamp: 2021-12-07 15:28:00
# Current time & days to expiry: 2021-12-07 2.001388888888889
# Curr time & days to EXpiry 2021-12-07 2.001388888888889
# Processing timestamp: 2021-12-07 15:29:00
# Current time & days to expiry: 2021-12-07 2.0006944444444446
# Curr time & days to EXpiry 2021-12-07 2.0006944444444446
# Processing timestamp: 2021-12-07 15:30:00
# Current time & days to expiry: 2021-12-07 2.0
# Curr time & days to EXpiry 2021-12-07 2.0
# Processing timestamp: 2021-12-08 09:15:00
# Current time & days to expiry: 2021-12-08 1.2604166666666667
# Curr time & days to EXpiry 2021-12-08 1.2604166666666667
# Processing timestamp: 2021-12-08 09:16:00
# Current time & days to expiry: 2021-12-08 1.2597222222222222
# Curr time & days to EXpiry 2021-12-08 1.2597222222222222
# Processing timestamp: 2021-12-08 09:17:00
# Current time & days to expiry: 2021-12-08 1.2590277777777779
# Curr time & days to EXpiry 2021-12-08 1.2590277777777779
# Processing timestamp: 2021-12-08 09:18:00
# Current time & days to expiry: 2021-12-08 1.2583333333333333
# Curr time & days to EXpiry 2021-12-08 1.2583333333333333
# Processing timestamp: 2021-12-08 09:19:00
# Current time & days to expiry: 2021-12-08 1.257638888888889
# Curr time & days to EXpiry 2021-12-08 1.257638888888889
# Processing timestamp: 2021-12-08 09:20:00
# Current time & days to expiry: 2021-12-08 1.2569444444444444
# Curr time & days to EXpiry 2021-12-08 1.2569444444444444
# Processing timestamp: 2021-12-08 09:21:00
# Current time & days to expiry: 2021-12-08 1.25625
# Curr time & days to EXpiry 2021-12-08 1.25625
# Processing timestamp: 2021-12-08 09:22:00
# Current time & days to expiry: 2021-12-08 1.2555555555555555
# Curr time & days to EXpiry 2021-12-08 1.2555555555555555
# Processing timestamp: 2021-12-08 09:23:00
# Current time & days to expiry: 2021-12-08 1.2548611111111112
# Curr time & days to EXpiry 2021-12-08 1.2548611111111112
# Processing timestamp: 2021-12-08 09:24:00
# Current time & days to expiry: 2021-12-08 1.2541666666666667
# Curr time & days to EXpiry 2021-12-08 1.2541666666666667
# Processing timestamp: 2021-12-08 09:25:00
# Current time & days to expiry: 2021-12-08 1.2534722222222223
# Curr time & days to EXpiry 2021-12-08 1.2534722222222223
# Processing timestamp: 2021-12-08 09:26:00
# Current time & days to expiry: 2021-12-08 1.2527777777777778
# Curr time & days to EXpiry 2021-12-08 1.2527777777777778
# Processing timestamp: 2021-12-08 09:27:00
# Current time & days to expiry: 2021-12-08 1.2520833333333334
# Curr time & days to EXpiry 2021-12-08 1.2520833333333334
# Processing timestamp: 2021-12-08 09:28:00
# Current time & days to expiry: 2021-12-08 1.2513888888888889
# Curr time & days to EXpiry 2021-12-08 1.2513888888888889
# Processing timestamp: 2021-12-08 09:29:00
# Current time & days to expiry: 2021-12-08 1.2506944444444446
# Curr time & days to EXpiry 2021-12-08 1.2506944444444446
# Processing timestamp: 2021-12-08 09:30:00
# Current time & days to expiry: 2021-12-08 1.25
# Curr time & days to EXpiry 2021-12-08 1.25
# Processing timestamp: 2021-12-08 09:31:00
# Current time & days to expiry: 2021-12-08 1.2493055555555554
# Curr time & days to EXpiry 2021-12-08 1.2493055555555554
# Processing timestamp: 2021-12-08 09:32:00
# Current time & days to expiry: 2021-12-08 1.2486111111111111
# Curr time & days to EXpiry 2021-12-08 1.2486111111111111
# Processing timestamp: 2021-12-08 09:33:00
# Current time & days to expiry: 2021-12-08 1.2479166666666666
# Curr time & days to EXpiry 2021-12-08 1.2479166666666666
# Processing timestamp: 2021-12-08 09:34:00
# Current time & days to expiry: 2021-12-08 1.2472222222222222
# Curr time & days to EXpiry 2021-12-08 1.2472222222222222
# Processing timestamp: 2021-12-08 09:35:00
# Current time & days to expiry: 2021-12-08 1.2465277777777777
# Curr time & days to EXpiry 2021-12-08 1.2465277777777777
# Processing timestamp: 2021-12-08 09:36:00
# Current time & days to expiry: 2021-12-08 1.2458333333333333
# Curr time & days to EXpiry 2021-12-08 1.2458333333333333
# Processing timestamp: 2021-12-08 09:37:00
# Current time & days to expiry: 2021-12-08 1.2451388888888888
# Curr time & days to EXpiry 2021-12-08 1.2451388888888888
# Processing timestamp: 2021-12-08 09:38:00
# Current time & days to expiry: 2021-12-08 1.2444444444444445
# Curr time & days to EXpiry 2021-12-08 1.2444444444444445
# Processing timestamp: 2021-12-08 09:39:00
# Current time & days to expiry: 2021-12-08 1.24375
# Curr time & days to EXpiry 2021-12-08 1.24375
# Processing timestamp: 2021-12-08 09:40:00
# Current time & days to expiry: 2021-12-08 1.2430555555555556
# Curr time & days to EXpiry 2021-12-08 1.2430555555555556
# Processing timestamp: 2021-12-08 09:41:00
# Current time & days to expiry: 2021-12-08 1.242361111111111
# Curr time & days to EXpiry 2021-12-08 1.242361111111111
# Processing timestamp: 2021-12-08 09:42:00
# Current time & days to expiry: 2021-12-08 1.2416666666666667
# Curr time & days to EXpiry 2021-12-08 1.2416666666666667
# Processing timestamp: 2021-12-08 09:43:00
# Current time & days to expiry: 2021-12-08 1.2409722222222221
# Curr time & days to EXpiry 2021-12-08 1.2409722222222221
# Processing timestamp: 2021-12-08 09:44:00
# Current time & days to expiry: 2021-12-08 1.2402777777777778
# Curr time & days to EXpiry 2021-12-08 1.2402777777777778
# Processing timestamp: 2021-12-08 09:45:00
# Current time & days to expiry: 2021-12-08 1.2395833333333333
# Curr time & days to EXpiry 2021-12-08 1.2395833333333333
# Processing timestamp: 2021-12-08 09:46:00
# Current time & days to expiry: 2021-12-08 1.238888888888889
# Curr time & days to EXpiry 2021-12-08 1.238888888888889
# ...
# OI 36042650.0 28338450.0
# OI 36042650.0 28338450.0
# OI 35858650.0 28499600.0
# OI 35854300.0 28499700.0
# OI 35854300.0 28499700.0
# OI 35880650.0 28543150.0
# OI 35880650.0 28543200.0
# OI 35880650.0 28543200.0
# OI 35785750.0 28562700.0
# OI 35785750.0 28562700.0
# OI 40921550.0 27241150.0
# OI 35755950.0 28837500.0
# OI 35755950.0 28837500.0
# OI 35755950.0 28837500.0
# OI 40906150.0 27709300.0
# OI 40906150.0 27709300.0
# OI 40906150.0 27709300.0
# OI 40597750.0 27934800.0
# OI 40597750.0 27934800.0
# OI 40597750.0 27934800.0
# OI 40657000.0 28115950.0
# OI 40657000.0 28115950.0
# OI 40657000.0 28115950.0
# OI 40769700.0 28225950.0
# OI 40769700.0 28225950.0
# OI 40769700.0 28225950.0
# OI 40563700.0 28437900.0
# OI 40563700.0 28437900.0
# OI 40563700.0 28437900.0
# OI 39753900.0 28923400.0
# OI 39753900.0 28923400.0
# OI 39753900.0 28923400.0
# OI 39200650.0 29319050.0
# OI 39200650.0 29319050.0
# OI 39200650.0 29319050.0
# OI 39270750.0 29610400.0
# OI 39270750.0 29610400.0
# OI 39270750.0 29610400.0
# OI 39086250.0 29685500.0
# OI 39086250.0 29685500.0
# OI 39086250.0 29685500.0
# OI 38945150.0 29610000.0
# OI 38945150.0 29610000.0
# OI 38945150.0 29610000.0
# OI 39191200.0 29501500.0
# OI 39191200.0 29501500.0
# OI 39191200.0 29501500.0
# OI 38821850.0 29212400.0
# OI 38821850.0 29212400.0
# OI 38821850.0 29212400.0
# OI 38519000.0 29168200.0
# OI 38519000.0 29168200.0
# OI 38519000.0 29168200.0
# OI 38319650.0 29293500.0
# OI 38319650.0 29293500.0
# OI 38319650.0 29293500.0
# OI 38179250.0 29393700.0
# OI 38179250.0 29393700.0
# OI 38179250.0 29393700.0
# OI 37922300.0 29297350.0
# OI 37922300.0 29297350.0
# OI 37922300.0 29297350.0
# OI 37872000.0 29348150.0
# OI 37872000.0 29348150.0
# OI 37872000.0 29348150.0
# OI 37699400.0 29420400.0
# OI 37699400.0 29420400.0
# OI 37699400.0 29420400.0
# OI 37485200.0 29581150.0
# OI 37485200.0 29581150.0
# OI 37485200.0 29581150.0
# OI 37456850.0 29603500.0
# OI 37456850.0 29603500.0
# OI 37456850.0 29603500.0
# OI 37613000.0 29532350.0
# OI 37613000.0 29532350.0
# OI 37613000.0 29532350.0
# OI 37595650.0 29354700.0
# OI 37595650.0 29354700.0
# OI 37595650.0 29354700.0
# OI 37667600.0 29223350.0
# OI 37667600.0 29223350.0
# OI 37667600.0 29223350.0
# OI 37477150.0 29271550.0
# OI 37477150.0 29271550.0
# OI 37477150.0 29271550.0
# OI 37428000.0 29326900.0
# OI 37428000.0 29326900.0
# OI 37428000.0 29326900.0
# OI 37407400.0 29212300.0
# OI 37407400.0 29212300.0
# OI 37407400.0 29212300.0
# OI 37402100.0 29312650.0
# OI 37402100.0 29312650.0
# OI 37402100.0 29312650.0
# OI 37333600.0 29214150.0
# OI 37333600.0 29214150.0
# OI 37333600.0 29214150.0
# OI 36828400.0 29131400.0
# OI 36828400.0 29131400.0
# OI 36828400.0 29131400.0
# OI 36832350.0 29252450.0
# OI 36832350.0 29252450.0
# OI 36832350.0 29252450.0
# OI 36525500.0 29092000.0
# OI 36525500.0 29092000.0
# OI 36525500.0 29092000.0
# OI 36103250.0 29108250.0
# OI 36103250.0 29108250.0
# OI 36103250.0 29108250.0
# OI 35929450.0 29155450.0
# OI 35929450.0 29155450.0
# OI 35929450.0 29155450.0
# OI 35790200.0 28994350.0
# OI 35790200.0 28994350.0
# OI 35790200.0 28994350.0
# OI 35761800.0 28723500.0
# OI 35761800.0 28723500.0
# OI 35761800.0 28723500.0
# OI 35444400.0 28451300.0
# OI 35444400.0 28451300.0
# OI 35444400.0 28451300.0
# OI 35313600.0 28197500.0
# OI 35313600.0 28197500.0
# OI 35313600.0 28197500.0
# OI 35013400.0 27509500.0
# OI 35013400.0 27509500.0
# OI 35013400.0 27509500.0
# OI 34056400.0 22053100.0
# OI 33882000.0 27002000.0
# OI 33882000.0 27002000.0
# OI 33470150.0 26995450.0
# OI 33470150.0 26995450.0
# OI 33470150.0 26995450.0
# OI 33622600.0 26947750.0
# OI 33622600.0 26947750.0
# OI 33622600.0 26947750.0
# OI 33317200.0 26791900.0
# OI 33317200.0 26789900.0
# OI 33317200.0 26789900.0
# OI 33139500.0 26390750.0
# OI 33139500.0 26390750.0
# OI 33139500.0 26390750.0
# OI 32781300.0 26184100.0
# OI 32781300.0 26184100.0
# OI 32781300.0 26184100.0
# OI 32978500.0 25599150.0
# OI 32978500.0 25599150.0
# OI 32978500.0 25599150.0
# OI 33033400.0 25358150.0
# OI 33033400.0 25358150.0
# OI 33033400.0 25358150.0
# OI 32596000.0 24818500.0
# OI 32596000.0 24818500.0
# OI 32596000.0 24818500.0
# OI 31911050.0 23718600.0
# OI 31911050.0 23718600.0
# OI 31911050.0 23718600.0
# OI 31911050.0 23718600.0
# OI 31569100.0 18409900.0
# OI 35834150.0 16918900.0
# OI 38187100.0 19384100.0
# OI 33693750.0 20785800.0
# OI 33693750.0 20785800.0
# OI 35417850.0 22230200.0
# OI 35417850.0 22230200.0
# OI 34269650.0 26883100.0
# OI 35732200.0 27450050.0
# OI 35732200.0 27450050.0
# OI 35732200.0 27450050.0
# OI 36751350.0 27714950.0
# OI 36751350.0 27714950.0
# OI 36751350.0 27714950.0
# OI 38165500.0 28402250.0
# OI 38165500.0 28402250.0
# OI 38165500.0 28402250.0
# OI 38959900.0 29087000.0
# OI 38959900.0 29087000.0
# OI 38959900.0 29087000.0
# OI 39613400.0 29824350.0
# OI 39613400.0 29824350.0
# OI 40943200.0 24584400.0
# OI 41030300.0 25232650.0
# OI 41030300.0 25232650.0
# OI 41030300.0 25232650.0
# OI 40531200.0 31423200.0
# OI 40531200.0 31423200.0
# OI 40531200.0 31423200.0
# OI 41378950.0 31957550.0
# OI 41378950.0 31957550.0
# OI 41378950.0 31957550.0
# OI 41929500.0 32937750.0
# OI 41929500.0 32937750.0
# OI 41929500.0 32937750.0
# OI 43106100.0 33432000.0
# OI 43106100.0 33432000.0
# OI 43106100.0 33432000.0
# OI 44016800.0 34212050.0
# OI 44016800.0 34212050.0
# OI 44016800.0 34212050.0
# OI 44662850.0 34168050.0
# OI 44662850.0 34168050.0
# OI 44662850.0 34168050.0
# OI 45032850.0 34273150.0
# OI 45032850.0 34273150.0
# OI 45032850.0 34273150.0
# OI 45522550.0 33940850.0
# OI 45522550.0 33940850.0
# OI 45522550.0 33940850.0
# OI 45728250.0 34176450.0
# OI 45728250.0 34176450.0
# OI 45728250.0 34176450.0
# OI 46186300.0 34548600.0
# OI 46186300.0 34548600.0
# OI 46186300.0 34548600.0
# OI 46534250.0 34771600.0
# OI 38066700.0 36455100.0
# OI 38066700.0 36455100.0
# OI 38381250.0 35229400.0
# OI 38380700.0 35229400.0
# OI 38380700.0 35229400.0
# OI 39057100.0 34774150.0
# OI 39057100.0 34774150.0
# OI 39057100.0 34774150.0
# OI 39500450.0 33104600.0
# OI 39500450.0 33104600.0
# OI 39500450.0 33104600.0
# OI 40523500.0 33476200.0
# OI 40523500.0 33476200.0
# OI 40523500.0 33476200.0
# OI 41398450.0 33784400.0
# OI 41398450.0 33784400.0
# OI 41398450.0 33784400.0
# OI 41818000.0 33007650.0
# OI 41818000.0 33007650.0
# OI 41818000.0 33007650.0
# OI 42063950.0 32734750.0
# OI 42063950.0 32734750.0
# OI 42063950.0 32734750.0
# OI 42490250.0 33328050.0
# OI 42490250.0 33328050.0
# OI 42490250.0 33328050.0
# OI 42806350.0 33383950.0
# OI 42806350.0 33383950.0
# OI 42806350.0 33383950.0
# OI 42687700.0 34052850.0
# OI 42687700.0 34052850.0
# OI 42687700.0 34052850.0
# OI 42545500.0 34611050.0
# OI 42545500.0 34611050.0
# OI 42545500.0 34611050.0
# OI 52322300.0 33108050.0
# OI 52322300.0 33108050.0
# OI 52322300.0 33108050.0
# OI 52582050.0 33612600.0
# OI 52582050.0 33612600.0
# OI 52582050.0 33612600.0
# OI 52272300.0 33833950.0
# OI 52272300.0 33833950.0
# OI 52272300.0 33833950.0
# OI 52587450.0 34390900.0
# OI 52586250.0 34391450.0
# OI 52586250.0 34391450.0
# OI 52886800.0 34741250.0
# OI 52886800.0 34741250.0
# OI 52886800.0 34741250.0
# OI 53000950.0 35295750.0
# OI 53000950.0 35297000.0
# OI 53000950.0 35297000.0
# OI 52820550.0 35619350.0
# OI 52820550.0 35619450.0
# OI 52820550.0 35619450.0
# OI 53076100.0 35948800.0
# OI 53076100.0 35948800.0
# OI 53076100.0 35948800.0
# OI 53282050.0 36281100.0
# OI 53282050.0 36281100.0
# OI 53282050.0 36281100.0
# OI 53355300.0 36322400.0
# OI 43570100.0 38321950.0
# OI 43570100.0 38321950.0
# OI 43381100.0 37973600.0
# OI 43381100.0 37973600.0
# OI 43381100.0 37973600.0
# OI 43802150.0 37789000.0
# OI 43801550.0 37795200.0
# OI 43801550.0 37795200.0
# OI 44119850.0 37993450.0
# OI 44119800.0 37993450.0
# OI 53853200.0 35970900.0
# OI 53618150.0 35799900.0
# OI 53617200.0 35799900.0
# OI 53617200.0 35799900.0
# OI 53709300.0 36188900.0
# OI 53723950.0 36189450.0
# OI 53723950.0 36189450.0
# OI 54028800.0 36631250.0
# OI 54021300.0 36631800.0
# OI 54021300.0 36631800.0
# OI 54021300.0 36642250.0
# OI 53704600.0 36814750.0
# OI 53704600.0 36814750.0
# OI 53704600.0 36814750.0
# OI 53846800.0 37009100.0
# OI 53846800.0 37009100.0
# OI 44120150.0 39024150.0
# OI 44221100.0 39047300.0
# OI 53975650.0 37022800.0
# OI 53975650.0 37022800.0
# OI 54082650.0 36900000.0
# OI 54082650.0 36900000.0
# OI 54082650.0 36900000.0
# OI 54327850.0 36997700.0
# OI 54327850.0 36997700.0
# OI 44577700.0 39005500.0
# OI 44658050.0 39031650.0
# OI 54392900.0 37020350.0
# OI 54392900.0 37020350.0
# OI 54549150.0 37266950.0
# OI 44825100.0 39276300.0
# OI 54549150.0 37266950.0
# OI 54346900.0 37303050.0
# OI 54346900.0 37303050.0
# OI 54346900.0 37303050.0
# OI 54293350.0 37668150.0
# OI 54293350.0 37668150.0
# OI 54293350.0 37668150.0
# OI 53367700.0 37607650.0
# OI 53367700.0 37607650.0
# OI 53367700.0 37607650.0
# OI 53471950.0 38304000.0
# OI 53471950.0 38304000.0
# OI 53471950.0 38304000.0
# OI 53108650.0 38501800.0
# OI 53108650.0 38501800.0
# OI 53108650.0 38501800.0
# OI 52228150.0 37962000.0
# OI 52228150.0 37962000.0
# OI 52228150.0 37962000.0
# OI 53704250.0 32622600.0
# OI 53704250.0 32622600.0
# OI 53704250.0 32622600.0
# OI 52053450.0 32533300.0
# OI 52053450.0 32533300.0
# OI 52053450.0 32533300.0
# OI 51614800.0 33103400.0
# OI 51614800.0 33103400.0
# OI 49660600.0 38213350.0
# OI 49068000.0 37864600.0
# OI 49068000.0 37864600.0
# OI 49068000.0 37864600.0
# OI 49287600.0 38003650.0
# OI 49287600.0 38003650.0
# OI 51261050.0 33006100.0
# OI 51249350.0 32965250.0
# OI 51249350.0 32965250.0
# OI 51249350.0 32965250.0
# OI 50594350.0 32529500.0
# OI 50594350.0 32529500.0
# OI 50594350.0 32529500.0
# OI 49280750.0 32521850.0
# OI 49280750.0 32521850.0
# OI 49280750.0 32521850.0
# OI 47300650.0 32756000.0
# OI 47300650.0 32756000.0
# OI 47300650.0 32756000.0
# OI 47057700.0 32413550.0
# OI 47057700.0 32413550.0
# OI 47057700.0 32413550.0
# OI 46685800.0 32389350.0
# OI 46685800.0 32389350.0
# OI 46685800.0 32389350.0
# OI 46632750.0 32590250.0
# OI 46632750.0 32590250.0
# OI 46632750.0 32590250.0
# OI 46149250.0 32918300.0
# OI 46149250.0 32918300.0
# OI 46149250.0 32918300.0
# OI 46182800.0 33251550.0
# OI 46182800.0 33251550.0
# OI 46182800.0 33251550.0
# OI 46103750.0 33450000.0
# OI 46103750.0 33450000.0
# OI 46103750.0 33450000.0
# OI 45204350.0 33463150.0
# OI 45204350.0 33463150.0
# OI 45204350.0 33463150.0
# OI 44281450.0 33318050.0
# OI 44281450.0 33318050.0
# OI 44281450.0 33318050.0
# OI 44554650.0 33696800.0
# OI 44554650.0 33696800.0
# OI 44554650.0 33696800.0
# OI 44719150.0 33920300.0
# OI 44719150.0 33920300.0
# OI 49432600.0 31590500.0
# OI 49048700.0 31558450.0
# OI 49048700.0 31558450.0
# OI 49048700.0 31558450.0
# OI 48416450.0 31970050.0
# OI 48416450.0 31970050.0
# OI 43697150.0 34288650.0
# OI 43984550.0 34624600.0
# OI 43984550.0 34624600.0
# OI 43984550.0 34624600.0
# OI 44122000.0 34424450.0
# OI 44122000.0 34424450.0
# OI 44122000.0 34424450.0
# OI 44113100.0 34235000.0
# OI 44113100.0 34235000.0
# OI 44113100.0 34235000.0
# OI 43941850.0 33578850.0
# OI 43941850.0 33578850.0
# OI 43941850.0 33578850.0
# OI 44126600.0 33759600.0
# OI 44126600.0 33759600.0
# OI 44126600.0 33759600.0
# OI 44437050.0 33881950.0
# OI 44437050.0 33881950.0
# OI 44437050.0 33881950.0
# OI 44687300.0 33527700.0
# OI 44685400.0 33527700.0
# OI 44685400.0 33527700.0
# OI 44831250.0 32847800.0
# OI 42929000.0 38136750.0
# OI 44831250.0 32847800.0
# OI 44673800.0 31010350.0
# OI 44673800.0 31010350.0
# OI 44673800.0 31010350.0
# OI 45483700.0 30943350.0
# OI 45483700.0 30943350.0
# OI 45483700.0 30943350.0
# OI 45329850.0 30729300.0
# OI 45329850.0 30729300.0
# OI 45329850.0 30729300.0
# OI 45196700.0 30603700.0
# OI 45196700.0 30603700.0
# OI 45196700.0 30603700.0
# OI 45486750.0 31016350.0
# OI 45486750.0 31016350.0
# OI 45486750.0 31016350.0
# OI 45396500.0 31134450.0
# OI 45396500.0 31134450.0
# OI 45396500.0 31134450.0
# OI 45329150.0 31483050.0
# OI 45329150.0 31483050.0
# OI 45329150.0 31483050.0
# OI 45417600.0 31248850.0
# OI 45417600.0 31248850.0
# OI 45417600.0 31248850.0
# OI 45445600.0 31415650.0
# OI 45445600.0 31415650.0
# OI 45445600.0 31415650.0
# OI 45471200.0 31349950.0
# OI 45471200.0 31349950.0
# OI 45471200.0 31349950.0
# OI 44980300.0 30188600.0
# OI 44980300.0 30188600.0
# OI 44980300.0 30188600.0
# OI 45108550.0 30079300.0
# OI 45108550.0 30079300.0
# OI 45108550.0 30079300.0
# OI 44997800.0 30176750.0
# OI 43170750.0 35212300.0
# OI 44997800.0 30176750.0
# OI 44979250.0 30152950.0
# OI 43148800.0 35104500.0
# OI 43148800.0 35104500.0
# OI 42426100.0 34064700.0
# OI 42426100.0 34064700.0
# OI 42426100.0 34064700.0
# OI 42236500.0 33003350.0
# OI 42236500.0 33003350.0
# OI 42236500.0 33003350.0
# OI 42298550.0 33142050.0
# OI 42298550.0 33142050.0
# OI 44052250.0 28310700.0
# OI 43537950.0 28657400.0
# OI 43537950.0 28657400.0
# OI 43537950.0 28657400.0
# OI 43208500.0 28714600.0
# OI 43208500.0 28714600.0
# OI 43208500.0 28714600.0
# OI 43331250.0 28953450.0
# OI 41573550.0 33793500.0
# OI 41573550.0 33793500.0
# OI 41567450.0 33637450.0
# OI 41567450.0 33637450.0
# OI 41567450.0 33637450.0
# OI 41475050.0 33198850.0
# OI 41475050.0 33198850.0
# OI 41475050.0 33198850.0
# OI 41081450.0 32668000.0
# OI 41081450.0 32668000.0
# OI 41081450.0 32668000.0
# OI 42167550.0 27921900.0
# OI 42167550.0 27921900.0
# OI 42167550.0 27921900.0
# OI 41940550.0 27563550.0
# OI 41940550.0 27563550.0
# OI 41940550.0 27563550.0
# OI 41385450.0 26838300.0
# OI 41386100.0 26838300.0
# OI 41386100.0 26838300.0
# OI 40099850.0 26837050.0
# OI 40099850.0 26837050.0
# OI 40099850.0 26837050.0
# OI 38204450.0 27105600.0
# OI 38204450.0 27105600.0
# OI 38204450.0 27105600.0
# OI 41604000.0 26041000.0
# OI 37595450.0 27567200.0
# OI 37595450.0 27567200.0
# OI 36530350.0 27857650.0
# OI 36530350.0 27857650.0
# OI 36530350.0 27857650.0
# OI 34753800.0 27764700.0
# OI 34753800.0 27764700.0
# OI 34753800.0 27764700.0
# OI 33513400.0 26072600.0
# OI 33513400.0 26072600.0
# OI 33513400.0 26072600.0
# OI 32203300.0 24341550.0
# OI 32198350.0 24342500.0
# OI 32198350.0 24342500.0
# OI 30080650.0 22179900.0
# OI 30080650.0 22190550.0
# OI 30080650.0 22190550.0
# OI 28794150.0 20382150.0
# OI 28724650.0 20376700.0
# OI 28724650.0 20376700.0
# OI 27223050.0 18265450.0
# OI 27223050.0 18265450.0
# OI 26838050.0 17232700.0
# OI 26838050.0 17232700.0
#                     Ticker     Open     High      Low    Close  Volume  \
# Date/Time
# 2021-12-03 09:15:00  NIFTY  17424.9  17455.9  17415.9  17455.9       0
# 2021-12-03 09:16:00  NIFTY  17458.0  17479.5  17458.0  17476.3       0
# 2021-12-03 09:17:00  NIFTY  17476.4  17476.4  17452.7  17452.7       0
# 2021-12-03 09:18:00  NIFTY  17452.4  17467.0  17442.0  17466.3       0
# 2021-12-03 09:19:00  NIFTY  17467.6  17478.0  17467.0  17477.3       0
#
#                      Open Interest  INDIAVIX  ATM_Delta     ATM_OI  ...  \
# Date/Time                                                           ...
# 2021-12-03 09:15:00              0     18.02   0.544436   223900.0  ...
# 2021-12-03 09:16:00              0     18.13   0.534026  1641450.0  ...
# 2021-12-03 09:17:00              0     18.10   0.541019   413150.0  ...
# 2021-12-03 09:18:00              0     18.05   0.545529   413150.0  ...
# 2021-12-03 09:19:00              0     18.07   0.533874  1781650.0  ...
#
#                      OTM4_PE_Gamma  OTM4_PE_Theta  OTM4_PE_Vega  OTM4_PE_Rho  \
# Date/Time
# 2021-12-03 09:15:00       0.000064      -0.527784      0.090235    -0.017593
# 2021-12-03 09:16:00       0.000060      -0.561006      0.090222    -0.017803
# 2021-12-03 09:17:00       0.000066      -0.517535      0.090269    -0.017561
# 2021-12-03 09:18:00       0.000069      -0.493868      0.090425    -0.017453
# 2021-12-03 09:19:00       0.000061      -0.554157      0.090250    -0.017772
#
#                      OTM5_PE_Delta  OTM5_PE_OI  OTM5_PE_Gamma  OTM5_PE_Theta  \
# Date/Time
# 2021-12-03 09:15:00      -0.437058     63800.0       0.000058      -0.578080
# 2021-12-03 09:16:00      -0.430963     10750.0       0.000054      -0.627444
# 2021-12-03 09:17:00      -0.435766     68850.0       0.000058      -0.587378
# 2021-12-03 09:18:00      -0.439395     68850.0       0.000060      -0.560020
# 2021-12-03 09:19:00      -0.432752     11100.0       0.000055      -0.616164
#
#                      OTM5_PE_Vega  OTM5_PE_Rho
# Date/Time
# 2021-12-03 09:15:00      0.090065    -0.017900
# 2021-12-03 09:16:00      0.089934    -0.018160
# 2021-12-03 09:17:00      0.089991    -0.017933
# 2021-12-03 09:18:00      0.090187    -0.017815
# 2021-12-03 09:19:00      0.089994    -0.018113
#
# [5 rows x 163 columns]
# Greeks and Open Interest data have been populated and the DataFrame has been saved to CSV.

# %%
print(nifty_with_greeks.head())
# Out:
#                     Ticker     Open     High      Low    Close  Volume  \
# Date/Time
# 2021-12-03 09:15:00  NIFTY  17424.9  17455.9  17415.9  17455.9       0
# 2021-12-03 09:16:00  NIFTY  17458.0  17479.5  17458.0  17476.3       0
# 2021-12-03 09:17:00  NIFTY  17476.4  17476.4  17452.7  17452.7       0
# 2021-12-03 09:18:00  NIFTY  17452.4  17467.0  17442.0  17466.3       0
# 2021-12-03 09:19:00  NIFTY  17467.6  17478.0  17467.0  17477.3       0
#
#                      Open Interest  INDIAVIX  ATM_Delta     ATM_OI  ...  \
# Date/Time                                                           ...
# 2021-12-03 09:15:00              0     18.02   0.544436   223900.0  ...
# 2021-12-03 09:16:00              0     18.13   0.534026  1641450.0  ...
# 2021-12-03 09:17:00              0     18.10   0.541019   413150.0  ...
# 2021-12-03 09:18:00              0     18.05   0.545529   413150.0  ...
# 2021-12-03 09:19:00              0     18.07   0.533874  1781650.0  ...
#
#                      OTM4_PE_Theta  OTM4_PE_Vega  OTM4_PE_Rho  OTM5_PE_Delta  \
# Date/Time
# 2021-12-03 09:15:00      -0.527784      0.090235    -0.017593      -0.437058
# 2021-12-03 09:16:00      -0.561006      0.090222    -0.017803      -0.430963
# 2021-12-03 09:17:00      -0.517535      0.090269    -0.017561      -0.435766
# 2021-12-03 09:18:00      -0.493868      0.090425    -0.017453      -0.439395
# 2021-12-03 09:19:00      -0.554157      0.090250    -0.017772      -0.432752
#
#                      OTM5_PE_OI  OTM5_PE_Gamma  OTM5_PE_Theta  OTM5_PE_Vega  \
# Date/Time
# 2021-12-03 09:15:00     63800.0       0.000058      -0.578080      0.090065
# 2021-12-03 09:16:00     10750.0       0.000054      -0.627444      0.089934
# 2021-12-03 09:17:00     68850.0       0.000058      -0.587378      0.089991
# 2021-12-03 09:18:00     68850.0       0.000060      -0.560020      0.090187
# 2021-12-03 09:19:00     11100.0       0.000055      -0.616164      0.089994
#
#                      OTM5_PE_Rho  PCR_Volume
# Date/Time
# 2021-12-03 09:15:00    -0.017900    0.391401
# 2021-12-03 09:16:00    -0.018160    0.481277
# 2021-12-03 09:17:00    -0.017933    0.548286
# 2021-12-03 09:18:00    -0.017815    0.595565
# 2021-12-03 09:19:00    -0.018113    0.598725
#
# [5 rows x 164 columns]

# %%
print("PCR_Volume" in nifty_with_greeks.columns)
# Out:
# True

# %%
pd.set_option('display.max_columns', None)
print(nifty_with_greeks.columns.tolist())
# Out:
# ['Ticker', 'Open', 'High', 'Low', 'Close', 'Volume', 'Open Interest', 'INDIAVIX', 'ATM_Delta', 'ATM_OI', 'ATM_Call_Volume', 'ATM_Put_Volume', 'ATM_Gamma', 'ATM_Theta', 'ATM_Vega', 'ATM_Rho', 'ITM1_Delta', 'ITM1_OI', 'ITM1_Call_Volume', 'ITM1_Put_Volume', 'ITM1_Gamma', 'ITM1_Theta', 'ITM1_Vega', 'ITM1_Rho', 'OTM1_Delta', 'OTM1_OI', 'OTM1_Call_Volume', 'OTM1_Put_Volume', 'OTM1_Gamma', 'OTM1_Theta', 'OTM1_Vega', 'OTM1_Rho', 'ITM2_Delta', 'ITM2_OI', 'ITM2_Call_Volume', 'ITM2_Put_Volume', 'ITM2_Gamma', 'ITM2_Theta', 'ITM2_Vega', 'ITM2_Rho', 'OTM2_Delta', 'OTM2_OI', 'OTM2_Call_Volume', 'OTM2_Put_Volume', 'OTM2_Gamma', 'OTM2_Theta', 'OTM2_Vega', 'OTM2_Rho', 'ITM3_Delta', 'ITM3_OI', 'ITM3_Call_Volume', 'ITM3_Put_Volume', 'ITM3_Gamma', 'ITM3_Theta', 'ITM3_Vega', 'ITM3_Rho', 'OTM3_Delta', 'OTM3_OI', 'OTM3_Call_Volume', 'OTM3_Put_Volume', 'OTM3_Gamma', 'OTM3_Theta', 'OTM3_Vega', 'OTM3_Rho', 'ITM4_Delta', 'ITM4_OI', 'ITM4_Call_Volume', 'ITM4_Put_Volume', 'ITM4_Gamma', 'ITM4_Theta', 'ITM4_Vega', 'ITM4_Rho', 'OTM4_Delta', 'OTM4_OI', 'OTM4_Call_Volume', 'OTM4_Put_Volume', 'OTM4_Gamma', 'OTM4_Theta', 'OTM4_Vega', 'OTM4_Rho', 'ITM5_Delta', 'ITM5_OI', 'ITM5_Call_Volume', 'ITM5_Put_Volume', 'ITM5_Gamma', 'ITM5_Theta', 'ITM5_Vega', 'ITM5_Rho', 'OTM5_Delta', 'OTM5_OI', 'OTM5_Call_Volume', 'OTM5_Put_Volume', 'OTM5_Gamma', 'OTM5_Theta', 'OTM5_Vega', 'OTM5_Rho', 'PCR', 'ATM_PE_Delta', 'ATM_PE_OI', 'ATM_PE_Gamma', 'ATM_PE_Theta', 'ATM_PE_Vega', 'ATM_PE_Rho', 'ITM1_PE_Delta', 'ITM1_PE_OI', 'ITM1_PE_Gamma', 'ITM1_PE_Theta', 'ITM1_PE_Vega', 'ITM1_PE_Rho', 'ITM2_PE_Delta', 'ITM2_PE_OI', 'ITM2_PE_Gamma', 'ITM2_PE_Theta', 'ITM2_PE_Vega', 'ITM2_PE_Rho', 'ITM3_PE_Delta', 'ITM3_PE_OI', 'ITM3_PE_Gamma', 'ITM3_PE_Theta', 'ITM3_PE_Vega', 'ITM3_PE_Rho', 'ITM4_PE_Delta', 'ITM4_PE_OI', 'ITM4_PE_Gamma', 'ITM4_PE_Theta', 'ITM4_PE_Vega', 'ITM4_PE_Rho', 'ITM5_PE_Delta', 'ITM5_PE_OI', 'ITM5_PE_Gamma', 'ITM5_PE_Theta', 'ITM5_PE_Vega', 'ITM5_PE_Rho', 'OTM1_PE_Delta', 'OTM1_PE_OI', 'OTM1_PE_Gamma', 'OTM1_PE_Theta', 'OTM1_PE_Vega', 'OTM1_PE_Rho', 'OTM2_PE_Delta', 'OTM2_PE_OI', 'OTM2_PE_Gamma', 'OTM2_PE_Theta', 'OTM2_PE_Vega', 'OTM2_PE_Rho', 'OTM3_PE_Delta', 'OTM3_PE_OI', 'OTM3_PE_Gamma', 'OTM3_PE_Theta', 'OTM3_PE_Vega', 'OTM3_PE_Rho', 'OTM4_PE_Delta', 'OTM4_PE_OI', 'OTM4_PE_Gamma', 'OTM4_PE_Theta', 'OTM4_PE_Vega', 'OTM4_PE_Rho', 'OTM5_PE_Delta', 'OTM5_PE_OI', 'OTM5_PE_Gamma', 'OTM5_PE_Theta', 'OTM5_PE_Vega', 'OTM5_PE_Rho', 'PCR_Volume']
