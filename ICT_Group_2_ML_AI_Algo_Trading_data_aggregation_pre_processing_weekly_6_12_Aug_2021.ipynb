# %% [markdown]
# <a href="https://colab.research.google.com/github/jjikku/OptiGene-Algo/blob/main/ICT_Group_2_ML_AI_Algo_Trading_data_aggregation_pre_processing_weekly_6_12_Aug_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# Specify the exact path to the CSV file
file_path = "/content/drive/My Drive/NIfty_Dataset/06_12_AUG_2021_weekly_expiryWEEKdata_VEGE_NF_AND_BNF_Options.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Exclude rows where the ticker contains any of the following
excluded_tickers = [
    "BANKNIFTY", "FINNIFTY", "FUT", "NIFTYAUTO", "NIFTYENERGY",
    "NIFTYFINSERVICE", "NIFTYFMCG", "NIFTYINFRA", "NIFTYIT", "NIFTYMEDIA",
    "NIFTYMETAL", "NIFTYMIDCAP50", "NIFTYPHARMA", "NIFTYPSUBANK",
    "NIFTYREALTY", "USDINR-I"
]

# Create a regular expression pattern that matches any of the excluded tickers
pattern = '|'.join(excluded_tickers)

# Apply the mask to filter the DataFrame
mask = ~df['Ticker'].str.contains(pattern)
df_filtered = df[mask]

# Get unique values in the 'Ticker' column after filtering
unique_tickers = df_filtered['Ticker'].unique()

# Extract all rows that match the unique tickers
final_df = df[df['Ticker'].isin(unique_tickers)]

# Create a new CSV file with the extracted rows
output_file_path = "/content/drive/My Drive/NIfty_Dataset/weekly_filtered_tickers_data_06_12_AUG.csv"
final_df.to_csv(output_file_path, index=False)

print(f"Created new CSV file at: {output_file_path}")
# Out:
# Mounted at /content/drive
# Created new CSV file at: /content/drive/My Drive/NIfty_Dataset/weekly_filtered_tickers_data_06_12_AUG.csv

# %%
# print(unique_tickers)

# %%
# final_df.count()

# %%
# final_df['Open Interest'].count()

# %%
# non_zero_count = final_df['Open Interest'].ne(0).sum()
# print(f"The count of non-zero 'Open Interest' values is: {non_zero_count}")

# %%
# Create a separate DataFrame for each unique ticker and store it in a dictionary
dfs = {ticker: df[df['Ticker'] == ticker] for ticker in unique_tickers}

# Now dfs is a dictionary with tickers as keys and the corresponding DataFrame as values

# Assuming df is your original DataFrame with all tickers
for ticker in unique_tickers:
    # Select the DataFrame for the current ticker
    ticker_df = df[df['Ticker'] == ticker].copy()  # Use copy to avoid SettingWithCopyWarning

    # Convert 'Date/Time' to datetime and set as index
    ticker_df['Date/Time'] = pd.to_datetime(ticker_df['Date/Time'], format='%d-%m-%Y %H:%M:%S')
    ticker_df.set_index('Date/Time', inplace=True)

    # Remove duplicate indices if any
    ticker_df = ticker_df[~ticker_df.index.duplicated(keep='first')]

    # Assign the processed DataFrame back to the dfs dictionary
    dfs[ticker] = ticker_df

# Now dfs is a dictionary where each value is a DataFrame with 'Date/Time' as a datetime index

# %%
# Iterate through the dfs dictionary
for ticker, dataframe in dfs.items():
    # Check if the ticker ends with 'PE' or 'CE'
    if ticker.endswith('PE') or ticker.endswith('CE'):
        # Forward fill any NaN values
        dataframe['Open Interest'] = dataframe['Open Interest'].fillna(method='ffill')

        # Replace zero values with the forward filled values
        dataframe['Open Interest'] = dataframe['Open Interest'].replace(to_replace=0, method='ffill')

        # Assign the processed DataFrame back to the dfs dictionary
        dfs[ticker] = dataframe

# %%
import numpy as np
# Get the DataFrame for NIFTY as the reference
reference_df = dfs['NIFTY'].copy()

# Get all timestamps from the NIFTY DataFrame
reference_timestamps = reference_df.index
print("REF",reference_timestamps)

# Function to insert missing timestamps into a DataFrame
def insert_missing_timestamps(df, reference_ts):
    # Ensure the DataFrame index is unique and sorted
    df = df[~df.index.duplicated(keep='first')].sort_index()

    # Find the missing timestamps
    missing_timestamps = reference_ts.difference(df.index)

    # Insert rows with NaNs for missing timestamps
    for ts in missing_timestamps:
        if ts not in df.index:
            df.loc[ts] = [np.nan] * len(df.columns)

    # Sort the DataFrame after inserting new rows
    df.sort_index(inplace=True)

    return df

# Iterate over each DataFrame in dfs
for ticker, dataframe in dfs.items():
    if ticker != 'NIFTY':  # Skip the NIFTY DataFrame as it is the reference
        # Insert missing timestamps without altering existing data
        print("TICKER",ticker)
        dfs[ticker] = insert_missing_timestamps(dataframe, reference_timestamps)
# Out:
# REF DatetimeIndex(['2021-08-06 09:15:00', '2021-08-06 09:16:00',
#                '2021-08-06 09:17:00', '2021-08-06 09:18:00',
#                '2021-08-06 09:19:00', '2021-08-06 09:20:00',
#                '2021-08-06 09:21:00', '2021-08-06 09:22:00',
#                '2021-08-06 09:23:00', '2021-08-06 09:24:00',
#                ...
#                '2021-08-12 15:21:00', '2021-08-12 15:22:00',
#                '2021-08-12 15:23:00', '2021-08-12 15:24:00',
#                '2021-08-12 15:25:00', '2021-08-12 15:26:00',
#                '2021-08-12 15:27:00', '2021-08-12 15:28:00',
#                '2021-08-12 15:29:00', '2021-08-12 15:30:00'],
#               dtype='datetime64[ns]', name='Date/Time', length=1879, freq=None)
# TICKER INDIAVIX
# TICKER NIFTYWK15000CE
# TICKER NIFTYWK15000PE
# TICKER NIFTYWK15050CE
# TICKER NIFTYWK15050PE
# TICKER NIFTYWK15100CE
# TICKER NIFTYWK15100PE
# TICKER NIFTYWK15150CE
# TICKER NIFTYWK15150PE
# TICKER NIFTYWK15200CE
# TICKER NIFTYWK15200PE
# TICKER NIFTYWK15250CE
# TICKER NIFTYWK15250PE
# TICKER NIFTYWK15300CE
# TICKER NIFTYWK15300PE
# TICKER NIFTYWK15350CE
# TICKER NIFTYWK15350PE
# TICKER NIFTYWK15400CE
# TICKER NIFTYWK15400PE
# TICKER NIFTYWK15450CE
# TICKER NIFTYWK15450PE
# TICKER NIFTYWK15500CE
# TICKER NIFTYWK15500PE
# TICKER NIFTYWK15550CE
# TICKER NIFTYWK15550PE
# TICKER NIFTYWK15600CE
# TICKER NIFTYWK15600PE
# TICKER NIFTYWK15650CE
# TICKER NIFTYWK15650PE
# TICKER NIFTYWK15700CE
# TICKER NIFTYWK15700PE
# TICKER NIFTYWK15750CE
# TICKER NIFTYWK15750PE
# TICKER NIFTYWK15800CE
# TICKER NIFTYWK15800PE
# TICKER NIFTYWK15850CE
# TICKER NIFTYWK15850PE
# TICKER NIFTYWK15900CE
# TICKER NIFTYWK15900PE
# TICKER NIFTYWK15950CE
# TICKER NIFTYWK15950PE
# TICKER NIFTYWK16000CE
# TICKER NIFTYWK16000PE
# TICKER NIFTYWK16050CE
# TICKER NIFTYWK16050PE
# TICKER NIFTYWK16100CE
# TICKER NIFTYWK16100PE
# TICKER NIFTYWK16150CE
# TICKER NIFTYWK16150PE
# TICKER NIFTYWK16200CE
# TICKER NIFTYWK16200PE
# TICKER NIFTYWK16250CE
# TICKER NIFTYWK16250PE
# TICKER NIFTYWK16300CE
# TICKER NIFTYWK16300PE
# TICKER NIFTYWK16350CE
# TICKER NIFTYWK16350PE
# TICKER NIFTYWK16400CE
# TICKER NIFTYWK16400PE
# TICKER NIFTYWK16450CE
# TICKER NIFTYWK16450PE
# TICKER NIFTYWK16500CE
# TICKER NIFTYWK16500PE
# TICKER NIFTYWK16550CE
# TICKER NIFTYWK16550PE
# TICKER NIFTYWK16600CE
# TICKER NIFTYWK16600PE
# TICKER NIFTYWK16650CE
# TICKER NIFTYWK16650PE

# %%
# # Define trading hours
# trading_hours = pd.date_range(start='09:15:00', end='15:30:00', freq='1min')

# # Get the DataFrame for NIFTY as the reference
# reference_df = dfs['NIFTY'].copy()

# # Generate a full range of timestamps for all trading days in the reference NIFTY DataFrame
# all_trading_days = reference_df.index.normalize().unique()
# all_possible_timestamps = pd.DatetimeIndex([pd.Timestamp(day) + pd.Timedelta(minutes=m.minute + m.hour * 60)
#                                             for day in all_trading_days for m in trading_hours])

# # Now update all DataFrames in dfs to have the same timestamps as the reference NIFTY DataFrame
# for ticker, dataframe in dfs.items():
#     # Reindex to the full range of possible timestamps, forward filling the missing data
#     dataframe = dataframe.reindex(all_possible_timestamps, method='ffill')

#     # Forward fill the Open Interest, if the ticker ends with 'PE' or 'CE'
#     if ticker.endswith(('PE', 'CE')):
#         dataframe['Open Interest'].fillna(method='ffill', inplace=True)
#         dataframe['Open Interest'].replace(to_replace=0, method='ffill', inplace=True)

#     # Update the dictionary with the modified DataFrame
#     dfs[ticker] = dataframe

# # After this loop, each DataFrame in dfs should have no missing timestamps and the 'Open Interest' column should be forward filled.

# %%
# Define the market open and close times
market_open_time = '09:15:00'
market_close_time = '15:30:00'

# Create a new dictionary to store the filled DataFrames
filled_dfs = {}

for ticker, dataframe in dfs.items():
    # Copy the DataFrame to avoid modifying the original
    df_filled = dataframe.copy()

    # Get unique trading days
    trading_days = df_filled.index.normalize().unique()

    # Forward fill for each day
    for day in trading_days:
        # Select the data for the current trading day
        day_data = df_filled[df_filled.index.date == day.date()]

        # Forward fill the data for the current day
        df_filled.loc[day_data.index] = day_data.fillna(method='ffill')

    # Now, backward fill the entire DataFrame to cover the start of the day
    df_filled = df_filled.fillna(method='bfill')

    # Assign the filled DataFrame to the new dictionary
    filled_dfs[ticker] = df_filled

# %%
# Assuming filled_dfs is your dictionary containing DataFrames with filled values
for ticker in unique_tickers:
    # Select the DataFrame for the current ticker
    ticker_df = filled_dfs[ticker].copy()  # Use copy to avoid SettingWithCopyWarning

    # Since filled_dfs already contains the DataFrames with 'Date/Time' as a datetime index,
    #  do not need to convert 'Date/Time' again, and  can use ticker_df directly if needed

    # Remove duplicate indices if any (if this step is still necessary)
    ticker_df = ticker_df[~ticker_df.index.duplicated(keep='first')]


    # Assign the processed DataFrame back to the dfs dictionary
    dfs[ticker] = ticker_df

# Now dfs is a dictionary where each value is a DataFrame with 'Date/Time' as a datetime index

# %%
print(dfs['NIFTY'])
# Out:
#                     Ticker     Open     High      Low    Close  Volume  \
# Date/Time
# 2021-08-06 09:15:00  NIFTY  16304.4  16304.4  16274.9  16289.0       0
# 2021-08-06 09:16:00  NIFTY  16290.0  16314.9  16285.7  16312.1       0
# 2021-08-06 09:17:00  NIFTY  16310.6  16312.0  16303.9  16307.6       0
# 2021-08-06 09:18:00  NIFTY  16306.4  16317.5  16301.9  16317.5       0
# 2021-08-06 09:19:00  NIFTY  16317.8  16318.6  16313.0  16316.3       0
# ...                    ...      ...      ...      ...      ...     ...
# 2021-08-12 15:26:00  NIFTY  16366.4  16367.0  16363.3  16364.6       0
# 2021-08-12 15:27:00  NIFTY  16364.1  16366.8  16364.1  16366.5       0
# 2021-08-12 15:28:00  NIFTY  16364.8  16366.9  16359.9  16361.3       0
# 2021-08-12 15:29:00  NIFTY  16360.8  16363.1  16356.9  16361.4       0
# 2021-08-12 15:30:00  NIFTY  16359.9  16359.9  16359.9  16359.9       1
#
#                      Open Interest
# Date/Time
# 2021-08-06 09:15:00              0
# 2021-08-06 09:16:00              0
# 2021-08-06 09:17:00              0
# 2021-08-06 09:18:00              0
# 2021-08-06 09:19:00              0
# ...                            ...
# 2021-08-12 15:26:00              0
# 2021-08-12 15:27:00              0
# 2021-08-12 15:28:00              0
# 2021-08-12 15:29:00              0
# 2021-08-12 15:30:00              0
#
# [1879 rows x 7 columns]

# %%
# Assuming dfs['NIFTY'] is the DataFrame you want to save
nifty_df = dfs['NIFTY']

# Specify the path in your Google Drive where you want to save the CSV
csv_file_path = '/content/drive/My Drive/NIfty_Dataset/NIFTY_06_12_AUG_2021.csv'

# Save the DataFrame to CSV
nifty_df.to_csv(csv_file_path, index=True)

print(f"DataFrame saved to {csv_file_path}")
# Out:
# DataFrame saved to /content/drive/My Drive/NIfty_Dataset/NIFTY_06_12_AUG_2021.csv

# %%
# Assuming dfs['NIFTY'] is the DataFrame you want to save
indiavix_df = dfs['INDIAVIX']

# Specify the path in your Google Drive where you want to save the CSV
csv_file_path = '/content/drive/My Drive/NIfty_Dataset/INDIAVIX_06_12_AUG_2021.csv'

# Save the DataFrame to CSV
indiavix_df.to_csv(csv_file_path, index=True)

print(f"DataFrame saved to {csv_file_path}")
# Out:
# DataFrame saved to /content/drive/My Drive/NIfty_Dataset/INDIAVIX_06_12_AUG_2021.csv

# %%
# !pip install mibian
# Out:
# Collecting mibian
#   Downloading mibian-0.1.3.zip (4.3 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mibian
#   Building wheel for mibian (setup.py) ... done
#   Created wheel for mibian: filename=mibian-0.1.3-py3-none-any.whl size=4024 sha256=74664ff9fb1d9bdda95570635b6b9a9e71cf683e560eef81d0b0442c469bcab2
#   Stored in directory: /root/.cache/pip/wheels/2c/4f/a7/be034e17cc306b0850f5f1a5b4541281b49475c58620a7ff40
# Successfully built mibian
# Installing collected packages: mibian
# Successfully installed mibian-0.1.3

# %%
indiavix_df = pd.read_csv('/content/drive/My Drive/NIfty_Dataset/INDIAVIX_06_12_AUG_2021.csv')
# Print the columns to check the exact name of the 'Date/Time' column
print(indiavix_df.columns)
# Out:
# Index(['Date/Time', 'Ticker', 'Open', 'High', 'Low', 'Close', 'Volume',
#        'Open Interest'],
#       dtype='object')

# %%
print(indiavix_df.index)
# Out:
# RangeIndex(start=0, stop=1879, step=1)

# %%
# !pip install datetime
# Out:
# Collecting datetime
#   Downloading DateTime-5.3-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 1.5 MB/s eta 0:00:00
# Collecting zope.interface (from datetime)
#   Downloading zope.interface-6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from datetime) (2023.3.post1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from zope.interface->datetime) (67.7.2)
# Installing collected packages: zope.interface, datetime
# Successfully installed datetime-5.3 zope.interface-6.1

# %%
import pandas as pd
import numpy as np
import mibian
from datetime import time, datetime, timedelta


indiavix_df = pd.read_csv('/content/drive/My Drive/NIfty_Dataset/INDIAVIX_06_12_AUG_2021.csv', index_col='Date/Time', parse_dates=['Date/Time'])
indiavix_df.rename(columns={'Close': 'INDIAVIX'}, inplace=True)

# Load the NIFTY data
nifty_df = pd.read_csv('/content/drive/My Drive/NIfty_Dataset/NIFTY_06_12_AUG_2021.csv', index_col='Date/Time', parse_dates=['Date/Time'])

# Join INDIAVIX data with NIFTY data
nifty_df = nifty_df.join(indiavix_df['INDIAVIX'], how='left')
nifty_df['INDIAVIX'].fillna(method='ffill', inplace=True)  # Fill NaN values with the forward fill method


# Check if the 'INDIAVIX' column exists after the join operation
if 'INDIAVIX' not in nifty_df.columns:
    raise KeyError('The INDIAVIX column was not found after the join operation. Please check the column names and join operation.')

print("NIFTYDF",nifty_df)
print("columns",nifty_df.columns)

# Constants
interest_rate = 3.32  # 3-month Indian government bond yield as annual percentage
days_in_year = 365  # Days in a year for the Greeks' calculations
strike_step = 50  # Known step between strike prices
minutes_in_a_year = 365 * 24 * 60  # Total minutes in a year
market_close_time = time(15, 30)



def calculate_minutes_to_expiry(current_timestamp, expiry_date, market_close_time):
    # Ensure market_close_time is a datetime.time object
    if isinstance(market_close_time, pd.Timestamp):
        market_close_time = market_close_time.time()

    closing_time = datetime.combine(expiry_date, market_close_time)

    # If the current timestamp is on the expiry date
    if current_timestamp.date() == expiry_date.date():
        # Calculate the remaining time until market close
        return max(int((closing_time - current_timestamp).total_seconds() / 60), 0)
    else:
        # Calculate time from the current timestamp to the end of day
        end_of_day = datetime.combine(current_timestamp.date(), time(23, 59))  # Last minute of the current day
        minutes_today = int((end_of_day - current_timestamp).total_seconds() / 60) + 1  # Plus one for the last minute

        # Calculate full days until the expiry date
        full_days = (expiry_date.date() - current_timestamp.date()).days - 1  # Minus one because we already counted today

        # Calculate minutes from the start of the expiry day to the market close
        start_of_expiry_day = datetime.combine(expiry_date.date(), time(0, 0))  # Midnight of the expiry day
        minutes_expiry_day = int((closing_time - start_of_expiry_day).total_seconds() / 60)

        # Total minutes is the sum of all parts
        return minutes_today + (full_days * 24 * 60) + minutes_expiry_day


# Function to calculate the Greeks using the Black-Scholes model
def calculate_greeks(underlying_price, strike_price, minutes_to_expiry, volatility, interest_rate, option_type):
    # Convert minutes to expiry into years for the Black-Scholes model
    time_to_expiry_in_years = minutes_to_expiry / minutes_in_a_year

    # Ensure we do not have a division by zero or negative time to expiry
    if time_to_expiry_in_years <= 0:
        return {greek: 0 for greek in ['Delta', 'Gamma', 'Theta', 'Vega', 'Rho']}

    # Convert annual interest rate and volatility from percentages to decimals
    annual_interest_rate = interest_rate / 100
    annual_volatility = volatility / 100

    # Black-Scholes model calculations
    bs = mibian.BS([underlying_price, strike_price, annual_interest_rate * 100, time_to_expiry_in_years * 365], volatility=annual_volatility * 100)

    # Return a dictionary of Greeks
    return {
        'Delta': bs.callDelta if option_type == 'call' else bs.putDelta,
        'Gamma': bs.gamma,
        'Theta': bs.callTheta / 365 if option_type == 'call' else bs.putTheta / 365,
        'Vega': bs.vega / 100,  # per 1% change in IV
        'Rho': bs.callRho / 100 if option_type == 'call' else bs.putRho / 100  # per 1% change in interest rate
    }


# Function to populate the DataFrame with strikes and Greeks
def populate_greeks(nifty_df, indiavix_df, strike_step, dfs):

    expiry_date = nifty_df.index.max().normalize() + pd.Timedelta(hours=15, minutes=30)
    print("EXPIRY DAY", expiry_date)
    market_close_time = expiry_date #pd.to_datetime(expiry_date.strftime('%Y-%m-%d') + ' 15:30:00')  # Assuming 3:30 PM market close

    # Create columns for Greeks in the dataframe
    for strike_type in ['ATM', 'ITM1', 'OTM1', 'ITM2', 'OTM2', 'ITM3', 'OTM3', 'ITM4', 'OTM4', 'ITM5', 'OTM5']:
        for greek in ['Delta', 'Gamma', 'Theta', 'Vega', 'Rho']:
            nifty_df[f'{strike_type}_{greek}'] = np.nan
            nifty_df[f'{strike_type}_OI'] = np.nan
            nifty_df[f'{strike_type}_Call_Volume'] = np.nan
            nifty_df[f'{strike_type}_Put_Volume'] = np.nan

    nifty_df['PCR'] = np.nan

    # Iterate over the dataframe and calculate Greeks
    for timestamp, row in nifty_df.iterrows():
        total_call_oi = 0
        total_put_oi = 0
        nifty_close = row['Close']
        # Find ATM, ITM, and OTM strikes
        atm_strike = int(round(nifty_close / strike_step) * strike_step)  # Closest strike
        itm_strikes = [atm_strike - i * strike_step for i in range(1, 6)]
        otm_strikes = [atm_strike + i * strike_step for i in range(1, 6)]
        all_strikes = [atm_strike] + itm_strikes + otm_strikes

        print(f"Processing timestamp: {timestamp}")

        # Get VIX value for the timestamp
        vix_value = indiavix_df.loc[timestamp, 'INDIAVIX'] if timestamp in indiavix_df.index else np.nan
        if vix_value is None:
            print(f"VIX value is missing for timestamp: {timestamp}")
            continue  # Skip this iteration if VIX value is missing


        minutes_to_expiry = calculate_minutes_to_expiry(timestamp, expiry_date, market_close_time)
        print("Current time & days to expiry:", timestamp.date(), minutes_to_expiry / (60 * 24))

        print("Curr time & days to EXpiry", timestamp.date(),minutes_to_expiry/(60*24))
        # Calculate Greeks for all strikes
        for i, strike in enumerate(all_strikes, start=1):
            if i == 1:  # ATM
                strike_type = 'ATM'
            elif i <= 6:  # ITM strikes
                strike_type = f'ITM{i-1}'
            else:  # OTM strikes
                strike_type = f'OTM{i-6}'

            call_key = f'NIFTYWK{strike}CE'
            put_key = f'NIFTYWK{strike}PE'

            call_volume = dfs[call_key].loc[timestamp, 'Volume'] if timestamp in dfs[call_key].index else np.nan
            put_volume = dfs[put_key].loc[timestamp, 'Volume'] if timestamp in dfs[put_key].index else np.nan

            # Populate volume data
            nifty_df.at[timestamp, f'{strike_type}_Call_Volume'] = call_volume
            nifty_df.at[timestamp, f'{strike_type}_Put_Volume'] = put_volume

            # print(f"Retrieving data for strike {strike} ({call_key} and {put_key})")

             # Check if the keys are present in the dfs dictionary
            if call_key not in dfs or put_key not in dfs:
                print(f"Missing data for strike {strike}: {call_key} or {put_key} not in dfs")
                continue

            # Check if the timestamp exists in the dfs DataFrames
            if timestamp not in dfs[call_key].index:
                print(f"Timestamp {timestamp} not found in dfs for {call_key}")
                continue
            if timestamp not in dfs[put_key].index:
                print(f"Timestamp {timestamp} not found in dfs for {put_key}")
                continue

            call_close = dfs[call_key].loc[timestamp, 'Close'] if timestamp in dfs[call_key].index else np.nan
            put_close = dfs[put_key].loc[timestamp, 'Close'] if timestamp in dfs[put_key].index else np.nan
            call_oi = dfs[call_key].loc[timestamp, 'Open Interest'] if timestamp in dfs[call_key].index else np.nan
            put_oi = dfs[put_key].loc[timestamp, 'Open Interest'] if timestamp in dfs[put_key].index else np.nan
            # print(f"Call Close: {call_close}, Put Close: {put_close}, Call OI: {call_oi}, Put OI: {put_oi}")

            #print("STRIKE",nifty_close, strike)
            # Calculate Greeks using the close prices
            if not np.isnan(call_close):
                greeks = calculate_greeks(nifty_close, strike, minutes_to_expiry, call_close, interest_rate, option_type='call')
                # Populate Greeks for call
                for greek_name, greek_value in greeks.items():
                    nifty_df.at[timestamp, f'{strike_type}_{greek_name}'] = greek_value
                    nifty_df.at[timestamp, f'{strike_type}_OI'] = call_oi  # Populate OI for call

            if not np.isnan(put_close):
                greeks = calculate_greeks(nifty_close, strike, minutes_to_expiry, put_close, interest_rate, option_type='put')
                # Populate Greeks for put
                for greek_name, greek_value in greeks.items():
                    nifty_df.at[timestamp, f'{strike_type}_PE_{greek_name}'] = greek_value
                    nifty_df.at[timestamp, f'{strike_type}_PE_OI'] = put_oi  # Populate OI for put

    return nifty_df

# Populate the DataFrame with Greeks
nifty_with_greeks = populate_greeks(nifty_df, indiavix_df, strike_step, dfs)

def calculate_pcr(row):
    total_call_oi = sum(row.get(f'{strike}_OI', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    total_put_oi = sum(row.get(f'{strike}_PE_OI', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    print("OI", total_call_oi, total_put_oi)
    return total_put_oi / total_call_oi if total_call_oi != 0 else np.nan

# Function to calculate PCR for volume
def calculate_pcr_volume(row):
    total_call_volume = sum(row.get(f'{strike}_Call_Volume', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    total_put_volume = sum(row.get(f'{strike}_Put_Volume', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    return total_put_volume / total_call_volume if total_call_volume != 0 else np.nan

# Apply PCR calculation to each row
nifty_with_greeks['PCR'] = nifty_with_greeks.apply(calculate_pcr, axis=1)
print(nifty_with_greeks.head())
# Apply PCR calculation for volume to each row
nifty_with_greeks['PCR_Volume'] = nifty_with_greeks.apply(calculate_pcr_volume, axis=1)
# # Output the DataFrame to a CSV
nifty_with_greeks.to_csv('/content/drive/My Drive/NIfty_Dataset/NIFTY_with_Greeks_06_12_AUG_2021.csv')

print("Greeks and Open Interest data have been populated and the DataFrame has been saved to CSV.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Curr time & days to EXpiry 2021-08-10 2.1902777777777778
# Processing timestamp: 2021-08-10 10:57:00
# Current time & days to expiry: 2021-08-10 2.189583333333333
# Curr time & days to EXpiry 2021-08-10 2.189583333333333
# Processing timestamp: 2021-08-10 10:58:00
# Current time & days to expiry: 2021-08-10 2.188888888888889
# Curr time & days to EXpiry 2021-08-10 2.188888888888889
# Processing timestamp: 2021-08-10 10:59:00
# Current time & days to expiry: 2021-08-10 2.1881944444444446
# Curr time & days to EXpiry 2021-08-10 2.1881944444444446
# Processing timestamp: 2021-08-10 11:00:00
# Current time & days to expiry: 2021-08-10 2.1875
# Curr time & days to EXpiry 2021-08-10 2.1875
# Processing timestamp: 2021-08-10 11:01:00
# Current time & days to expiry: 2021-08-10 2.1868055555555554
# Curr time & days to EXpiry 2021-08-10 2.1868055555555554
# Processing timestamp: 2021-08-10 11:02:00
# Current time & days to expiry: 2021-08-10 2.186111111111111
# Curr time & days to EXpiry 2021-08-10 2.186111111111111
# Processing timestamp: 2021-08-10 11:03:00
# Current time & days to expiry: 2021-08-10 2.185416666666667
# Curr time & days to EXpiry 2021-08-10 2.185416666666667
# Processing timestamp: 2021-08-10 11:04:00
# Current time & days to expiry: 2021-08-10 2.1847222222222222
# Curr time & days to EXpiry 2021-08-10 2.1847222222222222
# Processing timestamp: 2021-08-10 11:05:00
# Current time & days to expiry: 2021-08-10 2.1840277777777777
# Curr time & days to EXpiry 2021-08-10 2.1840277777777777
# Processing timestamp: 2021-08-10 11:06:00
# Current time & days to expiry: 2021-08-10 2.183333333333333
# Curr time & days to EXpiry 2021-08-10 2.183333333333333
# Processing timestamp: 2021-08-10 11:07:00
# Current time & days to expiry: 2021-08-10 2.182638888888889
# Curr time & days to EXpiry 2021-08-10 2.182638888888889
# Processing timestamp: 2021-08-10 11:08:00
# Current time & days to expiry: 2021-08-10 2.1819444444444445
# Curr time & days to EXpiry 2021-08-10 2.1819444444444445
# Processing timestamp: 2021-08-10 11:09:00
# Current time & days to expiry: 2021-08-10 2.18125
# Curr time & days to EXpiry 2021-08-10 2.18125
# Processing timestamp: 2021-08-10 11:10:00
# Current time & days to expiry: 2021-08-10 2.1805555555555554
# Curr time & days to EXpiry 2021-08-10 2.1805555555555554
# Processing timestamp: 2021-08-10 11:11:00
# Current time & days to expiry: 2021-08-10 2.1798611111111112
# Curr time & days to EXpiry 2021-08-10 2.1798611111111112
# Processing timestamp: 2021-08-10 11:12:00
# Current time & days to expiry: 2021-08-10 2.1791666666666667
# Curr time & days to EXpiry 2021-08-10 2.1791666666666667
# Processing timestamp: 2021-08-10 11:13:00
# Current time & days to expiry: 2021-08-10 2.178472222222222
# Curr time & days to EXpiry 2021-08-10 2.178472222222222
# Processing timestamp: 2021-08-10 11:14:00
# Current time & days to expiry: 2021-08-10 2.1777777777777776
# Curr time & days to EXpiry 2021-08-10 2.1777777777777776
# Processing timestamp: 2021-08-10 11:15:00
# Current time & days to expiry: 2021-08-10 2.1770833333333335
# Curr time & days to EXpiry 2021-08-10 2.1770833333333335
# Processing timestamp: 2021-08-10 11:16:00
# Current time & days to expiry: 2021-08-10 2.176388888888889
# Curr time & days to EXpiry 2021-08-10 2.176388888888889
# Processing timestamp: 2021-08-10 11:17:00
# Current time & days to expiry: 2021-08-10 2.1756944444444444
# Curr time & days to EXpiry 2021-08-10 2.1756944444444444
# Processing timestamp: 2021-08-10 11:18:00
# Current time & days to expiry: 2021-08-10 2.175
# Curr time & days to EXpiry 2021-08-10 2.175
# Processing timestamp: 2021-08-10 11:19:00
# Current time & days to expiry: 2021-08-10 2.1743055555555557
# Curr time & days to EXpiry 2021-08-10 2.1743055555555557
# Processing timestamp: 2021-08-10 11:20:00
# Current time & days to expiry: 2021-08-10 2.173611111111111
# Curr time & days to EXpiry 2021-08-10 2.173611111111111
# Processing timestamp: 2021-08-10 11:21:00
# Current time & days to expiry: 2021-08-10 2.1729166666666666
# Curr time & days to EXpiry 2021-08-10 2.1729166666666666
# Processing timestamp: 2021-08-10 11:22:00
# Current time & days to expiry: 2021-08-10 2.172222222222222
# Curr time & days to EXpiry 2021-08-10 2.172222222222222
# Processing timestamp: 2021-08-10 11:23:00
# Current time & days to expiry: 2021-08-10 2.171527777777778
# Curr time & days to EXpiry 2021-08-10 2.171527777777778
# Processing timestamp: 2021-08-10 11:24:00
# Current time & days to expiry: 2021-08-10 2.1708333333333334
# Curr time & days to EXpiry 2021-08-10 2.1708333333333334
# Processing timestamp: 2021-08-10 11:25:00
# Current time & days to expiry: 2021-08-10 2.170138888888889
# Curr time & days to EXpiry 2021-08-10 2.170138888888889
# Processing timestamp: 2021-08-10 11:26:00
# Current time & days to expiry: 2021-08-10 2.1694444444444443
# Curr time & days to EXpiry 2021-08-10 2.1694444444444443
# Processing timestamp: 2021-08-10 11:27:00
# Current time & days to expiry: 2021-08-10 2.16875
# Curr time & days to EXpiry 2021-08-10 2.16875
# Processing timestamp: 2021-08-10 11:28:00
# Current time & days to expiry: 2021-08-10 2.1680555555555556
# Curr time & days to EXpiry 2021-08-10 2.1680555555555556
# Processing timestamp: 2021-08-10 11:29:00
# Current time & days to expiry: 2021-08-10 2.167361111111111
# Curr time & days to EXpiry 2021-08-10 2.167361111111111
# Processing timestamp: 2021-08-10 11:30:00
# Current time & days to expiry: 2021-08-10 2.1666666666666665
# Curr time & days to EXpiry 2021-08-10 2.1666666666666665
# Processing timestamp: 2021-08-10 11:31:00
# Current time & days to expiry: 2021-08-10 2.1659722222222224
# Curr time & days to EXpiry 2021-08-10 2.1659722222222224
# Processing timestamp: 2021-08-10 11:32:00
# Current time & days to expiry: 2021-08-10 2.165277777777778
# Curr time & days to EXpiry 2021-08-10 2.165277777777778
# Processing timestamp: 2021-08-10 11:33:00
# Current time & days to expiry: 2021-08-10 2.1645833333333333
# Curr time & days to EXpiry 2021-08-10 2.1645833333333333
# Processing timestamp: 2021-08-10 11:34:00
# Current time & days to expiry: 2021-08-10 2.1638888888888888
# Curr time & days to EXpiry 2021-08-10 2.1638888888888888
# Processing timestamp: 2021-08-10 11:35:00
# Current time & days to expiry: 2021-08-10 2.1631944444444446
# Curr time & days to EXpiry 2021-08-10 2.1631944444444446
# Processing timestamp: 2021-08-10 11:36:00
# Current time & days to expiry: 2021-08-10 2.1625
# Curr time & days to EXpiry 2021-08-10 2.1625
# Processing timestamp: 2021-08-10 11:37:00
# Current time & days to expiry: 2021-08-10 2.1618055555555555
# Curr time & days to EXpiry 2021-08-10 2.1618055555555555
# Processing timestamp: 2021-08-10 11:38:00
# Current time & days to expiry: 2021-08-10 2.161111111111111
# Curr time & days to EXpiry 2021-08-10 2.161111111111111
# Processing timestamp: 2021-08-10 11:39:00
# Current time & days to expiry: 2021-08-10 2.160416666666667
# Curr time & days to EXpiry 2021-08-10 2.160416666666667
# Processing timestamp: 2021-08-10 11:40:00
# Current time & days to expiry: 2021-08-10 2.1597222222222223
# Curr time & days to EXpiry 2021-08-10 2.1597222222222223
# Processing timestamp: 2021-08-10 11:41:00
# Current time & days to expiry: 2021-08-10 2.1590277777777778
# Curr time & days to EXpiry 2021-08-10 2.1590277777777778
# Processing timestamp: 2021-08-10 11:42:00
# Current time & days to expiry: 2021-08-10 2.158333333333333
# Curr time & days to EXpiry 2021-08-10 2.158333333333333
# Processing timestamp: 2021-08-10 11:43:00
# Current time & days to expiry: 2021-08-10 2.157638888888889
# Curr time & days to EXpiry 2021-08-10 2.157638888888889
# Processing timestamp: 2021-08-10 11:44:00
# Current time & days to expiry: 2021-08-10 2.1569444444444446
# Curr time & days to EXpiry 2021-08-10 2.1569444444444446
# Processing timestamp: 2021-08-10 11:45:00
# Current time & days to expiry: 2021-08-10 2.15625
# Curr time & days to EXpiry 2021-08-10 2.15625
# Processing timestamp: 2021-08-10 11:46:00
# Current time & days to expiry: 2021-08-10 2.1555555555555554
# Curr time & days to EXpiry 2021-08-10 2.1555555555555554
# Processing timestamp: 2021-08-10 11:47:00
# Current time & days to expiry: 2021-08-10 2.154861111111111
# Curr time & days to EXpiry 2021-08-10 2.154861111111111
# Processing timestamp: 2021-08-10 11:48:00
# Current time & days to expiry: 2021-08-10 2.154166666666667
# Curr time & days to EXpiry 2021-08-10 2.154166666666667
# Processing timestamp: 2021-08-10 11:49:00
# Current time & days to expiry: 2021-08-10 2.1534722222222222
# Curr time & days to EXpiry 2021-08-10 2.1534722222222222
# Processing timestamp: 2021-08-10 11:50:00
# Current time & days to expiry: 2021-08-10 2.1527777777777777
# Curr time & days to EXpiry 2021-08-10 2.1527777777777777
# Processing timestamp: 2021-08-10 11:51:00
# Current time & days to expiry: 2021-08-10 2.152083333333333
# Curr time & days to EXpiry 2021-08-10 2.152083333333333
# Processing timestamp: 2021-08-10 11:52:00
# Current time & days to expiry: 2021-08-10 2.151388888888889
# Curr time & days to EXpiry 2021-08-10 2.151388888888889
# Processing timestamp: 2021-08-10 11:53:00
# Current time & days to expiry: 2021-08-10 2.1506944444444445
# Curr time & days to EXpiry 2021-08-10 2.1506944444444445
# Processing timestamp: 2021-08-10 11:54:00
# Current time & days to expiry: 2021-08-10 2.15
# Curr time & days to EXpiry 2021-08-10 2.15
# Processing timestamp: 2021-08-10 11:55:00
# Current time & days to expiry: 2021-08-10 2.1493055555555554
# Curr time & days to EXpiry 2021-08-10 2.1493055555555554
# Processing timestamp: 2021-08-10 11:56:00
# Current time & days to expiry: 2021-08-10 2.1486111111111112
# Curr time & days to EXpiry 2021-08-10 2.1486111111111112
# Processing timestamp: 2021-08-10 11:57:00
# Current time & days to expiry: 2021-08-10 2.1479166666666667
# Curr time & days to EXpiry 2021-08-10 2.1479166666666667
# Processing timestamp: 2021-08-10 11:58:00
# Current time & days to expiry: 2021-08-10 2.147222222222222
# Curr time & days to EXpiry 2021-08-10 2.147222222222222
# Processing timestamp: 2021-08-10 11:59:00
# Current time & days to expiry: 2021-08-10 2.1465277777777776
# Curr time & days to EXpiry 2021-08-10 2.1465277777777776
# Processing timestamp: 2021-08-10 12:00:00
# Current time & days to expiry: 2021-08-10 2.1458333333333335
# Curr time & days to EXpiry 2021-08-10 2.1458333333333335
# Processing timestamp: 2021-08-10 12:01:00
# Current time & days to expiry: 2021-08-10 2.145138888888889
# Curr time & days to EXpiry 2021-08-10 2.145138888888889
# Processing timestamp: 2021-08-10 12:02:00
# Current time & days to expiry: 2021-08-10 2.1444444444444444
# Curr time & days to EXpiry 2021-08-10 2.1444444444444444
# Processing timestamp: 2021-08-10 12:03:00
# Current time & days to expiry: 2021-08-10 2.14375
# Curr time & days to EXpiry 2021-08-10 2.14375
# Processing timestamp: 2021-08-10 12:04:00
# Current time & days to expiry: 2021-08-10 2.1430555555555557
# Curr time & days to EXpiry 2021-08-10 2.1430555555555557
# Processing timestamp: 2021-08-10 12:05:00
# Current time & days to expiry: 2021-08-10 2.142361111111111
# Curr time & days to EXpiry 2021-08-10 2.142361111111111
# Processing timestamp: 2021-08-10 12:06:00
# Current time & days to expiry: 2021-08-10 2.1416666666666666
# Curr time & days to EXpiry 2021-08-10 2.1416666666666666
# Processing timestamp: 2021-08-10 12:07:00
# Current time & days to expiry: 2021-08-10 2.140972222222222
# Curr time & days to EXpiry 2021-08-10 2.140972222222222
# Processing timestamp: 2021-08-10 12:08:00
# Current time & days to expiry: 2021-08-10 2.140277777777778
# Curr time & days to EXpiry 2021-08-10 2.140277777777778
# Processing timestamp: 2021-08-10 12:09:00
# Current time & days to expiry: 2021-08-10 2.1395833333333334
# Curr time & days to EXpiry 2021-08-10 2.1395833333333334
# Processing timestamp: 2021-08-10 12:10:00
# Current time & days to expiry: 2021-08-10 2.138888888888889
# Curr time & days to EXpiry 2021-08-10 2.138888888888889
# Processing timestamp: 2021-08-10 12:11:00
# Current time & days to expiry: 2021-08-10 2.1381944444444443
# Curr time & days to EXpiry 2021-08-10 2.1381944444444443
# Processing timestamp: 2021-08-10 12:12:00
# Current time & days to expiry: 2021-08-10 2.1375
# Curr time & days to EXpiry 2021-08-10 2.1375
# Processing timestamp: 2021-08-10 12:13:00
# Current time & days to expiry: 2021-08-10 2.1368055555555556
# Curr time & days to EXpiry 2021-08-10 2.1368055555555556
# Processing timestamp: 2021-08-10 12:14:00
# Current time & days to expiry: 2021-08-10 2.136111111111111
# Curr time & days to EXpiry 2021-08-10 2.136111111111111
# Processing timestamp: 2021-08-10 12:15:00
# Current time & days to expiry: 2021-08-10 2.1354166666666665
# Curr time & days to EXpiry 2021-08-10 2.1354166666666665
# Processing timestamp: 2021-08-10 12:16:00
# Current time & days to expiry: 2021-08-10 2.1347222222222224
# Curr time & days to EXpiry 2021-08-10 2.1347222222222224
# Processing timestamp: 2021-08-10 12:17:00
# Current time & days to expiry: 2021-08-10 2.134027777777778
# Curr time & days to EXpiry 2021-08-10 2.134027777777778
# Processing timestamp: 2021-08-10 12:18:00
# Current time & days to expiry: 2021-08-10 2.1333333333333333
# Curr time & days to EXpiry 2021-08-10 2.1333333333333333
# Processing timestamp: 2021-08-10 12:19:00
# Current time & days to expiry: 2021-08-10 2.1326388888888888
# Curr time & days to EXpiry 2021-08-10 2.1326388888888888
# Processing timestamp: 2021-08-10 12:20:00
# Current time & days to expiry: 2021-08-10 2.1319444444444446
# Curr time & days to EXpiry 2021-08-10 2.1319444444444446
# Processing timestamp: 2021-08-10 12:21:00
# Current time & days to expiry: 2021-08-10 2.13125
# Curr time & days to EXpiry 2021-08-10 2.13125
# Processing timestamp: 2021-08-10 12:22:00
# Current time & days to expiry: 2021-08-10 2.1305555555555555
# Curr time & days to EXpiry 2021-08-10 2.1305555555555555
# Processing timestamp: 2021-08-10 12:23:00
# Current time & days to expiry: 2021-08-10 2.129861111111111
# Curr time & days to EXpiry 2021-08-10 2.129861111111111
# Processing timestamp: 2021-08-10 12:24:00
# Current time & days to expiry: 2021-08-10 2.129166666666667
# Curr time & days to EXpiry 2021-08-10 2.129166666666667
# Processing timestamp: 2021-08-10 12:25:00
# Current time & days to expiry: 2021-08-10 2.1284722222222223
# Curr time & days to EXpiry 2021-08-10 2.1284722222222223
# Processing timestamp: 2021-08-10 12:26:00
# Current time & days to expiry: 2021-08-10 2.1277777777777778
# Curr time & days to EXpiry 2021-08-10 2.1277777777777778
# Processing timestamp: 2021-08-10 12:27:00
# Current time & days to expiry: 2021-08-10 2.127083333333333
# Curr time & days to EXpiry 2021-08-10 2.127083333333333
# Processing timestamp: 2021-08-10 12:28:00
# Current time & days to expiry: 2021-08-10 2.126388888888889
# Curr time & days to EXpiry 2021-08-10 2.126388888888889
# Processing timestamp: 2021-08-10 12:29:00
# Current time & days to expiry: 2021-08-10 2.1256944444444446
# Curr time & days to EXpiry 2021-08-10 2.1256944444444446
# Processing timestamp: 2021-08-10 12:30:00
# Current time & days to expiry: 2021-08-10 2.125
# Curr time & days to EXpiry 2021-08-10 2.125
# Processing timestamp: 2021-08-10 12:31:00
# Current time & days to expiry: 2021-08-10 2.1243055555555554
# Curr time & days to EXpiry 2021-08-10 2.1243055555555554
# Processing timestamp: 2021-08-10 12:32:00
# Current time & days to expiry: 2021-08-10 2.123611111111111
# Curr time & days to EXpiry 2021-08-10 2.123611111111111
# Processing timestamp: 2021-08-10 12:33:00
# Current time & days to expiry: 2021-08-10 2.122916666666667
# Curr time & days to EXpiry 2021-08-10 2.122916666666667
# Processing timestamp: 2021-08-10 12:34:00
# Current time & days to expiry: 2021-08-10 2.1222222222222222
# Curr time & days to EXpiry 2021-08-10 2.1222222222222222
# Processing timestamp: 2021-08-10 12:35:00
# Current time & days to expiry: 2021-08-10 2.1215277777777777
# Curr time & days to EXpiry 2021-08-10 2.1215277777777777
# Processing timestamp: 2021-08-10 12:36:00
# Current time & days to expiry: 2021-08-10 2.120833333333333
# Curr time & days to EXpiry 2021-08-10 2.120833333333333
# Processing timestamp: 2021-08-10 12:37:00
# Current time & days to expiry: 2021-08-10 2.120138888888889
# Curr time & days to EXpiry 2021-08-10 2.120138888888889
# Processing timestamp: 2021-08-10 12:38:00
# Current time & days to expiry: 2021-08-10 2.1194444444444445
# Curr time & days to EXpiry 2021-08-10 2.1194444444444445
# Processing timestamp: 2021-08-10 12:39:00
# Current time & days to expiry: 2021-08-10 2.11875
# Curr time & days to EXpiry 2021-08-10 2.11875
# Processing timestamp: 2021-08-10 12:40:00
# Current time & days to expiry: 2021-08-10 2.1180555555555554
# Curr time & days to EXpiry 2021-08-10 2.1180555555555554
# Processing timestamp: 2021-08-10 12:41:00
# Current time & days to expiry: 2021-08-10 2.1173611111111112
# Curr time & days to EXpiry 2021-08-10 2.1173611111111112
# Processing timestamp: 2021-08-10 12:42:00
# Current time & days to expiry: 2021-08-10 2.1166666666666667
# Curr time & days to EXpiry 2021-08-10 2.1166666666666667
# Processing timestamp: 2021-08-10 12:43:00
# Current time & days to expiry: 2021-08-10 2.115972222222222
# Curr time & days to EXpiry 2021-08-10 2.115972222222222
# Processing timestamp: 2021-08-10 12:44:00
# Current time & days to expiry: 2021-08-10 2.1152777777777776
# Curr time & days to EXpiry 2021-08-10 2.1152777777777776
# Processing timestamp: 2021-08-10 12:45:00
# Current time & days to expiry: 2021-08-10 2.1145833333333335
# Curr time & days to EXpiry 2021-08-10 2.1145833333333335
# Processing timestamp: 2021-08-10 12:46:00
# Current time & days to expiry: 2021-08-10 2.113888888888889
# Curr time & days to EXpiry 2021-08-10 2.113888888888889
# Processing timestamp: 2021-08-10 12:47:00
# Current time & days to expiry: 2021-08-10 2.1131944444444444
# Curr time & days to EXpiry 2021-08-10 2.1131944444444444
# Processing timestamp: 2021-08-10 12:48:00
# Current time & days to expiry: 2021-08-10 2.1125
# Curr time & days to EXpiry 2021-08-10 2.1125
# Processing timestamp: 2021-08-10 12:49:00
# Current time & days to expiry: 2021-08-10 2.1118055555555557
# Curr time & days to EXpiry 2021-08-10 2.1118055555555557
# Processing timestamp: 2021-08-10 12:50:00
# Current time & days to expiry: 2021-08-10 2.111111111111111
# Curr time & days to EXpiry 2021-08-10 2.111111111111111
# Processing timestamp: 2021-08-10 12:51:00
# Current time & days to expiry: 2021-08-10 2.1104166666666666
# Curr time & days to EXpiry 2021-08-10 2.1104166666666666
# Processing timestamp: 2021-08-10 12:52:00
# Current time & days to expiry: 2021-08-10 2.109722222222222
# Curr time & days to EXpiry 2021-08-10 2.109722222222222
# Processing timestamp: 2021-08-10 12:53:00
# Current time & days to expiry: 2021-08-10 2.109027777777778
# Curr time & days to EXpiry 2021-08-10 2.109027777777778
# Processing timestamp: 2021-08-10 12:54:00
# Current time & days to expiry: 2021-08-10 2.1083333333333334
# Curr time & days to EXpiry 2021-08-10 2.1083333333333334
# Processing timestamp: 2021-08-10 12:55:00
# Current time & days to expiry: 2021-08-10 2.107638888888889
# Curr time & days to EXpiry 2021-08-10 2.107638888888889
# Processing timestamp: 2021-08-10 12:56:00
# Current time & days to expiry: 2021-08-10 2.1069444444444443
# Curr time & days to EXpiry 2021-08-10 2.1069444444444443
# Processing timestamp: 2021-08-10 12:57:00
# Current time & days to expiry: 2021-08-10 2.10625
# Curr time & days to EXpiry 2021-08-10 2.10625
# Processing timestamp: 2021-08-10 12:58:00
# Current time & days to expiry: 2021-08-10 2.1055555555555556
# Curr time & days to EXpiry 2021-08-10 2.1055555555555556
# Processing timestamp: 2021-08-10 12:59:00
# Current time & days to expiry: 2021-08-10 2.104861111111111
# Curr time & days to EXpiry 2021-08-10 2.104861111111111
# Processing timestamp: 2021-08-10 13:00:00
# Current time & days to expiry: 2021-08-10 2.1041666666666665
# Curr time & days to EXpiry 2021-08-10 2.1041666666666665
# Processing timestamp: 2021-08-10 13:01:00
# Current time & days to expiry: 2021-08-10 2.1034722222222224
# Curr time & days to EXpiry 2021-08-10 2.1034722222222224
# Processing timestamp: 2021-08-10 13:02:00
# Current time & days to expiry: 2021-08-10 2.102777777777778
# Curr time & days to EXpiry 2021-08-10 2.102777777777778
# Processing timestamp: 2021-08-10 13:03:00
# Current time & days to expiry: 2021-08-10 2.1020833333333333
# Curr time & days to EXpiry 2021-08-10 2.1020833333333333
# Processing timestamp: 2021-08-10 13:04:00
# Current time & days to expiry: 2021-08-10 2.1013888888888888
# Curr time & days to EXpiry 2021-08-10 2.1013888888888888
# Processing timestamp: 2021-08-10 13:05:00
# Current time & days to expiry: 2021-08-10 2.1006944444444446
# Curr time & days to EXpiry 2021-08-10 2.1006944444444446
# Processing timestamp: 2021-08-10 13:06:00
# Current time & days to expiry: 2021-08-10 2.1
# Curr time & days to EXpiry 2021-08-10 2.1
# Processing timestamp: 2021-08-10 13:07:00
# Current time & days to expiry: 2021-08-10 2.0993055555555555
# Curr time & days to EXpiry 2021-08-10 2.0993055555555555
# Processing timestamp: 2021-08-10 13:08:00
# Current time & days to expiry: 2021-08-10 2.098611111111111
# Curr time & days to EXpiry 2021-08-10 2.098611111111111
# Processing timestamp: 2021-08-10 13:09:00
# Current time & days to expiry: 2021-08-10 2.097916666666667
# Curr time & days to EXpiry 2021-08-10 2.097916666666667
# Processing timestamp: 2021-08-10 13:10:00
# Current time & days to expiry: 2021-08-10 2.0972222222222223
# Curr time & days to EXpiry 2021-08-10 2.0972222222222223
# Processing timestamp: 2021-08-10 13:11:00
# Current time & days to expiry: 2021-08-10 2.0965277777777778
# Curr time & days to EXpiry 2021-08-10 2.0965277777777778
# Processing timestamp: 2021-08-10 13:12:00
# Current time & days to expiry: 2021-08-10 2.095833333333333
# Curr time & days to EXpiry 2021-08-10 2.095833333333333
# Processing timestamp: 2021-08-10 13:13:00
# Current time & days to expiry: 2021-08-10 2.095138888888889
# Curr time & days to EXpiry 2021-08-10 2.095138888888889
# Processing timestamp: 2021-08-10 13:14:00
# Current time & days to expiry: 2021-08-10 2.0944444444444446
# Curr time & days to EXpiry 2021-08-10 2.0944444444444446
# Processing timestamp: 2021-08-10 13:15:00
# Current time & days to expiry: 2021-08-10 2.09375
# Curr time & days to EXpiry 2021-08-10 2.09375
# Processing timestamp: 2021-08-10 13:16:00
# Current time & days to expiry: 2021-08-10 2.0930555555555554
# Curr time & days to EXpiry 2021-08-10 2.0930555555555554
# Processing timestamp: 2021-08-10 13:17:00
# Current time & days to expiry: 2021-08-10 2.092361111111111
# Curr time & days to EXpiry 2021-08-10 2.092361111111111
# Processing timestamp: 2021-08-10 13:18:00
# Current time & days to expiry: 2021-08-10 2.091666666666667
# Curr time & days to EXpiry 2021-08-10 2.091666666666667
# Processing timestamp: 2021-08-10 13:19:00
# Current time & days to expiry: 2021-08-10 2.0909722222222222
# Curr time & days to EXpiry 2021-08-10 2.0909722222222222
# Processing timestamp: 2021-08-10 13:20:00
# Current time & days to expiry: 2021-08-10 2.0902777777777777
# Curr time & days to EXpiry 2021-08-10 2.0902777777777777
# Processing timestamp: 2021-08-10 13:21:00
# Current time & days to expiry: 2021-08-10 2.089583333333333
# Curr time & days to EXpiry 2021-08-10 2.089583333333333
# Processing timestamp: 2021-08-10 13:22:00
# Current time & days to expiry: 2021-08-10 2.088888888888889
# Curr time & days to EXpiry 2021-08-10 2.088888888888889
# Processing timestamp: 2021-08-10 13:23:00
# Current time & days to expiry: 2021-08-10 2.0881944444444445
# Curr time & days to EXpiry 2021-08-10 2.0881944444444445
# Processing timestamp: 2021-08-10 13:24:00
# Current time & days to expiry: 2021-08-10 2.0875
# Curr time & days to EXpiry 2021-08-10 2.0875
# Processing timestamp: 2021-08-10 13:25:00
# Current time & days to expiry: 2021-08-10 2.0868055555555554
# Curr time & days to EXpiry 2021-08-10 2.0868055555555554
# Processing timestamp: 2021-08-10 13:26:00
# Current time & days to expiry: 2021-08-10 2.0861111111111112
# Curr time & days to EXpiry 2021-08-10 2.0861111111111112
# Processing timestamp: 2021-08-10 13:27:00
# Current time & days to expiry: 2021-08-10 2.0854166666666667
# Curr time & days to EXpiry 2021-08-10 2.0854166666666667
# Processing timestamp: 2021-08-10 13:28:00
# Current time & days to expiry: 2021-08-10 2.084722222222222
# Curr time & days to EXpiry 2021-08-10 2.084722222222222
# Processing timestamp: 2021-08-10 13:29:00
# Current time & days to expiry: 2021-08-10 2.0840277777777776
# Curr time & days to EXpiry 2021-08-10 2.0840277777777776
# Processing timestamp: 2021-08-10 13:30:00
# Current time & days to expiry: 2021-08-10 2.0833333333333335
# Curr time & days to EXpiry 2021-08-10 2.0833333333333335
# Processing timestamp: 2021-08-10 13:31:00
# Current time & days to expiry: 2021-08-10 2.082638888888889
# Curr time & days to EXpiry 2021-08-10 2.082638888888889
# Processing timestamp: 2021-08-10 13:32:00
# Current time & days to expiry: 2021-08-10 2.0819444444444444
# Curr time & days to EXpiry 2021-08-10 2.0819444444444444
# Processing timestamp: 2021-08-10 13:33:00
# Current time & days to expiry: 2021-08-10 2.08125
# Curr time & days to EXpiry 2021-08-10 2.08125
# Processing timestamp: 2021-08-10 13:34:00
# Current time & days to expiry: 2021-08-10 2.0805555555555557
# Curr time & days to EXpiry 2021-08-10 2.0805555555555557
# Processing timestamp: 2021-08-10 13:35:00
# Current time & days to expiry: 2021-08-10 2.079861111111111
# Curr time & days to EXpiry 2021-08-10 2.079861111111111
# Processing timestamp: 2021-08-10 13:36:00
# Current time & days to expiry: 2021-08-10 2.0791666666666666
# Curr time & days to EXpiry 2021-08-10 2.0791666666666666
# Processing timestamp: 2021-08-10 13:37:00
# Current time & days to expiry: 2021-08-10 2.078472222222222
# Curr time & days to EXpiry 2021-08-10 2.078472222222222
# Processing timestamp: 2021-08-10 13:38:00
# Current time & days to expiry: 2021-08-10 2.077777777777778
# Curr time & days to EXpiry 2021-08-10 2.077777777777778
# Processing timestamp: 2021-08-10 13:39:00
# Current time & days to expiry: 2021-08-10 2.0770833333333334
# Curr time & days to EXpiry 2021-08-10 2.0770833333333334
# Processing timestamp: 2021-08-10 13:40:00
# Current time & days to expiry: 2021-08-10 2.076388888888889
# Curr time & days to EXpiry 2021-08-10 2.076388888888889
# Processing timestamp: 2021-08-10 13:41:00
# Current time & days to expiry: 2021-08-10 2.0756944444444443
# Curr time & days to EXpiry 2021-08-10 2.0756944444444443
# Processing timestamp: 2021-08-10 13:42:00
# Current time & days to expiry: 2021-08-10 2.075
# Curr time & days to EXpiry 2021-08-10 2.075
# Processing timestamp: 2021-08-10 13:43:00
# Current time & days to expiry: 2021-08-10 2.0743055555555556
# Curr time & days to EXpiry 2021-08-10 2.0743055555555556
# Processing timestamp: 2021-08-10 13:44:00
# Current time & days to expiry: 2021-08-10 2.073611111111111
# Curr time & days to EXpiry 2021-08-10 2.073611111111111
# Processing timestamp: 2021-08-10 13:45:00
# Current time & days to expiry: 2021-08-10 2.0729166666666665
# Curr time & days to EXpiry 2021-08-10 2.0729166666666665
# Processing timestamp: 2021-08-10 13:46:00
# Current time & days to expiry: 2021-08-10 2.0722222222222224
# Curr time & days to EXpiry 2021-08-10 2.0722222222222224
# Processing timestamp: 2021-08-10 13:47:00
# Current time & days to expiry: 2021-08-10 2.071527777777778
# Curr time & days to EXpiry 2021-08-10 2.071527777777778
# Processing timestamp: 2021-08-10 13:48:00
# Current time & days to expiry: 2021-08-10 2.0708333333333333
# Curr time & days to EXpiry 2021-08-10 2.0708333333333333
# Processing timestamp: 2021-08-10 13:49:00
# Current time & days to expiry: 2021-08-10 2.0701388888888888
# Curr time & days to EXpiry 2021-08-10 2.0701388888888888
# Processing timestamp: 2021-08-10 13:50:00
# Current time & days to expiry: 2021-08-10 2.0694444444444446
# Curr time & days to EXpiry 2021-08-10 2.0694444444444446
# Processing timestamp: 2021-08-10 13:51:00
# Current time & days to expiry: 2021-08-10 2.06875
# Curr time & days to EXpiry 2021-08-10 2.06875
# Processing timestamp: 2021-08-10 13:52:00
# Current time & days to expiry: 2021-08-10 2.0680555555555555
# Curr time & days to EXpiry 2021-08-10 2.0680555555555555
# Processing timestamp: 2021-08-10 13:53:00
# Current time & days to expiry: 2021-08-10 2.067361111111111
# Curr time & days to EXpiry 2021-08-10 2.067361111111111
# Processing timestamp: 2021-08-10 13:54:00
# Current time & days to expiry: 2021-08-10 2.066666666666667
# Curr time & days to EXpiry 2021-08-10 2.066666666666667
# Processing timestamp: 2021-08-10 13:55:00
# Current time & days to expiry: 2021-08-10 2.0659722222222223
# Curr time & days to EXpiry 2021-08-10 2.0659722222222223
# Processing timestamp: 2021-08-10 13:56:00
# Current time & days to expiry: 2021-08-10 2.0652777777777778
# Curr time & days to EXpiry 2021-08-10 2.0652777777777778
# Processing timestamp: 2021-08-10 13:57:00
# Current time & days to expiry: 2021-08-10 2.064583333333333
# Curr time & days to EXpiry 2021-08-10 2.064583333333333
# Processing timestamp: 2021-08-10 13:58:00
# Current time & days to expiry: 2021-08-10 2.063888888888889
# Curr time & days to EXpiry 2021-08-10 2.063888888888889
# Processing timestamp: 2021-08-10 13:59:00
# Current time & days to expiry: 2021-08-10 2.0631944444444446
# Curr time & days to EXpiry 2021-08-10 2.0631944444444446
# Processing timestamp: 2021-08-10 14:00:00
# Current time & days to expiry: 2021-08-10 2.0625
# Curr time & days to EXpiry 2021-08-10 2.0625
# Processing timestamp: 2021-08-10 14:01:00
# Current time & days to expiry: 2021-08-10 2.0618055555555554
# Curr time & days to EXpiry 2021-08-10 2.0618055555555554
# Processing timestamp: 2021-08-10 14:02:00
# Current time & days to expiry: 2021-08-10 2.061111111111111
# Curr time & days to EXpiry 2021-08-10 2.061111111111111
# Processing timestamp: 2021-08-10 14:03:00
# Current time & days to expiry: 2021-08-10 2.060416666666667
# Curr time & days to EXpiry 2021-08-10 2.060416666666667
# Processing timestamp: 2021-08-10 14:04:00
# Current time & days to expiry: 2021-08-10 2.0597222222222222
# Curr time & days to EXpiry 2021-08-10 2.0597222222222222
# Processing timestamp: 2021-08-10 14:05:00
# Current time & days to expiry: 2021-08-10 2.0590277777777777
# Curr time & days to EXpiry 2021-08-10 2.0590277777777777
# Processing timestamp: 2021-08-10 14:06:00
# Current time & days to expiry: 2021-08-10 2.058333333333333
# Curr time & days to EXpiry 2021-08-10 2.058333333333333
# Processing timestamp: 2021-08-10 14:07:00
# Current time & days to expiry: 2021-08-10 2.057638888888889
# Curr time & days to EXpiry 2021-08-10 2.057638888888889
# Processing timestamp: 2021-08-10 14:08:00
# Current time & days to expiry: 2021-08-10 2.0569444444444445
# Curr time & days to EXpiry 2021-08-10 2.0569444444444445
# Processing timestamp: 2021-08-10 14:09:00
# Current time & days to expiry: 2021-08-10 2.05625
# Curr time & days to EXpiry 2021-08-10 2.05625
# Processing timestamp: 2021-08-10 14:10:00
# Current time & days to expiry: 2021-08-10 2.0555555555555554
# Curr time & days to EXpiry 2021-08-10 2.0555555555555554
# Processing timestamp: 2021-08-10 14:11:00
# Current time & days to expiry: 2021-08-10 2.0548611111111112
# Curr time & days to EXpiry 2021-08-10 2.0548611111111112
# Processing timestamp: 2021-08-10 14:12:00
# Current time & days to expiry: 2021-08-10 2.0541666666666667
# Curr time & days to EXpiry 2021-08-10 2.0541666666666667
# Processing timestamp: 2021-08-10 14:13:00
# Current time & days to expiry: 2021-08-10 2.053472222222222
# Curr time & days to EXpiry 2021-08-10 2.053472222222222
# Processing timestamp: 2021-08-10 14:14:00
# Current time & days to expiry: 2021-08-10 2.0527777777777776
# Curr time & days to EXpiry 2021-08-10 2.0527777777777776
# Processing timestamp: 2021-08-10 14:15:00
# Current time & days to expiry: 2021-08-10 2.0520833333333335
# Curr time & days to EXpiry 2021-08-10 2.0520833333333335
# Processing timestamp: 2021-08-10 14:16:00
# Current time & days to expiry: 2021-08-10 2.051388888888889
# Curr time & days to EXpiry 2021-08-10 2.051388888888889
# Processing timestamp: 2021-08-10 14:17:00
# Current time & days to expiry: 2021-08-10 2.0506944444444444
# Curr time & days to EXpiry 2021-08-10 2.0506944444444444
# Processing timestamp: 2021-08-10 14:18:00
# Current time & days to expiry: 2021-08-10 2.05
# Curr time & days to EXpiry 2021-08-10 2.05
# Processing timestamp: 2021-08-10 14:19:00
# Current time & days to expiry: 2021-08-10 2.0493055555555557
# Curr time & days to EXpiry 2021-08-10 2.0493055555555557
# Processing timestamp: 2021-08-10 14:20:00
# Current time & days to expiry: 2021-08-10 2.048611111111111
# Curr time & days to EXpiry 2021-08-10 2.048611111111111
# Processing timestamp: 2021-08-10 14:21:00
# Current time & days to expiry: 2021-08-10 2.0479166666666666
# Curr time & days to EXpiry 2021-08-10 2.0479166666666666
# Processing timestamp: 2021-08-10 14:22:00
# Current time & days to expiry: 2021-08-10 2.047222222222222
# Curr time & days to EXpiry 2021-08-10 2.047222222222222
# Processing timestamp: 2021-08-10 14:23:00
# Current time & days to expiry: 2021-08-10 2.046527777777778
# Curr time & days to EXpiry 2021-08-10 2.046527777777778
# Processing timestamp: 2021-08-10 14:24:00
# Current time & days to expiry: 2021-08-10 2.0458333333333334
# Curr time & days to EXpiry 2021-08-10 2.0458333333333334
# Processing timestamp: 2021-08-10 14:25:00
# Current time & days to expiry: 2021-08-10 2.045138888888889
# Curr time & days to EXpiry 2021-08-10 2.045138888888889
# Processing timestamp: 2021-08-10 14:26:00
# Current time & days to expiry: 2021-08-10 2.0444444444444443
# Curr time & days to EXpiry 2021-08-10 2.0444444444444443
# Processing timestamp: 2021-08-10 14:27:00
# Current time & days to expiry: 2021-08-10 2.04375
# Curr time & days to EXpiry 2021-08-10 2.04375
# Processing timestamp: 2021-08-10 14:28:00
# Current time & days to expiry: 2021-08-10 2.0430555555555556
# Curr time & days to EXpiry 2021-08-10 2.0430555555555556
# Processing timestamp: 2021-08-10 14:29:00
# Current time & days to expiry: 2021-08-10 2.042361111111111
# Curr time & days to EXpiry 2021-08-10 2.042361111111111
# Processing timestamp: 2021-08-10 14:30:00
# Current time & days to expiry: 2021-08-10 2.0416666666666665
# Curr time & days to EXpiry 2021-08-10 2.0416666666666665
# Processing timestamp: 2021-08-10 14:31:00
# Current time & days to expiry: 2021-08-10 2.0409722222222224
# Curr time & days to EXpiry 2021-08-10 2.0409722222222224
# Processing timestamp: 2021-08-10 14:32:00
# Current time & days to expiry: 2021-08-10 2.040277777777778
# Curr time & days to EXpiry 2021-08-10 2.040277777777778
# Processing timestamp: 2021-08-10 14:33:00
# Current time & days to expiry: 2021-08-10 2.0395833333333333
# Curr time & days to EXpiry 2021-08-10 2.0395833333333333
# Processing timestamp: 2021-08-10 14:34:00
# Current time & days to expiry: 2021-08-10 2.0388888888888888
# Curr time & days to EXpiry 2021-08-10 2.0388888888888888
# Processing timestamp: 2021-08-10 14:35:00
# Current time & days to expiry: 2021-08-10 2.0381944444444446
# Curr time & days to EXpiry 2021-08-10 2.0381944444444446
# Processing timestamp: 2021-08-10 14:36:00
# Current time & days to expiry: 2021-08-10 2.0375
# Curr time & days to EXpiry 2021-08-10 2.0375
# Processing timestamp: 2021-08-10 14:37:00
# Current time & days to expiry: 2021-08-10 2.0368055555555555
# Curr time & days to EXpiry 2021-08-10 2.0368055555555555
# Processing timestamp: 2021-08-10 14:38:00
# Current time & days to expiry: 2021-08-10 2.036111111111111
# Curr time & days to EXpiry 2021-08-10 2.036111111111111
# Processing timestamp: 2021-08-10 14:39:00
# Current time & days to expiry: 2021-08-10 2.035416666666667
# Curr time & days to EXpiry 2021-08-10 2.035416666666667
# Processing timestamp: 2021-08-10 14:40:00
# Current time & days to expiry: 2021-08-10 2.0347222222222223
# Curr time & days to EXpiry 2021-08-10 2.0347222222222223
# Processing timestamp: 2021-08-10 14:41:00
# Current time & days to expiry: 2021-08-10 2.0340277777777778
# Curr time & days to EXpiry 2021-08-10 2.0340277777777778
# Processing timestamp: 2021-08-10 14:42:00
# Current time & days to expiry: 2021-08-10 2.033333333333333
# Curr time & days to EXpiry 2021-08-10 2.033333333333333
# Processing timestamp: 2021-08-10 14:43:00
# Current time & days to expiry: 2021-08-10 2.032638888888889
# Curr time & days to EXpiry 2021-08-10 2.032638888888889
# Processing timestamp: 2021-08-10 14:44:00
# Current time & days to expiry: 2021-08-10 2.0319444444444446
# Curr time & days to EXpiry 2021-08-10 2.0319444444444446
# Processing timestamp: 2021-08-10 14:45:00
# Current time & days to expiry: 2021-08-10 2.03125
# Curr time & days to EXpiry 2021-08-10 2.03125
# Processing timestamp: 2021-08-10 14:46:00
# Current time & days to expiry: 2021-08-10 2.0305555555555554
# Curr time & days to EXpiry 2021-08-10 2.0305555555555554
# Processing timestamp: 2021-08-10 14:47:00
# Current time & days to expiry: 2021-08-10 2.029861111111111
# Curr time & days to EXpiry 2021-08-10 2.029861111111111
# Processing timestamp: 2021-08-10 14:48:00
# Current time & days to expiry: 2021-08-10 2.029166666666667
# Curr time & days to EXpiry 2021-08-10 2.029166666666667
# Processing timestamp: 2021-08-10 14:49:00
# Current time & days to expiry: 2021-08-10 2.0284722222222222
# Curr time & days to EXpiry 2021-08-10 2.0284722222222222
# Processing timestamp: 2021-08-10 14:50:00
# Current time & days to expiry: 2021-08-10 2.0277777777777777
# Curr time & days to EXpiry 2021-08-10 2.0277777777777777
# Processing timestamp: 2021-08-10 14:51:00
# Current time & days to expiry: 2021-08-10 2.027083333333333
# Curr time & days to EXpiry 2021-08-10 2.027083333333333
# Processing timestamp: 2021-08-10 14:52:00
# Current time & days to expiry: 2021-08-10 2.026388888888889
# Curr time & days to EXpiry 2021-08-10 2.026388888888889
# Processing timestamp: 2021-08-10 14:53:00
# Current time & days to expiry: 2021-08-10 2.0256944444444445
# Curr time & days to EXpiry 2021-08-10 2.0256944444444445
# Processing timestamp: 2021-08-10 14:54:00
# Current time & days to expiry: 2021-08-10 2.025
# Curr time & days to EXpiry 2021-08-10 2.025
# Processing timestamp: 2021-08-10 14:55:00
# Current time & days to expiry: 2021-08-10 2.0243055555555554
# Curr time & days to EXpiry 2021-08-10 2.0243055555555554
# Processing timestamp: 2021-08-10 14:56:00
# Current time & days to expiry: 2021-08-10 2.0236111111111112
# Curr time & days to EXpiry 2021-08-10 2.0236111111111112
# Processing timestamp: 2021-08-10 14:57:00
# Current time & days to expiry: 2021-08-10 2.0229166666666667
# Curr time & days to EXpiry 2021-08-10 2.0229166666666667
# Processing timestamp: 2021-08-10 14:58:00
# Current time & days to expiry: 2021-08-10 2.022222222222222
# Curr time & days to EXpiry 2021-08-10 2.022222222222222
# Processing timestamp: 2021-08-10 14:59:00
# Current time & days to expiry: 2021-08-10 2.0215277777777776
# Curr time & days to EXpiry 2021-08-10 2.0215277777777776
# Processing timestamp: 2021-08-10 15:00:00
# Current time & days to expiry: 2021-08-10 2.0208333333333335
# Curr time & days to EXpiry 2021-08-10 2.0208333333333335
# Processing timestamp: 2021-08-10 15:01:00
# Current time & days to expiry: 2021-08-10 2.020138888888889
# Curr time & days to EXpiry 2021-08-10 2.020138888888889
# Processing timestamp: 2021-08-10 15:02:00
# Current time & days to expiry: 2021-08-10 2.0194444444444444
# Curr time & days to EXpiry 2021-08-10 2.0194444444444444
# Processing timestamp: 2021-08-10 15:03:00
# Current time & days to expiry: 2021-08-10 2.01875
# Curr time & days to EXpiry 2021-08-10 2.01875
# Processing timestamp: 2021-08-10 15:04:00
# Current time & days to expiry: 2021-08-10 2.0180555555555557
# Curr time & days to EXpiry 2021-08-10 2.0180555555555557
# Processing timestamp: 2021-08-10 15:05:00
# Current time & days to expiry: 2021-08-10 2.017361111111111
# Curr time & days to EXpiry 2021-08-10 2.017361111111111
# Processing timestamp: 2021-08-10 15:06:00
# Current time & days to expiry: 2021-08-10 2.0166666666666666
# Curr time & days to EXpiry 2021-08-10 2.0166666666666666
# Processing timestamp: 2021-08-10 15:07:00
# Current time & days to expiry: 2021-08-10 2.015972222222222
# Curr time & days to EXpiry 2021-08-10 2.015972222222222
# Processing timestamp: 2021-08-10 15:08:00
# Current time & days to expiry: 2021-08-10 2.015277777777778
# Curr time & days to EXpiry 2021-08-10 2.015277777777778
# Processing timestamp: 2021-08-10 15:09:00
# Current time & days to expiry: 2021-08-10 2.0145833333333334
# Curr time & days to EXpiry 2021-08-10 2.0145833333333334
# Processing timestamp: 2021-08-10 15:10:00
# Current time & days to expiry: 2021-08-10 2.013888888888889
# Curr time & days to EXpiry 2021-08-10 2.013888888888889
# Processing timestamp: 2021-08-10 15:11:00
# Current time & days to expiry: 2021-08-10 2.0131944444444443
# Curr time & days to EXpiry 2021-08-10 2.0131944444444443
# Processing timestamp: 2021-08-10 15:12:00
# Current time & days to expiry: 2021-08-10 2.0125
# Curr time & days to EXpiry 2021-08-10 2.0125
# Processing timestamp: 2021-08-10 15:13:00
# Current time & days to expiry: 2021-08-10 2.0118055555555556
# Curr time & days to EXpiry 2021-08-10 2.0118055555555556
# Processing timestamp: 2021-08-10 15:14:00
# Current time & days to expiry: 2021-08-10 2.011111111111111
# Curr time & days to EXpiry 2021-08-10 2.011111111111111
# Processing timestamp: 2021-08-10 15:15:00
# Current time & days to expiry: 2021-08-10 2.0104166666666665
# Curr time & days to EXpiry 2021-08-10 2.0104166666666665
# Processing timestamp: 2021-08-10 15:16:00
# Current time & days to expiry: 2021-08-10 2.0097222222222224
# Curr time & days to EXpiry 2021-08-10 2.0097222222222224
# Processing timestamp: 2021-08-10 15:17:00
# Current time & days to expiry: 2021-08-10 2.009027777777778
# Curr time & days to EXpiry 2021-08-10 2.009027777777778
# Processing timestamp: 2021-08-10 15:18:00
# Current time & days to expiry: 2021-08-10 2.0083333333333333
# Curr time & days to EXpiry 2021-08-10 2.0083333333333333
# Processing timestamp: 2021-08-10 15:19:00
# Current time & days to expiry: 2021-08-10 2.0076388888888888
# Curr time & days to EXpiry 2021-08-10 2.0076388888888888
# Processing timestamp: 2021-08-10 15:20:00
# Current time & days to expiry: 2021-08-10 2.0069444444444446
# Curr time & days to EXpiry 2021-08-10 2.0069444444444446
# Processing timestamp: 2021-08-10 15:21:00
# Current time & days to expiry: 2021-08-10 2.00625
# Curr time & days to EXpiry 2021-08-10 2.00625
# Processing timestamp: 2021-08-10 15:22:00
# Current time & days to expiry: 2021-08-10 2.0055555555555555
# Curr time & days to EXpiry 2021-08-10 2.0055555555555555
# Processing timestamp: 2021-08-10 15:23:00
# Current time & days to expiry: 2021-08-10 2.004861111111111
# Curr time & days to EXpiry 2021-08-10 2.004861111111111
# Processing timestamp: 2021-08-10 15:24:00
# Current time & days to expiry: 2021-08-10 2.004166666666667
# Curr time & days to EXpiry 2021-08-10 2.004166666666667
# Processing timestamp: 2021-08-10 15:25:00
# Current time & days to expiry: 2021-08-10 2.0034722222222223
# Curr time & days to EXpiry 2021-08-10 2.0034722222222223
# Processing timestamp: 2021-08-10 15:26:00
# Current time & days to expiry: 2021-08-10 2.0027777777777778
# Curr time & days to EXpiry 2021-08-10 2.0027777777777778
# Processing timestamp: 2021-08-10 15:27:00
# Current time & days to expiry: 2021-08-10 2.002083333333333
# Curr time & days to EXpiry 2021-08-10 2.002083333333333
# Processing timestamp: 2021-08-10 15:28:00
# Current time & days to expiry: 2021-08-10 2.001388888888889
# Curr time & days to EXpiry 2021-08-10 2.001388888888889
# Processing timestamp: 2021-08-10 15:29:00
# Current time & days to expiry: 2021-08-10 2.0006944444444446
# Curr time & days to EXpiry 2021-08-10 2.0006944444444446
# Processing timestamp: 2021-08-10 15:30:00
# Current time & days to expiry: 2021-08-10 2.0
# Curr time & days to EXpiry 2021-08-10 2.0
# Processing timestamp: 2021-08-11 09:15:00
# Current time & days to expiry: 2021-08-11 1.2604166666666667
# Curr time & days to EXpiry 2021-08-11 1.2604166666666667
# Processing timestamp: 2021-08-11 09:16:00
# Current time & days to expiry: 2021-08-11 1.2597222222222222
# Curr time & days to EXpiry 2021-08-11 1.2597222222222222
# Processing timestamp: 2021-08-11 09:17:00
# Current time & days to expiry: 2021-08-11 1.2590277777777779
# Curr time & days to EXpiry 2021-08-11 1.2590277777777779
# Processing timestamp: 2021-08-11 09:18:00
# Current time & days to expiry: 2021-08-11 1.2583333333333333
# Curr time & days to EXpiry 2021-08-11 1.2583333333333333
# Processing timestamp: 2021-08-11 09:19:00
# Current time & days to expiry: 2021-08-11 1.257638888888889
# Curr time & days to EXpiry 2021-08-11 1.257638888888889
# Processing timestamp: 2021-08-11 09:20:00
# Current time & days to expiry: 2021-08-11 1.2569444444444444
# Curr time & days to EXpiry 2021-08-11 1.2569444444444444
# Processing timestamp: 2021-08-11 09:21:00
# Current time & days to expiry: 2021-08-11 1.25625
# Curr time & days to EXpiry 2021-08-11 1.25625
# Processing timestamp: 2021-08-11 09:22:00
# Current time & days to expiry: 2021-08-11 1.2555555555555555
# Curr time & days to EXpiry 2021-08-11 1.2555555555555555
# Processing timestamp: 2021-08-11 09:23:00
# Current time & days to expiry: 2021-08-11 1.2548611111111112
# Curr time & days to EXpiry 2021-08-11 1.2548611111111112
# Processing timestamp: 2021-08-11 09:24:00
# Current time & days to expiry: 2021-08-11 1.2541666666666667
# Curr time & days to EXpiry 2021-08-11 1.2541666666666667
# Processing timestamp: 2021-08-11 09:25:00
# Current time & days to expiry: 2021-08-11 1.2534722222222223
# Curr time & days to EXpiry 2021-08-11 1.2534722222222223
# Processing timestamp: 2021-08-11 09:26:00
# Current time & days to expiry: 2021-08-11 1.2527777777777778
# Curr time & days to EXpiry 2021-08-11 1.2527777777777778
# Processing timestamp: 2021-08-11 09:27:00
# Current time & days to expiry: 2021-08-11 1.2520833333333334
# Curr time & days to EXpiry 2021-08-11 1.2520833333333334
# Processing timestamp: 2021-08-11 09:28:00
# Current time & days to expiry: 2021-08-11 1.2513888888888889
# Curr time & days to EXpiry 2021-08-11 1.2513888888888889
# Processing timestamp: 2021-08-11 09:29:00
# Current time & days to expiry: 2021-08-11 1.2506944444444446
# Curr time & days to EXpiry 2021-08-11 1.2506944444444446
# Processing timestamp: 2021-08-11 09:30:00
# Current time & days to expiry: 2021-08-11 1.25
# Curr time & days to EXpiry 2021-08-11 1.25
# Processing timestamp: 2021-08-11 09:31:00
# Current time & days to expiry: 2021-08-11 1.2493055555555554
# Curr time & days to EXpiry 2021-08-11 1.2493055555555554
# Processing timestamp: 2021-08-11 09:32:00
# Current time & days to expiry: 2021-08-11 1.2486111111111111
# Curr time & days to EXpiry 2021-08-11 1.2486111111111111
# Processing timestamp: 2021-08-11 09:33:00
# Current time & days to expiry: 2021-08-11 1.2479166666666666
# Curr time & days to EXpiry 2021-08-11 1.2479166666666666
# Processing timestamp: 2021-08-11 09:34:00
# Current time & days to expiry: 2021-08-11 1.2472222222222222
# Curr time & days to EXpiry 2021-08-11 1.2472222222222222
# Processing timestamp: 2021-08-11 09:35:00
# Current time & days to expiry: 2021-08-11 1.2465277777777777
# Curr time & days to EXpiry 2021-08-11 1.2465277777777777
# Processing timestamp: 2021-08-11 09:36:00
# Current time & days to expiry: 2021-08-11 1.2458333333333333
# Curr time & days to EXpiry 2021-08-11 1.2458333333333333
# Processing timestamp: 2021-08-11 09:37:00
# Current time & days to expiry: 2021-08-11 1.2451388888888888
# Curr time & days to EXpiry 2021-08-11 1.2451388888888888
# Processing timestamp: 2021-08-11 09:38:00
# Current time & days to expiry: 2021-08-11 1.2444444444444445
# Curr time & days to EXpiry 2021-08-11 1.2444444444444445
# Processing timestamp: 2021-08-11 09:39:00
# Current time & days to expiry: 2021-08-11 1.24375
# Curr time & days to EXpiry 2021-08-11 1.24375
# Processing timestamp: 2021-08-11 09:40:00
# Current time & days to expiry: 2021-08-11 1.2430555555555556
# Curr time & days to EXpiry 2021-08-11 1.2430555555555556
# Processing timestamp: 2021-08-11 09:41:00
# Current time & days to expiry: 2021-08-11 1.242361111111111
# Curr time & days to EXpiry 2021-08-11 1.242361111111111
# Processing timestamp: 2021-08-11 09:42:00
# Current time & days to expiry: 2021-08-11 1.2416666666666667
# Curr time & days to EXpiry 2021-08-11 1.2416666666666667
# Processing timestamp: 2021-08-11 09:43:00
# Current time & days to expiry: 2021-08-11 1.2409722222222221
# Curr time & days to EXpiry 2021-08-11 1.2409722222222221
# Processing timestamp: 2021-08-11 09:44:00
# Current time & days to expiry: 2021-08-11 1.2402777777777778
# Curr time & days to EXpiry 2021-08-11 1.2402777777777778
# Processing timestamp: 2021-08-11 09:45:00
# Current time & days to expiry: 2021-08-11 1.2395833333333333
# Curr time & days to EXpiry 2021-08-11 1.2395833333333333
# Processing timestamp: 2021-08-11 09:46:00
# Current time & days to expiry: 2021-08-11 1.238888888888889
# ...
# OI 38374100.0 22743250.0
# OI 38374100.0 22743250.0
# OI 38328050.0 22784850.0
# OI 38328050.0 22784850.0
# OI 38328650.0 22784850.0
# OI 38492050.0 22808550.0
# OI 38492050.0 22808550.0
# OI 38492050.0 22808550.0
# OI 38499300.0 22776650.0
# OI 38499300.0 22776650.0
# OI 38499300.0 22776650.0
# OI 38337550.0 22709950.0
# OI 38337550.0 22709950.0
# OI 38337550.0 22709950.0
# OI 38345050.0 22520400.0
# OI 38345050.0 22520400.0
# OI 38345050.0 22519100.0
# OI 38193550.0 22435000.0
# OI 38193550.0 22435000.0
# OI 38188400.0 22435000.0
# OI 38133900.0 22500100.0
# OI 38133900.0 22500100.0
# OI 38133900.0 22500100.0
# OI 38148650.0 22470200.0
# OI 38148650.0 22470200.0
# OI 38148650.0 22470200.0
# OI 38147900.0 22420150.0
# OI 38147900.0 22420150.0
# OI 38147900.0 22420150.0
# OI 37562900.0 22404050.0
# OI 37562900.0 22404050.0
# OI 37562900.0 22404050.0
# OI 37230350.0 22501700.0
# OI 37230350.0 22501700.0
# OI 37230350.0 22501700.0
# OI 37167750.0 22569600.0
# OI 37167750.0 22569600.0
# OI 37167750.0 22569600.0
# OI 37108800.0 22572100.0
# OI 37108800.0 22572100.0
# OI 37108800.0 22572100.0
# OI 37202050.0 22631250.0
# OI 37202050.0 22631250.0
# OI 37202050.0 22631250.0
# OI 36847500.0 22622900.0
# OI 36847500.0 22622900.0
# OI 36847500.0 22622900.0
# OI 36600000.0 22827900.0
# OI 36600000.0 22827900.0
# OI 36600000.0 22827900.0
# OI 36514200.0 23138750.0
# OI 36514200.0 23138750.0
# OI 36514200.0 23138750.0
# OI 36414150.0 23264400.0
# OI 36414150.0 23264400.0
# OI 36414150.0 23264400.0
# OI 36499250.0 23582250.0
# OI 36499250.0 23582250.0
# OI 36499250.0 23582250.0
# OI 36338000.0 23562950.0
# OI 36338000.0 23562950.0
# OI 36338000.0 23562950.0
# OI 36130350.0 23687200.0
# OI 36130350.0 23687200.0
# OI 36130350.0 23687200.0
# OI 36056600.0 23852000.0
# OI 36056600.0 23852000.0
# OI 36056600.0 23852000.0
# OI 36117500.0 23861750.0
# OI 36117500.0 23861750.0
# OI 36117500.0 23861750.0
# OI 35988250.0 23742500.0
# OI 35988250.0 23742500.0
# OI 35988250.0 23742500.0
# OI 36069850.0 23769550.0
# OI 36069850.0 23769550.0
# OI 36069850.0 23769550.0
# OI 36033900.0 23804300.0
# OI 36033900.0 23804300.0
# OI 36033900.0 23804300.0
# OI 36032250.0 23643500.0
# OI 36032250.0 23643500.0
# OI 36032250.0 23643500.0
# OI 36138000.0 23775500.0
# OI 36138000.0 23775500.0
# OI 36138000.0 23775500.0
# OI 36119750.0 23826650.0
# OI 36119750.0 23826650.0
# OI 36119750.0 23826650.0
# OI 36131000.0 23851700.0
# OI 36131000.0 23851700.0
# OI 36131000.0 23851700.0
# OI 36084650.0 23848800.0
# OI 36084650.0 23848800.0
# OI 36084650.0 23848800.0
# OI 36044800.0 23763950.0
# OI 36044800.0 23763950.0
# OI 36044800.0 23763950.0
# OI 35980500.0 23297300.0
# OI 35980500.0 23297300.0
# OI 35980500.0 23297300.0
# OI 35883850.0 23151800.0
# OI 35883850.0 23151800.0
# OI 35883850.0 23151800.0
# OI 35804550.0 23127850.0
# OI 35804550.0 23127850.0
# OI 35804550.0 23127850.0
# OI 35779150.0 23093350.0
# OI 35779150.0 23093350.0
# OI 35779150.0 23093350.0
# OI 35669750.0 23035650.0
# OI 35669750.0 23035650.0
# OI 35669750.0 23035650.0
# OI 35354850.0 23088400.0
# OI 35354850.0 23088400.0
# OI 35354850.0 23088400.0
# OI 35148850.0 22892450.0
# OI 35148850.0 22892450.0
# OI 35148850.0 22892450.0
# OI 35029000.0 22909150.0
# OI 35029000.0 22909150.0
# OI 35029000.0 22909150.0
# OI 34466800.0 22770650.0
# OI 34466800.0 22770650.0
# OI 34466800.0 22770650.0
# OI 34154300.0 22716800.0
# OI 34154300.0 22716800.0
# OI 34154300.0 22716800.0
# OI 33352650.0 22553300.0
# OI 33352650.0 22553300.0
# OI 34163550.0 18513000.0
# OI 32735600.0 22236700.0
# OI 33559350.0 18294100.0
# OI 33559350.0 18294100.0
# OI 33203450.0 18545800.0
# OI 33203450.0 18545800.0
# OI 33203450.0 18545550.0
# OI 32376300.0 18679150.0
# OI 32376300.0 18678850.0
# OI 32376300.0 18678850.0
# OI 31719850.0 18856800.0
# OI 31719850.0 18856800.0
# OI 31719850.0 18856800.0
# OI 31165300.0 18666700.0
# OI 31165250.0 18666700.0
# OI 31165250.0 18666700.0
# OI 30959450.0 18497050.0
# OI 30960000.0 18497050.0
# OI 30960000.0 18497050.0
# OI 30533150.0 18111350.0
# OI 30533150.0 18111350.0
# OI 30533150.0 18111050.0
# OI 29931850.0 17929700.0
# OI 29931850.0 17929700.0
# OI 29931850.0 17929750.0
# OI 29286350.0 17474900.0
# OI 29286350.0 17474900.0
# OI 29286350.0 17474850.0
# OI 29286350.0 17474850.0
# OI 28780300.0 17230700.0
# OI 28780300.0 17230700.0
# OI 34203950.0 18608350.0
# OI 34203950.0 18608350.0
# OI 30911400.0 19838900.0
# OI 32052350.0 22152550.0
# OI 32052350.0 22152550.0
# OI 32052350.0 22152550.0
# OI 32677300.0 23200150.0
# OI 32677300.0 23200150.0
# OI 32677300.0 23200150.0
# OI 33360500.0 23537950.0
# OI 33360500.0 23537950.0
# OI 33360500.0 23537950.0
# OI 34194400.0 24117700.0
# OI 34194400.0 24117700.0
# OI 34194400.0 24117700.0
# OI 34537250.0 24860950.0
# OI 34537250.0 24860950.0
# OI 34537250.0 24860950.0
# OI 35048750.0 25327000.0
# OI 35048750.0 25327000.0
# OI 35048750.0 25327000.0
# OI 35027400.0 25636500.0
# OI 35027400.0 25637300.0
# OI 35027400.0 25637300.0
# OI 35354950.0 26279550.0
# OI 35354650.0 26279550.0
# OI 35354650.0 26279550.0
# OI 35685700.0 26451350.0
# OI 35684900.0 26451350.0
# OI 35684900.0 26451350.0
# OI 36033000.0 27043800.0
# OI 36033000.0 27043800.0
# OI 36033000.0 27043800.0
# OI 36127300.0 27323400.0
# OI 36127300.0 27323400.0
# OI 36127300.0 27323400.0
# OI 36035350.0 27708400.0
# OI 36035350.0 27708400.0
# OI 36035350.0 27708400.0
# OI 36193700.0 27951150.0
# OI 36193700.0 27951150.0
# OI 36193700.0 27951150.0
# OI 36315100.0 28426600.0
# OI 36315100.0 28426600.0
# OI 40298050.0 27094800.0
# OI 39741400.0 27812400.0
# OI 39741400.0 27813750.0
# OI 39741400.0 27813750.0
# OI 40120200.0 28415000.0
# OI 40120200.0 28415000.0
# OI 40120200.0 28415000.0
# OI 40483750.0 28998350.0
# OI 40483750.0 28998550.0
# OI 36375400.0 30326350.0
# OI 40619450.0 29266250.0
# OI 40619450.0 29265650.0
# OI 40619450.0 29265650.0
# OI 40881400.0 29675050.0
# OI 40881400.0 29675050.0
# OI 40881400.0 29675050.0
# OI 41175350.0 30347400.0
# OI 41175350.0 30347300.0
# OI 37020200.0 31688300.0
# OI 41245200.0 30494300.0
# OI 41245200.0 30494100.0
# OI 41245200.0 30494100.0
# OI 40914350.0 30806550.0
# OI 40914350.0 30806550.0
# OI 40914350.0 30806550.0
# OI 40953250.0 31469850.0
# OI 40953250.0 31469800.0
# OI 40953250.0 31469800.0
# OI 41180900.0 31948050.0
# OI 41180900.0 31948050.0
# OI 41180900.0 31948050.0
# OI 41272000.0 32095500.0
# OI 41272000.0 32096500.0
# OI 41272000.0 32096500.0
# OI 41491100.0 32287900.0
# OI 41491100.0 32287900.0
# OI 41491100.0 32287900.0
# OI 41518750.0 32469350.0
# OI 41518750.0 32469350.0
# OI 41518750.0 32469350.0
# OI 41659250.0 32453550.0
# OI 37446500.0 33776950.0
# OI 41659250.0 32453550.0
# OI 37554700.0 33810650.0
# OI 37554700.0 33810650.0
# OI 37554700.0 33810650.0
# OI 37727950.0 33766350.0
# OI 41944600.0 32416400.0
# OI 41944600.0 32416300.0
# OI 42144950.0 32595400.0
# OI 42143800.0 32596250.0
# OI 42143800.0 32596250.0
# OI 42158250.0 32851750.0
# OI 42158250.0 32851800.0
# OI 42158250.0 32851800.0
# OI 42113850.0 33304150.0
# OI 42113850.0 33304000.0
# OI 42113850.0 33304000.0
# OI 42087150.0 33352500.0
# OI 37856100.0 34705100.0
# OI 42087150.0 33352650.0
# OI 42135950.0 33307350.0
# OI 42135950.0 33307350.0
# OI 42135950.0 33308000.0
# OI 42174300.0 33296900.0
# OI 42174300.0 33296850.0
# OI 42174300.0 33296950.0
# OI 42284950.0 33576900.0
# OI 42281050.0 33576750.0
# OI 42281050.0 33576750.0
# OI 42341000.0 33694450.0
# OI 42340300.0 33694600.0
# OI 42340300.0 33694600.0
# OI 42331600.0 33764150.0
# OI 42331600.0 33764000.0
# OI 42331600.0 33764000.0
# OI 42465600.0 33763150.0
# OI 42479600.0 33762550.0
# OI 42479600.0 33762550.0
# OI 42268650.0 34194350.0
# OI 42268650.0 34194000.0
# OI 42268650.0 34194000.0
# OI 42302750.0 34295350.0
# OI 42316100.0 34295250.0
# OI 42316100.0 34295650.0
# OI 42293250.0 34412300.0
# OI 42293250.0 34412600.0
# OI 42293250.0 34412600.0
# OI 42410950.0 34511050.0
# OI 42409600.0 34511700.0
# OI 42409600.0 34511700.0
# OI 42453400.0 34431300.0
# OI 42453400.0 34431300.0
# OI 42453400.0 34431300.0
# OI 42536200.0 34445000.0
# OI 42536200.0 34445000.0
# OI 42536200.0 34445000.0
# OI 42801900.0 34364050.0
# OI 42801900.0 34365150.0
# OI 42801900.0 34365150.0
# OI 42885350.0 34671700.0
# OI 42880200.0 34672200.0
# OI 42880200.0 34672200.0
# OI 42707350.0 34750200.0
# OI 42707350.0 34750150.0
# OI 42707350.0 34750450.0
# OI 42670100.0 35137450.0
# OI 42670100.0 35137250.0
# OI 42670100.0 35137250.0
# OI 42512300.0 36096400.0
# OI 42512300.0 36094100.0
# OI 42512300.0 36094100.0
# OI 42655350.0 36495750.0
# OI 42655350.0 36495950.0
# OI 42655350.0 36495950.0
# OI 42818050.0 36793650.0
# OI 42818050.0 36794100.0
# OI 42818050.0 36794100.0
# OI 42858000.0 36988850.0
# OI 42858000.0 36988900.0
# OI 42858000.0 36988900.0
# OI 42902300.0 37129150.0
# OI 42901100.0 37124900.0
# OI 42901100.0 37124850.0
# OI 42981200.0 37255950.0
# OI 42981200.0 37256250.0
# OI 42981200.0 37256250.0
# OI 43025500.0 38651350.0
# OI 43025500.0 38651400.0
# OI 43025500.0 38651400.0
# OI 42554800.0 39322250.0
# OI 42554800.0 39322950.0
# OI 42554800.0 39322950.0
# OI 42712100.0 39506850.0
# OI 42705250.0 39506650.0
# OI 42705250.0 39506650.0
# OI 42871800.0 39786150.0
# OI 42871800.0 39785600.0
# OI 42871800.0 39785600.0
# OI 42804400.0 39818250.0
# OI 42804400.0 39817950.0
# OI 42804400.0 39817950.0
# OI 42788900.0 39877150.0
# OI 42791600.0 39877150.0
# OI 42791600.0 39877300.0
# OI 42938700.0 40636600.0
# OI 42936550.0 40637050.0
# OI 42936550.0 40637050.0
# OI 42898650.0 41196600.0
# OI 42898650.0 41195800.0
# OI 42898650.0 41195800.0
# OI 41893150.0 41744000.0
# OI 41846050.0 41748650.0
# OI 41846050.0 41748650.0
# OI 42208350.0 42275300.0
# OI 42269450.0 42278150.0
# OI 42269450.0 42278150.0
# OI 42571950.0 42861650.0
# OI 42605750.0 42861800.0
# OI 42605750.0 42861800.0
# OI 42920350.0 43179750.0
# OI 43013150.0 43179350.0
# OI 43013150.0 43179350.0
# OI 43146350.0 43358550.0
# OI 43137750.0 43357950.0
# OI 43137750.0 43357950.0
# OI 43237900.0 43567700.0
# OI 43216300.0 43620750.0
# OI 43216300.0 43620750.0
# OI 43241150.0 43625500.0
# OI 42931850.0 43937100.0
# OI 42931850.0 43937100.0
# OI 42957500.0 43937100.0
# OI 43140300.0 44127500.0
# OI 43140300.0 44127500.0
# OI 43140300.0 44127500.0
# OI 42916600.0 44419500.0
# OI 42916600.0 44419500.0
# OI 42916600.0 44419500.0
# OI 42967950.0 44310500.0
# OI 42967950.0 44310500.0
# OI 42984950.0 44280950.0
# OI 42925950.0 44303300.0
# OI 42925950.0 44303300.0
# OI 42925950.0 44303300.0
# OI 43029200.0 44426900.0
# OI 43029200.0 44426900.0
# OI 43029200.0 44426900.0
# OI 43171950.0 44463300.0
# OI 43171950.0 44463300.0
# OI 43171950.0 44463300.0
# OI 43189200.0 44580250.0
# OI 43189200.0 44580250.0
# OI 43189200.0 44579600.0
# OI 43489600.0 45020200.0
# OI 43489600.0 45020200.0
# OI 43489600.0 45020200.0
# OI 43515050.0 45438450.0
# OI 43515050.0 45438450.0
# OI 43515050.0 45438450.0
# OI 43541100.0 45666500.0
# OI 43541100.0 45666300.0
# OI 43541100.0 45666300.0
# OI 43467400.0 46343250.0
# OI 43467400.0 46343250.0
# OI 43467400.0 46343250.0
# OI 43005250.0 46904000.0
# OI 43005250.0 46904000.0
# OI 43005250.0 46904000.0
# OI 41867600.0 47132000.0
# OI 41867600.0 47132000.0
# OI 41867600.0 47132000.0
# OI 41869700.0 47185600.0
# OI 41869700.0 47185600.0
# OI 41869700.0 47185600.0
# OI 42278800.0 47334050.0
# OI 42278800.0 47334050.0
# OI 42278800.0 47334050.0
# OI 42495450.0 47507150.0
# OI 42495450.0 47507150.0
# OI 42495450.0 47507150.0
# OI 42622450.0 47622250.0
# OI 42622450.0 47622250.0
# OI 42622450.0 47622250.0
# OI 42799450.0 47871400.0
# OI 42799450.0 47871400.0
# OI 42799450.0 47871400.0
# OI 43015700.0 47754250.0
# OI 43015700.0 47754250.0
# OI 43015700.0 47754250.0
# OI 43039800.0 47584100.0
# OI 43039800.0 47584100.0
# OI 43039800.0 47584100.0
# OI 42985250.0 47273750.0
# OI 42985250.0 47272100.0
# OI 42985250.0 47272100.0
# OI 42845050.0 46756700.0
# OI 42845050.0 46756700.0
# OI 42845050.0 46756700.0
# OI 42762300.0 46606000.0
# OI 42762300.0 46606000.0
# OI 42762300.0 46606000.0
# OI 42959150.0 46661150.0
# OI 42959150.0 46661150.0
# OI 42959150.0 46661150.0
# OI 43034850.0 46654400.0
# OI 43034850.0 46654400.0
# OI 43034850.0 46654400.0
# OI 42876600.0 46412050.0
# OI 42876600.0 46412050.0
# OI 42876600.0 46412050.0
# OI 42838500.0 45878200.0
# OI 42838500.0 45878200.0
# OI 42838500.0 45878200.0
# OI 42949100.0 45420300.0
# OI 42949100.0 45420300.0
# OI 42949100.0 45420300.0
# OI 42390950.0 44803700.0
# OI 42390950.0 44803700.0
# OI 42390950.0 44803700.0
# OI 41971650.0 43981200.0
# OI 41971650.0 43981200.0
# OI 41971650.0 43981200.0
# OI 41352200.0 42540000.0
# OI 41352200.0 42540000.0
# OI 41352200.0 42540000.0
# OI 40713200.0 41564550.0
# OI 40713200.0 41564550.0
# OI 40713200.0 41564550.0
# OI 40357150.0 40685900.0
# OI 40357150.0 40685900.0
# OI 40357150.0 40685900.0
# OI 39648900.0 39595650.0
# OI 39648900.0 39595650.0
# OI 39648900.0 39595650.0
# OI 38604450.0 39552450.0
# OI 38604450.0 39552450.0
# OI 38604450.0 39552450.0
# OI 38151250.0 39160900.0
# OI 38151250.0 39160900.0
# OI 38151250.0 39160900.0
# OI 37510950.0 38137550.0
# OI 37510950.0 38137550.0
# OI 37510950.0 38137550.0
# OI 37519300.0 37769300.0
# OI 37519300.0 37769300.0
# OI 37519300.0 37769300.0
# OI 37220000.0 37382150.0
# OI 37220000.0 37382200.0
# OI 37220000.0 37382200.0
# OI 36780400.0 37025900.0
# OI 36780400.0 37025950.0
# OI 36780400.0 37025950.0
# OI 36449600.0 36597600.0
# OI 36449600.0 36597600.0
# OI 36449600.0 36597600.0
# OI 36073650.0 36195400.0
# OI 36073650.0 36195400.0
# OI 36073650.0 36195400.0
# OI 34498650.0 36248050.0
# OI 34498650.0 36248050.0
# OI 34498650.0 36248050.0
# OI 33542600.0 35827650.0
# OI 33542600.0 35827650.0
# OI 33542600.0 35827650.0
# OI 32952250.0 35667000.0
# OI 32952250.0 35667000.0
# OI 32952250.0 35667000.0
# OI 32190950.0 35071850.0
# OI 32190950.0 35071850.0
# OI 32190950.0 35071850.0
# OI 30857950.0 34586550.0
# OI 30857950.0 34586550.0
# OI 30857950.0 34586550.0
# OI 29254050.0 33799250.0
# OI 29254050.0 33799250.0
# OI 29254050.0 33799250.0
# OI 28219100.0 32132950.0
# OI 28219100.0 32132950.0
# OI 28219100.0 32132950.0
# OI 26865050.0 30229500.0
# OI 26865050.0 30229500.0
# OI 26865050.0 30229500.0
# OI 25353100.0 28699200.0
# OI 25353100.0 28699050.0
# OI 25353100.0 28699050.0
# OI 23799650.0 26103300.0
# OI 23799650.0 26103300.0
# OI 23799650.0 26103300.0
# OI 23799650.0 26103300.0
#                     Ticker     Open     High      Low    Close  Volume  \
# Date/Time
# 2021-08-06 09:15:00  NIFTY  16304.4  16304.4  16274.9  16289.0       0
# 2021-08-06 09:16:00  NIFTY  16290.0  16314.9  16285.7  16312.1       0
# 2021-08-06 09:17:00  NIFTY  16310.6  16312.0  16303.9  16307.6       0
# 2021-08-06 09:18:00  NIFTY  16306.4  16317.5  16301.9  16317.5       0
# 2021-08-06 09:19:00  NIFTY  16317.8  16318.6  16313.0  16316.3       0
#
#                      Open Interest  INDIAVIX  ATM_Delta     ATM_OI  ...  \
# Date/Time                                                           ...
# 2021-08-06 09:15:00              0     13.05   0.524913  2791400.0  ...
# 2021-08-06 09:16:00              0     12.98   0.530710  2791400.0  ...
# 2021-08-06 09:17:00              0     13.08   0.529341  3005400.0  ...
# 2021-08-06 09:18:00              0     13.12   0.531621  3005400.0  ...
# 2021-08-06 09:19:00              0     13.12   0.531487  3005400.0  ...
#
#                      OTM4_PE_Gamma  OTM4_PE_Theta  OTM4_PE_Vega  OTM4_PE_Rho  \
# Date/Time
# 2021-08-06 09:15:00       0.000078      -0.440285      0.084521    -0.016339
# 2021-08-06 09:16:00       0.000081      -0.419614      0.084683    -0.016223
# 2021-08-06 09:17:00       0.000081      -0.421468      0.084656    -0.016237
# 2021-08-06 09:18:00       0.000082      -0.417664      0.084701    -0.016200
# 2021-08-06 09:19:00       0.000082      -0.416670      0.084696    -0.016198
#
#                      OTM5_PE_Delta  OTM5_PE_OI  OTM5_PE_Gamma  OTM5_PE_Theta  \
# Date/Time
# 2021-08-06 09:15:00      -0.447125      9050.0       0.000069      -0.494760
# 2021-08-06 09:16:00      -0.446844      9050.0       0.000070      -0.487877
# 2021-08-06 09:17:00      -0.445951      9250.0       0.000069      -0.494636
# 2021-08-06 09:18:00      -0.445117      9250.0       0.000069      -0.495748
# 2021-08-06 09:19:00      -0.446200      9250.0       0.000069      -0.490104
#
#                      OTM5_PE_Vega  OTM5_PE_Rho
# Date/Time
# 2021-08-06 09:15:00      0.084357    -0.016653
# 2021-08-06 09:16:00      0.084464    -0.016584
# 2021-08-06 09:17:00      0.084411    -0.016612
# 2021-08-06 09:18:00      0.084433    -0.016594
# 2021-08-06 09:19:00      0.084453    -0.016576
#
# [5 rows x 163 columns]
# Greeks and Open Interest data have been populated and the DataFrame has been saved to CSV.

# %%
print(nifty_with_greeks.head())
# Out:
#                     Ticker     Open     High      Low    Close  Volume  \
# Date/Time
# 2021-08-06 09:15:00  NIFTY  16304.4  16304.4  16274.9  16289.0       0
# 2021-08-06 09:16:00  NIFTY  16290.0  16314.9  16285.7  16312.1       0
# 2021-08-06 09:17:00  NIFTY  16310.6  16312.0  16303.9  16307.6       0
# 2021-08-06 09:18:00  NIFTY  16306.4  16317.5  16301.9  16317.5       0
# 2021-08-06 09:19:00  NIFTY  16317.8  16318.6  16313.0  16316.3       0
#
#                      Open Interest  INDIAVIX  ATM_Delta     ATM_OI  ...  \
# Date/Time                                                           ...
# 2021-08-06 09:15:00              0     13.05   0.524913  2791400.0  ...
# 2021-08-06 09:16:00              0     12.98   0.530710  2791400.0  ...
# 2021-08-06 09:17:00              0     13.08   0.529341  3005400.0  ...
# 2021-08-06 09:18:00              0     13.12   0.531621  3005400.0  ...
# 2021-08-06 09:19:00              0     13.12   0.531487  3005400.0  ...
#
#                      OTM4_PE_Theta  OTM4_PE_Vega  OTM4_PE_Rho  OTM5_PE_Delta  \
# Date/Time
# 2021-08-06 09:15:00      -0.440285      0.084521    -0.016339      -0.447125
# 2021-08-06 09:16:00      -0.419614      0.084683    -0.016223      -0.446844
# 2021-08-06 09:17:00      -0.421468      0.084656    -0.016237      -0.445951
# 2021-08-06 09:18:00      -0.417664      0.084701    -0.016200      -0.445117
# 2021-08-06 09:19:00      -0.416670      0.084696    -0.016198      -0.446200
#
#                      OTM5_PE_OI  OTM5_PE_Gamma  OTM5_PE_Theta  OTM5_PE_Vega  \
# Date/Time
# 2021-08-06 09:15:00      9050.0       0.000069      -0.494760      0.084357
# 2021-08-06 09:16:00      9050.0       0.000070      -0.487877      0.084464
# 2021-08-06 09:17:00      9250.0       0.000069      -0.494636      0.084411
# 2021-08-06 09:18:00      9250.0       0.000069      -0.495748      0.084433
# 2021-08-06 09:19:00      9250.0       0.000069      -0.490104      0.084453
#
#                      OTM5_PE_Rho  PCR_Volume
# Date/Time
# 2021-08-06 09:15:00    -0.016653    0.819552
# 2021-08-06 09:16:00    -0.016584    0.587300
# 2021-08-06 09:17:00    -0.016612    0.687586
# 2021-08-06 09:18:00    -0.016594    0.666823
# 2021-08-06 09:19:00    -0.016576    0.648473
#
# [5 rows x 164 columns]

# %%
print("PCR_Volume" in nifty_with_greeks.columns)
# Out:
# True

# %%
pd.set_option('display.max_columns', None)
print(nifty_with_greeks.columns.tolist())
# Out:
# ['Ticker', 'Open', 'High', 'Low', 'Close', 'Volume', 'Open Interest', 'INDIAVIX', 'ATM_Delta', 'ATM_OI', 'ATM_Call_Volume', 'ATM_Put_Volume', 'ATM_Gamma', 'ATM_Theta', 'ATM_Vega', 'ATM_Rho', 'ITM1_Delta', 'ITM1_OI', 'ITM1_Call_Volume', 'ITM1_Put_Volume', 'ITM1_Gamma', 'ITM1_Theta', 'ITM1_Vega', 'ITM1_Rho', 'OTM1_Delta', 'OTM1_OI', 'OTM1_Call_Volume', 'OTM1_Put_Volume', 'OTM1_Gamma', 'OTM1_Theta', 'OTM1_Vega', 'OTM1_Rho', 'ITM2_Delta', 'ITM2_OI', 'ITM2_Call_Volume', 'ITM2_Put_Volume', 'ITM2_Gamma', 'ITM2_Theta', 'ITM2_Vega', 'ITM2_Rho', 'OTM2_Delta', 'OTM2_OI', 'OTM2_Call_Volume', 'OTM2_Put_Volume', 'OTM2_Gamma', 'OTM2_Theta', 'OTM2_Vega', 'OTM2_Rho', 'ITM3_Delta', 'ITM3_OI', 'ITM3_Call_Volume', 'ITM3_Put_Volume', 'ITM3_Gamma', 'ITM3_Theta', 'ITM3_Vega', 'ITM3_Rho', 'OTM3_Delta', 'OTM3_OI', 'OTM3_Call_Volume', 'OTM3_Put_Volume', 'OTM3_Gamma', 'OTM3_Theta', 'OTM3_Vega', 'OTM3_Rho', 'ITM4_Delta', 'ITM4_OI', 'ITM4_Call_Volume', 'ITM4_Put_Volume', 'ITM4_Gamma', 'ITM4_Theta', 'ITM4_Vega', 'ITM4_Rho', 'OTM4_Delta', 'OTM4_OI', 'OTM4_Call_Volume', 'OTM4_Put_Volume', 'OTM4_Gamma', 'OTM4_Theta', 'OTM4_Vega', 'OTM4_Rho', 'ITM5_Delta', 'ITM5_OI', 'ITM5_Call_Volume', 'ITM5_Put_Volume', 'ITM5_Gamma', 'ITM5_Theta', 'ITM5_Vega', 'ITM5_Rho', 'OTM5_Delta', 'OTM5_OI', 'OTM5_Call_Volume', 'OTM5_Put_Volume', 'OTM5_Gamma', 'OTM5_Theta', 'OTM5_Vega', 'OTM5_Rho', 'PCR', 'ATM_PE_Delta', 'ATM_PE_OI', 'ATM_PE_Gamma', 'ATM_PE_Theta', 'ATM_PE_Vega', 'ATM_PE_Rho', 'ITM1_PE_Delta', 'ITM1_PE_OI', 'ITM1_PE_Gamma', 'ITM1_PE_Theta', 'ITM1_PE_Vega', 'ITM1_PE_Rho', 'ITM2_PE_Delta', 'ITM2_PE_OI', 'ITM2_PE_Gamma', 'ITM2_PE_Theta', 'ITM2_PE_Vega', 'ITM2_PE_Rho', 'ITM3_PE_Delta', 'ITM3_PE_OI', 'ITM3_PE_Gamma', 'ITM3_PE_Theta', 'ITM3_PE_Vega', 'ITM3_PE_Rho', 'ITM4_PE_Delta', 'ITM4_PE_OI', 'ITM4_PE_Gamma', 'ITM4_PE_Theta', 'ITM4_PE_Vega', 'ITM4_PE_Rho', 'ITM5_PE_Delta', 'ITM5_PE_OI', 'ITM5_PE_Gamma', 'ITM5_PE_Theta', 'ITM5_PE_Vega', 'ITM5_PE_Rho', 'OTM1_PE_Delta', 'OTM1_PE_OI', 'OTM1_PE_Gamma', 'OTM1_PE_Theta', 'OTM1_PE_Vega', 'OTM1_PE_Rho', 'OTM2_PE_Delta', 'OTM2_PE_OI', 'OTM2_PE_Gamma', 'OTM2_PE_Theta', 'OTM2_PE_Vega', 'OTM2_PE_Rho', 'OTM3_PE_Delta', 'OTM3_PE_OI', 'OTM3_PE_Gamma', 'OTM3_PE_Theta', 'OTM3_PE_Vega', 'OTM3_PE_Rho', 'OTM4_PE_Delta', 'OTM4_PE_OI', 'OTM4_PE_Gamma', 'OTM4_PE_Theta', 'OTM4_PE_Vega', 'OTM4_PE_Rho', 'OTM5_PE_Delta', 'OTM5_PE_OI', 'OTM5_PE_Gamma', 'OTM5_PE_Theta', 'OTM5_PE_Vega', 'OTM5_PE_Rho', 'PCR_Volume']

# %%
print(nifty_with_greeks['PCR_Volume'])
# Out:
# Date/Time
# 2021-08-06 09:15:00    0.819552
# 2021-08-06 09:16:00    0.587300
# 2021-08-06 09:17:00    0.687586
# 2021-08-06 09:18:00    0.666823
# 2021-08-06 09:19:00    0.648473
#                          ...
# 2021-08-12 15:26:00    1.304063
# 2021-08-12 15:27:00    1.544585
# 2021-08-12 15:28:00    1.182061
# 2021-08-12 15:29:00    0.893059
# 2021-08-12 15:30:00    0.893059
# Name: PCR_Volume, Length: 1879, dtype: float64
