# %% [markdown]
# <a href="https://colab.research.google.com/github/jjikku/OptiGene-Algo/blob/main/ICT_Group_2_ML_AI_Algo_Trading_data_aggregation_pre_processing_weekly_8_14_Oct_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# Specify the exact path to the CSV file
file_path = "/content/drive/My Drive/NIfty_Dataset/08-14--OCT-2021-WEEKLY-expiry_data__VEGE_NF_AND_BNF_Options.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Exclude rows where the ticker contains any of the following
excluded_tickers = [
    "BANKNIFTY", "FINNIFTY", "FUT", "NIFTYAUTO", "NIFTYENERGY",
    "NIFTYFINSERVICE", "NIFTYFMCG", "NIFTYINFRA", "NIFTYIT", "NIFTYMEDIA",
    "NIFTYMETAL", "NIFTYMIDCAP50", "NIFTYPHARMA", "NIFTYPSUBANK",
    "NIFTYREALTY", "USDINR-I"
]

# Create a regular expression pattern that matches any of the excluded tickers
pattern = '|'.join(excluded_tickers)

# Apply the mask to filter the DataFrame
mask = ~df['Ticker'].str.contains(pattern)
df_filtered = df[mask]

# Get unique values in the 'Ticker' column after filtering
unique_tickers = df_filtered['Ticker'].unique()

# Extract all rows that match the unique tickers
final_df = df[df['Ticker'].isin(unique_tickers)]

# Create a new CSV file with the extracted rows
output_file_path = "/content/drive/My Drive/NIfty_Dataset/weekly_filtered_tickers_data_8_14_Oct.csv"
final_df.to_csv(output_file_path, index=False)

print(f"Created new CSV file at: {output_file_path}")
# Out:
# Mounted at /content/drive
# Created new CSV file at: /content/drive/My Drive/NIfty_Dataset/weekly_filtered_tickers_data_8_14_Oct.csv

# %%
# print(unique_tickers)

# %%
# final_df.count()

# %%
# final_df['Open Interest'].count()

# %%
# non_zero_count = final_df['Open Interest'].ne(0).sum()
# print(f"The count of non-zero 'Open Interest' values is: {non_zero_count}")

# %%
# Create a separate DataFrame for each unique ticker and store it in a dictionary
dfs = {ticker: df[df['Ticker'] == ticker] for ticker in unique_tickers}

# Now dfs is a dictionary with tickers as keys and the corresponding DataFrame as values

# Assuming df is your original DataFrame with all tickers
for ticker in unique_tickers:
    # Select the DataFrame for the current ticker
    ticker_df = df[df['Ticker'] == ticker].copy()  # Use copy to avoid SettingWithCopyWarning

    # Convert 'Date/Time' to datetime and set as index
    ticker_df['Date/Time'] = pd.to_datetime(ticker_df['Date/Time'], format='%d-%m-%Y %H:%M:%S')
    ticker_df.set_index('Date/Time', inplace=True)

    # Remove duplicate indices if any
    ticker_df = ticker_df[~ticker_df.index.duplicated(keep='first')]

    # Assign the processed DataFrame back to the dfs dictionary
    dfs[ticker] = ticker_df

# Now dfs is a dictionary where each value is a DataFrame with 'Date/Time' as a datetime index

# %%
# Iterate through the dfs dictionary
for ticker, dataframe in dfs.items():
    # Check if the ticker ends with 'PE' or 'CE'
    if ticker.endswith('PE') or ticker.endswith('CE'):
        # Forward fill any NaN values
        dataframe['Open Interest'] = dataframe['Open Interest'].fillna(method='ffill')

        # Replace zero values with the forward filled values
        dataframe['Open Interest'] = dataframe['Open Interest'].replace(to_replace=0, method='ffill')

        # Assign the processed DataFrame back to the dfs dictionary
        dfs[ticker] = dataframe

# %%
import numpy as np
# Get the DataFrame for NIFTY as the reference
reference_df = dfs['NIFTY'].copy()

# Get all timestamps from the NIFTY DataFrame
reference_timestamps = reference_df.index
print("REF",reference_timestamps)

# Function to insert missing timestamps into a DataFrame
def insert_missing_timestamps(df, reference_ts):
    # Ensure the DataFrame index is unique and sorted
    df = df[~df.index.duplicated(keep='first')].sort_index()

    # Find the missing timestamps
    missing_timestamps = reference_ts.difference(df.index)

    # Insert rows with NaNs for missing timestamps
    for ts in missing_timestamps:
        if ts not in df.index:
            df.loc[ts] = [np.nan] * len(df.columns)

    # Sort the DataFrame after inserting new rows
    df.sort_index(inplace=True)

    return df

# Iterate over each DataFrame in dfs
for ticker, dataframe in dfs.items():
    if ticker != 'NIFTY':  # Skip the NIFTY DataFrame as it is the reference
        # Insert missing timestamps without altering existing data
        print("TICKER",ticker)
        dfs[ticker] = insert_missing_timestamps(dataframe, reference_timestamps)
# Out:
# REF DatetimeIndex(['2021-10-08 09:15:00', '2021-10-08 09:16:00',
#                '2021-10-08 09:17:00', '2021-10-08 09:18:00',
#                '2021-10-08 09:19:00', '2021-10-08 09:20:00',
#                '2021-10-08 09:21:00', '2021-10-08 09:22:00',
#                '2021-10-08 09:23:00', '2021-10-08 09:24:00',
#                ...
#                '2021-10-14 15:21:00', '2021-10-14 15:22:00',
#                '2021-10-14 15:23:00', '2021-10-14 15:24:00',
#                '2021-10-14 15:25:00', '2021-10-14 15:26:00',
#                '2021-10-14 15:27:00', '2021-10-14 15:28:00',
#                '2021-10-14 15:29:00', '2021-10-14 15:30:00'],
#               dtype='datetime64[ns]', name='Date/Time', length=1878, freq=None)
# TICKER INDIAVIX
# TICKER NIFTYWK16000CE
# TICKER NIFTYWK16000PE
# TICKER NIFTYWK16050CE
# TICKER NIFTYWK16050PE
# TICKER NIFTYWK16100CE
# TICKER NIFTYWK16100PE
# TICKER NIFTYWK16150CE
# TICKER NIFTYWK16150PE
# TICKER NIFTYWK16200CE
# TICKER NIFTYWK16200PE
# TICKER NIFTYWK16250CE
# TICKER NIFTYWK16250PE
# TICKER NIFTYWK16300CE
# TICKER NIFTYWK16300PE
# TICKER NIFTYWK16350CE
# TICKER NIFTYWK16350PE
# TICKER NIFTYWK16400CE
# TICKER NIFTYWK16400PE
# TICKER NIFTYWK16450CE
# TICKER NIFTYWK16450PE
# TICKER NIFTYWK16500CE
# TICKER NIFTYWK16500PE
# TICKER NIFTYWK16550CE
# TICKER NIFTYWK16550PE
# TICKER NIFTYWK16600CE
# TICKER NIFTYWK16600PE
# TICKER NIFTYWK16650CE
# TICKER NIFTYWK16650PE
# TICKER NIFTYWK16700CE
# TICKER NIFTYWK16700PE
# TICKER NIFTYWK16750CE
# TICKER NIFTYWK16750PE
# TICKER NIFTYWK16800CE
# TICKER NIFTYWK16800PE
# TICKER NIFTYWK16850CE
# TICKER NIFTYWK16850PE
# TICKER NIFTYWK16900CE
# TICKER NIFTYWK16900PE
# TICKER NIFTYWK16950CE
# TICKER NIFTYWK16950PE
# TICKER NIFTYWK17000CE
# TICKER NIFTYWK17000PE
# TICKER NIFTYWK17050CE
# TICKER NIFTYWK17050PE
# TICKER NIFTYWK17100CE
# TICKER NIFTYWK17100PE
# TICKER NIFTYWK17150CE
# TICKER NIFTYWK17150PE
# TICKER NIFTYWK17200CE
# TICKER NIFTYWK17200PE
# TICKER NIFTYWK17250CE
# TICKER NIFTYWK17250PE
# TICKER NIFTYWK17300CE
# TICKER NIFTYWK17300PE
# TICKER NIFTYWK17350CE
# TICKER NIFTYWK17350PE
# TICKER NIFTYWK17400CE
# TICKER NIFTYWK17400PE
# TICKER NIFTYWK17450CE
# TICKER NIFTYWK17450PE
# TICKER NIFTYWK17500CE
# TICKER NIFTYWK17500PE
# TICKER NIFTYWK17550CE
# TICKER NIFTYWK17550PE
# TICKER NIFTYWK17600CE
# TICKER NIFTYWK17600PE
# TICKER NIFTYWK17650CE
# TICKER NIFTYWK17650PE
# TICKER NIFTYWK17700CE
# TICKER NIFTYWK17700PE
# TICKER NIFTYWK17750CE
# TICKER NIFTYWK17750PE
# TICKER NIFTYWK17800CE
# TICKER NIFTYWK17800PE
# TICKER NIFTYWK17850CE
# TICKER NIFTYWK17850PE
# TICKER NIFTYWK17900CE
# TICKER NIFTYWK17900PE
# TICKER NIFTYWK17950CE
# TICKER NIFTYWK17950PE
# TICKER NIFTYWK18000CE
# TICKER NIFTYWK18000PE
# TICKER NIFTYWK18050CE
# TICKER NIFTYWK18050PE
# TICKER NIFTYWK18100CE
# TICKER NIFTYWK18100PE
# TICKER NIFTYWK18150CE
# TICKER NIFTYWK18150PE
# TICKER NIFTYWK18200CE
# TICKER NIFTYWK18200PE
# TICKER NIFTYWK18250CE
# TICKER NIFTYWK18250PE
# TICKER NIFTYWK18300CE
# TICKER NIFTYWK18300PE
# TICKER NIFTYWK18350CE
# TICKER NIFTYWK18350PE
# TICKER NIFTYWK18400CE
# TICKER NIFTYWK18400PE
# TICKER NIFTYWK18450CE
# TICKER NIFTYWK18450PE
# TICKER NIFTYWK18500CE
# TICKER NIFTYWK18500PE
# TICKER NIFTYWK18550CE
# TICKER NIFTYWK18550PE
# TICKER NIFTYWK18600CE
# TICKER NIFTYWK18600PE
# TICKER NIFTYWK18650CE
# TICKER NIFTYWK18650PE
# TICKER NIFTYWK18700CE
# TICKER NIFTYWK18700PE
# TICKER NIFTYWK18750CE
# TICKER NIFTYWK18750PE
# TICKER NIFTYWK18800CE
# TICKER NIFTYWK18800PE
# TICKER NIFTYWK18850CE
# TICKER NIFTYWK18850PE
# TICKER NIFTYWK18900CE
# TICKER NIFTYWK18900PE
# TICKER NIFTYWK18950CE
# TICKER NIFTYWK18950PE
# TICKER NIFTYWK19000CE
# TICKER NIFTYWK19000PE
# TICKER NIFTYWK19050CE
# TICKER NIFTYWK19050PE
# TICKER NIFTYWK19100CE
# TICKER NIFTYWK19100PE
# TICKER NIFTYWK19150CE
# TICKER NIFTYWK19150PE
# TICKER NIFTYWK19200CE
# TICKER NIFTYWK19250CE
# TICKER NIFTYWK19300CE
# TICKER NIFTYWK19350CE
# TICKER NIFTYWK19350PE
# TICKER NIFTYWK19400CE
# TICKER NIFTYWK19450CE
# TICKER NIFTYWK19450PE

# %%
# # Define trading hours
# trading_hours = pd.date_range(start='09:15:00', end='15:30:00', freq='1min')

# # Get the DataFrame for NIFTY as the reference
# reference_df = dfs['NIFTY'].copy()

# # Generate a full range of timestamps for all trading days in the reference NIFTY DataFrame
# all_trading_days = reference_df.index.normalize().unique()
# all_possible_timestamps = pd.DatetimeIndex([pd.Timestamp(day) + pd.Timedelta(minutes=m.minute + m.hour * 60)
#                                             for day in all_trading_days for m in trading_hours])

# # Now update all DataFrames in dfs to have the same timestamps as the reference NIFTY DataFrame
# for ticker, dataframe in dfs.items():
#     # Reindex to the full range of possible timestamps, forward filling the missing data
#     dataframe = dataframe.reindex(all_possible_timestamps, method='ffill')

#     # Forward fill the Open Interest, if the ticker ends with 'PE' or 'CE'
#     if ticker.endswith(('PE', 'CE')):
#         dataframe['Open Interest'].fillna(method='ffill', inplace=True)
#         dataframe['Open Interest'].replace(to_replace=0, method='ffill', inplace=True)

#     # Update the dictionary with the modified DataFrame
#     dfs[ticker] = dataframe

# # After this loop, each DataFrame in dfs should have no missing timestamps and the 'Open Interest' column should be forward filled.

# %%
# Define the market open and close times
market_open_time = '09:15:00'
market_close_time = '15:30:00'

# Create a new dictionary to store the filled DataFrames
filled_dfs = {}

for ticker, dataframe in dfs.items():
    # Copy the DataFrame to avoid modifying the original
    df_filled = dataframe.copy()

    # Get unique trading days
    trading_days = df_filled.index.normalize().unique()

    # Forward fill for each day
    for day in trading_days:
        # Select the data for the current trading day
        day_data = df_filled[df_filled.index.date == day.date()]

        # Forward fill the data for the current day
        df_filled.loc[day_data.index] = day_data.fillna(method='ffill')

    # Now, backward fill the entire DataFrame to cover the start of the day
    df_filled = df_filled.fillna(method='bfill')

    # Assign the filled DataFrame to the new dictionary
    filled_dfs[ticker] = df_filled

# %%
# Assuming filled_dfs is your dictionary containing DataFrames with filled values
for ticker in unique_tickers:
    # Select the DataFrame for the current ticker
    ticker_df = filled_dfs[ticker].copy()  # Use copy to avoid SettingWithCopyWarning

    # Since filled_dfs already contains the DataFrames with 'Date/Time' as a datetime index,
    #  do not need to convert 'Date/Time' again, and  can use ticker_df directly if needed

    # Remove duplicate indices if any (if this step is still necessary)
    ticker_df = ticker_df[~ticker_df.index.duplicated(keep='first')]


    # Assign the processed DataFrame back to the dfs dictionary
    dfs[ticker] = ticker_df

# Now dfs is a dictionary where each value is a DataFrame with 'Date/Time' as a datetime index

# %%
print(dfs['NIFTY'])
# Out:
#                     Ticker     Open     High      Low    Close  Volume  \
# Date/Time
# 2021-10-08 09:15:00  NIFTY  17886.8  17892.5  17869.6  17885.3       0
# 2021-10-08 09:16:00  NIFTY  17886.1  17891.5  17873.5  17873.5       0
# 2021-10-08 09:17:00  NIFTY  17873.7  17881.2  17868.4  17871.2       0
# 2021-10-08 09:18:00  NIFTY  17872.0  17879.3  17871.8  17873.4       0
# 2021-10-08 09:19:00  NIFTY  17873.9  17878.7  17865.1  17865.1       0
# ...                    ...      ...      ...      ...      ...     ...
# 2021-10-14 15:26:00  NIFTY  18336.6  18338.3  18334.6  18335.8       0
# 2021-10-14 15:27:00  NIFTY  18336.2  18339.7  18334.5  18335.9       0
# 2021-10-14 15:28:00  NIFTY  18336.8  18338.5  18332.2  18334.5       0
# 2021-10-14 15:29:00  NIFTY  18334.0  18339.0  18332.5  18339.0       0
# 2021-10-14 15:30:00  NIFTY  18335.7  18335.7  18335.7  18335.7       0
#
#                      Open Interest
# Date/Time
# 2021-10-08 09:15:00              0
# 2021-10-08 09:16:00              0
# 2021-10-08 09:17:00              0
# 2021-10-08 09:18:00              0
# 2021-10-08 09:19:00              0
# ...                            ...
# 2021-10-14 15:26:00              0
# 2021-10-14 15:27:00              0
# 2021-10-14 15:28:00              0
# 2021-10-14 15:29:00              0
# 2021-10-14 15:30:00              0
#
# [1878 rows x 7 columns]

# %%
# Assuming dfs['NIFTY'] is the DataFrame you want to save
nifty_df = dfs['NIFTY']

# Specify the path in your Google Drive where you want to save the CSV
csv_file_path = '/content/drive/My Drive/NIfty_Dataset/NIFTY_8_14_Oct_2021.csv'

# Save the DataFrame to CSV
nifty_df.to_csv(csv_file_path, index=True)

print(f"DataFrame saved to {csv_file_path}")
# Out:
# DataFrame saved to /content/drive/My Drive/NIfty_Dataset/NIFTY_8_14_Oct_2021.csv

# %%
# Assuming dfs['NIFTY'] is the DataFrame you want to save
indiavix_df = dfs['INDIAVIX']

# Specify the path in your Google Drive where you want to save the CSV
csv_file_path = '/content/drive/My Drive/NIfty_Dataset/INDIAVIX_8_14_Oct_2021.csv'

# Save the DataFrame to CSV
indiavix_df.to_csv(csv_file_path, index=True)

print(f"DataFrame saved to {csv_file_path}")
# Out:
# DataFrame saved to /content/drive/My Drive/NIfty_Dataset/INDIAVIX_8_14_Oct_2021.csv

# %%
# !pip install mibian
# Out:
# Collecting mibian
#   Downloading mibian-0.1.3.zip (4.3 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mibian
#   Building wheel for mibian (setup.py) ... done
#   Created wheel for mibian: filename=mibian-0.1.3-py3-none-any.whl size=4024 sha256=b708c086bb4cbf75e5f91f03639f13008f07e39119db805d8d0f8de8d9b4efe6
#   Stored in directory: /root/.cache/pip/wheels/2c/4f/a7/be034e17cc306b0850f5f1a5b4541281b49475c58620a7ff40
# Successfully built mibian
# Installing collected packages: mibian
# Successfully installed mibian-0.1.3

# %%
indiavix_df = pd.read_csv('/content/drive/My Drive/NIfty_Dataset/INDIAVIX_8_14_Oct_2021.csv')
# Print the columns to check the exact name of the 'Date/Time' column
print(indiavix_df.columns)
# Out:
# Index(['Date/Time', 'Ticker', 'Open', 'High', 'Low', 'Close', 'Volume',
#        'Open Interest'],
#       dtype='object')

# %%
print(indiavix_df.index)
# Out:
# RangeIndex(start=0, stop=1878, step=1)

# %%
# !pip install datetime
# Out:
# Collecting datetime
#   Downloading DateTime-5.3-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 2.0 MB/s eta 0:00:00
# Collecting zope.interface (from datetime)
#   Downloading zope.interface-6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from datetime) (2023.3.post1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from zope.interface->datetime) (67.7.2)
# Installing collected packages: zope.interface, datetime
# Successfully installed datetime-5.3 zope.interface-6.1

# %%
import pandas as pd
import numpy as np
import mibian
from datetime import time, datetime, timedelta


indiavix_df = pd.read_csv('/content/drive/My Drive/NIfty_Dataset/INDIAVIX_8_14_Oct_2021.csv', index_col='Date/Time', parse_dates=['Date/Time'])
indiavix_df.rename(columns={'Close': 'INDIAVIX'}, inplace=True)

# Load the NIFTY data
nifty_df = pd.read_csv('/content/drive/My Drive/NIfty_Dataset/NIFTY_8_14_Oct_2021.csv', index_col='Date/Time', parse_dates=['Date/Time'])

# Join INDIAVIX data with NIFTY data
nifty_df = nifty_df.join(indiavix_df['INDIAVIX'], how='left')
nifty_df['INDIAVIX'].fillna(method='ffill', inplace=True)  # Fill NaN values with the forward fill method


# Check if the 'INDIAVIX' column exists after the join operation
if 'INDIAVIX' not in nifty_df.columns:
    raise KeyError('The INDIAVIX column was not found after the join operation. Please check the column names and join operation.')

print("NIFTYDF",nifty_df)
print("columns",nifty_df.columns)

# Constants
interest_rate = 3.32  # 3-month Indian government bond yield as annual percentage
days_in_year = 365  # Days in a year for the Greeks' calculations
strike_step = 50  # Known step between strike prices
minutes_in_a_year = 365 * 24 * 60  # Total minutes in a year
market_close_time = time(15, 30)



def calculate_minutes_to_expiry(current_timestamp, expiry_date, market_close_time):
    # Ensure market_close_time is a datetime.time object
    if isinstance(market_close_time, pd.Timestamp):
        market_close_time = market_close_time.time()

    closing_time = datetime.combine(expiry_date, market_close_time)

    # If the current timestamp is on the expiry date
    if current_timestamp.date() == expiry_date.date():
        # Calculate the remaining time until market close
        return max(int((closing_time - current_timestamp).total_seconds() / 60), 0)
    else:
        # Calculate time from the current timestamp to the end of day
        end_of_day = datetime.combine(current_timestamp.date(), time(23, 59))  # Last minute of the current day
        minutes_today = int((end_of_day - current_timestamp).total_seconds() / 60) + 1  # Plus one for the last minute

        # Calculate full days until the expiry date
        full_days = (expiry_date.date() - current_timestamp.date()).days - 1  # Minus one because we already counted today

        # Calculate minutes from the start of the expiry day to the market close
        start_of_expiry_day = datetime.combine(expiry_date.date(), time(0, 0))  # Midnight of the expiry day
        minutes_expiry_day = int((closing_time - start_of_expiry_day).total_seconds() / 60)

        # Total minutes is the sum of all parts
        return minutes_today + (full_days * 24 * 60) + minutes_expiry_day


# Function to calculate the Greeks using the Black-Scholes model
def calculate_greeks(underlying_price, strike_price, minutes_to_expiry, volatility, interest_rate, option_type):
    # Convert minutes to expiry into years for the Black-Scholes model
    time_to_expiry_in_years = minutes_to_expiry / minutes_in_a_year

    # Ensure we do not have a division by zero or negative time to expiry
    if time_to_expiry_in_years <= 0:
        return {greek: 0 for greek in ['Delta', 'Gamma', 'Theta', 'Vega', 'Rho']}

    # Convert annual interest rate and volatility from percentages to decimals
    annual_interest_rate = interest_rate / 100
    annual_volatility = volatility / 100

    # Black-Scholes model calculations
    bs = mibian.BS([underlying_price, strike_price, annual_interest_rate * 100, time_to_expiry_in_years * 365], volatility=annual_volatility * 100)

    # Return a dictionary of Greeks
    return {
        'Delta': bs.callDelta if option_type == 'call' else bs.putDelta,
        'Gamma': bs.gamma,
        'Theta': bs.callTheta / 365 if option_type == 'call' else bs.putTheta / 365,
        'Vega': bs.vega / 100,  # per 1% change in IV
        'Rho': bs.callRho / 100 if option_type == 'call' else bs.putRho / 100  # per 1% change in interest rate
    }


# Function to populate the DataFrame with strikes and Greeks
def populate_greeks(nifty_df, indiavix_df, strike_step, dfs):

    expiry_date = nifty_df.index.max().normalize() + pd.Timedelta(hours=15, minutes=30)
    print("EXPIRY DAY", expiry_date)
    market_close_time = expiry_date #pd.to_datetime(expiry_date.strftime('%Y-%m-%d') + ' 15:30:00')  # Assuming 3:30 PM market close

    # Create columns for Greeks in the dataframe
    for strike_type in ['ATM', 'ITM1', 'OTM1', 'ITM2', 'OTM2', 'ITM3', 'OTM3', 'ITM4', 'OTM4', 'ITM5', 'OTM5']:
        for greek in ['Delta', 'Gamma', 'Theta', 'Vega', 'Rho']:
            nifty_df[f'{strike_type}_{greek}'] = np.nan
            nifty_df[f'{strike_type}_OI'] = np.nan
            nifty_df[f'{strike_type}_Call_Volume'] = np.nan
            nifty_df[f'{strike_type}_Put_Volume'] = np.nan

    nifty_df['PCR'] = np.nan

    # Iterate over the dataframe and calculate Greeks
    for timestamp, row in nifty_df.iterrows():
        total_call_oi = 0
        total_put_oi = 0
        nifty_close = row['Close']
        # Find ATM, ITM, and OTM strikes
        atm_strike = int(round(nifty_close / strike_step) * strike_step)  # Closest strike
        itm_strikes = [atm_strike - i * strike_step for i in range(1, 6)]
        otm_strikes = [atm_strike + i * strike_step for i in range(1, 6)]
        all_strikes = [atm_strike] + itm_strikes + otm_strikes

        print(f"Processing timestamp: {timestamp}")

        # Get VIX value for the timestamp
        vix_value = indiavix_df.loc[timestamp, 'INDIAVIX'] if timestamp in indiavix_df.index else np.nan
        if vix_value is None:
            print(f"VIX value is missing for timestamp: {timestamp}")
            continue  # Skip this iteration if VIX value is missing


        minutes_to_expiry = calculate_minutes_to_expiry(timestamp, expiry_date, market_close_time)
        print("Current time & days to expiry:", timestamp.date(), minutes_to_expiry / (60 * 24))

        print("Curr time & days to EXpiry", timestamp.date(),minutes_to_expiry/(60*24))
        # Calculate Greeks for all strikes
        for i, strike in enumerate(all_strikes, start=1):
            if i == 1:  # ATM
                strike_type = 'ATM'
            elif i <= 6:  # ITM strikes
                strike_type = f'ITM{i-1}'
            else:  # OTM strikes
                strike_type = f'OTM{i-6}'

            call_key = f'NIFTYWK{strike}CE'
            put_key = f'NIFTYWK{strike}PE'

            call_volume = dfs[call_key].loc[timestamp, 'Volume'] if timestamp in dfs[call_key].index else np.nan
            put_volume = dfs[put_key].loc[timestamp, 'Volume'] if timestamp in dfs[put_key].index else np.nan

            # Populate volume data
            nifty_df.at[timestamp, f'{strike_type}_Call_Volume'] = call_volume
            nifty_df.at[timestamp, f'{strike_type}_Put_Volume'] = put_volume

            # print(f"Retrieving data for strike {strike} ({call_key} and {put_key})")

             # Check if the keys are present in the dfs dictionary
            if call_key not in dfs or put_key not in dfs:
                print(f"Missing data for strike {strike}: {call_key} or {put_key} not in dfs")
                continue

            # Check if the timestamp exists in the dfs DataFrames
            if timestamp not in dfs[call_key].index:
                print(f"Timestamp {timestamp} not found in dfs for {call_key}")
                continue
            if timestamp not in dfs[put_key].index:
                print(f"Timestamp {timestamp} not found in dfs for {put_key}")
                continue

            call_close = dfs[call_key].loc[timestamp, 'Close'] if timestamp in dfs[call_key].index else np.nan
            put_close = dfs[put_key].loc[timestamp, 'Close'] if timestamp in dfs[put_key].index else np.nan
            call_oi = dfs[call_key].loc[timestamp, 'Open Interest'] if timestamp in dfs[call_key].index else np.nan
            put_oi = dfs[put_key].loc[timestamp, 'Open Interest'] if timestamp in dfs[put_key].index else np.nan
            # print(f"Call Close: {call_close}, Put Close: {put_close}, Call OI: {call_oi}, Put OI: {put_oi}")

            #print("STRIKE",nifty_close, strike)
            # Calculate Greeks using the close prices
            if not np.isnan(call_close):
                greeks = calculate_greeks(nifty_close, strike, minutes_to_expiry, call_close, interest_rate, option_type='call')
                # Populate Greeks for call
                for greek_name, greek_value in greeks.items():
                    nifty_df.at[timestamp, f'{strike_type}_{greek_name}'] = greek_value
                    nifty_df.at[timestamp, f'{strike_type}_OI'] = call_oi  # Populate OI for call

            if not np.isnan(put_close):
                greeks = calculate_greeks(nifty_close, strike, minutes_to_expiry, put_close, interest_rate, option_type='put')
                # Populate Greeks for put
                for greek_name, greek_value in greeks.items():
                    nifty_df.at[timestamp, f'{strike_type}_PE_{greek_name}'] = greek_value
                    nifty_df.at[timestamp, f'{strike_type}_PE_OI'] = put_oi  # Populate OI for put

    return nifty_df

# Populate the DataFrame with Greeks
nifty_with_greeks = populate_greeks(nifty_df, indiavix_df, strike_step, dfs)

def calculate_pcr(row):
    total_call_oi = sum(row.get(f'{strike}_OI', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    total_put_oi = sum(row.get(f'{strike}_PE_OI', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    print("OI", total_call_oi, total_put_oi)
    return total_put_oi / total_call_oi if total_call_oi != 0 else np.nan

# Function to calculate PCR for volume
def calculate_pcr_volume(row):
    total_call_volume = sum(row.get(f'{strike}_Call_Volume', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    total_put_volume = sum(row.get(f'{strike}_Put_Volume', 0) for strike in ['ATM'] + [f'ITM{i}' for i in range(1, 6)] + [f'OTM{i}' for i in range(1, 6)])
    return total_put_volume / total_call_volume if total_call_volume != 0 else np.nan

# Apply PCR calculation to each row
nifty_with_greeks['PCR'] = nifty_with_greeks.apply(calculate_pcr, axis=1)
print(nifty_with_greeks.head())
# Apply PCR calculation for volume to each row
nifty_with_greeks['PCR_Volume'] = nifty_with_greeks.apply(calculate_pcr_volume, axis=1)
# # Output the DataFrame to a CSV
nifty_with_greeks.to_csv('/content/drive/My Drive/NIfty_Dataset/NIFTY_with_Greeks_8_14_Oct_2021.csv')

print("Greeks and Open Interest data have been populated and the DataFrame has been saved to CSV.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Current time & days to expiry: 2021-10-12 2.191666666666667
# Curr time & days to EXpiry 2021-10-12 2.191666666666667
# Processing timestamp: 2021-10-12 10:55:00
# Current time & days to expiry: 2021-10-12 2.1909722222222223
# Curr time & days to EXpiry 2021-10-12 2.1909722222222223
# Processing timestamp: 2021-10-12 10:56:00
# Current time & days to expiry: 2021-10-12 2.1902777777777778
# Curr time & days to EXpiry 2021-10-12 2.1902777777777778
# Processing timestamp: 2021-10-12 10:57:00
# Current time & days to expiry: 2021-10-12 2.189583333333333
# Curr time & days to EXpiry 2021-10-12 2.189583333333333
# Processing timestamp: 2021-10-12 10:58:00
# Current time & days to expiry: 2021-10-12 2.188888888888889
# Curr time & days to EXpiry 2021-10-12 2.188888888888889
# Processing timestamp: 2021-10-12 10:59:00
# Current time & days to expiry: 2021-10-12 2.1881944444444446
# Curr time & days to EXpiry 2021-10-12 2.1881944444444446
# Processing timestamp: 2021-10-12 11:00:00
# Current time & days to expiry: 2021-10-12 2.1875
# Curr time & days to EXpiry 2021-10-12 2.1875
# Processing timestamp: 2021-10-12 11:01:00
# Current time & days to expiry: 2021-10-12 2.1868055555555554
# Curr time & days to EXpiry 2021-10-12 2.1868055555555554
# Processing timestamp: 2021-10-12 11:02:00
# Current time & days to expiry: 2021-10-12 2.186111111111111
# Curr time & days to EXpiry 2021-10-12 2.186111111111111
# Processing timestamp: 2021-10-12 11:03:00
# Current time & days to expiry: 2021-10-12 2.185416666666667
# Curr time & days to EXpiry 2021-10-12 2.185416666666667
# Processing timestamp: 2021-10-12 11:04:00
# Current time & days to expiry: 2021-10-12 2.1847222222222222
# Curr time & days to EXpiry 2021-10-12 2.1847222222222222
# Processing timestamp: 2021-10-12 11:05:00
# Current time & days to expiry: 2021-10-12 2.1840277777777777
# Curr time & days to EXpiry 2021-10-12 2.1840277777777777
# Processing timestamp: 2021-10-12 11:06:00
# Current time & days to expiry: 2021-10-12 2.183333333333333
# Curr time & days to EXpiry 2021-10-12 2.183333333333333
# Processing timestamp: 2021-10-12 11:07:00
# Current time & days to expiry: 2021-10-12 2.182638888888889
# Curr time & days to EXpiry 2021-10-12 2.182638888888889
# Processing timestamp: 2021-10-12 11:08:00
# Current time & days to expiry: 2021-10-12 2.1819444444444445
# Curr time & days to EXpiry 2021-10-12 2.1819444444444445
# Processing timestamp: 2021-10-12 11:09:00
# Current time & days to expiry: 2021-10-12 2.18125
# Curr time & days to EXpiry 2021-10-12 2.18125
# Processing timestamp: 2021-10-12 11:10:00
# Current time & days to expiry: 2021-10-12 2.1805555555555554
# Curr time & days to EXpiry 2021-10-12 2.1805555555555554
# Processing timestamp: 2021-10-12 11:11:00
# Current time & days to expiry: 2021-10-12 2.1798611111111112
# Curr time & days to EXpiry 2021-10-12 2.1798611111111112
# Processing timestamp: 2021-10-12 11:12:00
# Current time & days to expiry: 2021-10-12 2.1791666666666667
# Curr time & days to EXpiry 2021-10-12 2.1791666666666667
# Processing timestamp: 2021-10-12 11:13:00
# Current time & days to expiry: 2021-10-12 2.178472222222222
# Curr time & days to EXpiry 2021-10-12 2.178472222222222
# Processing timestamp: 2021-10-12 11:14:00
# Current time & days to expiry: 2021-10-12 2.1777777777777776
# Curr time & days to EXpiry 2021-10-12 2.1777777777777776
# Processing timestamp: 2021-10-12 11:15:00
# Current time & days to expiry: 2021-10-12 2.1770833333333335
# Curr time & days to EXpiry 2021-10-12 2.1770833333333335
# Processing timestamp: 2021-10-12 11:16:00
# Current time & days to expiry: 2021-10-12 2.176388888888889
# Curr time & days to EXpiry 2021-10-12 2.176388888888889
# Processing timestamp: 2021-10-12 11:17:00
# Current time & days to expiry: 2021-10-12 2.1756944444444444
# Curr time & days to EXpiry 2021-10-12 2.1756944444444444
# Processing timestamp: 2021-10-12 11:18:00
# Current time & days to expiry: 2021-10-12 2.175
# Curr time & days to EXpiry 2021-10-12 2.175
# Processing timestamp: 2021-10-12 11:19:00
# Current time & days to expiry: 2021-10-12 2.1743055555555557
# Curr time & days to EXpiry 2021-10-12 2.1743055555555557
# Processing timestamp: 2021-10-12 11:20:00
# Current time & days to expiry: 2021-10-12 2.173611111111111
# Curr time & days to EXpiry 2021-10-12 2.173611111111111
# Processing timestamp: 2021-10-12 11:21:00
# Current time & days to expiry: 2021-10-12 2.1729166666666666
# Curr time & days to EXpiry 2021-10-12 2.1729166666666666
# Processing timestamp: 2021-10-12 11:22:00
# Current time & days to expiry: 2021-10-12 2.172222222222222
# Curr time & days to EXpiry 2021-10-12 2.172222222222222
# Processing timestamp: 2021-10-12 11:23:00
# Current time & days to expiry: 2021-10-12 2.171527777777778
# Curr time & days to EXpiry 2021-10-12 2.171527777777778
# Processing timestamp: 2021-10-12 11:24:00
# Current time & days to expiry: 2021-10-12 2.1708333333333334
# Curr time & days to EXpiry 2021-10-12 2.1708333333333334
# Processing timestamp: 2021-10-12 11:25:00
# Current time & days to expiry: 2021-10-12 2.170138888888889
# Curr time & days to EXpiry 2021-10-12 2.170138888888889
# Processing timestamp: 2021-10-12 11:26:00
# Current time & days to expiry: 2021-10-12 2.1694444444444443
# Curr time & days to EXpiry 2021-10-12 2.1694444444444443
# Processing timestamp: 2021-10-12 11:27:00
# Current time & days to expiry: 2021-10-12 2.16875
# Curr time & days to EXpiry 2021-10-12 2.16875
# Processing timestamp: 2021-10-12 11:28:00
# Current time & days to expiry: 2021-10-12 2.1680555555555556
# Curr time & days to EXpiry 2021-10-12 2.1680555555555556
# Processing timestamp: 2021-10-12 11:29:00
# Current time & days to expiry: 2021-10-12 2.167361111111111
# Curr time & days to EXpiry 2021-10-12 2.167361111111111
# Processing timestamp: 2021-10-12 11:30:00
# Current time & days to expiry: 2021-10-12 2.1666666666666665
# Curr time & days to EXpiry 2021-10-12 2.1666666666666665
# Processing timestamp: 2021-10-12 11:31:00
# Current time & days to expiry: 2021-10-12 2.1659722222222224
# Curr time & days to EXpiry 2021-10-12 2.1659722222222224
# Processing timestamp: 2021-10-12 11:32:00
# Current time & days to expiry: 2021-10-12 2.165277777777778
# Curr time & days to EXpiry 2021-10-12 2.165277777777778
# Processing timestamp: 2021-10-12 11:33:00
# Current time & days to expiry: 2021-10-12 2.1645833333333333
# Curr time & days to EXpiry 2021-10-12 2.1645833333333333
# Processing timestamp: 2021-10-12 11:34:00
# Current time & days to expiry: 2021-10-12 2.1638888888888888
# Curr time & days to EXpiry 2021-10-12 2.1638888888888888
# Processing timestamp: 2021-10-12 11:35:00
# Current time & days to expiry: 2021-10-12 2.1631944444444446
# Curr time & days to EXpiry 2021-10-12 2.1631944444444446
# Processing timestamp: 2021-10-12 11:36:00
# Current time & days to expiry: 2021-10-12 2.1625
# Curr time & days to EXpiry 2021-10-12 2.1625
# Processing timestamp: 2021-10-12 11:37:00
# Current time & days to expiry: 2021-10-12 2.1618055555555555
# Curr time & days to EXpiry 2021-10-12 2.1618055555555555
# Processing timestamp: 2021-10-12 11:38:00
# Current time & days to expiry: 2021-10-12 2.161111111111111
# Curr time & days to EXpiry 2021-10-12 2.161111111111111
# Processing timestamp: 2021-10-12 11:39:00
# Current time & days to expiry: 2021-10-12 2.160416666666667
# Curr time & days to EXpiry 2021-10-12 2.160416666666667
# Processing timestamp: 2021-10-12 11:40:00
# Current time & days to expiry: 2021-10-12 2.1597222222222223
# Curr time & days to EXpiry 2021-10-12 2.1597222222222223
# Processing timestamp: 2021-10-12 11:41:00
# Current time & days to expiry: 2021-10-12 2.1590277777777778
# Curr time & days to EXpiry 2021-10-12 2.1590277777777778
# Processing timestamp: 2021-10-12 11:42:00
# Current time & days to expiry: 2021-10-12 2.158333333333333
# Curr time & days to EXpiry 2021-10-12 2.158333333333333
# Processing timestamp: 2021-10-12 11:43:00
# Current time & days to expiry: 2021-10-12 2.157638888888889
# Curr time & days to EXpiry 2021-10-12 2.157638888888889
# Processing timestamp: 2021-10-12 11:44:00
# Current time & days to expiry: 2021-10-12 2.1569444444444446
# Curr time & days to EXpiry 2021-10-12 2.1569444444444446
# Processing timestamp: 2021-10-12 11:45:00
# Current time & days to expiry: 2021-10-12 2.15625
# Curr time & days to EXpiry 2021-10-12 2.15625
# Processing timestamp: 2021-10-12 11:46:00
# Current time & days to expiry: 2021-10-12 2.1555555555555554
# Curr time & days to EXpiry 2021-10-12 2.1555555555555554
# Processing timestamp: 2021-10-12 11:47:00
# Current time & days to expiry: 2021-10-12 2.154861111111111
# Curr time & days to EXpiry 2021-10-12 2.154861111111111
# Processing timestamp: 2021-10-12 11:48:00
# Current time & days to expiry: 2021-10-12 2.154166666666667
# Curr time & days to EXpiry 2021-10-12 2.154166666666667
# Processing timestamp: 2021-10-12 11:49:00
# Current time & days to expiry: 2021-10-12 2.1534722222222222
# Curr time & days to EXpiry 2021-10-12 2.1534722222222222
# Processing timestamp: 2021-10-12 11:50:00
# Current time & days to expiry: 2021-10-12 2.1527777777777777
# Curr time & days to EXpiry 2021-10-12 2.1527777777777777
# Processing timestamp: 2021-10-12 11:51:00
# Current time & days to expiry: 2021-10-12 2.152083333333333
# Curr time & days to EXpiry 2021-10-12 2.152083333333333
# Processing timestamp: 2021-10-12 11:52:00
# Current time & days to expiry: 2021-10-12 2.151388888888889
# Curr time & days to EXpiry 2021-10-12 2.151388888888889
# Processing timestamp: 2021-10-12 11:53:00
# Current time & days to expiry: 2021-10-12 2.1506944444444445
# Curr time & days to EXpiry 2021-10-12 2.1506944444444445
# Processing timestamp: 2021-10-12 11:54:00
# Current time & days to expiry: 2021-10-12 2.15
# Curr time & days to EXpiry 2021-10-12 2.15
# Processing timestamp: 2021-10-12 11:55:00
# Current time & days to expiry: 2021-10-12 2.1493055555555554
# Curr time & days to EXpiry 2021-10-12 2.1493055555555554
# Processing timestamp: 2021-10-12 11:56:00
# Current time & days to expiry: 2021-10-12 2.1486111111111112
# Curr time & days to EXpiry 2021-10-12 2.1486111111111112
# Processing timestamp: 2021-10-12 11:57:00
# Current time & days to expiry: 2021-10-12 2.1479166666666667
# Curr time & days to EXpiry 2021-10-12 2.1479166666666667
# Processing timestamp: 2021-10-12 11:58:00
# Current time & days to expiry: 2021-10-12 2.147222222222222
# Curr time & days to EXpiry 2021-10-12 2.147222222222222
# Processing timestamp: 2021-10-12 11:59:00
# Current time & days to expiry: 2021-10-12 2.1465277777777776
# Curr time & days to EXpiry 2021-10-12 2.1465277777777776
# Processing timestamp: 2021-10-12 12:00:00
# Current time & days to expiry: 2021-10-12 2.1458333333333335
# Curr time & days to EXpiry 2021-10-12 2.1458333333333335
# Processing timestamp: 2021-10-12 12:01:00
# Current time & days to expiry: 2021-10-12 2.145138888888889
# Curr time & days to EXpiry 2021-10-12 2.145138888888889
# Processing timestamp: 2021-10-12 12:02:00
# Current time & days to expiry: 2021-10-12 2.1444444444444444
# Curr time & days to EXpiry 2021-10-12 2.1444444444444444
# Processing timestamp: 2021-10-12 12:03:00
# Current time & days to expiry: 2021-10-12 2.14375
# Curr time & days to EXpiry 2021-10-12 2.14375
# Processing timestamp: 2021-10-12 12:04:00
# Current time & days to expiry: 2021-10-12 2.1430555555555557
# Curr time & days to EXpiry 2021-10-12 2.1430555555555557
# Processing timestamp: 2021-10-12 12:05:00
# Current time & days to expiry: 2021-10-12 2.142361111111111
# Curr time & days to EXpiry 2021-10-12 2.142361111111111
# Processing timestamp: 2021-10-12 12:06:00
# Current time & days to expiry: 2021-10-12 2.1416666666666666
# Curr time & days to EXpiry 2021-10-12 2.1416666666666666
# Processing timestamp: 2021-10-12 12:07:00
# Current time & days to expiry: 2021-10-12 2.140972222222222
# Curr time & days to EXpiry 2021-10-12 2.140972222222222
# Processing timestamp: 2021-10-12 12:08:00
# Current time & days to expiry: 2021-10-12 2.140277777777778
# Curr time & days to EXpiry 2021-10-12 2.140277777777778
# Processing timestamp: 2021-10-12 12:09:00
# Current time & days to expiry: 2021-10-12 2.1395833333333334
# Curr time & days to EXpiry 2021-10-12 2.1395833333333334
# Processing timestamp: 2021-10-12 12:10:00
# Current time & days to expiry: 2021-10-12 2.138888888888889
# Curr time & days to EXpiry 2021-10-12 2.138888888888889
# Processing timestamp: 2021-10-12 12:11:00
# Current time & days to expiry: 2021-10-12 2.1381944444444443
# Curr time & days to EXpiry 2021-10-12 2.1381944444444443
# Processing timestamp: 2021-10-12 12:12:00
# Current time & days to expiry: 2021-10-12 2.1375
# Curr time & days to EXpiry 2021-10-12 2.1375
# Processing timestamp: 2021-10-12 12:13:00
# Current time & days to expiry: 2021-10-12 2.1368055555555556
# Curr time & days to EXpiry 2021-10-12 2.1368055555555556
# Processing timestamp: 2021-10-12 12:14:00
# Current time & days to expiry: 2021-10-12 2.136111111111111
# Curr time & days to EXpiry 2021-10-12 2.136111111111111
# Processing timestamp: 2021-10-12 12:15:00
# Current time & days to expiry: 2021-10-12 2.1354166666666665
# Curr time & days to EXpiry 2021-10-12 2.1354166666666665
# Processing timestamp: 2021-10-12 12:16:00
# Current time & days to expiry: 2021-10-12 2.1347222222222224
# Curr time & days to EXpiry 2021-10-12 2.1347222222222224
# Processing timestamp: 2021-10-12 12:17:00
# Current time & days to expiry: 2021-10-12 2.134027777777778
# Curr time & days to EXpiry 2021-10-12 2.134027777777778
# Processing timestamp: 2021-10-12 12:18:00
# Current time & days to expiry: 2021-10-12 2.1333333333333333
# Curr time & days to EXpiry 2021-10-12 2.1333333333333333
# Processing timestamp: 2021-10-12 12:19:00
# Current time & days to expiry: 2021-10-12 2.1326388888888888
# Curr time & days to EXpiry 2021-10-12 2.1326388888888888
# Processing timestamp: 2021-10-12 12:20:00
# Current time & days to expiry: 2021-10-12 2.1319444444444446
# Curr time & days to EXpiry 2021-10-12 2.1319444444444446
# Processing timestamp: 2021-10-12 12:21:00
# Current time & days to expiry: 2021-10-12 2.13125
# Curr time & days to EXpiry 2021-10-12 2.13125
# Processing timestamp: 2021-10-12 12:22:00
# Current time & days to expiry: 2021-10-12 2.1305555555555555
# Curr time & days to EXpiry 2021-10-12 2.1305555555555555
# Processing timestamp: 2021-10-12 12:23:00
# Current time & days to expiry: 2021-10-12 2.129861111111111
# Curr time & days to EXpiry 2021-10-12 2.129861111111111
# Processing timestamp: 2021-10-12 12:24:00
# Current time & days to expiry: 2021-10-12 2.129166666666667
# Curr time & days to EXpiry 2021-10-12 2.129166666666667
# Processing timestamp: 2021-10-12 12:25:00
# Current time & days to expiry: 2021-10-12 2.1284722222222223
# Curr time & days to EXpiry 2021-10-12 2.1284722222222223
# Processing timestamp: 2021-10-12 12:26:00
# Current time & days to expiry: 2021-10-12 2.1277777777777778
# Curr time & days to EXpiry 2021-10-12 2.1277777777777778
# Processing timestamp: 2021-10-12 12:27:00
# Current time & days to expiry: 2021-10-12 2.127083333333333
# Curr time & days to EXpiry 2021-10-12 2.127083333333333
# Processing timestamp: 2021-10-12 12:28:00
# Current time & days to expiry: 2021-10-12 2.126388888888889
# Curr time & days to EXpiry 2021-10-12 2.126388888888889
# Processing timestamp: 2021-10-12 12:29:00
# Current time & days to expiry: 2021-10-12 2.1256944444444446
# Curr time & days to EXpiry 2021-10-12 2.1256944444444446
# Processing timestamp: 2021-10-12 12:30:00
# Current time & days to expiry: 2021-10-12 2.125
# Curr time & days to EXpiry 2021-10-12 2.125
# Processing timestamp: 2021-10-12 12:31:00
# Current time & days to expiry: 2021-10-12 2.1243055555555554
# Curr time & days to EXpiry 2021-10-12 2.1243055555555554
# Processing timestamp: 2021-10-12 12:32:00
# Current time & days to expiry: 2021-10-12 2.123611111111111
# Curr time & days to EXpiry 2021-10-12 2.123611111111111
# Processing timestamp: 2021-10-12 12:33:00
# Current time & days to expiry: 2021-10-12 2.122916666666667
# Curr time & days to EXpiry 2021-10-12 2.122916666666667
# Processing timestamp: 2021-10-12 12:34:00
# Current time & days to expiry: 2021-10-12 2.1222222222222222
# Curr time & days to EXpiry 2021-10-12 2.1222222222222222
# Processing timestamp: 2021-10-12 12:35:00
# Current time & days to expiry: 2021-10-12 2.1215277777777777
# Curr time & days to EXpiry 2021-10-12 2.1215277777777777
# Processing timestamp: 2021-10-12 12:36:00
# Current time & days to expiry: 2021-10-12 2.120833333333333
# Curr time & days to EXpiry 2021-10-12 2.120833333333333
# Processing timestamp: 2021-10-12 12:37:00
# Current time & days to expiry: 2021-10-12 2.120138888888889
# Curr time & days to EXpiry 2021-10-12 2.120138888888889
# Processing timestamp: 2021-10-12 12:38:00
# Current time & days to expiry: 2021-10-12 2.1194444444444445
# Curr time & days to EXpiry 2021-10-12 2.1194444444444445
# Processing timestamp: 2021-10-12 12:39:00
# Current time & days to expiry: 2021-10-12 2.11875
# Curr time & days to EXpiry 2021-10-12 2.11875
# Processing timestamp: 2021-10-12 12:40:00
# Current time & days to expiry: 2021-10-12 2.1180555555555554
# Curr time & days to EXpiry 2021-10-12 2.1180555555555554
# Processing timestamp: 2021-10-12 12:41:00
# Current time & days to expiry: 2021-10-12 2.1173611111111112
# Curr time & days to EXpiry 2021-10-12 2.1173611111111112
# Processing timestamp: 2021-10-12 12:42:00
# Current time & days to expiry: 2021-10-12 2.1166666666666667
# Curr time & days to EXpiry 2021-10-12 2.1166666666666667
# Processing timestamp: 2021-10-12 12:43:00
# Current time & days to expiry: 2021-10-12 2.115972222222222
# Curr time & days to EXpiry 2021-10-12 2.115972222222222
# Processing timestamp: 2021-10-12 12:44:00
# Current time & days to expiry: 2021-10-12 2.1152777777777776
# Curr time & days to EXpiry 2021-10-12 2.1152777777777776
# Processing timestamp: 2021-10-12 12:45:00
# Current time & days to expiry: 2021-10-12 2.1145833333333335
# Curr time & days to EXpiry 2021-10-12 2.1145833333333335
# Processing timestamp: 2021-10-12 12:46:00
# Current time & days to expiry: 2021-10-12 2.113888888888889
# Curr time & days to EXpiry 2021-10-12 2.113888888888889
# Processing timestamp: 2021-10-12 12:47:00
# Current time & days to expiry: 2021-10-12 2.1131944444444444
# Curr time & days to EXpiry 2021-10-12 2.1131944444444444
# Processing timestamp: 2021-10-12 12:48:00
# Current time & days to expiry: 2021-10-12 2.1125
# Curr time & days to EXpiry 2021-10-12 2.1125
# Processing timestamp: 2021-10-12 12:49:00
# Current time & days to expiry: 2021-10-12 2.1118055555555557
# Curr time & days to EXpiry 2021-10-12 2.1118055555555557
# Processing timestamp: 2021-10-12 12:50:00
# Current time & days to expiry: 2021-10-12 2.111111111111111
# Curr time & days to EXpiry 2021-10-12 2.111111111111111
# Processing timestamp: 2021-10-12 12:51:00
# Current time & days to expiry: 2021-10-12 2.1104166666666666
# Curr time & days to EXpiry 2021-10-12 2.1104166666666666
# Processing timestamp: 2021-10-12 12:52:00
# Current time & days to expiry: 2021-10-12 2.109722222222222
# Curr time & days to EXpiry 2021-10-12 2.109722222222222
# Processing timestamp: 2021-10-12 12:53:00
# Current time & days to expiry: 2021-10-12 2.109027777777778
# Curr time & days to EXpiry 2021-10-12 2.109027777777778
# Processing timestamp: 2021-10-12 12:54:00
# Current time & days to expiry: 2021-10-12 2.1083333333333334
# Curr time & days to EXpiry 2021-10-12 2.1083333333333334
# Processing timestamp: 2021-10-12 12:55:00
# Current time & days to expiry: 2021-10-12 2.107638888888889
# Curr time & days to EXpiry 2021-10-12 2.107638888888889
# Processing timestamp: 2021-10-12 12:56:00
# Current time & days to expiry: 2021-10-12 2.1069444444444443
# Curr time & days to EXpiry 2021-10-12 2.1069444444444443
# Processing timestamp: 2021-10-12 12:57:00
# Current time & days to expiry: 2021-10-12 2.10625
# Curr time & days to EXpiry 2021-10-12 2.10625
# Processing timestamp: 2021-10-12 12:58:00
# Current time & days to expiry: 2021-10-12 2.1055555555555556
# Curr time & days to EXpiry 2021-10-12 2.1055555555555556
# Processing timestamp: 2021-10-12 12:59:00
# Current time & days to expiry: 2021-10-12 2.104861111111111
# Curr time & days to EXpiry 2021-10-12 2.104861111111111
# Processing timestamp: 2021-10-12 13:00:00
# Current time & days to expiry: 2021-10-12 2.1041666666666665
# Curr time & days to EXpiry 2021-10-12 2.1041666666666665
# Processing timestamp: 2021-10-12 13:01:00
# Current time & days to expiry: 2021-10-12 2.1034722222222224
# Curr time & days to EXpiry 2021-10-12 2.1034722222222224
# Processing timestamp: 2021-10-12 13:02:00
# Current time & days to expiry: 2021-10-12 2.102777777777778
# Curr time & days to EXpiry 2021-10-12 2.102777777777778
# Processing timestamp: 2021-10-12 13:03:00
# Current time & days to expiry: 2021-10-12 2.1020833333333333
# Curr time & days to EXpiry 2021-10-12 2.1020833333333333
# Processing timestamp: 2021-10-12 13:04:00
# Current time & days to expiry: 2021-10-12 2.1013888888888888
# Curr time & days to EXpiry 2021-10-12 2.1013888888888888
# Processing timestamp: 2021-10-12 13:05:00
# Current time & days to expiry: 2021-10-12 2.1006944444444446
# Curr time & days to EXpiry 2021-10-12 2.1006944444444446
# Processing timestamp: 2021-10-12 13:06:00
# Current time & days to expiry: 2021-10-12 2.1
# Curr time & days to EXpiry 2021-10-12 2.1
# Processing timestamp: 2021-10-12 13:07:00
# Current time & days to expiry: 2021-10-12 2.0993055555555555
# Curr time & days to EXpiry 2021-10-12 2.0993055555555555
# Processing timestamp: 2021-10-12 13:08:00
# Current time & days to expiry: 2021-10-12 2.098611111111111
# Curr time & days to EXpiry 2021-10-12 2.098611111111111
# Processing timestamp: 2021-10-12 13:09:00
# Current time & days to expiry: 2021-10-12 2.097916666666667
# Curr time & days to EXpiry 2021-10-12 2.097916666666667
# Processing timestamp: 2021-10-12 13:10:00
# Current time & days to expiry: 2021-10-12 2.0972222222222223
# Curr time & days to EXpiry 2021-10-12 2.0972222222222223
# Processing timestamp: 2021-10-12 13:11:00
# Current time & days to expiry: 2021-10-12 2.0965277777777778
# Curr time & days to EXpiry 2021-10-12 2.0965277777777778
# Processing timestamp: 2021-10-12 13:12:00
# Current time & days to expiry: 2021-10-12 2.095833333333333
# Curr time & days to EXpiry 2021-10-12 2.095833333333333
# Processing timestamp: 2021-10-12 13:13:00
# Current time & days to expiry: 2021-10-12 2.095138888888889
# Curr time & days to EXpiry 2021-10-12 2.095138888888889
# Processing timestamp: 2021-10-12 13:14:00
# Current time & days to expiry: 2021-10-12 2.0944444444444446
# Curr time & days to EXpiry 2021-10-12 2.0944444444444446
# Processing timestamp: 2021-10-12 13:15:00
# Current time & days to expiry: 2021-10-12 2.09375
# Curr time & days to EXpiry 2021-10-12 2.09375
# Processing timestamp: 2021-10-12 13:16:00
# Current time & days to expiry: 2021-10-12 2.0930555555555554
# Curr time & days to EXpiry 2021-10-12 2.0930555555555554
# Processing timestamp: 2021-10-12 13:17:00
# Current time & days to expiry: 2021-10-12 2.092361111111111
# Curr time & days to EXpiry 2021-10-12 2.092361111111111
# Processing timestamp: 2021-10-12 13:18:00
# Current time & days to expiry: 2021-10-12 2.091666666666667
# Curr time & days to EXpiry 2021-10-12 2.091666666666667
# Processing timestamp: 2021-10-12 13:19:00
# Current time & days to expiry: 2021-10-12 2.0909722222222222
# Curr time & days to EXpiry 2021-10-12 2.0909722222222222
# Processing timestamp: 2021-10-12 13:20:00
# Current time & days to expiry: 2021-10-12 2.0902777777777777
# Curr time & days to EXpiry 2021-10-12 2.0902777777777777
# Processing timestamp: 2021-10-12 13:21:00
# Current time & days to expiry: 2021-10-12 2.089583333333333
# Curr time & days to EXpiry 2021-10-12 2.089583333333333
# Processing timestamp: 2021-10-12 13:22:00
# Current time & days to expiry: 2021-10-12 2.088888888888889
# Curr time & days to EXpiry 2021-10-12 2.088888888888889
# Processing timestamp: 2021-10-12 13:23:00
# Current time & days to expiry: 2021-10-12 2.0881944444444445
# Curr time & days to EXpiry 2021-10-12 2.0881944444444445
# Processing timestamp: 2021-10-12 13:24:00
# Current time & days to expiry: 2021-10-12 2.0875
# Curr time & days to EXpiry 2021-10-12 2.0875
# Processing timestamp: 2021-10-12 13:25:00
# Current time & days to expiry: 2021-10-12 2.0868055555555554
# Curr time & days to EXpiry 2021-10-12 2.0868055555555554
# Processing timestamp: 2021-10-12 13:26:00
# Current time & days to expiry: 2021-10-12 2.0861111111111112
# Curr time & days to EXpiry 2021-10-12 2.0861111111111112
# Processing timestamp: 2021-10-12 13:27:00
# Current time & days to expiry: 2021-10-12 2.0854166666666667
# Curr time & days to EXpiry 2021-10-12 2.0854166666666667
# Processing timestamp: 2021-10-12 13:28:00
# Current time & days to expiry: 2021-10-12 2.084722222222222
# Curr time & days to EXpiry 2021-10-12 2.084722222222222
# Processing timestamp: 2021-10-12 13:29:00
# Current time & days to expiry: 2021-10-12 2.0840277777777776
# Curr time & days to EXpiry 2021-10-12 2.0840277777777776
# Processing timestamp: 2021-10-12 13:30:00
# Current time & days to expiry: 2021-10-12 2.0833333333333335
# Curr time & days to EXpiry 2021-10-12 2.0833333333333335
# Processing timestamp: 2021-10-12 13:31:00
# Current time & days to expiry: 2021-10-12 2.082638888888889
# Curr time & days to EXpiry 2021-10-12 2.082638888888889
# Processing timestamp: 2021-10-12 13:32:00
# Current time & days to expiry: 2021-10-12 2.0819444444444444
# Curr time & days to EXpiry 2021-10-12 2.0819444444444444
# Processing timestamp: 2021-10-12 13:33:00
# Current time & days to expiry: 2021-10-12 2.08125
# Curr time & days to EXpiry 2021-10-12 2.08125
# Processing timestamp: 2021-10-12 13:34:00
# Current time & days to expiry: 2021-10-12 2.0805555555555557
# Curr time & days to EXpiry 2021-10-12 2.0805555555555557
# Processing timestamp: 2021-10-12 13:35:00
# Current time & days to expiry: 2021-10-12 2.079861111111111
# Curr time & days to EXpiry 2021-10-12 2.079861111111111
# Processing timestamp: 2021-10-12 13:36:00
# Current time & days to expiry: 2021-10-12 2.0791666666666666
# Curr time & days to EXpiry 2021-10-12 2.0791666666666666
# Processing timestamp: 2021-10-12 13:37:00
# Current time & days to expiry: 2021-10-12 2.078472222222222
# Curr time & days to EXpiry 2021-10-12 2.078472222222222
# Processing timestamp: 2021-10-12 13:38:00
# Current time & days to expiry: 2021-10-12 2.077777777777778
# Curr time & days to EXpiry 2021-10-12 2.077777777777778
# Processing timestamp: 2021-10-12 13:39:00
# Current time & days to expiry: 2021-10-12 2.0770833333333334
# Curr time & days to EXpiry 2021-10-12 2.0770833333333334
# Processing timestamp: 2021-10-12 13:40:00
# Current time & days to expiry: 2021-10-12 2.076388888888889
# Curr time & days to EXpiry 2021-10-12 2.076388888888889
# Processing timestamp: 2021-10-12 13:41:00
# Current time & days to expiry: 2021-10-12 2.0756944444444443
# Curr time & days to EXpiry 2021-10-12 2.0756944444444443
# Processing timestamp: 2021-10-12 13:42:00
# Current time & days to expiry: 2021-10-12 2.075
# Curr time & days to EXpiry 2021-10-12 2.075
# Processing timestamp: 2021-10-12 13:43:00
# Current time & days to expiry: 2021-10-12 2.0743055555555556
# Curr time & days to EXpiry 2021-10-12 2.0743055555555556
# Processing timestamp: 2021-10-12 13:44:00
# Current time & days to expiry: 2021-10-12 2.073611111111111
# Curr time & days to EXpiry 2021-10-12 2.073611111111111
# Processing timestamp: 2021-10-12 13:45:00
# Current time & days to expiry: 2021-10-12 2.0729166666666665
# Curr time & days to EXpiry 2021-10-12 2.0729166666666665
# Processing timestamp: 2021-10-12 13:46:00
# Current time & days to expiry: 2021-10-12 2.0722222222222224
# Curr time & days to EXpiry 2021-10-12 2.0722222222222224
# Processing timestamp: 2021-10-12 13:47:00
# Current time & days to expiry: 2021-10-12 2.071527777777778
# Curr time & days to EXpiry 2021-10-12 2.071527777777778
# Processing timestamp: 2021-10-12 13:48:00
# Current time & days to expiry: 2021-10-12 2.0708333333333333
# Curr time & days to EXpiry 2021-10-12 2.0708333333333333
# Processing timestamp: 2021-10-12 13:49:00
# Current time & days to expiry: 2021-10-12 2.0701388888888888
# Curr time & days to EXpiry 2021-10-12 2.0701388888888888
# Processing timestamp: 2021-10-12 13:50:00
# Current time & days to expiry: 2021-10-12 2.0694444444444446
# Curr time & days to EXpiry 2021-10-12 2.0694444444444446
# Processing timestamp: 2021-10-12 13:51:00
# Current time & days to expiry: 2021-10-12 2.06875
# Curr time & days to EXpiry 2021-10-12 2.06875
# Processing timestamp: 2021-10-12 13:52:00
# Current time & days to expiry: 2021-10-12 2.0680555555555555
# Curr time & days to EXpiry 2021-10-12 2.0680555555555555
# Processing timestamp: 2021-10-12 13:53:00
# Current time & days to expiry: 2021-10-12 2.067361111111111
# Curr time & days to EXpiry 2021-10-12 2.067361111111111
# Processing timestamp: 2021-10-12 13:54:00
# Current time & days to expiry: 2021-10-12 2.066666666666667
# Curr time & days to EXpiry 2021-10-12 2.066666666666667
# Processing timestamp: 2021-10-12 13:55:00
# Current time & days to expiry: 2021-10-12 2.0659722222222223
# Curr time & days to EXpiry 2021-10-12 2.0659722222222223
# Processing timestamp: 2021-10-12 13:56:00
# Current time & days to expiry: 2021-10-12 2.0652777777777778
# Curr time & days to EXpiry 2021-10-12 2.0652777777777778
# Processing timestamp: 2021-10-12 13:57:00
# Current time & days to expiry: 2021-10-12 2.064583333333333
# Curr time & days to EXpiry 2021-10-12 2.064583333333333
# Processing timestamp: 2021-10-12 13:58:00
# Current time & days to expiry: 2021-10-12 2.063888888888889
# Curr time & days to EXpiry 2021-10-12 2.063888888888889
# Processing timestamp: 2021-10-12 13:59:00
# Current time & days to expiry: 2021-10-12 2.0631944444444446
# Curr time & days to EXpiry 2021-10-12 2.0631944444444446
# Processing timestamp: 2021-10-12 14:00:00
# Current time & days to expiry: 2021-10-12 2.0625
# Curr time & days to EXpiry 2021-10-12 2.0625
# Processing timestamp: 2021-10-12 14:01:00
# Current time & days to expiry: 2021-10-12 2.0618055555555554
# Curr time & days to EXpiry 2021-10-12 2.0618055555555554
# Processing timestamp: 2021-10-12 14:02:00
# Current time & days to expiry: 2021-10-12 2.061111111111111
# Curr time & days to EXpiry 2021-10-12 2.061111111111111
# Processing timestamp: 2021-10-12 14:03:00
# Current time & days to expiry: 2021-10-12 2.060416666666667
# Curr time & days to EXpiry 2021-10-12 2.060416666666667
# Processing timestamp: 2021-10-12 14:04:00
# Current time & days to expiry: 2021-10-12 2.0597222222222222
# Curr time & days to EXpiry 2021-10-12 2.0597222222222222
# Processing timestamp: 2021-10-12 14:05:00
# Current time & days to expiry: 2021-10-12 2.0590277777777777
# Curr time & days to EXpiry 2021-10-12 2.0590277777777777
# Processing timestamp: 2021-10-12 14:06:00
# Current time & days to expiry: 2021-10-12 2.058333333333333
# Curr time & days to EXpiry 2021-10-12 2.058333333333333
# Processing timestamp: 2021-10-12 14:07:00
# Current time & days to expiry: 2021-10-12 2.057638888888889
# Curr time & days to EXpiry 2021-10-12 2.057638888888889
# Processing timestamp: 2021-10-12 14:08:00
# Current time & days to expiry: 2021-10-12 2.0569444444444445
# Curr time & days to EXpiry 2021-10-12 2.0569444444444445
# Processing timestamp: 2021-10-12 14:09:00
# Current time & days to expiry: 2021-10-12 2.05625
# Curr time & days to EXpiry 2021-10-12 2.05625
# Processing timestamp: 2021-10-12 14:10:00
# Current time & days to expiry: 2021-10-12 2.0555555555555554
# Curr time & days to EXpiry 2021-10-12 2.0555555555555554
# Processing timestamp: 2021-10-12 14:11:00
# Current time & days to expiry: 2021-10-12 2.0548611111111112
# Curr time & days to EXpiry 2021-10-12 2.0548611111111112
# Processing timestamp: 2021-10-12 14:12:00
# Current time & days to expiry: 2021-10-12 2.0541666666666667
# Curr time & days to EXpiry 2021-10-12 2.0541666666666667
# Processing timestamp: 2021-10-12 14:13:00
# Current time & days to expiry: 2021-10-12 2.053472222222222
# Curr time & days to EXpiry 2021-10-12 2.053472222222222
# Processing timestamp: 2021-10-12 14:14:00
# Current time & days to expiry: 2021-10-12 2.0527777777777776
# Curr time & days to EXpiry 2021-10-12 2.0527777777777776
# Processing timestamp: 2021-10-12 14:15:00
# Current time & days to expiry: 2021-10-12 2.0520833333333335
# Curr time & days to EXpiry 2021-10-12 2.0520833333333335
# Processing timestamp: 2021-10-12 14:16:00
# Current time & days to expiry: 2021-10-12 2.051388888888889
# Curr time & days to EXpiry 2021-10-12 2.051388888888889
# Processing timestamp: 2021-10-12 14:17:00
# Current time & days to expiry: 2021-10-12 2.0506944444444444
# Curr time & days to EXpiry 2021-10-12 2.0506944444444444
# Processing timestamp: 2021-10-12 14:18:00
# Current time & days to expiry: 2021-10-12 2.05
# Curr time & days to EXpiry 2021-10-12 2.05
# Processing timestamp: 2021-10-12 14:19:00
# Current time & days to expiry: 2021-10-12 2.0493055555555557
# Curr time & days to EXpiry 2021-10-12 2.0493055555555557
# Processing timestamp: 2021-10-12 14:20:00
# Current time & days to expiry: 2021-10-12 2.048611111111111
# Curr time & days to EXpiry 2021-10-12 2.048611111111111
# Processing timestamp: 2021-10-12 14:21:00
# Current time & days to expiry: 2021-10-12 2.0479166666666666
# Curr time & days to EXpiry 2021-10-12 2.0479166666666666
# Processing timestamp: 2021-10-12 14:22:00
# Current time & days to expiry: 2021-10-12 2.047222222222222
# Curr time & days to EXpiry 2021-10-12 2.047222222222222
# Processing timestamp: 2021-10-12 14:23:00
# Current time & days to expiry: 2021-10-12 2.046527777777778
# Curr time & days to EXpiry 2021-10-12 2.046527777777778
# Processing timestamp: 2021-10-12 14:24:00
# Current time & days to expiry: 2021-10-12 2.0458333333333334
# Curr time & days to EXpiry 2021-10-12 2.0458333333333334
# Processing timestamp: 2021-10-12 14:25:00
# Current time & days to expiry: 2021-10-12 2.045138888888889
# Curr time & days to EXpiry 2021-10-12 2.045138888888889
# Processing timestamp: 2021-10-12 14:26:00
# Current time & days to expiry: 2021-10-12 2.0444444444444443
# Curr time & days to EXpiry 2021-10-12 2.0444444444444443
# Processing timestamp: 2021-10-12 14:27:00
# Current time & days to expiry: 2021-10-12 2.04375
# Curr time & days to EXpiry 2021-10-12 2.04375
# Processing timestamp: 2021-10-12 14:28:00
# Current time & days to expiry: 2021-10-12 2.0430555555555556
# Curr time & days to EXpiry 2021-10-12 2.0430555555555556
# Processing timestamp: 2021-10-12 14:29:00
# Current time & days to expiry: 2021-10-12 2.042361111111111
# Curr time & days to EXpiry 2021-10-12 2.042361111111111
# Processing timestamp: 2021-10-12 14:30:00
# Current time & days to expiry: 2021-10-12 2.0416666666666665
# Curr time & days to EXpiry 2021-10-12 2.0416666666666665
# Processing timestamp: 2021-10-12 14:31:00
# Current time & days to expiry: 2021-10-12 2.0409722222222224
# Curr time & days to EXpiry 2021-10-12 2.0409722222222224
# Processing timestamp: 2021-10-12 14:32:00
# Current time & days to expiry: 2021-10-12 2.040277777777778
# Curr time & days to EXpiry 2021-10-12 2.040277777777778
# Processing timestamp: 2021-10-12 14:33:00
# Current time & days to expiry: 2021-10-12 2.0395833333333333
# Curr time & days to EXpiry 2021-10-12 2.0395833333333333
# Processing timestamp: 2021-10-12 14:34:00
# Current time & days to expiry: 2021-10-12 2.0388888888888888
# Curr time & days to EXpiry 2021-10-12 2.0388888888888888
# Processing timestamp: 2021-10-12 14:35:00
# Current time & days to expiry: 2021-10-12 2.0381944444444446
# Curr time & days to EXpiry 2021-10-12 2.0381944444444446
# Processing timestamp: 2021-10-12 14:36:00
# Current time & days to expiry: 2021-10-12 2.0375
# Curr time & days to EXpiry 2021-10-12 2.0375
# Processing timestamp: 2021-10-12 14:37:00
# Current time & days to expiry: 2021-10-12 2.0368055555555555
# Curr time & days to EXpiry 2021-10-12 2.0368055555555555
# Processing timestamp: 2021-10-12 14:38:00
# Current time & days to expiry: 2021-10-12 2.036111111111111
# Curr time & days to EXpiry 2021-10-12 2.036111111111111
# Processing timestamp: 2021-10-12 14:39:00
# Current time & days to expiry: 2021-10-12 2.035416666666667
# Curr time & days to EXpiry 2021-10-12 2.035416666666667
# Processing timestamp: 2021-10-12 14:40:00
# Current time & days to expiry: 2021-10-12 2.0347222222222223
# Curr time & days to EXpiry 2021-10-12 2.0347222222222223
# Processing timestamp: 2021-10-12 14:41:00
# Current time & days to expiry: 2021-10-12 2.0340277777777778
# Curr time & days to EXpiry 2021-10-12 2.0340277777777778
# Processing timestamp: 2021-10-12 14:42:00
# Current time & days to expiry: 2021-10-12 2.033333333333333
# Curr time & days to EXpiry 2021-10-12 2.033333333333333
# Processing timestamp: 2021-10-12 14:43:00
# Current time & days to expiry: 2021-10-12 2.032638888888889
# Curr time & days to EXpiry 2021-10-12 2.032638888888889
# Processing timestamp: 2021-10-12 14:44:00
# Current time & days to expiry: 2021-10-12 2.0319444444444446
# Curr time & days to EXpiry 2021-10-12 2.0319444444444446
# Processing timestamp: 2021-10-12 14:45:00
# Current time & days to expiry: 2021-10-12 2.03125
# Curr time & days to EXpiry 2021-10-12 2.03125
# Processing timestamp: 2021-10-12 14:46:00
# Current time & days to expiry: 2021-10-12 2.0305555555555554
# Curr time & days to EXpiry 2021-10-12 2.0305555555555554
# Processing timestamp: 2021-10-12 14:47:00
# Current time & days to expiry: 2021-10-12 2.029861111111111
# Curr time & days to EXpiry 2021-10-12 2.029861111111111
# Processing timestamp: 2021-10-12 14:48:00
# Current time & days to expiry: 2021-10-12 2.029166666666667
# Curr time & days to EXpiry 2021-10-12 2.029166666666667
# Processing timestamp: 2021-10-12 14:49:00
# Current time & days to expiry: 2021-10-12 2.0284722222222222
# Curr time & days to EXpiry 2021-10-12 2.0284722222222222
# Processing timestamp: 2021-10-12 14:50:00
# Current time & days to expiry: 2021-10-12 2.0277777777777777
# Curr time & days to EXpiry 2021-10-12 2.0277777777777777
# Processing timestamp: 2021-10-12 14:51:00
# Current time & days to expiry: 2021-10-12 2.027083333333333
# Curr time & days to EXpiry 2021-10-12 2.027083333333333
# Processing timestamp: 2021-10-12 14:52:00
# Current time & days to expiry: 2021-10-12 2.026388888888889
# Curr time & days to EXpiry 2021-10-12 2.026388888888889
# Processing timestamp: 2021-10-12 14:53:00
# Current time & days to expiry: 2021-10-12 2.0256944444444445
# Curr time & days to EXpiry 2021-10-12 2.0256944444444445
# Processing timestamp: 2021-10-12 14:54:00
# Current time & days to expiry: 2021-10-12 2.025
# Curr time & days to EXpiry 2021-10-12 2.025
# Processing timestamp: 2021-10-12 14:55:00
# Current time & days to expiry: 2021-10-12 2.0243055555555554
# Curr time & days to EXpiry 2021-10-12 2.0243055555555554
# Processing timestamp: 2021-10-12 14:56:00
# Current time & days to expiry: 2021-10-12 2.0236111111111112
# Curr time & days to EXpiry 2021-10-12 2.0236111111111112
# Processing timestamp: 2021-10-12 14:57:00
# Current time & days to expiry: 2021-10-12 2.0229166666666667
# Curr time & days to EXpiry 2021-10-12 2.0229166666666667
# Processing timestamp: 2021-10-12 14:58:00
# Current time & days to expiry: 2021-10-12 2.022222222222222
# Curr time & days to EXpiry 2021-10-12 2.022222222222222
# Processing timestamp: 2021-10-12 14:59:00
# Current time & days to expiry: 2021-10-12 2.0215277777777776
# Curr time & days to EXpiry 2021-10-12 2.0215277777777776
# Processing timestamp: 2021-10-12 15:00:00
# Current time & days to expiry: 2021-10-12 2.0208333333333335
# Curr time & days to EXpiry 2021-10-12 2.0208333333333335
# Processing timestamp: 2021-10-12 15:01:00
# Current time & days to expiry: 2021-10-12 2.020138888888889
# Curr time & days to EXpiry 2021-10-12 2.020138888888889
# Processing timestamp: 2021-10-12 15:02:00
# Current time & days to expiry: 2021-10-12 2.0194444444444444
# Curr time & days to EXpiry 2021-10-12 2.0194444444444444
# Processing timestamp: 2021-10-12 15:03:00
# Current time & days to expiry: 2021-10-12 2.01875
# Curr time & days to EXpiry 2021-10-12 2.01875
# Processing timestamp: 2021-10-12 15:04:00
# Current time & days to expiry: 2021-10-12 2.0180555555555557
# Curr time & days to EXpiry 2021-10-12 2.0180555555555557
# Processing timestamp: 2021-10-12 15:05:00
# Current time & days to expiry: 2021-10-12 2.017361111111111
# Curr time & days to EXpiry 2021-10-12 2.017361111111111
# Processing timestamp: 2021-10-12 15:06:00
# Current time & days to expiry: 2021-10-12 2.0166666666666666
# Curr time & days to EXpiry 2021-10-12 2.0166666666666666
# Processing timestamp: 2021-10-12 15:07:00
# Current time & days to expiry: 2021-10-12 2.015972222222222
# Curr time & days to EXpiry 2021-10-12 2.015972222222222
# Processing timestamp: 2021-10-12 15:08:00
# Current time & days to expiry: 2021-10-12 2.015277777777778
# Curr time & days to EXpiry 2021-10-12 2.015277777777778
# Processing timestamp: 2021-10-12 15:09:00
# Current time & days to expiry: 2021-10-12 2.0145833333333334
# Curr time & days to EXpiry 2021-10-12 2.0145833333333334
# Processing timestamp: 2021-10-12 15:10:00
# Current time & days to expiry: 2021-10-12 2.013888888888889
# Curr time & days to EXpiry 2021-10-12 2.013888888888889
# Processing timestamp: 2021-10-12 15:11:00
# Current time & days to expiry: 2021-10-12 2.0131944444444443
# Curr time & days to EXpiry 2021-10-12 2.0131944444444443
# Processing timestamp: 2021-10-12 15:12:00
# Current time & days to expiry: 2021-10-12 2.0125
# Curr time & days to EXpiry 2021-10-12 2.0125
# Processing timestamp: 2021-10-12 15:13:00
# Current time & days to expiry: 2021-10-12 2.0118055555555556
# Curr time & days to EXpiry 2021-10-12 2.0118055555555556
# Processing timestamp: 2021-10-12 15:14:00
# Current time & days to expiry: 2021-10-12 2.011111111111111
# Curr time & days to EXpiry 2021-10-12 2.011111111111111
# Processing timestamp: 2021-10-12 15:15:00
# Current time & days to expiry: 2021-10-12 2.0104166666666665
# Curr time & days to EXpiry 2021-10-12 2.0104166666666665
# Processing timestamp: 2021-10-12 15:16:00
# Current time & days to expiry: 2021-10-12 2.0097222222222224
# Curr time & days to EXpiry 2021-10-12 2.0097222222222224
# Processing timestamp: 2021-10-12 15:17:00
# Current time & days to expiry: 2021-10-12 2.009027777777778
# Curr time & days to EXpiry 2021-10-12 2.009027777777778
# Processing timestamp: 2021-10-12 15:18:00
# Current time & days to expiry: 2021-10-12 2.0083333333333333
# Curr time & days to EXpiry 2021-10-12 2.0083333333333333
# Processing timestamp: 2021-10-12 15:19:00
# Current time & days to expiry: 2021-10-12 2.0076388888888888
# Curr time & days to EXpiry 2021-10-12 2.0076388888888888
# Processing timestamp: 2021-10-12 15:20:00
# Current time & days to expiry: 2021-10-12 2.0069444444444446
# Curr time & days to EXpiry 2021-10-12 2.0069444444444446
# Processing timestamp: 2021-10-12 15:21:00
# Current time & days to expiry: 2021-10-12 2.00625
# Curr time & days to EXpiry 2021-10-12 2.00625
# Processing timestamp: 2021-10-12 15:22:00
# Current time & days to expiry: 2021-10-12 2.0055555555555555
# Curr time & days to EXpiry 2021-10-12 2.0055555555555555
# Processing timestamp: 2021-10-12 15:23:00
# Current time & days to expiry: 2021-10-12 2.004861111111111
# Curr time & days to EXpiry 2021-10-12 2.004861111111111
# Processing timestamp: 2021-10-12 15:24:00
# Current time & days to expiry: 2021-10-12 2.004166666666667
# Curr time & days to EXpiry 2021-10-12 2.004166666666667
# Processing timestamp: 2021-10-12 15:25:00
# Current time & days to expiry: 2021-10-12 2.0034722222222223
# Curr time & days to EXpiry 2021-10-12 2.0034722222222223
# Processing timestamp: 2021-10-12 15:26:00
# Current time & days to expiry: 2021-10-12 2.0027777777777778
# Curr time & days to EXpiry 2021-10-12 2.0027777777777778
# Processing timestamp: 2021-10-12 15:27:00
# Current time & days to expiry: 2021-10-12 2.002083333333333
# Curr time & days to EXpiry 2021-10-12 2.002083333333333
# Processing timestamp: 2021-10-12 15:28:00
# Current time & days to expiry: 2021-10-12 2.001388888888889
# Curr time & days to EXpiry 2021-10-12 2.001388888888889
# Processing timestamp: 2021-10-12 15:29:00
# Current time & days to expiry: 2021-10-12 2.0006944444444446
# Curr time & days to EXpiry 2021-10-12 2.0006944444444446
# Processing timestamp: 2021-10-13 09:15:00
# Current time & days to expiry: 2021-10-13 1.2604166666666667
# Curr time & days to EXpiry 2021-10-13 1.2604166666666667
# Processing timestamp: 2021-10-13 09:16:00
# Current time & days to expiry: 2021-10-13 1.2597222222222222
# Curr time & days to EXpiry 2021-10-13 1.2597222222222222
# Processing timestamp: 2021-10-13 09:17:00
# Current time & days to expiry: 2021-10-13 1.2590277777777779
# Curr time & days to EXpiry 2021-10-13 1.2590277777777779
# Processing timestamp: 2021-10-13 09:18:00
# Current time & days to expiry: 2021-10-13 1.2583333333333333
# Curr time & days to EXpiry 2021-10-13 1.2583333333333333
# Processing timestamp: 2021-10-13 09:19:00
# Current time & days to expiry: 2021-10-13 1.257638888888889
# Curr time & days to EXpiry 2021-10-13 1.257638888888889
# Processing timestamp: 2021-10-13 09:20:00
# Current time & days to expiry: 2021-10-13 1.2569444444444444
# Curr time & days to EXpiry 2021-10-13 1.2569444444444444
# Processing timestamp: 2021-10-13 09:21:00
# Current time & days to expiry: 2021-10-13 1.25625
# Curr time & days to EXpiry 2021-10-13 1.25625
# Processing timestamp: 2021-10-13 09:22:00
# Current time & days to expiry: 2021-10-13 1.2555555555555555
# Curr time & days to EXpiry 2021-10-13 1.2555555555555555
# Processing timestamp: 2021-10-13 09:23:00
# Current time & days to expiry: 2021-10-13 1.2548611111111112
# Curr time & days to EXpiry 2021-10-13 1.2548611111111112
# Processing timestamp: 2021-10-13 09:24:00
# Current time & days to expiry: 2021-10-13 1.2541666666666667
# Curr time & days to EXpiry 2021-10-13 1.2541666666666667
# Processing timestamp: 2021-10-13 09:25:00
# Current time & days to expiry: 2021-10-13 1.2534722222222223
# Curr time & days to EXpiry 2021-10-13 1.2534722222222223
# Processing timestamp: 2021-10-13 09:26:00
# Current time & days to expiry: 2021-10-13 1.2527777777777778
# Curr time & days to EXpiry 2021-10-13 1.2527777777777778
# Processing timestamp: 2021-10-13 09:27:00
# Current time & days to expiry: 2021-10-13 1.2520833333333334
# Curr time & days to EXpiry 2021-10-13 1.2520833333333334
# Processing timestamp: 2021-10-13 09:28:00
# Current time & days to expiry: 2021-10-13 1.2513888888888889
# Curr time & days to EXpiry 2021-10-13 1.2513888888888889
# Processing timestamp: 2021-10-13 09:29:00
# Current time & days to expiry: 2021-10-13 1.2506944444444446
# Curr time & days to EXpiry 2021-10-13 1.2506944444444446
# Processing timestamp: 2021-10-13 09:30:00
# Current time & days to expiry: 2021-10-13 1.25
# Curr time & days to EXpiry 2021-10-13 1.25
# Processing timestamp: 2021-10-13 09:31:00
# Current time & days to expiry: 2021-10-13 1.2493055555555554
# Curr time & days to EXpiry 2021-10-13 1.2493055555555554
# Processing timestamp: 2021-10-13 09:32:00
# Current time & days to expiry: 2021-10-13 1.2486111111111111
# Curr time & days to EXpiry 2021-10-13 1.2486111111111111
# Processing timestamp: 2021-10-13 09:33:00
# Current time & days to expiry: 2021-10-13 1.2479166666666666
# Curr time & days to EXpiry 2021-10-13 1.2479166666666666
# Processing timestamp: 2021-10-13 09:34:00
# Current time & days to expiry: 2021-10-13 1.2472222222222222
# Curr time & days to EXpiry 2021-10-13 1.2472222222222222
# Processing timestamp: 2021-10-13 09:35:00
# Current time & days to expiry: 2021-10-13 1.2465277777777777
# Curr time & days to EXpiry 2021-10-13 1.2465277777777777
# Processing timestamp: 2021-10-13 09:36:00
# Current time & days to expiry: 2021-10-13 1.2458333333333333
# Curr time & days to EXpiry 2021-10-13 1.2458333333333333
# Processing timestamp: 2021-10-13 09:37:00
# Current time & days to expiry: 2021-10-13 1.2451388888888888
# Curr time & days to EXpiry 2021-10-13 1.2451388888888888
# Processing timestamp: 2021-10-13 09:38:00
# Current time & days to expiry: 2021-10-13 1.2444444444444445
# Curr time & days to EXpiry 2021-10-13 1.2444444444444445
# Processing timestamp: 2021-10-13 09:39:00
# Current time & days to expiry: 2021-10-13 1.24375
# Curr time & days to EXpiry 2021-10-13 1.24375
# Processing timestamp: 2021-10-13 09:40:00
# Current time & days to expiry: 2021-10-13 1.2430555555555556
# Curr time & days to EXpiry 2021-10-13 1.2430555555555556
# Processing timestamp: 2021-10-13 09:41:00
# Current time & days to expiry: 2021-10-13 1.242361111111111
# Curr time & days to EXpiry 2021-10-13 1.242361111111111
# Processing timestamp: 2021-10-13 09:42:00
# Current time & days to expiry: 2021-10-13 1.2416666666666667
# Curr time & days to EXpiry 2021-10-13 1.2416666666666667
# Processing timestamp: 2021-10-13 09:43:00
# Current time & days to expiry: 2021-10-13 1.2409722222222221
# Curr time & days to EXpiry 2021-10-13 1.2409722222222221
# Processing timestamp: 2021-10-13 09:44:00
# Current time & days to expiry: 2021-10-13 1.2402777777777778
# Curr time & days to EXpiry 2021-10-13 1.2402777777777778
# ...
# OI 28299050.0 26870150.0
# OI 28299050.0 26870150.0
# OI 28299050.0 26870150.0
# OI 28280150.0 26894400.0
# OI 28280150.0 26894800.0
# OI 28280150.0 26894800.0
# OI 27989450.0 26965950.0
# OI 27989450.0 26966750.0
# OI 27989450.0 26966750.0
# OI 28095350.0 27226050.0
# OI 28095350.0 27226050.0
# OI 28095350.0 27226050.0
# OI 28144900.0 27269800.0
# OI 28144900.0 27269800.0
# OI 28144900.0 27269800.0
# OI 28187700.0 27339100.0
# OI 28187700.0 27339100.0
# OI 28187700.0 27339100.0
# OI 28281050.0 27472300.0
# OI 28281050.0 27472300.0
# OI 28281050.0 27472300.0
# OI 28342250.0 27646050.0
# OI 28342250.0 27646050.0
# OI 28342250.0 27646050.0
# OI 27923250.0 27904550.0
# OI 27923250.0 27904550.0
# OI 27923250.0 27904550.0
# OI 27605300.0 28176800.0
# OI 27605300.0 28176800.0
# OI 27605300.0 28176800.0
# OI 27497350.0 28427250.0
# OI 27497350.0 28427250.0
# OI 27497350.0 28427250.0
# OI 27502150.0 28640050.0
# OI 27502150.0 28640050.0
# OI 27502150.0 28640050.0
# OI 27586250.0 28735850.0
# OI 27586250.0 28735850.0
# OI 27586250.0 28735850.0
# OI 27691800.0 28718500.0
# OI 27691800.0 28718500.0
# OI 27691800.0 28718500.0
# OI 27657300.0 28850750.0
# OI 27657300.0 28850750.0
# OI 27657300.0 28850750.0
# OI 27718600.0 28787150.0
# OI 27718600.0 28787150.0
# OI 27718600.0 28787150.0
# OI 27655600.0 28821800.0
# OI 27642850.0 23569600.0
# OI 27642850.0 23569600.0
# OI 27160250.0 23383450.0
# OI 27160250.0 23383450.0
# OI 27160250.0 23383450.0
# OI 27214200.0 23523950.0
# OI 27214200.0 23525350.0
# OI 27214200.0 23525350.0
# OI 26789000.0 23655700.0
# OI 26789000.0 23655800.0
# OI 26789000.0 23655800.0
# OI 26632000.0 23698150.0
# OI 26632000.0 23698150.0
# OI 26632000.0 23698150.0
# OI 26729050.0 23826050.0
# OI 26729050.0 23826050.0
# OI 26729050.0 23826150.0
# OI 26445500.0 24051500.0
# OI 26445500.0 24051400.0
# OI 26445500.0 24051400.0
# OI 26279000.0 24248150.0
# OI 26279000.0 24248150.0
# OI 26279000.0 24248150.0
# OI 26214800.0 24018450.0
# OI 26214800.0 24018400.0
# OI 26214800.0 24018400.0
# OI 26183500.0 24023200.0
# OI 26027550.0 29152000.0
# OI 26027550.0 29152000.0
# OI 26008900.0 29112350.0
# OI 26008900.0 29112350.0
# OI 26008900.0 29112350.0
# OI 25945150.0 28975600.0
# OI 25945150.0 28975600.0
# OI 25945150.0 28975600.0
# OI 25966100.0 23406150.0
# OI 25966100.0 23406150.0
# OI 25966100.0 23406150.0
# OI 25981050.0 23247350.0
# OI 25981050.0 23247350.0
# OI 25981050.0 23247350.0
# OI 25771650.0 23162600.0
# OI 25771650.0 23162600.0
# OI 25771650.0 23162350.0
# OI 25779100.0 23197900.0
# OI 25779100.0 23197900.0
# OI 25779100.0 23197900.0
# OI 25806050.0 23068950.0
# OI 25806050.0 23068950.0
# OI 25806050.0 23069150.0
# OI 25635900.0 23041550.0
# OI 25635900.0 23041700.0
# OI 25635900.0 23041700.0
# OI 25799850.0 23135250.0
# OI 25799850.0 23135800.0
# OI 25799850.0 23135800.0
# OI 25902800.0 23300700.0
# OI 25902800.0 23300700.0
# OI 25902800.0 23300700.0
# OI 26011950.0 23480150.0
# OI 26011950.0 23480150.0
# OI 26011950.0 23480150.0
# OI 26121000.0 23482250.0
# OI 26121000.0 23481900.0
# OI 26121000.0 23481900.0
# OI 26094100.0 23398900.0
# OI 26094100.0 23398900.0
# OI 26094100.0 23398900.0
# OI 26161650.0 23377100.0
# OI 25728100.0 28046450.0
# OI 25728100.0 28046450.0
# OI 26159700.0 23292700.0
# OI 26159700.0 23292000.0
# OI 26159700.0 23291900.0
# OI 26276500.0 23229400.0
# OI 26276500.0 23230150.0
# OI 26276500.0 23230150.0
# OI 26372050.0 23056450.0
# OI 26372050.0 23055650.0
# OI 26372050.0 23055650.0
# OI 26014000.0 27119100.0
# OI 26014000.0 27119100.0
# OI 26014000.0 27119100.0
# OI 26025100.0 26720050.0
# OI 26025100.0 26720050.0
# OI 26025100.0 26720050.0
# OI 25847300.0 26471900.0
# OI 25847300.0 26471900.0
# OI 25847300.0 26471900.0
# OI 25515050.0 26147350.0
# OI 25515050.0 26147350.0
# OI 25515050.0 26147350.0
# OI 25284450.0 25544500.0
# OI 25284450.0 25544500.0
# OI 25284450.0 25544500.0
# OI 25373000.0 24735150.0
# OI 25264700.0 24689900.0
# OI 25264700.0 24689900.0
# OI 25523550.0 24409850.0
# OI 25454100.0 24329550.0
# OI 25454100.0 24329550.0
# OI 25555500.0 23924200.0
# OI 25478450.0 23800000.0
# OI 25478450.0 23800000.0
# OI 25321500.0 23509750.0
# OI 25242650.0 23245050.0
# OI 25242650.0 23245050.0
# OI 25178900.0 22728850.0
# OI 25085400.0 22403600.0
# OI 25085400.0 22403600.0
# OI 29037600.0 15815550.0
# OI 28199500.0 10801200.0
# OI 29287100.0 12828300.0
# OI 29287100.0 12828500.0
# OI 29287100.0 12828500.0
# OI 30653900.0 15351750.0
# OI 30653900.0 15351750.0
# OI 30653900.0 15351750.0
# OI 31261350.0 17192950.0
# OI 31261350.0 17193400.0
# OI 31774150.0 22187450.0
# OI 32696900.0 23301100.0
# OI 32696900.0 23301100.0
# OI 32207900.0 18251800.0
# OI 33359100.0 19016800.0
# OI 33359100.0 19017100.0
# OI 33359100.0 19017100.0
# OI 34615450.0 24767950.0
# OI 34615450.0 24767950.0
# OI 34615450.0 24767950.0
# OI 34861000.0 19511350.0
# OI 34861000.0 19513850.0
# OI 34861000.0 19513850.0
# OI 35281700.0 25020050.0
# OI 35281700.0 25020050.0
# OI 35281700.0 25020050.0
# OI 36030000.0 25205350.0
# OI 36030000.0 25205350.0
# OI 36030000.0 25205350.0
# OI 36759050.0 25367550.0
# OI 36759050.0 25367550.0
# OI 36402850.0 20062400.0
# OI 37261050.0 25765650.0
# OI 37261050.0 25765650.0
# OI 36923900.0 20427300.0
# OI 37384150.0 20805550.0
# OI 37384150.0 20805550.0
# OI 37721550.0 26161850.0
# OI 38064800.0 26289650.0
# OI 38064800.0 26289650.0
# OI 37726950.0 20901100.0
# OI 37867250.0 21003400.0
# OI 37867250.0 21003400.0
# OI 37867250.0 21003400.0
# OI 37800700.0 21360100.0
# OI 37800700.0 21360100.0
# OI 37800700.0 21360100.0
# OI 37629200.0 21608200.0
# OI 37629200.0 21608200.0
# OI 37629200.0 21608000.0
# OI 37588850.0 21976000.0
# OI 37588850.0 21975900.0
# OI 37588850.0 21975900.0
# OI 37817700.0 22432500.0
# OI 37817700.0 22432650.0
# OI 37817700.0 22432650.0
# OI 37836000.0 22671400.0
# OI 38106800.0 28083850.0
# OI 37830500.0 22671400.0
# OI 38099550.0 22857500.0
# OI 38358550.0 28256200.0
# OI 38358550.0 28256200.0
# OI 38715850.0 28390050.0
# OI 38715850.0 28390050.0
# OI 38715850.0 28390050.0
# OI 38688550.0 23036550.0
# OI 38688550.0 23036550.0
# OI 38688550.0 23036150.0
# OI 38715100.0 23219600.0
# OI 38715100.0 23219600.0
# OI 38715100.0 23219600.0
# OI 38856950.0 23346800.0
# OI 38856950.0 23346800.0
# OI 38856950.0 23346950.0
# OI 39020200.0 23492550.0
# OI 39020200.0 23492550.0
# OI 39020200.0 23492550.0
# OI 39080300.0 23415900.0
# OI 39080300.0 23415900.0
# OI 39080300.0 23415850.0
# OI 39529600.0 28847400.0
# OI 39529600.0 28847400.0
# OI 39529600.0 28847400.0
# OI 39366250.0 23782900.0
# OI 39583950.0 29070800.0
# OI 39366250.0 23782450.0
# OI 39652100.0 24086700.0
# OI 39652100.0 24086700.0
# OI 39652100.0 24086700.0
# OI 39641200.0 24287700.0
# OI 39641200.0 24287450.0
# OI 39641200.0 24287450.0
# OI 39687450.0 24637700.0
# OI 39687450.0 24637700.0
# OI 39687450.0 24637700.0
# OI 39813800.0 24743850.0
# OI 39813800.0 24744150.0
# OI 39813800.0 24744150.0
# OI 39650400.0 24814450.0
# OI 39650400.0 24815350.0
# OI 39650400.0 24815350.0
# OI 39131150.0 24964200.0
# OI 39131150.0 24964750.0
# OI 39131150.0 24964750.0
# OI 38824800.0 25052200.0
# OI 38824800.0 25052450.0
# OI 38824800.0 25052450.0
# OI 37942900.0 25292300.0
# OI 37942900.0 25292300.0
# OI 37942900.0 25292300.0
# OI 37073300.0 25422400.0
# OI 37073300.0 25422200.0
# OI 37073300.0 25422200.0
# OI 37212550.0 25689800.0
# OI 37212550.0 25689750.0
# OI 37212550.0 25689750.0
# OI 37359750.0 26044000.0
# OI 37359750.0 26044000.0
# OI 37359750.0 26044400.0
# OI 37437100.0 26319550.0
# OI 37443500.0 26319550.0
# OI 37443500.0 26319550.0
# OI 37159700.0 26617850.0
# OI 37134850.0 26531250.0
# OI 37134850.0 26531250.0
# OI 36952550.0 26721000.0
# OI 36952550.0 26638000.0
# OI 36952550.0 26638000.0
# OI 35833250.0 26828000.0
# OI 35815000.0 26776950.0
# OI 35815000.0 26776950.0
# OI 35941650.0 27226200.0
# OI 35931350.0 27246350.0
# OI 35931350.0 27246350.0
# OI 36078200.0 27568300.0
# OI 36071200.0 27625450.0
# OI 36071200.0 27625450.0
# OI 36110900.0 27825300.0
# OI 36087250.0 27931250.0
# OI 36087250.0 27931250.0
# OI 36171700.0 28028650.0
# OI 36155050.0 28048600.0
# OI 36155050.0 28048600.0
# OI 36213100.0 28060450.0
# OI 36206450.0 28069500.0
# OI 36206450.0 28070050.0
# OI 36353750.0 28060100.0
# OI 36342500.0 28141450.0
# OI 36342500.0 28141450.0
# OI 36307050.0 28094550.0
# OI 36294100.0 28088150.0
# OI 36294100.0 28088150.0
# OI 36262450.0 28189500.0
# OI 36260500.0 28072700.0
# OI 36260500.0 28072700.0
# OI 36276800.0 28042350.0
# OI 36176600.0 28212400.0
# OI 36176600.0 28212400.0
# OI 36176600.0 28212400.0
# OI 36076300.0 28521850.0
# OI 36076300.0 28521850.0
# OI 36076300.0 28521850.0
# OI 36112200.0 28642700.0
# OI 36112200.0 28642700.0
# OI 36112200.0 28642700.0
# OI 36297350.0 28642450.0
# OI 36297350.0 28642450.0
# OI 36297350.0 28642450.0
# OI 36424800.0 28672200.0
# OI 36424800.0 28672200.0
# OI 36424800.0 28672200.0
# OI 36720700.0 28655750.0
# OI 36720700.0 28655750.0
# OI 36720700.0 28655750.0
# OI 36882850.0 28732400.0
# OI 36882850.0 28732400.0
# OI 36882850.0 28732400.0
# OI 36988300.0 28761000.0
# OI 36988300.0 28761000.0
# OI 36988300.0 28761000.0
# OI 37007600.0 28766100.0
# OI 37007600.0 28766100.0
# OI 37007600.0 28766100.0
# OI 37269150.0 28718650.0
# OI 37269150.0 28718650.0
# OI 37269150.0 28718650.0
# OI 37120400.0 28545800.0
# OI 37120400.0 28545800.0
# OI 37120400.0 28545800.0
# OI 37288600.0 28708100.0
# OI 37288600.0 28708100.0
# OI 37288600.0 28708100.0
# OI 37436300.0 28713050.0
# OI 37436300.0 28713050.0
# OI 37436300.0 28713050.0
# OI 37550000.0 28727950.0
# OI 37550000.0 28728250.0
# OI 37550000.0 28728250.0
# OI 37475500.0 28541650.0
# OI 37475500.0 28541800.0
# OI 37475500.0 28541800.0
# OI 37728100.0 28405850.0
# OI 37728100.0 28405850.0
# OI 37728100.0 28405850.0
# OI 37888150.0 28411000.0
# OI 37888150.0 28411000.0
# OI 37888150.0 28411200.0
# OI 37799150.0 28358550.0
# OI 37799150.0 28358500.0
# OI 37799150.0 28358500.0
# OI 37755150.0 28346000.0
# OI 37755150.0 28346000.0
# OI 37755150.0 28346000.0
# OI 37728650.0 28316150.0
# OI 37728650.0 28316150.0
# OI 37728650.0 28316150.0
# OI 38266400.0 28201950.0
# OI 38266400.0 28201950.0
# OI 38266400.0 28201950.0
# OI 38486550.0 28022950.0
# OI 38486550.0 28022950.0
# OI 38486550.0 28022950.0
# OI 38796500.0 28192500.0
# OI 38796500.0 28192500.0
# OI 38796500.0 28192500.0
# OI 38862450.0 28126850.0
# OI 38862450.0 28126850.0
# OI 38862450.0 28126850.0
# OI 38664400.0 31761300.0
# OI 38614550.0 27295900.0
# OI 38664400.0 31761300.0
# OI 38676300.0 31335600.0
# OI 38676300.0 31335600.0
# OI 38676300.0 31335600.0
# OI 38754750.0 27072900.0
# OI 38754750.0 27072900.0
# OI 38820750.0 31545300.0
# OI 39221550.0 27429300.0
# OI 39221550.0 27429300.0
# OI 39221550.0 27429300.0
# OI 38765950.0 27371950.0
# OI 38765950.0 27371950.0
# OI 38765950.0 27371950.0
# OI 38572300.0 27399350.0
# OI 38572300.0 27399350.0
# OI 38572300.0 27399350.0
# OI 38569950.0 27574100.0
# OI 38569950.0 27574450.0
# OI 38569950.0 27574450.0
# OI 38723450.0 31871150.0
# OI 38723450.0 31871150.0
# OI 38723450.0 31871150.0
# OI 38630000.0 31699700.0
# OI 38630000.0 31699700.0
# OI 38630000.0 31699700.0
# OI 38772100.0 31169650.0
# OI 38772100.0 31169650.0
# OI 38772100.0 31169650.0
# OI 38813400.0 30428850.0
# OI 38813400.0 30428850.0
# OI 38813400.0 30428850.0
# OI 39060350.0 30299650.0
# OI 39060350.0 30299650.0
# OI 39007800.0 25971800.0
# OI 37675200.0 25924350.0
# OI 37675200.0 25924350.0
# OI 37675200.0 25924350.0
# OI 37006500.0 26040400.0
# OI 37006500.0 26042400.0
# OI 37006500.0 26042400.0
# OI 35000350.0 25712700.0
# OI 35000350.0 25712700.0
# OI 35000350.0 25712700.0
# OI 34799850.0 25715050.0
# OI 34799850.0 25715050.0
# OI 34799850.0 25715050.0
# OI 34441700.0 25439550.0
# OI 34441700.0 25440000.0
# OI 34441700.0 25440000.0
# OI 34353900.0 25425300.0
# OI 34353900.0 25425250.0
# OI 34353900.0 25425250.0
# OI 34323250.0 25363550.0
# OI 34299200.0 25363500.0
# OI 34299200.0 25363500.0
# OI 34229800.0 24969450.0
# OI 34229800.0 24969450.0
# OI 34229800.0 24969450.0
# OI 33393700.0 24697800.0
# OI 33393700.0 24698500.0
# OI 33393700.0 24698500.0
# OI 32823800.0 24434050.0
# OI 32823800.0 24434350.0
# OI 32823800.0 24434350.0
# OI 32807800.0 24403400.0
# OI 32811300.0 24403400.0
# OI 32811300.0 24403400.0
# OI 32798800.0 24384050.0
# OI 32798800.0 24384050.0
# OI 32798800.0 24384050.0
# OI 32912100.0 24600300.0
# OI 32912100.0 24600300.0
# OI 32912100.0 24600300.0
# OI 32732900.0 24494750.0
# OI 32732900.0 24494750.0
# OI 32732900.0 24494750.0
# OI 32876400.0 24375050.0
# OI 32876400.0 24375050.0
# OI 32876400.0 24375050.0
# OI 32262500.0 24281800.0
# OI 32262500.0 24281800.0
# OI 32262500.0 24281800.0
# OI 32123000.0 24114900.0
# OI 32123000.0 24114900.0
# OI 32123000.0 24114900.0
# OI 31910300.0 23333500.0
# OI 31910300.0 23333500.0
# OI 31910300.0 23333500.0
# OI 31770400.0 22376800.0
# OI 31770400.0 22376800.0
# OI 31770400.0 22376800.0
# OI 31532150.0 22279600.0
# OI 31532150.0 22275900.0
# OI 31532150.0 22275900.0
# OI 31608300.0 21857950.0
# OI 31608300.0 21862250.0
# OI 31608300.0 21862250.0
# OI 31640250.0 21468800.0
# OI 31640250.0 21468800.0
# OI 31640250.0 21468800.0
# OI 31336650.0 21438850.0
# OI 31331300.0 21438750.0
# OI 31331300.0 21438750.0
# OI 30648500.0 21071300.0
# OI 30648500.0 21065500.0
# OI 30648500.0 21065500.0
# OI 30386600.0 21033650.0
# OI 30386600.0 21033650.0
# OI 30386600.0 21033650.0
# OI 31812500.0 20183800.0
# OI 31812500.0 20183800.0
# OI 31812500.0 20183800.0
# OI 31042450.0 20200800.0
# OI 31020450.0 20200800.0
# OI 31020450.0 20200800.0
# OI 30782950.0 20504100.0
# OI 30774500.0 20504100.0
# OI 30774500.0 20504100.0
# OI 30193400.0 20025950.0
# OI 30193400.0 20025950.0
# OI 30193400.0 20025950.0
# OI 29123450.0 19103250.0
# OI 29123450.0 19103250.0
# OI 29123450.0 19103250.0
# OI 28699200.0 17983450.0
# OI 28699200.0 17981700.0
# OI 28699200.0 17981700.0
# OI 28409150.0 16888500.0
# OI 28392750.0 16890400.0
# OI 28392750.0 16890400.0
# OI 27798550.0 15858100.0
# OI 27773950.0 15857750.0
# OI 27773950.0 15857750.0
# OI 27003350.0 15392750.0
# OI 26988050.0 15334750.0
# OI 26988050.0 15334750.0
# OI 25727000.0 14887400.0
# OI 25673000.0 14839800.0
# OI 25673000.0 14839800.0
# OI 23003050.0 14336400.0
# OI 22917850.0 14266300.0
# OI 22917850.0 14266300.0
# OI 21842450.0 13261700.0
# OI 21811600.0 13137300.0
# OI 21811600.0 13137300.0
# OI 21811600.0 13137300.0
#                     Ticker     Open     High      Low    Close  Volume  \
# Date/Time
# 2021-10-08 09:15:00  NIFTY  17886.8  17892.5  17869.6  17885.3       0
# 2021-10-08 09:16:00  NIFTY  17886.1  17891.5  17873.5  17873.5       0
# 2021-10-08 09:17:00  NIFTY  17873.7  17881.2  17868.4  17871.2       0
# 2021-10-08 09:18:00  NIFTY  17872.0  17879.3  17871.8  17873.4       0
# 2021-10-08 09:19:00  NIFTY  17873.9  17878.7  17865.1  17865.1       0
#
#                      Open Interest  INDIAVIX  ATM_Delta     ATM_OI  ...  \
# Date/Time                                                           ...
# 2021-10-08 09:15:00              0     16.01   0.528682  1401900.0  ...
# 2021-10-08 09:16:00              0     16.19   0.538884   721100.0  ...
# 2021-10-08 09:17:00              0     16.26   0.538875   752050.0  ...
# 2021-10-08 09:18:00              0     16.21   0.539312   752050.0  ...
# 2021-10-08 09:19:00              0     16.26   0.537532   752050.0  ...
#
#                      OTM4_PE_Gamma  OTM4_PE_Theta  OTM4_PE_Vega  OTM4_PE_Rho  \
# Date/Time
# 2021-10-08 09:15:00       0.000063      -0.541544      0.092485    -0.018074
# 2021-10-08 09:16:00       0.000070      -0.488620      0.092599    -0.017774
# 2021-10-08 09:17:00       0.000071      -0.482579      0.092615    -0.017758
# 2021-10-08 09:18:00       0.000071      -0.482742      0.092616    -0.017751
# 2021-10-08 09:19:00       0.000069      -0.493107      0.092537    -0.017801
#
#                      OTM5_PE_Delta  OTM5_PE_OI  OTM5_PE_Gamma  OTM5_PE_Theta  \
# Date/Time
# 2021-10-08 09:15:00      -0.429417      2550.0       0.000052      -0.646681
# 2021-10-08 09:16:00      -0.440592     77800.0       0.000060      -0.560354
# 2021-10-08 09:17:00      -0.440003     77600.0       0.000060      -0.565032
# 2021-10-08 09:18:00      -0.441999     77600.0       0.000062      -0.551514
# 2021-10-08 09:19:00      -0.440685     77600.0       0.000060      -0.563028
#
#                      OTM5_PE_Vega  OTM5_PE_Rho
# Date/Time
# 2021-10-08 09:15:00      0.091980    -0.018564
# 2021-10-08 09:16:00      0.092342    -0.018157
# 2021-10-08 09:17:00      0.092304    -0.018175
# 2021-10-08 09:18:00      0.092380    -0.018124
# 2021-10-08 09:19:00      0.092287    -0.018175
#
# [5 rows x 163 columns]
# Greeks and Open Interest data have been populated and the DataFrame has been saved to CSV.

# %%
print(nifty_with_greeks.head())
# Out:
#                     Ticker     Open     High      Low    Close  Volume  \
# Date/Time
# 2021-10-08 09:15:00  NIFTY  17886.8  17892.5  17869.6  17885.3       0
# 2021-10-08 09:16:00  NIFTY  17886.1  17891.5  17873.5  17873.5       0
# 2021-10-08 09:17:00  NIFTY  17873.7  17881.2  17868.4  17871.2       0
# 2021-10-08 09:18:00  NIFTY  17872.0  17879.3  17871.8  17873.4       0
# 2021-10-08 09:19:00  NIFTY  17873.9  17878.7  17865.1  17865.1       0
#
#                      Open Interest  INDIAVIX  ATM_Delta     ATM_OI  ...  \
# Date/Time                                                           ...
# 2021-10-08 09:15:00              0     16.01   0.528682  1401900.0  ...
# 2021-10-08 09:16:00              0     16.19   0.538884   721100.0  ...
# 2021-10-08 09:17:00              0     16.26   0.538875   752050.0  ...
# 2021-10-08 09:18:00              0     16.21   0.539312   752050.0  ...
# 2021-10-08 09:19:00              0     16.26   0.537532   752050.0  ...
#
#                      OTM4_PE_Theta  OTM4_PE_Vega  OTM4_PE_Rho  OTM5_PE_Delta  \
# Date/Time
# 2021-10-08 09:15:00      -0.541544      0.092485    -0.018074      -0.429417
# 2021-10-08 09:16:00      -0.488620      0.092599    -0.017774      -0.440592
# 2021-10-08 09:17:00      -0.482579      0.092615    -0.017758      -0.440003
# 2021-10-08 09:18:00      -0.482742      0.092616    -0.017751      -0.441999
# 2021-10-08 09:19:00      -0.493107      0.092537    -0.017801      -0.440685
#
#                      OTM5_PE_OI  OTM5_PE_Gamma  OTM5_PE_Theta  OTM5_PE_Vega  \
# Date/Time
# 2021-10-08 09:15:00      2550.0       0.000052      -0.646681      0.091980
# 2021-10-08 09:16:00     77800.0       0.000060      -0.560354      0.092342
# 2021-10-08 09:17:00     77600.0       0.000060      -0.565032      0.092304
# 2021-10-08 09:18:00     77600.0       0.000062      -0.551514      0.092380
# 2021-10-08 09:19:00     77600.0       0.000060      -0.563028      0.092287
#
#                      OTM5_PE_Rho  PCR_Volume
# Date/Time
# 2021-10-08 09:15:00    -0.018564    0.422998
# 2021-10-08 09:16:00    -0.018157    0.715245
# 2021-10-08 09:17:00    -0.018175    0.819466
# 2021-10-08 09:18:00    -0.018124    0.827158
# 2021-10-08 09:19:00    -0.018175    0.883308
#
# [5 rows x 164 columns]

# %%
print("PCR_Volume" in nifty_with_greeks.columns)
# Out:
# True

# %%
pd.set_option('display.max_columns', None)
print(nifty_with_greeks.columns.tolist())
# Out:
# ['Ticker', 'Open', 'High', 'Low', 'Close', 'Volume', 'Open Interest', 'INDIAVIX', 'ATM_Delta', 'ATM_OI', 'ATM_Call_Volume', 'ATM_Put_Volume', 'ATM_Gamma', 'ATM_Theta', 'ATM_Vega', 'ATM_Rho', 'ITM1_Delta', 'ITM1_OI', 'ITM1_Call_Volume', 'ITM1_Put_Volume', 'ITM1_Gamma', 'ITM1_Theta', 'ITM1_Vega', 'ITM1_Rho', 'OTM1_Delta', 'OTM1_OI', 'OTM1_Call_Volume', 'OTM1_Put_Volume', 'OTM1_Gamma', 'OTM1_Theta', 'OTM1_Vega', 'OTM1_Rho', 'ITM2_Delta', 'ITM2_OI', 'ITM2_Call_Volume', 'ITM2_Put_Volume', 'ITM2_Gamma', 'ITM2_Theta', 'ITM2_Vega', 'ITM2_Rho', 'OTM2_Delta', 'OTM2_OI', 'OTM2_Call_Volume', 'OTM2_Put_Volume', 'OTM2_Gamma', 'OTM2_Theta', 'OTM2_Vega', 'OTM2_Rho', 'ITM3_Delta', 'ITM3_OI', 'ITM3_Call_Volume', 'ITM3_Put_Volume', 'ITM3_Gamma', 'ITM3_Theta', 'ITM3_Vega', 'ITM3_Rho', 'OTM3_Delta', 'OTM3_OI', 'OTM3_Call_Volume', 'OTM3_Put_Volume', 'OTM3_Gamma', 'OTM3_Theta', 'OTM3_Vega', 'OTM3_Rho', 'ITM4_Delta', 'ITM4_OI', 'ITM4_Call_Volume', 'ITM4_Put_Volume', 'ITM4_Gamma', 'ITM4_Theta', 'ITM4_Vega', 'ITM4_Rho', 'OTM4_Delta', 'OTM4_OI', 'OTM4_Call_Volume', 'OTM4_Put_Volume', 'OTM4_Gamma', 'OTM4_Theta', 'OTM4_Vega', 'OTM4_Rho', 'ITM5_Delta', 'ITM5_OI', 'ITM5_Call_Volume', 'ITM5_Put_Volume', 'ITM5_Gamma', 'ITM5_Theta', 'ITM5_Vega', 'ITM5_Rho', 'OTM5_Delta', 'OTM5_OI', 'OTM5_Call_Volume', 'OTM5_Put_Volume', 'OTM5_Gamma', 'OTM5_Theta', 'OTM5_Vega', 'OTM5_Rho', 'PCR', 'ATM_PE_Delta', 'ATM_PE_OI', 'ATM_PE_Gamma', 'ATM_PE_Theta', 'ATM_PE_Vega', 'ATM_PE_Rho', 'ITM1_PE_Delta', 'ITM1_PE_OI', 'ITM1_PE_Gamma', 'ITM1_PE_Theta', 'ITM1_PE_Vega', 'ITM1_PE_Rho', 'ITM2_PE_Delta', 'ITM2_PE_OI', 'ITM2_PE_Gamma', 'ITM2_PE_Theta', 'ITM2_PE_Vega', 'ITM2_PE_Rho', 'ITM3_PE_Delta', 'ITM3_PE_OI', 'ITM3_PE_Gamma', 'ITM3_PE_Theta', 'ITM3_PE_Vega', 'ITM3_PE_Rho', 'ITM4_PE_Delta', 'ITM4_PE_OI', 'ITM4_PE_Gamma', 'ITM4_PE_Theta', 'ITM4_PE_Vega', 'ITM4_PE_Rho', 'ITM5_PE_Delta', 'ITM5_PE_OI', 'ITM5_PE_Gamma', 'ITM5_PE_Theta', 'ITM5_PE_Vega', 'ITM5_PE_Rho', 'OTM1_PE_Delta', 'OTM1_PE_OI', 'OTM1_PE_Gamma', 'OTM1_PE_Theta', 'OTM1_PE_Vega', 'OTM1_PE_Rho', 'OTM2_PE_Delta', 'OTM2_PE_OI', 'OTM2_PE_Gamma', 'OTM2_PE_Theta', 'OTM2_PE_Vega', 'OTM2_PE_Rho', 'OTM3_PE_Delta', 'OTM3_PE_OI', 'OTM3_PE_Gamma', 'OTM3_PE_Theta', 'OTM3_PE_Vega', 'OTM3_PE_Rho', 'OTM4_PE_Delta', 'OTM4_PE_OI', 'OTM4_PE_Gamma', 'OTM4_PE_Theta', 'OTM4_PE_Vega', 'OTM4_PE_Rho', 'OTM5_PE_Delta', 'OTM5_PE_OI', 'OTM5_PE_Gamma', 'OTM5_PE_Theta', 'OTM5_PE_Vega', 'OTM5_PE_Rho', 'PCR_Volume']

# %%
print(nifty_with_greeks['PCR_Volume'])
# Out:
# Date/Time
# 2021-10-08 09:15:00    0.422998
# 2021-10-08 09:16:00    0.715245
# 2021-10-08 09:17:00    0.819466
# 2021-10-08 09:18:00    0.827158
# 2021-10-08 09:19:00    0.883308
#                          ...
# 2021-10-14 15:26:00    0.502434
# 2021-10-14 15:27:00    0.885119
# 2021-10-14 15:28:00    0.927285
# 2021-10-14 15:29:00    1.106076
# 2021-10-14 15:30:00    1.106076
# Name: PCR_Volume, Length: 1878, dtype: float64
